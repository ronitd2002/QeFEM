# %%
import os
import math
import time
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn.functional as F

try:
    from tqdm import tqdm
except ModuleNotFoundError:
    tqdm = lambda x, **kwargs: x

# %%
# !pwd
# Out:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/v2

# %%
K2000_HIST_BEST = 33337

# %%
DATA_MAXCUT_DIR = Path("./../../data-maxcut")
RESULTS_DIR = Path(".")
OUT_DIR = RESULTS_DIR / "full_res"
OUT_DIR.mkdir(parents=True, exist_ok=True)

GSET_HIST_PATH = RESULTS_DIR / "gset_validation.txt"
GSET_VANILLA_PATH = RESULTS_DIR / "naive_vanilla_fem_G1-G54_full_results.csv"
GSET_QEFEM_V1_PATH = RESULTS_DIR / "qefem_v1_benchmark_table.csv"
K2000_RESULTS_PATH = RESULTS_DIR / "K2000_adam_anneal_vs_baselines_comparison.csv"

DEVICE = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
DTYPE = torch.float32

# %%
def build_gset_history_df(hist_path=GSET_HIST_PATH, out_dir=OUT_DIR):
    rows = []

    with open(hist_path, "r") as f:
        for line in f:
            if not line.strip():
                continue

            g_idx, best_cut = line.split()[:2]
            g_idx = int(g_idx)

            if 1 <= g_idx <= 54:
                rows.append({
                    "instance": f"G{g_idx}",
                    "best_known_cut": float(best_cut),
                })

    df = pd.DataFrame(rows)
    df.to_csv(out_dir / "gset_history_best_G1-G54.csv", index=False)
    return df

def build_gset_vanilla_best_df(vanilla_path=GSET_VANILLA_PATH, out_dir=OUT_DIR):
    df_raw = pd.read_csv(vanilla_path)

    df = df_raw.loc[:, ["instance", "vanilla_fem_best_cut", "gap"]].copy()
    df = df.rename(columns={
        "instance": "graph_name",
        "vanilla_fem_best_cut": "cut_value",
    })

    df.to_csv(out_dir / "gset_vanilla_best_G1-G54.csv", index=False)
    return df

def build_gset_qefem_v1_best_df(qefem_v1_path=GSET_QEFEM_V1_PATH, out_dir=OUT_DIR):
    df_raw = pd.read_csv(qefem_v1_path)

    df = df_raw.copy()
    df["g_idx"] = df["instance"].str.replace("G", "", regex=False).astype(int)
    df = df[(df["g_idx"] >= 1) & (df["g_idx"] <= 54)]

    df = df.loc[:, ["instance", "v1_best", "v1_gap"]].copy()
    df = df.rename(columns={
        "instance": "graph_name",
        "v1_best": "cut_value",
        "v1_gap": "gap",
    })

    df.to_csv(out_dir / "gset_qefem_v1_best_G1-G54.csv", index=False)
    return df

def build_k2000_vanilla_best_df(k2000_path=K2000_RESULTS_PATH, out_dir=OUT_DIR):
    df_raw = pd.read_csv(k2000_path)

    df = df_raw[df_raw["method"].str.startswith("vanilla")].copy()
    df = df.loc[:, ["method", "cut", "gap"]]
    df = df.rename(columns={
        "method": "graph_name",
        "cut": "cut_value",
    })

    df.to_csv(out_dir / "k2000_vanilla_best.csv", index=False)
    return df

def build_k2000_qefem_v1_best_df(k2000_path=K2000_RESULTS_PATH, out_dir=OUT_DIR):
    df_raw = pd.read_csv(k2000_path)

    df = df_raw[df_raw["method"].str.startswith("QEFEM")].copy()
    df = df.loc[:, ["method", "cut", "gap"]]
    df = df.rename(columns={
        "method": "graph_name",
        "cut": "cut_value",
    })

    df.to_csv(out_dir / "k2000_qefem_v1_best.csv", index=False)
    return df

def build_all_reference_dfs():
    gset_history_df = build_gset_history_df()
    gset_vanilla_df = build_gset_vanilla_best_df()
    gset_qefem_v1_df = build_gset_qefem_v1_best_df()
    k2000_vanilla_df = build_k2000_vanilla_best_df()
    k2000_qefem_v1_df = build_k2000_qefem_v1_best_df()

    return {
        "gset_history": gset_history_df,
        "gset_vanilla": gset_vanilla_df,
        "gset_qefem_v1": gset_qefem_v1_df,
        "k2000_vanilla": k2000_vanilla_df,
        "k2000_qefem_v1": k2000_qefem_v1_df,
    }

# %%
def build_gset_history_df(hist_path=GSET_HIST_PATH, out_dir=OUT_DIR):
    rows = []

    with open(hist_path, "r") as f:
        for line in f:
            if not line.strip():
                continue

            g_idx, best_cut = line.split()[:2]
            g_idx = int(g_idx)

            if 1 <= g_idx <= 54:
                rows.append({
                    "instance": f"G{g_idx}",
                    "best_known_cut": float(best_cut),
                })

    df = pd.DataFrame(rows)
    df.to_csv(out_dir / "gset_history_best_G1-G54.csv", index=False)
    return df

def build_gset_vanilla_best_df(vanilla_path=GSET_VANILLA_PATH, out_dir=OUT_DIR):
    df_raw = pd.read_csv(vanilla_path)

    df = df_raw.loc[:, ["instance", "vanilla_fem_best_cut", "gap"]].copy()
    df = df.rename(columns={
        "instance": "graph_name",
        "vanilla_fem_best_cut": "cut_value",
    })

    df.to_csv(out_dir / "gset_vanilla_best_G1-G54.csv", index=False)
    return df

def build_gset_qefem_v1_best_df(qefem_v1_path=GSET_QEFEM_V1_PATH, out_dir=OUT_DIR):
    df_raw = pd.read_csv(qefem_v1_path)

    df = df_raw.copy()
    df["g_idx"] = df["instance"].str.replace("G", "", regex=False).astype(int)
    df = df[(df["g_idx"] >= 1) & (df["g_idx"] <= 54)]

    df = df.loc[:, ["instance", "v1_best", "v1_gap"]].copy()
    df = df.rename(columns={
        "instance": "graph_name",
        "v1_best": "cut_value",
        "v1_gap": "gap",
    })

    df.to_csv(out_dir / "gset_qefem_v1_best_G1-G54.csv", index=False)
    return df

def build_k2000_vanilla_best_df(k2000_path=K2000_RESULTS_PATH, out_dir=OUT_DIR):
    df_raw = pd.read_csv(k2000_path)

    df = df_raw[df_raw["method"].str.startswith("vanilla")].copy()
    df = df.loc[:, ["method", "cut", "gap"]]
    df = df.rename(columns={
        "method": "graph_name",
        "cut": "cut_value",
    })

    df.to_csv(out_dir / "k2000_vanilla_best.csv", index=False)
    return df

def build_k2000_qefem_v1_best_df(k2000_path=K2000_RESULTS_PATH, out_dir=OUT_DIR):
    df_raw = pd.read_csv(k2000_path)

    df = df_raw[df_raw["method"].str.startswith("QEFEM")].copy()
    df = df.loc[:, ["method", "cut", "gap"]]
    df = df.rename(columns={
        "method": "graph_name",
        "cut": "cut_value",
    })

    df.to_csv(out_dir / "k2000_qefem_v1_best.csv", index=False)
    return df

def build_all_reference_dfs():
    gset_history_df = build_gset_history_df()
    gset_vanilla_df = build_gset_vanilla_best_df()
    gset_qefem_v1_df = build_gset_qefem_v1_best_df()
    k2000_vanilla_df = build_k2000_vanilla_best_df()
    k2000_qefem_v1_df = build_k2000_qefem_v1_best_df()

    return {
        "gset_history": gset_history_df,
        "gset_vanilla": gset_vanilla_df,
        "gset_qefem_v1": gset_qefem_v1_df,
        "k2000_vanilla": k2000_vanilla_df,
        "k2000_qefem_v1": k2000_qefem_v1_df,
    }

reference_dfs = build_all_reference_dfs()

# %%
def load_gset_dense(g_idx, data_dir=DATA_MAXCUT_DIR, device=DEVICE, dtype=DTYPE):
    if not (1 <= int(g_idx) <= 54):
        raise ValueError("g_idx must be between 1 and 54.")

    path = data_dir / f"G{int(g_idx)}"

    with open(path, "r") as f:
        n, m = map(int, f.readline().split())

        W_cpu = torch.zeros((n, n), dtype=dtype, device="cpu")

        for _ in range(m):
            i, j, w = f.readline().split()
            i = int(i) - 1
            j = int(j) - 1
            w = float(w)

            W_cpu[i, j] = w
            W_cpu[j, i] = w

    return W_cpu.to(device=device)

def load_k2000_dense(data_dir=DATA_MAXCUT_DIR, device=DEVICE, dtype=DTYPE):
    path = data_dir / "k2000"

    with open(path, "r") as f:
        n, m = map(int, f.readline().split())

        W_cpu = torch.zeros((n, n), dtype=dtype, device="cpu")

        for _ in range(m):
            i, j, w = f.readline().split()
            i = int(i) - 1
            j = int(j) - 1
            w = float(w)

            W_cpu[i, j] = w
            W_cpu[j, i] = w

    return W_cpu.to(device=device)

# %%
EPS = 1e-8
GRAD_CLIP_DEFAULT = 1.0
BLOCH_LENGTH_INIT = 1e-2
FIELD_NOISE = 1e-3
THETA_INIT = math.pi / 2
THETA_NOISE = 1e-3

# %%
def print_gset_hparam_help():
    print(
        """
get_gset_local_hparams input sequence:

Required:
    g_idx

Common tunables:
    n_batch
    n_rep
    n_steps
    optimizer
    lr
    grad_type
    grad_clip
    T_max
    T_min
    beta_schedule
    gamma_max
    gamma_min
    gamma_schedule

Adam tunables:
    adam_betas
    adam_weight_decay

RMSprop tunables:
    rmsprop_alpha
    rmsprop_momentum
    rmsprop_weight_decay

Example:
    hp = get_gset_local_hparams(
        4,
        n_batch=10000,
        n_rep=1,
        n_steps=1000,
        optimizer="adam",
        lr=1e-2,
        grad_type="explicit",
        T_max=0.5,
        T_min=8e-5,
        beta_schedule="exponential_beta",
        gamma_max=1.0,
        gamma_min=1e-3,
        gamma_schedule="exponential",
    )
"""
    )


def get_gset_local_hparams(
    g_idx,
    *,
    n_batch=10000,
    n_rep=1,
    n_steps=1000,

    optimizer="adam",
    lr=1e-2,

    adam_betas=(0.9, 0.999),
    adam_weight_decay=0.0,

    rmsprop_alpha=0.99,
    rmsprop_momentum=0.0,
    rmsprop_weight_decay=0.0,

    grad_type="auto",
    grad_clip=GRAD_CLIP_DEFAULT,

    T_max=0.5,
    T_min=8e-5,
    beta_schedule="exponential_beta",

    gamma_max=1.0,
    gamma_min=1e-3,
    gamma_schedule="exponential",

    show_help=False,
):
    if show_help:
        print_gset_hparam_help()

    if not isinstance(g_idx, int):
        print("ERROR: g_idx must be an integer.")
        print_gset_hparam_help()
        raise TypeError("g_idx must be an integer.")

    if g_idx < 1 or g_idx > 54:
        print("ERROR: g_idx must be between 1 and 54.")
        print_gset_hparam_help()
        raise ValueError("g_idx must be between 1 and 54.")

    optimizer = optimizer.lower()
    grad_type = grad_type.lower()
    beta_schedule = beta_schedule.lower()
    gamma_schedule = gamma_schedule.lower()

    if optimizer not in ["adam", "rmsprop"]:
        print("ERROR: optimizer must be either 'adam' or 'rmsprop'.")
        print_gset_hparam_help()
        raise ValueError("Invalid optimizer.")

    if grad_type not in ["auto", "explicit"]:
        print("ERROR: grad_type must be either 'auto' or 'explicit'.")
        print_gset_hparam_help()
        raise ValueError("Invalid grad_type.")

    if beta_schedule not in ["linear_temperature", "linear_beta", "exponential_beta"]:
        print("ERROR: beta_schedule must be one of:")
        print("    'linear_temperature', 'linear_beta', 'exponential_beta'")
        print_gset_hparam_help()
        raise ValueError("Invalid beta_schedule.")

    if gamma_schedule not in ["linear", "exponential", "constant"]:
        print("ERROR: gamma_schedule must be one of:")
        print("    'linear', 'exponential', 'constant'")
        print_gset_hparam_help()
        raise ValueError("Invalid gamma_schedule.")

    if n_batch <= 0:
        print("ERROR: n_batch must be positive.")
        print_gset_hparam_help()
        raise ValueError("Invalid n_batch.")

    if n_rep <= 0:
        print("ERROR: n_rep must be positive.")
        print_gset_hparam_help()
        raise ValueError("Invalid n_rep.")

    if n_steps <= 0:
        print("ERROR: n_steps must be positive.")
        print_gset_hparam_help()
        raise ValueError("Invalid n_steps.")

    if lr <= 0:
        print("ERROR: lr must be positive.")
        print_gset_hparam_help()
        raise ValueError("Invalid lr.")

    if T_max <= 0 or T_min <= 0:
        print("ERROR: T_max and T_min must both be positive.")
        print_gset_hparam_help()
        raise ValueError("Invalid temperature range.")

    if gamma_max < 0 or gamma_min < 0:
        print("ERROR: gamma_max and gamma_min must be non-negative.")
        print_gset_hparam_help()
        raise ValueError("Invalid gamma range.")

    return {
        "graph_name": f"G{g_idx}",

        "n_batch": int(n_batch),
        "n_rep": int(n_rep),
        "n_steps": int(n_steps),

        "optimizer": optimizer,
        "lr": float(lr),

        "adam_betas": adam_betas,
        "adam_weight_decay": float(adam_weight_decay),

        "rmsprop_alpha": float(rmsprop_alpha),
        "rmsprop_momentum": float(rmsprop_momentum),
        "rmsprop_weight_decay": float(rmsprop_weight_decay),

        "grad_type": grad_type,
        "gradient_mode": grad_type,
        "grad_clip": grad_clip,

        "T_max": float(T_max),
        "T_min": float(T_min),
        "beta_schedule": beta_schedule,

        "gamma_max": float(gamma_max),
        "gamma_min": float(gamma_min),
        "gamma_schedule": gamma_schedule,
    }

# %%
def print_k2000_hparam_help():
    print(
        """
get_k2000_local_hparams input sequence:

Common tunables:
    n_batch
    n_rep
    n_steps
    optimizer
    lr
    grad_type
    grad_clip
    T_max
    T_min
    beta_schedule
    gamma_max
    gamma_min
    gamma_schedule

Adam tunables:
    adam_betas
    adam_weight_decay

RMSprop tunables:
    rmsprop_alpha
    rmsprop_momentum
    rmsprop_weight_decay

Example:
    hp = get_k2000_local_hparams(
        n_batch=10000,
        n_rep=1,
        n_steps=1000,
        optimizer="rmsprop",
        lr=3e-2,
        rmsprop_alpha=0.56,
        rmsprop_momentum=0.63,
        rmsprop_weight_decay=0.013,
        grad_type="explicit",
        T_max=1.16,
        T_min=6e-5,
        beta_schedule="linear_temperature",
        gamma_max=1.0,
        gamma_min=1e-3,
        gamma_schedule="exponential",
    )
"""
    )


def get_k2000_local_hparams(
    *,
    n_batch=10000,
    n_rep=1,
    n_steps=1000,

    optimizer="adam",
    lr=None,

    adam_betas=(0.9, 0.999),
    adam_weight_decay=0.0,

    rmsprop_alpha=0.56,
    rmsprop_momentum=0.63,
    rmsprop_weight_decay=0.013,

    grad_type="auto",
    grad_clip=GRAD_CLIP_DEFAULT,

    T_max=1.16,
    T_min=6e-5,
    beta_schedule="linear_temperature",

    gamma_max=1.0,
    gamma_min=1e-3,
    gamma_schedule="exponential",

    show_help=False,
):
    if show_help:
        print_k2000_hparam_help()

    optimizer = optimizer.lower()
    grad_type = grad_type.lower()
    beta_schedule = beta_schedule.lower()
    gamma_schedule = gamma_schedule.lower()

    if optimizer not in ["adam", "rmsprop"]:
        print("ERROR: optimizer must be either 'adam' or 'rmsprop'.")
        print_k2000_hparam_help()
        raise ValueError("Invalid optimizer.")

    if lr is None:
        if optimizer == "adam":
            lr = 1e-2
        elif optimizer == "rmsprop":
            lr = 3e-2

    if grad_type not in ["auto", "explicit"]:
        print("ERROR: grad_type must be either 'auto' or 'explicit'.")
        print_k2000_hparam_help()
        raise ValueError("Invalid grad_type.")

    if beta_schedule not in ["linear_temperature", "linear_beta", "exponential_beta"]:
        print("ERROR: beta_schedule must be one of:")
        print("    'linear_temperature', 'linear_beta', 'exponential_beta'")
        print_k2000_hparam_help()
        raise ValueError("Invalid beta_schedule.")

    if gamma_schedule not in ["linear", "exponential", "constant"]:
        print("ERROR: gamma_schedule must be one of:")
        print("    'linear', 'exponential', 'constant'")
        print_k2000_hparam_help()
        raise ValueError("Invalid gamma_schedule.")

    if n_batch <= 0:
        print("ERROR: n_batch must be positive.")
        print_k2000_hparam_help()
        raise ValueError("Invalid n_batch.")

    if n_rep <= 0:
        print("ERROR: n_rep must be positive.")
        print_k2000_hparam_help()
        raise ValueError("Invalid n_rep.")

    if n_steps <= 0:
        print("ERROR: n_steps must be positive.")
        print_k2000_hparam_help()
        raise ValueError("Invalid n_steps.")

    if lr <= 0:
        print("ERROR: lr must be positive.")
        print_k2000_hparam_help()
        raise ValueError("Invalid lr.")

    if T_max <= 0 or T_min <= 0:
        print("ERROR: T_max and T_min must both be positive.")
        print_k2000_hparam_help()
        raise ValueError("Invalid temperature range.")

    if gamma_max < 0 or gamma_min < 0:
        print("ERROR: gamma_max and gamma_min must be non-negative.")
        print_k2000_hparam_help()
        raise ValueError("Invalid gamma range.")

    return {
        "graph_name": f"K2000_{optimizer}",

        "n_batch": int(n_batch),
        "n_rep": int(n_rep),
        "n_steps": int(n_steps),

        "optimizer": optimizer,
        "lr": float(lr),

        "adam_betas": adam_betas,
        "adam_weight_decay": float(adam_weight_decay),

        "rmsprop_alpha": float(rmsprop_alpha),
        "rmsprop_momentum": float(rmsprop_momentum),
        "rmsprop_weight_decay": float(rmsprop_weight_decay),

        "grad_type": grad_type,
        "gradient_mode": grad_type,
        "grad_clip": grad_clip,

        "T_max": float(T_max),
        "T_min": float(T_min),
        "beta_schedule": beta_schedule,

        "gamma_max": float(gamma_max),
        "gamma_min": float(gamma_min),
        "gamma_schedule": gamma_schedule,
    }

# %%
# ============================================================
# REQUIRED CORE QEFEM V2 FUNCTIONS
# Paste this BEFORE the full K2000 + G1-G54 benchmark cell
# ============================================================

import math
import time
import torch
import pandas as pd

# ----------------------------
# Core helpers
# ----------------------------

def logit_from_value(x, device=DEVICE, dtype=DTYPE):
    x = torch.tensor(float(x), device=device, dtype=dtype)
    return torch.logit(x)


def bloch_from_fields(fields, theta):
    R = torch.sigmoid(fields)
    rx = R * torch.sin(theta)
    rz = R * torch.cos(theta)
    return R, rx, rz


def expected_cut(W, rz):
    single_input = False

    if rz.dim() == 1:
        rz = rz.unsqueeze(0)
        single_input = True

    rz = rz.to(device=W.device, dtype=W.dtype)

    quad = torch.einsum("ri,ij,rj->r", rz, W, rz)
    cut = 0.25 * (W.sum() - quad)

    if single_input:
        return cut.squeeze(0)

    return cut


def discrete_cut(W, spins):
    single_input = False

    if spins.dim() == 1:
        spins = spins.unsqueeze(0)
        single_input = True

    spins = spins.to(device=W.device, dtype=W.dtype)

    quad = torch.einsum("ri,ij,rj->r", spins, W, spins)
    cut = 0.25 * (W.sum() - quad)

    if single_input:
        return cut.squeeze(0)

    return cut


def quantum_entropy(R, eps=EPS):
    single_input = False

    if R.dim() == 1:
        R = R.unsqueeze(0)
        single_input = True

    R = R.clamp(eps, 1.0 - eps)

    lam_plus = 0.5 * (1.0 + R)
    lam_minus = 0.5 * (1.0 - R)

    S_site = -(
        lam_plus * torch.log(lam_plus)
        + lam_minus * torch.log(lam_minus)
    )

    S = S_site.sum(dim=1)

    if single_input:
        return S.squeeze(0)

    return S


def transverse_driver_energy(rx, gamma):
    single_input = False

    if rx.dim() == 1:
        rx = rx.unsqueeze(0)
        single_input = True

    gamma = torch.as_tensor(gamma, device=rx.device, dtype=rx.dtype)
    driver = -gamma * rx.sum(dim=1)

    if single_input:
        return driver.squeeze(0)

    return driver


def qefem_free_energy(W, fields, theta, beta, gamma, eps=EPS):
    beta = torch.as_tensor(beta, device=W.device, dtype=W.dtype)
    gamma = torch.as_tensor(gamma, device=W.device, dtype=W.dtype)

    R, rx, rz = bloch_from_fields(fields, theta)

    ecut = expected_cut(W, rz)
    entropy = quantum_entropy(R, eps=eps)
    driver = transverse_driver_energy(rx, gamma)

    internal_energy = -ecut
    F = internal_energy + driver - entropy / beta

    aux = {
        "R": R,
        "rx": rx,
        "rz": rz,
        "expected_cut": ecut,
        "entropy": entropy,
        "driver_energy": driver,
        "internal_energy": internal_energy,
        "free_energy": F,
        "beta": beta,
        "gamma": gamma,
    }

    return F, aux


# ----------------------------
# Schedules
# ----------------------------

def make_beta_schedule(local_hparams, device=DEVICE, dtype=DTYPE):
    n_steps = int(local_hparams["n_steps"])

    T_max = float(local_hparams["T_max"])
    T_min = float(local_hparams["T_min"])

    beta_schedule = local_hparams.get("beta_schedule", "linear_temperature").lower()

    if beta_schedule == "linear_temperature":
        T = torch.linspace(T_max, T_min, n_steps, device=device, dtype=dtype)
        beta = 1.0 / T

    elif beta_schedule == "linear_beta":
        beta_min = 1.0 / T_max
        beta_max = 1.0 / T_min
        beta = torch.linspace(beta_min, beta_max, n_steps, device=device, dtype=dtype)

    elif beta_schedule == "exponential_beta":
        beta_min = 1.0 / T_max
        beta_max = 1.0 / T_min
        beta = torch.exp(
            torch.linspace(
                math.log(beta_min),
                math.log(beta_max),
                n_steps,
                device=device,
                dtype=dtype,
            )
        )

    else:
        raise ValueError("beta_schedule must be linear_temperature, linear_beta, or exponential_beta.")

    return beta


def make_gamma_schedule(local_hparams, device=DEVICE, dtype=DTYPE):
    n_steps = int(local_hparams["n_steps"])

    gamma_max = float(local_hparams["gamma_max"])
    gamma_min = float(local_hparams["gamma_min"])

    gamma_schedule = local_hparams.get("gamma_schedule", "linear").lower()

    if gamma_schedule == "linear":
        gamma = torch.linspace(gamma_max, gamma_min, n_steps, device=device, dtype=dtype)

    elif gamma_schedule == "exponential":
        if gamma_max <= 0 or gamma_min <= 0:
            raise ValueError("exponential gamma requires gamma_max > 0 and gamma_min > 0.")

        gamma = torch.exp(
            torch.linspace(
                math.log(gamma_max),
                math.log(gamma_min),
                n_steps,
                device=device,
                dtype=dtype,
            )
        )

    elif gamma_schedule == "constant":
        gamma = torch.full((n_steps,), gamma_max, device=device, dtype=dtype)

    else:
        raise ValueError("gamma_schedule must be linear, exponential, or constant.")

    return gamma


# ----------------------------
# Optimizer
# ----------------------------

def make_optimizer(params, local_hparams):
    optimizer_name = local_hparams["optimizer"].lower()
    lr = float(local_hparams["lr"])

    if optimizer_name == "adam":
        return torch.optim.Adam(
            params,
            lr=lr,
            betas=local_hparams.get("adam_betas", (0.9, 0.999)),
            weight_decay=float(local_hparams.get("adam_weight_decay", 0.0)),
        )

    if optimizer_name == "rmsprop":
        return torch.optim.RMSprop(
            params,
            lr=lr,
            alpha=float(local_hparams.get("rmsprop_alpha", 0.99)),
            momentum=float(local_hparams.get("rmsprop_momentum", 0.0)),
            weight_decay=float(local_hparams.get("rmsprop_weight_decay", 0.0)),
        )

    raise ValueError("optimizer must be adam or rmsprop.")


def grad_global_norm(params):
    total = torch.zeros((), device=params[0].device)

    for p in params:
        if p.grad is not None:
            total = total + p.grad.detach().pow(2).sum()

    return total.sqrt()


# ----------------------------
# SINGLE INSTANCE RUNNER
# ----------------------------

def run_qefem_single_instance(
    W,
    best_known_cut,
    local_hparams,
    seed=0,
    print_every=50,
    device=DEVICE,
    dtype=DTYPE,
    eps=EPS,
):
    graph_name = local_hparams["graph_name"]
    optimizer_name = local_hparams["optimizer"].lower()
    grad_type = local_hparams.get("grad_type", local_hparams.get("gradient_mode", "auto")).lower()

    if grad_type != "auto":
        raise NotImplementedError("Only grad_type='auto' is implemented in this cell.")

    W = W.to(device=device, dtype=dtype)

    n = W.shape[0]
    n_batch = int(local_hparams["n_batch"])
    n_rep = int(local_hparams["n_rep"])
    n_steps = int(local_hparams["n_steps"])

    beta_values = make_beta_schedule(local_hparams, device=device, dtype=dtype)
    gamma_values = make_gamma_schedule(local_hparams, device=device, dtype=dtype)

    best_cut_so_far = -float("inf")
    best_rep_so_far = None
    best_outer_rep = None
    best_step = None
    best_spins = None

    history = []

    print(f"Starting {graph_name} | historical best = {float(best_known_cut):.0f}")

    t0 = time.time()

    for outer_rep in range(n_rep):
        rep_t0 = time.time()

        torch.manual_seed(seed + outer_rep)

        field_center = logit_from_value(BLOCH_LENGTH_INIT, device=device, dtype=dtype)

        fields = field_center + FIELD_NOISE * torch.randn(
            n_batch, n, device=device, dtype=dtype
        )

        theta = THETA_INIT + THETA_NOISE * torch.randn(
            n_batch, n, device=device, dtype=dtype
        )

        fields.requires_grad_(True)
        theta.requires_grad_(True)

        optimizer = make_optimizer([fields, theta], local_hparams)

        for step in range(n_steps):
            beta = beta_values[step]
            gamma = gamma_values[step]

            optimizer.zero_grad(set_to_none=True)

            F_val, aux = qefem_free_energy(
                W=W,
                fields=fields,
                theta=theta,
                beta=beta,
                gamma=gamma,
                eps=eps,
            )

            loss = F_val.sum()
            loss.backward()

            grad_norm_before = grad_global_norm([fields, theta]).item()

            grad_clip = local_hparams.get("grad_clip", None)
            if grad_clip is not None:
                torch.nn.utils.clip_grad_norm_(
                    [fields, theta],
                    max_norm=float(grad_clip),
                )

            grad_norm_after = grad_global_norm([fields, theta]).item()

            optimizer.step()

            with torch.no_grad():
                R, rx, rz = bloch_from_fields(fields, theta)

                spins = torch.where(
                    rz >= 0,
                    torch.ones_like(rz),
                    -torch.ones_like(rz),
                )

                ecut = expected_cut(W, rz)
                hcut = discrete_cut(W, spins)
                entropy = quantum_entropy(R, eps=eps)

                hard_max = hcut.max()
                hard_argmax = int(torch.argmax(hcut).item())

                if hard_max.item() > best_cut_so_far:
                    best_cut_so_far = float(hard_max.item())
                    best_rep_so_far = hard_argmax
                    best_outer_rep = outer_rep
                    best_step = step
                    best_spins = spins[hard_argmax].detach().cpu().clone()

                rep_elapsed = time.time() - rep_t0
                total_elapsed = time.time() - t0
                global_step = outer_rep * n_steps + step

                gap_now = float(best_known_cut - best_cut_so_far)
                gap_percent_now = 100.0 * gap_now / float(best_known_cut)
                acc_now = 100.0 * best_cut_so_far / float(best_known_cut)

                history.append({
                    "graph_name": graph_name,
                    "optimizer": optimizer_name,
                    "grad_type": grad_type,

                    "outer_rep": outer_rep,
                    "step": step,
                    "global_step": global_step,

                    "beta": float(beta.item()),
                    "gamma": float(gamma.item()),

                    "free_energy_mean": float(F_val.mean().detach().item()),
                    "free_energy_min": float(F_val.min().detach().item()),
                    "free_energy_max": float(F_val.max().detach().item()),

                    "expected_cut_mean": float(ecut.mean().item()),
                    "expected_cut_max": float(ecut.max().item()),
                    "expected_cut_min": float(ecut.min().item()),

                    "hard_cut_mean": float(hcut.mean().item()),
                    "hard_cut_max": float(hcut.max().item()),
                    "hard_cut_min": float(hcut.min().item()),

                    "best_cut_so_far": float(best_cut_so_far),
                    "best_known_cut": float(best_known_cut),
                    "gap_so_far": gap_now,
                    "gap_percent_so_far": gap_percent_now,
                    "accuracy_percent_so_far": acc_now,

                    "best_replica_in_batch": hard_argmax,
                    "best_replica_so_far": best_rep_so_far,
                    "best_outer_rep_so_far": best_outer_rep,
                    "best_step_so_far": best_step,

                    "entropy_mean": float(entropy.mean().item()),
                    "entropy_min": float(entropy.min().item()),
                    "entropy_max": float(entropy.max().item()),

                    "R_mean": float(R.mean().item()),
                    "R_min": float(R.min().item()),
                    "R_max": float(R.max().item()),

                    "rx_abs_mean": float(rx.abs().mean().item()),
                    "rz_abs_mean": float(rz.abs().mean().item()),

                    "grad_norm_before_clip": grad_norm_before,
                    "grad_norm_after_clip": grad_norm_after,

                    "rep_elapsed_sec": float(rep_elapsed),
                    "elapsed_sec": float(total_elapsed),
                })

                if (
                    step == 0
                    or (step + 1) % print_every == 0
                    or step == n_steps - 1
                    or best_cut_so_far >= best_known_cut
                ):
                    print(
                        f"{graph_name} | "
                        f"rep {outer_rep + 1}/{n_rep} | "
                        f"gap {gap_now:.1f} | "
                        f"acc {acc_now:.4f}% | "
                        f"step {step + 1}/{n_steps} | "
                        f"beta {beta.item():.4g} | "
                        f"gamma {gamma.item():.4g} | "
                        f"ecut {ecut.max().item():.1f} | "
                        f"hcut {hcut.max().item():.1f} | "
                        f"best_rep {best_rep_so_far} | "
                        f"S {entropy.mean().item():.4f} | "
                        f"rep_t {rep_elapsed:.1f}s | "
                        f"total_t {total_elapsed:.1f}s"
                    )

                #if best_cut_so_far >= best_known_cut:
                    #break

        del fields, theta, optimizer

        if DEVICE.type == "mps":
            torch.mps.empty_cache()

        #if best_cut_so_far >= best_known_cut:
            #break

    history_df = pd.DataFrame(history)

    elapsed_total = time.time() - t0

    gap = float(best_known_cut - best_cut_so_far)
    gap_percent = 100.0 * gap / float(best_known_cut)
    accuracy = best_cut_so_far / float(best_known_cut)
    accuracy_percent = 100.0 * accuracy

    summary = {
        "graph_name": graph_name,
        "optimizer": optimizer_name,
        "grad_type": grad_type,

        "best_cut": float(best_cut_so_far),
        "best_known_cut": float(best_known_cut),

        "gap": gap,
        "gap_percent": gap_percent,
        "accuracy": accuracy,
        "accuracy_percent": accuracy_percent,
        "success": bool(best_cut_so_far >= best_known_cut),

        "best_outer_rep": best_outer_rep,
        "best_replica": best_rep_so_far,
        "best_step": best_step,

        "n_batch": n_batch,
        "n_rep_requested": n_rep,
        "n_rep_completed": int(history_df["outer_rep"].max() + 1) if len(history_df) else 0,
        "n_steps": n_steps,
        "total_replica_attempts_completed": int((history_df["outer_rep"].max() + 1) * n_batch) if len(history_df) else 0,

        "T_max": float(local_hparams["T_max"]),
        "T_min": float(local_hparams["T_min"]),
        "beta_schedule": local_hparams["beta_schedule"],

        "gamma_max": float(local_hparams["gamma_max"]),
        "gamma_min": float(local_hparams["gamma_min"]),
        "gamma_schedule": local_hparams["gamma_schedule"],

        "lr": float(local_hparams["lr"]),
        "grad_clip": local_hparams.get("grad_clip", None),

        "elapsed_sec": float(elapsed_total),
    }

    return {
        "summary": summary,
        "history": history_df,
        "best_spins": best_spins,
    }

print("run_qefem_single_instance is now defined. Finally. The notebook has been appeased.")
# Out:
# run_qefem_single_instance is now defined. Finally. The notebook has been appeased.

# %%
# ============================================================
# FULL QEFEM V2 BENCHMARK RUN: K2000 FIRST, THEN G1-G54
# Saves:
#   full_res/K2000_qefem_v2_anneal_history.csv
#   full_res/K2000_qefem_v2_summary.csv
#   full_res/G{idx}_qefem_v2_anneal_history.csv
#   full_res/G{idx}_qefem_v2_summary.csv
#   full_res/qefem_v2_full_benchmark_table_partial.csv
#   full_res/qefem_v2_full_benchmark_table.csv
# ============================================================

import time
from pathlib import Path
import pandas as pd
import torch

# ----------------------------
# Robust paths because notebooks are little demons
# ----------------------------

CWD = Path.cwd()

OUT_DIR = CWD / "full_res"
OUT_DIR.mkdir(parents=True, exist_ok=True)

def find_existing_file(candidates):
    for p in candidates:
        p = Path(p)
        if p.exists():
            return p
    raise FileNotFoundError("None of these paths exist:\n" + "\n".join(str(p) for p in candidates))

def find_existing_dir(candidates):
    for p in candidates:
        p = Path(p)
        if p.exists() and p.is_dir():
            return p
    raise FileNotFoundError("None of these directories exist:\n" + "\n".join(str(p) for p in candidates))

DATA_MAXCUT_DIR = find_existing_dir([
    CWD / "../../data-maxcut",
    CWD / "../data-maxcut",
    CWD / "data-maxcut",
])

GSET_HIST_PATH = find_existing_file([
    CWD / "gset_validation.txt",
    CWD / "../gset_validation.txt",
    CWD / "../../gset_validation.txt",
])

K2000_PATH = find_existing_file([
    DATA_MAXCUT_DIR / "WK2000_1.rud",
    DATA_MAXCUT_DIR / "k2000",
    CWD / "WK2000_1.rud",
    CWD / "../WK2000_1.rud",
])

print("CWD:", CWD)
print("OUT_DIR:", OUT_DIR)
print("DATA_MAXCUT_DIR:", DATA_MAXCUT_DIR)
print("GSET_HIST_PATH:", GSET_HIST_PATH)
print("K2000_PATH:", K2000_PATH)
print("DEVICE:", DEVICE)

# ----------------------------
# Robust loaders
# ----------------------------

def load_gset_dense_v2(g_idx, data_dir=DATA_MAXCUT_DIR, device=DEVICE, dtype=DTYPE):
    g_idx = int(g_idx)
    if not (1 <= g_idx <= 54):
        raise ValueError("g_idx must be between 1 and 54.")

    path = Path(data_dir) / f"G{g_idx}"

    with open(path, "r") as f:
        n, m = map(int, f.readline().split())
        W_cpu = torch.zeros((n, n), dtype=dtype, device="cpu")

        for _ in range(m):
            i, j, w = f.readline().split()
            i = int(i) - 1
            j = int(j) - 1
            w = float(w)

            W_cpu[i, j] = w
            W_cpu[j, i] = w

    return W_cpu.to(device=device)

def load_k2000_dense_v2(path=K2000_PATH, device=DEVICE, dtype=DTYPE):
    path = Path(path)

    with open(path, "r") as f:
        n, m = map(int, f.readline().split())
        W_cpu = torch.zeros((n, n), dtype=dtype, device="cpu")

        for _ in range(m):
            i, j, w = f.readline().split()
            i = int(i) - 1
            j = int(j) - 1
            w = float(w)

            W_cpu[i, j] = w
            W_cpu[j, i] = w

    return W_cpu.to(device=device)

# ----------------------------
# History / best-known table
# ----------------------------

def build_gset_history_df_v2(hist_path=GSET_HIST_PATH):
    rows = []

    with open(hist_path, "r") as f:
        for line in f:
            if not line.strip():
                continue

            g_idx, best_cut = line.split()[:2]
            g_idx = int(g_idx)

            if 1 <= g_idx <= 54:
                rows.append({
                    "graph_name": f"G{g_idx}",
                    "best_known_cut": float(best_cut),
                })

    df = pd.DataFrame(rows).sort_values(
        by="graph_name",
        key=lambda x: x.str.replace("G", "", regex=False).astype(int)
    ).reset_index(drop=True)

    df.to_csv(OUT_DIR / "gset_history_best_G1-G54.csv", index=False)
    return df

gset_history_df = build_gset_history_df_v2()

# ----------------------------
# Preferred V2 hyperparams
# ----------------------------

def get_v2_gset_benchmark_hparams(g_idx, n_batch=10000):
    return get_gset_local_hparams(
        int(g_idx),

        n_batch=int(n_batch),
        n_rep=1,
        n_steps=2000,

        optimizer="adam",
        lr=0.01,

        adam_betas=(0.9, 0.999),
        adam_weight_decay=0.0,

        rmsprop_alpha=0.99,
        rmsprop_momentum=0.0,
        rmsprop_weight_decay=0.0,

        grad_type="auto",
        grad_clip=1.0,

        T_max=0.5,
        T_min=8e-5,
        beta_schedule="linear_temperature",

        gamma_max=1.0,
        gamma_min=1e-3,
        gamma_schedule="linear",
    )

def get_v2_k2000_benchmark_hparams(n_batch=10000):
    return get_k2000_local_hparams(
        n_batch=int(n_batch),
        n_rep=1,
        n_steps=2000,

        optimizer="adam",
        lr=0.01,

        adam_betas=(0.9, 0.999),
        adam_weight_decay=0.0,

        rmsprop_alpha=0.99,
        rmsprop_momentum=0.0,
        rmsprop_weight_decay=0.0,

        grad_type="auto",
        grad_clip=1.0,

        T_max=0.5,
        T_min=8e-5,
        beta_schedule="linear_temperature",

        gamma_max=1.0,
        gamma_min=1e-3,
        gamma_schedule="linear",
    )

# ----------------------------
# Summary normalization
# Similar to V1 comparison metrics
# ----------------------------

def normalize_v2_summary(summary, n_nodes):
    best_known = float(summary["best_known_cut"])
    best_cut = float(summary["best_cut"])

    gap_abs = best_known - best_cut
    gap_percent = 100.0 * gap_abs / best_known
    accuracy_percent = 100.0 * best_cut / best_known

    return {
        "graph_name": summary["graph_name"],
        "n_nodes": int(n_nodes),

        "best_known_cut": best_known,
        "qefem_v2_best_cut": best_cut,

        "v2_gap": gap_abs,
        "v2_gap_percent": gap_percent,
        "v2_accuracy_percent": accuracy_percent,
        "success": bool(best_cut >= best_known),

        "optimizer": summary.get("optimizer", None),
        "grad_type": summary.get("grad_type", None),

        "n_batch": summary.get("n_batch", None),
        "n_rep_requested": summary.get("n_rep_requested", None),
        "n_rep_completed": summary.get("n_rep_completed", None),
        "n_steps": summary.get("n_steps", None),

        "lr": summary.get("lr", None),
        "grad_clip": summary.get("grad_clip", None),

        "T_max": summary.get("T_max", None),
        "T_min": summary.get("T_min", None),
        "beta_schedule": summary.get("beta_schedule", None),

        "gamma_max": summary.get("gamma_max", None),
        "gamma_min": summary.get("gamma_min", None),
        "gamma_schedule": summary.get("gamma_schedule", None),

        "best_outer_rep": summary.get("best_outer_rep", None),
        "best_replica": summary.get("best_replica", None),
        "best_step": summary.get("best_step", None),

        "elapsed_sec": summary.get("elapsed_sec", None),
    }

# ----------------------------
# Run one instance and save
# ----------------------------

def run_and_save_one_v2(graph_name, W, best_known_cut, local_hparams, print_every=50):
    print("=" * 110)
    print(f"STARTING {graph_name} | historical best = {best_known_cut:.0f}")
    print("=" * 110)

    result = run_qefem_single_instance(
        W=W,
        best_known_cut=float(best_known_cut),
        local_hparams=local_hparams,
        seed=0,
        print_every=print_every,
    )

    history_df = result["history"].copy()
    summary = result["summary"].copy()

    history_path = OUT_DIR / f"{graph_name}_qefem_v2_anneal_history.csv"
    summary_path = OUT_DIR / f"{graph_name}_qefem_v2_summary.csv"

    history_df.to_csv(history_path, index=False)
    pd.DataFrame([summary]).to_csv(summary_path, index=False)

    row = normalize_v2_summary(summary, n_nodes=W.shape[0])
    row["history_path"] = str(history_path)
    row["summary_path"] = str(summary_path)

    print(f"FINISHED {graph_name}")
    print(
        f"best = {row['qefem_v2_best_cut']:.0f} | "
        f"gap = {row['v2_gap']:.0f} | "
        f"gap% = {row['v2_gap_percent']:.4f}% | "
        f"acc = {row['v2_accuracy_percent']:.4f}% | "
        f"time = {row['elapsed_sec']:.2f}s"
    )
    print()

    return row

# ----------------------------
# FULL RUN: K2000 first, then G1-G54
# ----------------------------

all_rows = []

FULL_RUN_T0 = time.time()

# ---- K2000 first ----

W_K2000 = load_k2000_dense_v2()
k2000_hparams = get_v2_k2000_benchmark_hparams(n_batch=10000)

k2000_row = run_and_save_one_v2(
    graph_name="K2000",
    W=W_K2000,
    best_known_cut=K2000_HIST_BEST,
    local_hparams=k2000_hparams,
    print_every=50,
)

all_rows.append(k2000_row)

benchmark_df = pd.DataFrame(all_rows)
benchmark_df.to_csv(OUT_DIR / "qefem_v2_full_benchmark_table_partial.csv", index=False)

del W_K2000
if DEVICE.type == "mps":
    torch.mps.empty_cache()

# ---- G1-G54 next ----

for g_idx in range(1, 55):
    graph_name = f"G{g_idx}"

    best_known_cut = float(
        gset_history_df.loc[
            gset_history_df["graph_name"] == graph_name,
            "best_known_cut"
        ].iloc[0]
    )

    W = load_gset_dense_v2(g_idx)
    local_hparams = get_v2_gset_benchmark_hparams(g_idx, n_batch=10000)

    row = run_and_save_one_v2(
        graph_name=graph_name,
        W=W,
        best_known_cut=best_known_cut,
        local_hparams=local_hparams,
        print_every=50,
    )

    all_rows.append(row)

    benchmark_df = pd.DataFrame(all_rows)
    benchmark_df.to_csv(OUT_DIR / "qefem_v2_full_benchmark_table_partial.csv", index=False)

    del W
    if DEVICE.type == "mps":
        torch.mps.empty_cache()

# ---- final benchmark table ----

benchmark_df = pd.DataFrame(all_rows)

ordered_cols = [
    "graph_name",
    "n_nodes",
    "best_known_cut",
    "qefem_v2_best_cut",
    "v2_gap",
    "v2_gap_percent",
    "v2_accuracy_percent",
    "success",
    "optimizer",
    "grad_type",
    "n_batch",
    "n_rep_requested",
    "n_rep_completed",
    "n_steps",
    "lr",
    "grad_clip",
    "T_max",
    "T_min",
    "beta_schedule",
    "gamma_max",
    "gamma_min",
    "gamma_schedule",
    "best_outer_rep",
    "best_replica",
    "best_step",
    "elapsed_sec",
    "history_path",
    "summary_path",
]

benchmark_df = benchmark_df[[c for c in ordered_cols if c in benchmark_df.columns]]

benchmark_df.to_csv(OUT_DIR / "qefem_v2_full_benchmark_table.csv", index=False)

print("=" * 110)
print("FULL QEFEM V2 BENCHMARK COMPLETE")
print(f"Total elapsed = {time.time() - FULL_RUN_T0:.2f}s")
print(f"Saved final table to: {OUT_DIR / 'qefem_v2_full_benchmark_table.csv'}")
print(f"Saved partial table to: {OUT_DIR / 'qefem_v2_full_benchmark_table_partial.csv'}")
print("=" * 110)

benchmark_df
# Out:
# CWD: /Users/ronit/Desktop/QeFEM/main/maxcut_results/v2
# OUT_DIR: /Users/ronit/Desktop/QeFEM/main/maxcut_results/v2/full_res
# DATA_MAXCUT_DIR: /Users/ronit/Desktop/QeFEM/main/maxcut_results/v2/../../data-maxcut
# GSET_HIST_PATH: /Users/ronit/Desktop/QeFEM/main/maxcut_results/v2/gset_validation.txt
# K2000_PATH: /Users/ronit/Desktop/QeFEM/main/maxcut_results/v2/../../data-maxcut/k2000
# DEVICE: mps
# ==============================================================================================================
# STARTING K2000 | historical best = 33337
# ==============================================================================================================
# Starting K2000_adam | historical best = 33337
# K2000_adam | rep 1/1 | gap 37234.0 | acc -11.6897% | step 1/2000 | beta 2 | gamma 1 | ecut -520.0 | hcut -3897.0 | best_rep 4499 | S 1386.1924 | rep_t 0.7s | total_t 0.7s
# K2000_adam | rep 1/1 | gap 30448.0 | acc 8.6660% | step 50/2000 | beta 2.05 | gamma 0.9755 | ecut -520.0 | hcut -1735.0 | best_rep 8021 | S 1386.0259 | rep_t 37.0s | total_t 37.0s
# K2000_adam | rep 1/1 | gap 5603.0 | acc 83.1928% | step 100/2000 | beta 2.104 | gamma 0.9505 | ecut -520.0 | hcut 27734.0 | best_rep 2724 | S 1385.5801 | rep_t 83.0s | total_t 83.0s
# K2000_adam | rep 1/1 | gap 1134.0 | acc 96.5984% | step 150/2000 | beta 2.161 | gamma 0.9255 | ecut -487.3 | hcut 32203.0 | best_rep 6827 | S 1384.4323 | rep_t 118.6s | total_t 118.6s
# K2000_adam | rep 1/1 | gap 775.0 | acc 97.6753% | step 200/2000 | beta 2.221 | gamma 0.9005 | ecut -366.8 | hcut 32508.0 | best_rep 7983 | S 1381.7388 | rep_t 156.2s | total_t 156.2s
# K2000_adam | rep 1/1 | gap 775.0 | acc 97.6753% | step 250/2000 | beta 2.285 | gamma 0.8756 | ecut -72.0 | hcut 32346.0 | best_rep 7983 | S 1375.5599 | rep_t 205.8s | total_t 205.8s
# K2000_adam | rep 1/1 | gap 775.0 | acc 97.6753% | step 300/2000 | beta 2.352 | gamma 0.8506 | ecut 589.9 | hcut 32150.0 | best_rep 7983 | S 1361.9587 | rep_t 261.3s | total_t 261.3s
# K2000_adam | rep 1/1 | gap 775.0 | acc 97.6753% | step 350/2000 | beta 2.423 | gamma 0.8256 | ecut 1875.5 | hcut 31889.0 | best_rep 7983 | S 1335.0404 | rep_t 303.1s | total_t 303.1s
# K2000_adam | rep 1/1 | gap 775.0 | acc 97.6753% | step 400/2000 | beta 2.499 | gamma 0.8006 | ecut 3961.0 | hcut 31746.0 | best_rep 7983 | S 1288.6222 | rep_t 342.0s | total_t 342.0s
# K2000_adam | rep 1/1 | gap 775.0 | acc 97.6753% | step 450/2000 | beta 2.579 | gamma 0.7756 | ecut 6855.8 | hcut 31581.0 | best_rep 7983 | S 1218.4829 | rep_t 388.8s | total_t 388.8s
# K2000_adam | rep 1/1 | gap 775.0 | acc 97.6753% | step 500/2000 | beta 2.665 | gamma 0.7506 | ecut 10418.2 | hcut 31552.0 | best_rep 7983 | S 1123.8635 | rep_t 430.8s | total_t 430.8s
# K2000_adam | rep 1/1 | gap 775.0 | acc 97.6753% | step 550/2000 | beta 2.757 | gamma 0.7256 | ecut 14398.8 | hcut 31645.0 | best_rep 7983 | S 1007.8760 | rep_t 469.3s | total_t 469.3s
# K2000_adam | rep 1/1 | gap 775.0 | acc 97.6753% | step 600/2000 | beta 2.856 | gamma 0.7006 | ecut 18349.4 | hcut 31858.0 | best_rep 7983 | S 876.9611 | rep_t 513.8s | total_t 513.8s
# K2000_adam | rep 1/1 | gap 775.0 | acc 97.6753% | step 650/2000 | beta 2.961 | gamma 0.6757 | ecut 21919.5 | hcut 32094.0 | best_rep 7983 | S 739.6257 | rep_t 556.2s | total_t 556.2s
# K2000_adam | rep 1/1 | gap 775.0 | acc 97.6753% | step 700/2000 | beta 3.075 | gamma 0.6507 | ecut 24881.1 | hcut 32201.0 | best_rep 7983 | S 604.7820 | rep_t 597.8s | total_t 597.8s
# K2000_adam | rep 1/1 | gap 775.0 | acc 97.6753% | step 750/2000 | beta 3.198 | gamma 0.6257 | ecut 27196.8 | hcut 32400.0 | best_rep 7983 | S 480.0632 | rep_t 632.2s | total_t 632.2s
# K2000_adam | rep 1/1 | gap 707.0 | acc 97.8792% | step 800/2000 | beta 3.331 | gamma 0.6007 | ecut 28997.6 | hcut 32630.0 | best_rep 578 | S 370.3234 | rep_t 672.0s | total_t 672.0s
# K2000_adam | rep 1/1 | gap 482.0 | acc 98.5542% | step 850/2000 | beta 3.476 | gamma 0.5757 | ecut 30380.4 | hcut 32855.0 | best_rep 578 | S 276.6107 | rep_t 707.1s | total_t 707.1s
# K2000_adam | rep 1/1 | gap 386.0 | acc 98.8421% | step 900/2000 | beta 3.634 | gamma 0.5507 | ecut 31369.4 | hcut 32951.0 | best_rep 578 | S 198.2230 | rep_t 741.5s | total_t 741.5s
# K2000_adam | rep 1/1 | gap 312.0 | acc 99.0641% | step 950/2000 | beta 3.807 | gamma 0.5257 | ecut 32008.4 | hcut 33025.0 | best_rep 578 | S 135.7988 | rep_t 776.2s | total_t 776.2s
# K2000_adam | rep 1/1 | gap 302.0 | acc 99.0941% | step 1000/2000 | beta 3.997 | gamma 0.5007 | ecut 32402.7 | hcut 33035.0 | best_rep 578 | S 90.0055 | rep_t 813.3s | total_t 813.3s
# K2000_adam | rep 1/1 | gap 279.0 | acc 99.1631% | step 1050/2000 | beta 4.208 | gamma 0.4758 | ecut 32642.9 | hcut 33058.0 | best_rep 578 | S 59.2740 | rep_t 849.2s | total_t 849.2s
# K2000_adam | rep 1/1 | gap 233.0 | acc 99.3011% | step 1100/2000 | beta 4.441 | gamma 0.4508 | ecut 32823.2 | hcut 33104.0 | best_rep 578 | S 39.7622 | rep_t 885.7s | total_t 885.7s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1150/2000 | beta 4.703 | gamma 0.4258 | ecut 32922.8 | hcut 33105.0 | best_rep 578 | S 27.3752 | rep_t 921.3s | total_t 921.3s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1200/2000 | beta 4.996 | gamma 0.4008 | ecut 32979.6 | hcut 33105.0 | best_rep 578 | S 19.4424 | rep_t 957.7s | total_t 957.7s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1250/2000 | beta 5.329 | gamma 0.3758 | ecut 33015.7 | hcut 33105.0 | best_rep 578 | S 14.2161 | rep_t 994.4s | total_t 994.4s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1300/2000 | beta 5.71 | gamma 0.3508 | ecut 33039.6 | hcut 33105.0 | best_rep 578 | S 10.6728 | rep_t 1029.0s | total_t 1029.0s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1350/2000 | beta 6.149 | gamma 0.3258 | ecut 33055.8 | hcut 33105.0 | best_rep 578 | S 8.2079 | rep_t 1067.9s | total_t 1067.9s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1400/2000 | beta 6.661 | gamma 0.3008 | ecut 33067.2 | hcut 33105.0 | best_rep 578 | S 6.4493 | rep_t 1104.1s | total_t 1104.1s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1450/2000 | beta 7.266 | gamma 0.2759 | ecut 33075.4 | hcut 33105.0 | best_rep 578 | S 5.1663 | rep_t 1140.7s | total_t 1140.7s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1500/2000 | beta 7.992 | gamma 0.2509 | ecut 33081.4 | hcut 33105.0 | best_rep 578 | S 4.2104 | rep_t 1179.0s | total_t 1179.0s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1550/2000 | beta 8.88 | gamma 0.2259 | ecut 33086.0 | hcut 33105.0 | best_rep 578 | S 3.4844 | rep_t 1216.2s | total_t 1216.2s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1600/2000 | beta 9.989 | gamma 0.2009 | ecut 33089.5 | hcut 33105.0 | best_rep 578 | S 2.9235 | rep_t 1252.5s | total_t 1252.5s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1650/2000 | beta 11.41 | gamma 0.1759 | ecut 33092.2 | hcut 33105.0 | best_rep 578 | S 2.4828 | rep_t 1290.5s | total_t 1290.5s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1700/2000 | beta 13.31 | gamma 0.1509 | ecut 33094.4 | hcut 33105.0 | best_rep 578 | S 2.1316 | rep_t 1325.4s | total_t 1325.4s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1750/2000 | beta 15.97 | gamma 0.1259 | ecut 33096.2 | hcut 33105.0 | best_rep 578 | S 1.8482 | rep_t 1360.0s | total_t 1360.0s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1800/2000 | beta 19.96 | gamma 0.101 | ecut 33097.6 | hcut 33105.0 | best_rep 578 | S 1.6169 | rep_t 1394.9s | total_t 1394.9s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1850/2000 | beta 26.6 | gamma 0.07596 | ecut 33098.6 | hcut 33105.0 | best_rep 578 | S 1.4401 | rep_t 1428.6s | total_t 1428.6s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1900/2000 | beta 39.86 | gamma 0.05098 | ecut 33099.5 | hcut 33105.0 | best_rep 578 | S 1.2856 | rep_t 1463.4s | total_t 1463.4s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 1950/2000 | beta 79.46 | gamma 0.02599 | ecut 33100.1 | hcut 33105.0 | best_rep 578 | S 1.1697 | rep_t 1500.8s | total_t 1500.8s
# K2000_adam | rep 1/1 | gap 232.0 | acc 99.3041% | step 2000/2000 | beta 1.25e+04 | gamma 0.001 | ecut 33100.7 | hcut 33105.0 | best_rep 578 | S 1.0561 | rep_t 1538.0s | total_t 1538.0s
# FINISHED K2000
# best = 33105 | gap = 232 | gap% = 0.6959% | acc = 99.3041% | time = 1538.07s
#
# ==============================================================================================================
# STARTING G1 | historical best = 11624
# ==============================================================================================================
# Starting G1 | historical best = 11624
# G1 | rep 1/1 | gap 1853.0 | acc 84.0588% | step 1/2000 | beta 2 | gamma 1 | ecut 9588.0 | hcut 9771.0 | best_rep 2539 | S 554.4769 | rep_t 0.6s | total_t 0.6s
# G1 | rep 1/1 | gap 1699.0 | acc 85.3837% | step 50/2000 | beta 2.05 | gamma 0.9755 | ecut 9588.0 | hcut 9720.0 | best_rep 9157 | S 554.4104 | rep_t 11.2s | total_t 11.2s
# G1 | rep 1/1 | gap 1597.0 | acc 86.2612% | step 100/2000 | beta 2.104 | gamma 0.9505 | ecut 9588.0 | hcut 9928.0 | best_rep 9209 | S 554.2321 | rep_t 22.0s | total_t 22.0s
# G1 | rep 1/1 | gap 1597.0 | acc 86.2612% | step 150/2000 | beta 2.161 | gamma 0.9255 | ecut 9588.0 | hcut 9841.0 | best_rep 9209 | S 553.7673 | rep_t 31.9s | total_t 31.9s
# G1 | rep 1/1 | gap 1597.0 | acc 86.2612% | step 200/2000 | beta 2.221 | gamma 0.9005 | ecut 9588.0 | hcut 9843.0 | best_rep 9209 | S 552.5869 | rep_t 41.9s | total_t 41.9s
# G1 | rep 1/1 | gap 1597.0 | acc 86.2612% | step 250/2000 | beta 2.285 | gamma 0.8756 | ecut 9588.0 | hcut 9356.0 | best_rep 9209 | S 549.7062 | rep_t 52.0s | total_t 52.0s
# G1 | rep 1/1 | gap 272.0 | acc 97.6600% | step 300/2000 | beta 2.352 | gamma 0.8506 | ecut 9588.0 | hcut 11352.0 | best_rep 361 | S 543.0857 | rep_t 62.5s | total_t 62.5s
# G1 | rep 1/1 | gap 55.0 | acc 99.5268% | step 350/2000 | beta 2.423 | gamma 0.8256 | ecut 9674.3 | hcut 11567.0 | best_rep 7388 | S 529.3936 | rep_t 73.2s | total_t 73.2s
# G1 | rep 1/1 | gap 38.0 | acc 99.6731% | step 400/2000 | beta 2.499 | gamma 0.8006 | ecut 9820.4 | hcut 11584.0 | best_rep 2228 | S 505.2145 | rep_t 84.5s | total_t 84.5s
# G1 | rep 1/1 | gap 38.0 | acc 99.6731% | step 450/2000 | beta 2.579 | gamma 0.7756 | ecut 10050.9 | hcut 11584.0 | best_rep 2228 | S 467.8070 | rep_t 95.8s | total_t 95.8s
# G1 | rep 1/1 | gap 35.0 | acc 99.6989% | step 500/2000 | beta 2.665 | gamma 0.7506 | ecut 10329.0 | hcut 11587.0 | best_rep 7946 | S 417.7831 | rep_t 106.5s | total_t 106.5s
# G1 | rep 1/1 | gap 31.0 | acc 99.7333% | step 550/2000 | beta 2.757 | gamma 0.7256 | ecut 10611.7 | hcut 11593.0 | best_rep 7946 | S 358.7570 | rep_t 117.6s | total_t 117.6s
# G1 | rep 1/1 | gap 23.0 | acc 99.8021% | step 600/2000 | beta 2.856 | gamma 0.7006 | ecut 10867.4 | hcut 11601.0 | best_rep 5650 | S 295.7552 | rep_t 128.1s | total_t 128.1s
# G1 | rep 1/1 | gap 16.0 | acc 99.8624% | step 650/2000 | beta 2.961 | gamma 0.6757 | ecut 11081.9 | hcut 11608.0 | best_rep 5650 | S 233.8860 | rep_t 138.6s | total_t 138.6s
# G1 | rep 1/1 | gap 9.0 | acc 99.9226% | step 700/2000 | beta 3.075 | gamma 0.6507 | ecut 11247.5 | hcut 11615.0 | best_rep 7639 | S 177.4061 | rep_t 149.2s | total_t 149.2s
# G1 | rep 1/1 | gap 7.0 | acc 99.9398% | step 750/2000 | beta 3.198 | gamma 0.6257 | ecut 11366.9 | hcut 11617.0 | best_rep 7946 | S 129.2044 | rep_t 159.7s | total_t 159.7s
# G1 | rep 1/1 | gap 5.0 | acc 99.9570% | step 800/2000 | beta 3.331 | gamma 0.6007 | ecut 11448.0 | hcut 11619.0 | best_rep 6587 | S 90.7938 | rep_t 170.3s | total_t 170.3s
# G1 | rep 1/1 | gap 4.0 | acc 99.9656% | step 850/2000 | beta 3.476 | gamma 0.5757 | ecut 11501.0 | hcut 11620.0 | best_rep 8257 | S 62.2516 | rep_t 180.5s | total_t 180.5s
# G1 | rep 1/1 | gap 0.0 | acc 100.0000% | step 873/2000 | beta 3.547 | gamma 0.5642 | ecut 11520.2 | hcut 11624.0 | best_rep 6587 | S 52.0907 | rep_t 185.4s | total_t 185.4s
# FINISHED G1
# best = 11624 | gap = 0 | gap% = 0.0000% | acc = 100.0000% | time = 185.42s
#
# ==============================================================================================================
# STARTING G2 | historical best = 11620
# ==============================================================================================================
# Starting G2 | historical best = 11620
# G2 | rep 1/1 | gap 1830.0 | acc 84.2513% | step 1/2000 | beta 2 | gamma 1 | ecut 9588.0 | hcut 9790.0 | best_rep 288 | S 554.4769 | rep_t 0.1s | total_t 0.1s
# G2 | rep 1/1 | gap 1677.0 | acc 85.5680% | step 50/2000 | beta 2.05 | gamma 0.9755 | ecut 9588.0 | hcut 9704.0 | best_rep 4994 | S 554.4104 | rep_t 11.2s | total_t 11.2s
# G2 | rep 1/1 | gap 1630.0 | acc 85.9725% | step 100/2000 | beta 2.104 | gamma 0.9505 | ecut 9588.0 | hcut 9882.0 | best_rep 5273 | S 554.2321 | rep_t 21.9s | total_t 21.9s
# G2 | rep 1/1 | gap 1630.0 | acc 85.9725% | step 150/2000 | beta 2.161 | gamma 0.9255 | ecut 9588.0 | hcut 9863.0 | best_rep 5273 | S 553.7673 | rep_t 32.2s | total_t 32.2s
# G2 | rep 1/1 | gap 1630.0 | acc 85.9725% | step 200/2000 | beta 2.221 | gamma 0.9005 | ecut 9588.0 | hcut 9839.0 | best_rep 5273 | S 552.5869 | rep_t 42.5s | total_t 42.5s
# G2 | rep 1/1 | gap 1630.0 | acc 85.9725% | step 250/2000 | beta 2.285 | gamma 0.8756 | ecut 9588.0 | hcut 9576.0 | best_rep 5273 | S 549.7062 | rep_t 52.4s | total_t 52.4s
# G2 | rep 1/1 | gap 288.0 | acc 97.5215% | step 300/2000 | beta 2.352 | gamma 0.8506 | ecut 9588.0 | hcut 11329.0 | best_rep 4768 | S 543.0857 | rep_t 64.2s | total_t 64.2s
# G2 | rep 1/1 | gap 54.0 | acc 99.5353% | step 350/2000 | beta 2.423 | gamma 0.8256 | ecut 9673.2 | hcut 11566.0 | best_rep 5960 | S 529.3990 | rep_t 77.0s | total_t 77.0s
# G2 | rep 1/1 | gap 38.0 | acc 99.6730% | step 400/2000 | beta 2.499 | gamma 0.8006 | ecut 9817.6 | hcut 11580.0 | best_rep 1185 | S 505.2490 | rep_t 89.0s | total_t 89.0s
# G2 | rep 1/1 | gap 38.0 | acc 99.6730% | step 450/2000 | beta 2.579 | gamma 0.7756 | ecut 10042.9 | hcut 11581.0 | best_rep 1185 | S 467.8942 | rep_t 100.5s | total_t 100.5s
# G2 | rep 1/1 | gap 36.0 | acc 99.6902% | step 500/2000 | beta 2.665 | gamma 0.7506 | ecut 10316.2 | hcut 11584.0 | best_rep 6111 | S 417.9137 | rep_t 111.2s | total_t 111.2s
# G2 | rep 1/1 | gap 29.0 | acc 99.7504% | step 550/2000 | beta 2.757 | gamma 0.7256 | ecut 10600.8 | hcut 11591.0 | best_rep 1185 | S 358.9021 | rep_t 121.5s | total_t 121.5s
# G2 | rep 1/1 | gap 27.0 | acc 99.7676% | step 600/2000 | beta 2.856 | gamma 0.7006 | ecut 10862.6 | hcut 11593.0 | best_rep 6111 | S 295.9061 | rep_t 132.2s | total_t 132.2s
# G2 | rep 1/1 | gap 20.0 | acc 99.8279% | step 650/2000 | beta 2.961 | gamma 0.6757 | ecut 11077.9 | hcut 11600.0 | best_rep 5612 | S 234.0551 | rep_t 145.6s | total_t 145.6s
# G2 | rep 1/1 | gap 12.0 | acc 99.8967% | step 700/2000 | beta 3.075 | gamma 0.6507 | ecut 11241.5 | hcut 11608.0 | best_rep 8038 | S 177.6027 | rep_t 161.3s | total_t 161.3s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 341
#     337
#     338     W = load_gset_dense_v2(g_idx)
#     339     local_hparams = get_v2_gset_benchmark_hparams(g_idx, n_batch=10000)
#     340
# --> 341     row = run_and_save_one_v2(
#     342         graph_name=graph_name,
#     343         W=W,
#     344         best_known_cut=best_known_cut,
#
# Cell In[17], line 263, in run_and_save_one_v2(graph_name, W, best_known_cut, local_hparams, print_every)
#     259     print("=" * 110)
#     260     print(f"STARTING {graph_name} | historical best = {best_known_cut:.0f}")
#     261     print("=" * 110)
#     262
# --> 263     result = run_qefem_single_instance(
#     264         W=W,
#     265         best_known_cut=float(best_known_cut),
#     266         local_hparams=local_hparams,
#
# Cell In[15], line 326, in run_qefem_single_instance(W, best_known_cut, local_hparams, seed, print_every, device, dtype, eps)
#     322
#     323             loss = F_val.sum()
#     324             loss.backward()
#     325
# --> 326             grad_norm_before = grad_global_norm([fields, theta]).item()
#     327
#     328             grad_clip = local_hparams.get("grad_clip", None)
#     329             if grad_clip is not None:
#
# KeyboardInterrupt:

# %%
# ============================================================
# CONTINUE / RUN ONLY G1-G54
# Does NOT rerun K2000
# Skips any Gset instance whose history CSV already exists
# ============================================================

from pathlib import Path
import pandas as pd
import torch
import time

OUT_DIR = Path.cwd() / "full_res"
OUT_DIR.mkdir(parents=True, exist_ok=True)

gset_history_df = build_gset_history_df_v2()

gset_rows = []

partial_path = OUT_DIR / "qefem_v2_G1-G54_benchmark_table_partial.csv"
final_path = OUT_DIR / "qefem_v2_G1-G54_benchmark_table.csv"

if partial_path.exists():
    gset_rows = pd.read_csv(partial_path).to_dict("records")

already_done = set(row["graph_name"] for row in gset_rows)

for g_idx in range(1, 55):
    graph_name = f"G{g_idx}"

    history_path = OUT_DIR / f"{graph_name}_qefem_v2_anneal_history.csv"
    summary_path = OUT_DIR / f"{graph_name}_qefem_v2_summary.csv"

    if history_path.exists() and summary_path.exists():
        print(f"SKIPPING {graph_name} | already saved")
        if graph_name not in already_done:
            summary = pd.read_csv(summary_path).iloc[0].to_dict()
            row = normalize_v2_summary(summary, n_nodes=int(pd.read_csv(history_path, nrows=1).shape[0]) if False else 0)
            row["graph_name"] = graph_name
            row["history_path"] = str(history_path)
            row["summary_path"] = str(summary_path)
            gset_rows.append(row)
        continue

    best_known_cut = float(
        gset_history_df.loc[
            gset_history_df["graph_name"] == graph_name,
            "best_known_cut"
        ].iloc[0]
    )

    W = load_gset_dense_v2(g_idx)

    local_hparams = get_v2_gset_benchmark_hparams(
        g_idx=g_idx,
        n_batch=10000,
    )

    row = run_and_save_one_v2(
        graph_name=graph_name,
        W=W,
        best_known_cut=best_known_cut,
        local_hparams=local_hparams,
        print_every=50,
    )

    gset_rows.append(row)

    pd.DataFrame(gset_rows).to_csv(partial_path, index=False)

    del W

    if DEVICE.type == "mps":
        torch.mps.empty_cache()

gset_benchmark_df = pd.DataFrame(gset_rows)
gset_benchmark_df.to_csv(final_path, index=False)

print("=" * 100)
print("G1-G54 RUN COMPLETE")
print(f"Saved: {final_path}")
print("=" * 100)

gset_benchmark_df
# Out:
# SKIPPING G1 | already saved
# ==============================================================================================================
# STARTING G2 | historical best = 11620
# ==============================================================================================================
# Starting G2 | historical best = 11620
# G2 | rep 1/1 | gap 1830.0 | acc 84.2513% | step 1/2000 | beta 2 | gamma 1 | ecut 9588.0 | hcut 9790.0 | best_rep 288 | S 554.4769 | rep_t 0.8s | total_t 0.8s
# G2 | rep 1/1 | gap 1677.0 | acc 85.5680% | step 50/2000 | beta 2.05 | gamma 0.9755 | ecut 9588.0 | hcut 9704.0 | best_rep 4994 | S 554.4104 | rep_t 11.9s | total_t 11.9s
# G2 | rep 1/1 | gap 1630.0 | acc 85.9725% | step 100/2000 | beta 2.104 | gamma 0.9505 | ecut 9588.0 | hcut 9882.0 | best_rep 5273 | S 554.2321 | rep_t 23.8s | total_t 23.8s
# G2 | rep 1/1 | gap 1630.0 | acc 85.9725% | step 150/2000 | beta 2.161 | gamma 0.9255 | ecut 9588.0 | hcut 9863.0 | best_rep 5273 | S 553.7673 | rep_t 35.4s | total_t 35.4s
# G2 | rep 1/1 | gap 1630.0 | acc 85.9725% | step 200/2000 | beta 2.221 | gamma 0.9005 | ecut 9588.0 | hcut 9839.0 | best_rep 5273 | S 552.5869 | rep_t 50.7s | total_t 50.7s
# G2 | rep 1/1 | gap 1630.0 | acc 85.9725% | step 250/2000 | beta 2.285 | gamma 0.8756 | ecut 9588.0 | hcut 9576.0 | best_rep 5273 | S 549.7062 | rep_t 66.3s | total_t 66.3s
# G2 | rep 1/1 | gap 288.0 | acc 97.5215% | step 300/2000 | beta 2.352 | gamma 0.8506 | ecut 9588.0 | hcut 11329.0 | best_rep 4768 | S 543.0857 | rep_t 76.9s | total_t 76.9s
# G2 | rep 1/1 | gap 54.0 | acc 99.5353% | step 350/2000 | beta 2.423 | gamma 0.8256 | ecut 9673.2 | hcut 11566.0 | best_rep 5960 | S 529.3990 | rep_t 90.5s | total_t 90.5s
# G2 | rep 1/1 | gap 38.0 | acc 99.6730% | step 400/2000 | beta 2.499 | gamma 0.8006 | ecut 9817.6 | hcut 11580.0 | best_rep 1185 | S 505.2491 | rep_t 100.8s | total_t 100.8s
# G2 | rep 1/1 | gap 38.0 | acc 99.6730% | step 450/2000 | beta 2.579 | gamma 0.7756 | ecut 10042.9 | hcut 11581.0 | best_rep 1185 | S 467.8945 | rep_t 111.2s | total_t 111.2s
# G2 | rep 1/1 | gap 36.0 | acc 99.6902% | step 500/2000 | beta 2.665 | gamma 0.7506 | ecut 10316.2 | hcut 11584.0 | best_rep 6111 | S 417.9140 | rep_t 122.3s | total_t 122.3s
# G2 | rep 1/1 | gap 29.0 | acc 99.7504% | step 550/2000 | beta 2.757 | gamma 0.7256 | ecut 10600.8 | hcut 11591.0 | best_rep 1185 | S 358.9023 | rep_t 133.4s | total_t 133.4s
# G2 | rep 1/1 | gap 27.0 | acc 99.7676% | step 600/2000 | beta 2.856 | gamma 0.7006 | ecut 10862.6 | hcut 11593.0 | best_rep 6111 | S 295.9063 | rep_t 144.2s | total_t 144.2s
# G2 | rep 1/1 | gap 20.0 | acc 99.8279% | step 650/2000 | beta 2.961 | gamma 0.6757 | ecut 11077.9 | hcut 11600.0 | best_rep 5612 | S 234.0553 | rep_t 154.6s | total_t 154.6s
# G2 | rep 1/1 | gap 12.0 | acc 99.8967% | step 700/2000 | beta 3.075 | gamma 0.6507 | ecut 11241.5 | hcut 11608.0 | best_rep 8038 | S 177.6028 | rep_t 165.4s | total_t 165.4s
# G2 | rep 1/1 | gap 10.0 | acc 99.9139% | step 750/2000 | beta 3.198 | gamma 0.6257 | ecut 11360.2 | hcut 11610.0 | best_rep 8038 | S 129.4133 | rep_t 177.2s | total_t 177.2s
# G2 | rep 1/1 | gap 9.0 | acc 99.9225% | step 800/2000 | beta 3.331 | gamma 0.6007 | ecut 11440.4 | hcut 11611.0 | best_rep 614 | S 90.9771 | rep_t 189.1s | total_t 189.1s
# G2 | rep 1/1 | gap 8.0 | acc 99.9312% | step 850/2000 | beta 3.476 | gamma 0.5757 | ecut 11494.6 | hcut 11612.0 | best_rep 9914 | S 62.3874 | rep_t 199.6s | total_t 199.6s
# G2 | rep 1/1 | gap 8.0 | acc 99.9312% | step 900/2000 | beta 3.634 | gamma 0.5507 | ecut 11529.1 | hcut 11612.0 | best_rep 9914 | S 42.2799 | rep_t 210.5s | total_t 210.5s
# G2 | rep 1/1 | gap 6.0 | acc 99.9484% | step 950/2000 | beta 3.807 | gamma 0.5257 | ecut 11553.2 | hcut 11614.0 | best_rep 6282 | S 28.6036 | rep_t 221.0s | total_t 221.0s
# G2 | rep 1/1 | gap 3.0 | acc 99.9742% | step 1000/2000 | beta 3.997 | gamma 0.5007 | ecut 11569.3 | hcut 11617.0 | best_rep 4780 | S 19.4789 | rep_t 231.7s | total_t 231.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1033/2000 | beta 4.134 | gamma 0.4843 | ecut 11579.9 | hcut 11620.0 | best_rep 4780 | S 15.2200 | rep_t 238.5s | total_t 238.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1034/2000 | beta 4.138 | gamma 0.4838 | ecut 11580.1 | hcut 11620.0 | best_rep 4780 | S 15.1083 | rep_t 238.7s | total_t 238.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1035/2000 | beta 4.142 | gamma 0.4833 | ecut 11580.4 | hcut 11620.0 | best_rep 4780 | S 14.9976 | rep_t 238.9s | total_t 238.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1036/2000 | beta 4.147 | gamma 0.4828 | ecut 11580.6 | hcut 11620.0 | best_rep 4780 | S 14.8877 | rep_t 239.1s | total_t 239.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1037/2000 | beta 4.151 | gamma 0.4823 | ecut 11580.9 | hcut 11620.0 | best_rep 4780 | S 14.7788 | rep_t 239.3s | total_t 239.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1038/2000 | beta 4.155 | gamma 0.4818 | ecut 11581.1 | hcut 11620.0 | best_rep 4780 | S 14.6708 | rep_t 239.5s | total_t 239.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1039/2000 | beta 4.16 | gamma 0.4813 | ecut 11581.3 | hcut 11620.0 | best_rep 4780 | S 14.5637 | rep_t 239.7s | total_t 239.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1040/2000 | beta 4.164 | gamma 0.4808 | ecut 11581.5 | hcut 11620.0 | best_rep 4780 | S 14.4575 | rep_t 240.0s | total_t 240.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1041/2000 | beta 4.168 | gamma 0.4803 | ecut 11581.7 | hcut 11620.0 | best_rep 4780 | S 14.3522 | rep_t 240.2s | total_t 240.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1042/2000 | beta 4.173 | gamma 0.4798 | ecut 11581.9 | hcut 11620.0 | best_rep 4780 | S 14.2478 | rep_t 240.4s | total_t 240.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1043/2000 | beta 4.177 | gamma 0.4793 | ecut 11582.1 | hcut 11620.0 | best_rep 4780 | S 14.1443 | rep_t 240.6s | total_t 240.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1044/2000 | beta 4.181 | gamma 0.4788 | ecut 11582.3 | hcut 11620.0 | best_rep 4780 | S 14.0416 | rep_t 240.8s | total_t 240.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1045/2000 | beta 4.186 | gamma 0.4783 | ecut 11582.5 | hcut 11620.0 | best_rep 4780 | S 13.9398 | rep_t 241.0s | total_t 241.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1046/2000 | beta 4.19 | gamma 0.4778 | ecut 11582.7 | hcut 11620.0 | best_rep 4780 | S 13.8388 | rep_t 241.2s | total_t 241.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1047/2000 | beta 4.194 | gamma 0.4773 | ecut 11582.8 | hcut 11620.0 | best_rep 4780 | S 13.7387 | rep_t 241.5s | total_t 241.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1048/2000 | beta 4.199 | gamma 0.4768 | ecut 11583.0 | hcut 11620.0 | best_rep 4780 | S 13.6394 | rep_t 241.8s | total_t 241.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1049/2000 | beta 4.203 | gamma 0.4763 | ecut 11583.2 | hcut 11620.0 | best_rep 4780 | S 13.5409 | rep_t 242.0s | total_t 242.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1050/2000 | beta 4.208 | gamma 0.4758 | ecut 11583.3 | hcut 11620.0 | best_rep 4780 | S 13.4433 | rep_t 242.2s | total_t 242.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1051/2000 | beta 4.212 | gamma 0.4753 | ecut 11583.5 | hcut 11620.0 | best_rep 4780 | S 13.3465 | rep_t 242.6s | total_t 242.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1052/2000 | beta 4.217 | gamma 0.4748 | ecut 11583.6 | hcut 11620.0 | best_rep 4780 | S 13.2505 | rep_t 242.9s | total_t 242.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1053/2000 | beta 4.221 | gamma 0.4743 | ecut 11583.8 | hcut 11620.0 | best_rep 4780 | S 13.1553 | rep_t 243.1s | total_t 243.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1054/2000 | beta 4.225 | gamma 0.4738 | ecut 11583.9 | hcut 11620.0 | best_rep 4780 | S 13.0609 | rep_t 243.3s | total_t 243.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1055/2000 | beta 4.23 | gamma 0.4733 | ecut 11584.1 | hcut 11620.0 | best_rep 4780 | S 12.9672 | rep_t 243.5s | total_t 243.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1056/2000 | beta 4.234 | gamma 0.4728 | ecut 11584.3 | hcut 11620.0 | best_rep 4780 | S 12.8744 | rep_t 243.7s | total_t 243.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1057/2000 | beta 4.239 | gamma 0.4723 | ecut 11584.4 | hcut 11620.0 | best_rep 4780 | S 12.7823 | rep_t 243.9s | total_t 243.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1058/2000 | beta 4.243 | gamma 0.4718 | ecut 11584.6 | hcut 11620.0 | best_rep 4780 | S 12.6910 | rep_t 244.1s | total_t 244.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1059/2000 | beta 4.248 | gamma 0.4713 | ecut 11584.7 | hcut 11620.0 | best_rep 4780 | S 12.6005 | rep_t 244.3s | total_t 244.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1060/2000 | beta 4.252 | gamma 0.4708 | ecut 11584.9 | hcut 11620.0 | best_rep 4780 | S 12.5107 | rep_t 244.5s | total_t 244.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1061/2000 | beta 4.257 | gamma 0.4703 | ecut 11585.0 | hcut 11620.0 | best_rep 4780 | S 12.4216 | rep_t 244.8s | total_t 244.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1062/2000 | beta 4.261 | gamma 0.4698 | ecut 11585.1 | hcut 11620.0 | best_rep 4780 | S 12.3333 | rep_t 245.0s | total_t 245.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1063/2000 | beta 4.266 | gamma 0.4693 | ecut 11585.3 | hcut 11620.0 | best_rep 4780 | S 12.2457 | rep_t 245.2s | total_t 245.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1064/2000 | beta 4.271 | gamma 0.4688 | ecut 11585.4 | hcut 11620.0 | best_rep 4780 | S 12.1588 | rep_t 245.4s | total_t 245.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1065/2000 | beta 4.275 | gamma 0.4683 | ecut 11585.6 | hcut 11620.0 | best_rep 4780 | S 12.0726 | rep_t 245.7s | total_t 245.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1066/2000 | beta 4.28 | gamma 0.4678 | ecut 11585.8 | hcut 11620.0 | best_rep 4780 | S 11.9872 | rep_t 245.9s | total_t 245.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1067/2000 | beta 4.284 | gamma 0.4673 | ecut 11585.9 | hcut 11620.0 | best_rep 4780 | S 11.9025 | rep_t 246.1s | total_t 246.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1068/2000 | beta 4.289 | gamma 0.4668 | ecut 11586.0 | hcut 11620.0 | best_rep 4780 | S 11.8184 | rep_t 246.3s | total_t 246.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1069/2000 | beta 4.294 | gamma 0.4663 | ecut 11586.2 | hcut 11620.0 | best_rep 4780 | S 11.7351 | rep_t 246.5s | total_t 246.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1070/2000 | beta 4.298 | gamma 0.4658 | ecut 11586.3 | hcut 11620.0 | best_rep 4780 | S 11.6524 | rep_t 246.7s | total_t 246.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1071/2000 | beta 4.303 | gamma 0.4653 | ecut 11586.5 | hcut 11620.0 | best_rep 4780 | S 11.5704 | rep_t 246.9s | total_t 246.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1072/2000 | beta 4.307 | gamma 0.4648 | ecut 11586.6 | hcut 11620.0 | best_rep 4780 | S 11.4891 | rep_t 247.1s | total_t 247.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1073/2000 | beta 4.312 | gamma 0.4643 | ecut 11586.8 | hcut 11620.0 | best_rep 4780 | S 11.4085 | rep_t 247.4s | total_t 247.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1074/2000 | beta 4.317 | gamma 0.4638 | ecut 11586.9 | hcut 11620.0 | best_rep 4780 | S 11.3286 | rep_t 247.6s | total_t 247.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1075/2000 | beta 4.321 | gamma 0.4633 | ecut 11587.1 | hcut 11620.0 | best_rep 4780 | S 11.2493 | rep_t 247.8s | total_t 247.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1076/2000 | beta 4.326 | gamma 0.4628 | ecut 11587.2 | hcut 11620.0 | best_rep 4780 | S 11.1707 | rep_t 248.0s | total_t 248.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1077/2000 | beta 4.331 | gamma 0.4623 | ecut 11587.4 | hcut 11620.0 | best_rep 4780 | S 11.0927 | rep_t 248.2s | total_t 248.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1078/2000 | beta 4.335 | gamma 0.4618 | ecut 11587.5 | hcut 11620.0 | best_rep 4780 | S 11.0154 | rep_t 248.4s | total_t 248.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1079/2000 | beta 4.34 | gamma 0.4613 | ecut 11587.7 | hcut 11620.0 | best_rep 4780 | S 10.9388 | rep_t 248.6s | total_t 248.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1080/2000 | beta 4.345 | gamma 0.4608 | ecut 11587.8 | hcut 11620.0 | best_rep 4780 | S 10.8628 | rep_t 248.8s | total_t 248.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1081/2000 | beta 4.35 | gamma 0.4603 | ecut 11587.9 | hcut 11620.0 | best_rep 4780 | S 10.7874 | rep_t 249.0s | total_t 249.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1082/2000 | beta 4.354 | gamma 0.4598 | ecut 11588.0 | hcut 11620.0 | best_rep 4780 | S 10.7127 | rep_t 249.2s | total_t 249.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1083/2000 | beta 4.359 | gamma 0.4593 | ecut 11588.2 | hcut 11620.0 | best_rep 4780 | S 10.6386 | rep_t 249.4s | total_t 249.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1084/2000 | beta 4.364 | gamma 0.4588 | ecut 11588.3 | hcut 11620.0 | best_rep 4780 | S 10.5651 | rep_t 249.6s | total_t 249.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1085/2000 | beta 4.369 | gamma 0.4583 | ecut 11588.5 | hcut 11620.0 | best_rep 4780 | S 10.4922 | rep_t 249.8s | total_t 249.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1086/2000 | beta 4.373 | gamma 0.4578 | ecut 11588.6 | hcut 11620.0 | best_rep 4780 | S 10.4200 | rep_t 250.0s | total_t 250.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1087/2000 | beta 4.378 | gamma 0.4573 | ecut 11588.7 | hcut 11620.0 | best_rep 4780 | S 10.3483 | rep_t 250.2s | total_t 250.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1088/2000 | beta 4.383 | gamma 0.4568 | ecut 11588.8 | hcut 11620.0 | best_rep 4780 | S 10.2772 | rep_t 250.4s | total_t 250.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1089/2000 | beta 4.388 | gamma 0.4563 | ecut 11588.9 | hcut 11620.0 | best_rep 4780 | S 10.2067 | rep_t 250.6s | total_t 250.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1090/2000 | beta 4.393 | gamma 0.4558 | ecut 11589.1 | hcut 11620.0 | best_rep 4780 | S 10.1368 | rep_t 250.9s | total_t 250.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1091/2000 | beta 4.397 | gamma 0.4553 | ecut 11589.2 | hcut 11620.0 | best_rep 4780 | S 10.0675 | rep_t 251.1s | total_t 251.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1092/2000 | beta 4.402 | gamma 0.4548 | ecut 11589.3 | hcut 11620.0 | best_rep 4780 | S 9.9987 | rep_t 251.3s | total_t 251.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1093/2000 | beta 4.407 | gamma 0.4543 | ecut 11589.4 | hcut 11620.0 | best_rep 4780 | S 9.9306 | rep_t 251.5s | total_t 251.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1094/2000 | beta 4.412 | gamma 0.4538 | ecut 11589.5 | hcut 11620.0 | best_rep 4780 | S 9.8629 | rep_t 251.7s | total_t 251.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1095/2000 | beta 4.417 | gamma 0.4533 | ecut 11589.7 | hcut 11620.0 | best_rep 4780 | S 9.7959 | rep_t 251.9s | total_t 251.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1096/2000 | beta 4.422 | gamma 0.4528 | ecut 11589.8 | hcut 11620.0 | best_rep 4780 | S 9.7294 | rep_t 252.1s | total_t 252.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1097/2000 | beta 4.427 | gamma 0.4523 | ecut 11589.9 | hcut 11620.0 | best_rep 4780 | S 9.6634 | rep_t 252.3s | total_t 252.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1098/2000 | beta 4.432 | gamma 0.4518 | ecut 11590.0 | hcut 11620.0 | best_rep 4780 | S 9.5980 | rep_t 252.5s | total_t 252.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1099/2000 | beta 4.436 | gamma 0.4513 | ecut 11590.1 | hcut 11620.0 | best_rep 4780 | S 9.5332 | rep_t 252.7s | total_t 252.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1100/2000 | beta 4.441 | gamma 0.4508 | ecut 11590.2 | hcut 11620.0 | best_rep 4780 | S 9.4688 | rep_t 252.9s | total_t 252.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1101/2000 | beta 4.446 | gamma 0.4503 | ecut 11590.4 | hcut 11620.0 | best_rep 4780 | S 9.4050 | rep_t 253.1s | total_t 253.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1102/2000 | beta 4.451 | gamma 0.4498 | ecut 11590.5 | hcut 11620.0 | best_rep 4780 | S 9.3418 | rep_t 253.3s | total_t 253.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1103/2000 | beta 4.456 | gamma 0.4493 | ecut 11590.6 | hcut 11620.0 | best_rep 4780 | S 9.2790 | rep_t 253.5s | total_t 253.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1104/2000 | beta 4.461 | gamma 0.4488 | ecut 11590.7 | hcut 11620.0 | best_rep 4780 | S 9.2168 | rep_t 253.7s | total_t 253.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1105/2000 | beta 4.466 | gamma 0.4483 | ecut 11590.8 | hcut 11620.0 | best_rep 4780 | S 9.1551 | rep_t 253.9s | total_t 253.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1106/2000 | beta 4.471 | gamma 0.4478 | ecut 11590.9 | hcut 11620.0 | best_rep 4780 | S 9.0939 | rep_t 254.1s | total_t 254.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1107/2000 | beta 4.476 | gamma 0.4473 | ecut 11591.1 | hcut 11620.0 | best_rep 4780 | S 9.0332 | rep_t 254.3s | total_t 254.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1108/2000 | beta 4.481 | gamma 0.4468 | ecut 11591.1 | hcut 11620.0 | best_rep 4780 | S 8.9729 | rep_t 254.5s | total_t 254.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1109/2000 | beta 4.486 | gamma 0.4463 | ecut 11591.3 | hcut 11620.0 | best_rep 4780 | S 8.9132 | rep_t 254.7s | total_t 254.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1110/2000 | beta 4.491 | gamma 0.4458 | ecut 11591.4 | hcut 11620.0 | best_rep 4780 | S 8.8540 | rep_t 254.9s | total_t 254.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1111/2000 | beta 4.496 | gamma 0.4453 | ecut 11591.5 | hcut 11620.0 | best_rep 4780 | S 8.7953 | rep_t 255.1s | total_t 255.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1112/2000 | beta 4.501 | gamma 0.4448 | ecut 11591.6 | hcut 11620.0 | best_rep 4780 | S 8.7371 | rep_t 255.3s | total_t 255.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1113/2000 | beta 4.506 | gamma 0.4443 | ecut 11591.7 | hcut 11620.0 | best_rep 4780 | S 8.6793 | rep_t 255.6s | total_t 255.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1114/2000 | beta 4.512 | gamma 0.4438 | ecut 11591.8 | hcut 11620.0 | best_rep 4780 | S 8.6220 | rep_t 255.8s | total_t 255.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1115/2000 | beta 4.517 | gamma 0.4433 | ecut 11591.9 | hcut 11620.0 | best_rep 4780 | S 8.5653 | rep_t 256.0s | total_t 256.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1116/2000 | beta 4.522 | gamma 0.4428 | ecut 11592.0 | hcut 11620.0 | best_rep 4780 | S 8.5089 | rep_t 256.2s | total_t 256.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1117/2000 | beta 4.527 | gamma 0.4423 | ecut 11592.1 | hcut 11620.0 | best_rep 4780 | S 8.4531 | rep_t 256.4s | total_t 256.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1118/2000 | beta 4.532 | gamma 0.4418 | ecut 11592.2 | hcut 11620.0 | best_rep 4780 | S 8.3977 | rep_t 256.6s | total_t 256.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1119/2000 | beta 4.537 | gamma 0.4413 | ecut 11592.3 | hcut 11620.0 | best_rep 4780 | S 8.3428 | rep_t 256.9s | total_t 256.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1120/2000 | beta 4.542 | gamma 0.4408 | ecut 11592.4 | hcut 11620.0 | best_rep 4780 | S 8.2884 | rep_t 257.1s | total_t 257.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1121/2000 | beta 4.547 | gamma 0.4403 | ecut 11592.5 | hcut 11620.0 | best_rep 4780 | S 8.2343 | rep_t 257.3s | total_t 257.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1122/2000 | beta 4.553 | gamma 0.4398 | ecut 11592.6 | hcut 11620.0 | best_rep 4780 | S 8.1808 | rep_t 257.6s | total_t 257.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1123/2000 | beta 4.558 | gamma 0.4393 | ecut 11592.7 | hcut 11620.0 | best_rep 4780 | S 8.1277 | rep_t 257.7s | total_t 257.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1124/2000 | beta 4.563 | gamma 0.4388 | ecut 11592.8 | hcut 11620.0 | best_rep 4780 | S 8.0750 | rep_t 258.0s | total_t 258.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1125/2000 | beta 4.568 | gamma 0.4383 | ecut 11592.9 | hcut 11620.0 | best_rep 4780 | S 8.0228 | rep_t 258.3s | total_t 258.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1126/2000 | beta 4.573 | gamma 0.4378 | ecut 11593.0 | hcut 11620.0 | best_rep 4780 | S 7.9709 | rep_t 258.6s | total_t 258.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1127/2000 | beta 4.579 | gamma 0.4373 | ecut 11593.1 | hcut 11620.0 | best_rep 4780 | S 7.9196 | rep_t 258.8s | total_t 258.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1128/2000 | beta 4.584 | gamma 0.4368 | ecut 11593.2 | hcut 11620.0 | best_rep 4780 | S 7.8686 | rep_t 259.0s | total_t 259.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1129/2000 | beta 4.589 | gamma 0.4363 | ecut 11593.3 | hcut 11620.0 | best_rep 4780 | S 7.8181 | rep_t 259.2s | total_t 259.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1130/2000 | beta 4.594 | gamma 0.4358 | ecut 11593.4 | hcut 11620.0 | best_rep 4780 | S 7.7679 | rep_t 259.4s | total_t 259.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1131/2000 | beta 4.6 | gamma 0.4353 | ecut 11593.5 | hcut 11620.0 | best_rep 4780 | S 7.7182 | rep_t 259.6s | total_t 259.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1132/2000 | beta 4.605 | gamma 0.4348 | ecut 11593.6 | hcut 11620.0 | best_rep 4780 | S 7.6689 | rep_t 259.8s | total_t 259.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1133/2000 | beta 4.61 | gamma 0.4343 | ecut 11593.7 | hcut 11620.0 | best_rep 4780 | S 7.6201 | rep_t 260.0s | total_t 260.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1134/2000 | beta 4.616 | gamma 0.4338 | ecut 11593.8 | hcut 11620.0 | best_rep 4780 | S 7.5716 | rep_t 260.2s | total_t 260.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1135/2000 | beta 4.621 | gamma 0.4333 | ecut 11593.9 | hcut 11620.0 | best_rep 4780 | S 7.5235 | rep_t 260.4s | total_t 260.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1136/2000 | beta 4.626 | gamma 0.4328 | ecut 11594.0 | hcut 11620.0 | best_rep 4780 | S 7.4758 | rep_t 260.6s | total_t 260.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1137/2000 | beta 4.632 | gamma 0.4323 | ecut 11594.1 | hcut 11620.0 | best_rep 4780 | S 7.4285 | rep_t 260.8s | total_t 260.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1138/2000 | beta 4.637 | gamma 0.4318 | ecut 11594.2 | hcut 11620.0 | best_rep 4780 | S 7.3816 | rep_t 261.0s | total_t 261.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1139/2000 | beta 4.642 | gamma 0.4313 | ecut 11594.2 | hcut 11620.0 | best_rep 4780 | S 7.3351 | rep_t 261.2s | total_t 261.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1140/2000 | beta 4.648 | gamma 0.4308 | ecut 11594.3 | hcut 11620.0 | best_rep 4780 | S 7.2890 | rep_t 261.5s | total_t 261.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1141/2000 | beta 4.653 | gamma 0.4303 | ecut 11594.4 | hcut 11620.0 | best_rep 4780 | S 7.2433 | rep_t 261.7s | total_t 261.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1142/2000 | beta 4.659 | gamma 0.4298 | ecut 11594.5 | hcut 11620.0 | best_rep 4780 | S 7.1980 | rep_t 261.9s | total_t 261.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1143/2000 | beta 4.664 | gamma 0.4293 | ecut 11594.6 | hcut 11620.0 | best_rep 4780 | S 7.1530 | rep_t 262.1s | total_t 262.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1144/2000 | beta 4.67 | gamma 0.4288 | ecut 11594.7 | hcut 11620.0 | best_rep 4780 | S 7.1084 | rep_t 262.3s | total_t 262.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1145/2000 | beta 4.675 | gamma 0.4283 | ecut 11594.8 | hcut 11620.0 | best_rep 4780 | S 7.0642 | rep_t 262.5s | total_t 262.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1146/2000 | beta 4.68 | gamma 0.4278 | ecut 11594.9 | hcut 11620.0 | best_rep 4780 | S 7.0203 | rep_t 262.7s | total_t 262.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1147/2000 | beta 4.686 | gamma 0.4273 | ecut 11595.0 | hcut 11620.0 | best_rep 4780 | S 6.9768 | rep_t 262.9s | total_t 262.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1148/2000 | beta 4.691 | gamma 0.4268 | ecut 11595.0 | hcut 11620.0 | best_rep 4780 | S 6.9337 | rep_t 263.1s | total_t 263.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1149/2000 | beta 4.697 | gamma 0.4263 | ecut 11595.1 | hcut 11620.0 | best_rep 4780 | S 6.8909 | rep_t 263.3s | total_t 263.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1150/2000 | beta 4.703 | gamma 0.4258 | ecut 11595.2 | hcut 11620.0 | best_rep 4780 | S 6.8485 | rep_t 263.5s | total_t 263.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1151/2000 | beta 4.708 | gamma 0.4253 | ecut 11595.3 | hcut 11620.0 | best_rep 4780 | S 6.8065 | rep_t 263.7s | total_t 263.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1152/2000 | beta 4.714 | gamma 0.4248 | ecut 11595.4 | hcut 11620.0 | best_rep 4780 | S 6.7648 | rep_t 264.0s | total_t 264.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1153/2000 | beta 4.719 | gamma 0.4243 | ecut 11595.5 | hcut 11620.0 | best_rep 4780 | S 6.7234 | rep_t 264.1s | total_t 264.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1154/2000 | beta 4.725 | gamma 0.4238 | ecut 11595.6 | hcut 11620.0 | best_rep 4780 | S 6.6824 | rep_t 264.3s | total_t 264.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1155/2000 | beta 4.73 | gamma 0.4233 | ecut 11595.6 | hcut 11620.0 | best_rep 4780 | S 6.6418 | rep_t 264.5s | total_t 264.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1156/2000 | beta 4.736 | gamma 0.4228 | ecut 11595.7 | hcut 11620.0 | best_rep 4780 | S 6.6014 | rep_t 264.7s | total_t 264.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1157/2000 | beta 4.742 | gamma 0.4223 | ecut 11595.8 | hcut 11620.0 | best_rep 4780 | S 6.5615 | rep_t 264.9s | total_t 264.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1158/2000 | beta 4.747 | gamma 0.4218 | ecut 11595.9 | hcut 11620.0 | best_rep 4780 | S 6.5218 | rep_t 265.2s | total_t 265.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1159/2000 | beta 4.753 | gamma 0.4213 | ecut 11596.0 | hcut 11620.0 | best_rep 4780 | S 6.4825 | rep_t 265.4s | total_t 265.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1160/2000 | beta 4.758 | gamma 0.4208 | ecut 11596.0 | hcut 11620.0 | best_rep 4780 | S 6.4435 | rep_t 265.6s | total_t 265.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1161/2000 | beta 4.764 | gamma 0.4203 | ecut 11596.1 | hcut 11620.0 | best_rep 4780 | S 6.4049 | rep_t 265.8s | total_t 265.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1162/2000 | beta 4.77 | gamma 0.4198 | ecut 11596.2 | hcut 11620.0 | best_rep 4780 | S 6.3665 | rep_t 266.0s | total_t 266.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1163/2000 | beta 4.776 | gamma 0.4193 | ecut 11596.3 | hcut 11620.0 | best_rep 4780 | S 6.3285 | rep_t 266.2s | total_t 266.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1164/2000 | beta 4.781 | gamma 0.4188 | ecut 11596.4 | hcut 11620.0 | best_rep 4780 | S 6.2908 | rep_t 266.4s | total_t 266.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1165/2000 | beta 4.787 | gamma 0.4183 | ecut 11596.5 | hcut 11620.0 | best_rep 4780 | S 6.2534 | rep_t 266.6s | total_t 266.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1166/2000 | beta 4.793 | gamma 0.4178 | ecut 11596.5 | hcut 11620.0 | best_rep 4780 | S 6.2164 | rep_t 266.8s | total_t 266.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1167/2000 | beta 4.798 | gamma 0.4173 | ecut 11596.6 | hcut 11620.0 | best_rep 4780 | S 6.1796 | rep_t 267.0s | total_t 267.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1168/2000 | beta 4.804 | gamma 0.4168 | ecut 11596.7 | hcut 11620.0 | best_rep 4780 | S 6.1431 | rep_t 267.2s | total_t 267.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1169/2000 | beta 4.81 | gamma 0.4163 | ecut 11596.8 | hcut 11620.0 | best_rep 4780 | S 6.1069 | rep_t 267.4s | total_t 267.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1170/2000 | beta 4.816 | gamma 0.4158 | ecut 11596.9 | hcut 11620.0 | best_rep 4780 | S 6.0711 | rep_t 267.6s | total_t 267.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1171/2000 | beta 4.822 | gamma 0.4153 | ecut 11596.9 | hcut 11620.0 | best_rep 4780 | S 6.0355 | rep_t 267.9s | total_t 267.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1172/2000 | beta 4.827 | gamma 0.4148 | ecut 11597.0 | hcut 11620.0 | best_rep 4780 | S 6.0002 | rep_t 268.1s | total_t 268.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1173/2000 | beta 4.833 | gamma 0.4143 | ecut 11597.1 | hcut 11620.0 | best_rep 4780 | S 5.9652 | rep_t 268.3s | total_t 268.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1174/2000 | beta 4.839 | gamma 0.4138 | ecut 11597.1 | hcut 11620.0 | best_rep 4780 | S 5.9305 | rep_t 268.6s | total_t 268.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1175/2000 | beta 4.845 | gamma 0.4133 | ecut 11597.2 | hcut 11620.0 | best_rep 4780 | S 5.8961 | rep_t 268.9s | total_t 268.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1176/2000 | beta 4.851 | gamma 0.4128 | ecut 11597.3 | hcut 11620.0 | best_rep 4780 | S 5.8620 | rep_t 269.1s | total_t 269.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1177/2000 | beta 4.857 | gamma 0.4123 | ecut 11597.4 | hcut 11620.0 | best_rep 4780 | S 5.8281 | rep_t 269.4s | total_t 269.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1178/2000 | beta 4.863 | gamma 0.4118 | ecut 11597.5 | hcut 11620.0 | best_rep 4780 | S 5.7945 | rep_t 269.6s | total_t 269.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1179/2000 | beta 4.869 | gamma 0.4113 | ecut 11597.5 | hcut 11620.0 | best_rep 4780 | S 5.7612 | rep_t 269.8s | total_t 269.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1180/2000 | beta 4.874 | gamma 0.4108 | ecut 11597.6 | hcut 11620.0 | best_rep 4780 | S 5.7282 | rep_t 270.0s | total_t 270.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1181/2000 | beta 4.88 | gamma 0.4103 | ecut 11597.7 | hcut 11620.0 | best_rep 4780 | S 5.6954 | rep_t 270.3s | total_t 270.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1182/2000 | beta 4.886 | gamma 0.4098 | ecut 11597.7 | hcut 11620.0 | best_rep 4780 | S 5.6630 | rep_t 270.5s | total_t 270.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1183/2000 | beta 4.892 | gamma 0.4093 | ecut 11597.8 | hcut 11620.0 | best_rep 4780 | S 5.6307 | rep_t 270.7s | total_t 270.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1184/2000 | beta 4.898 | gamma 0.4088 | ecut 11597.9 | hcut 11620.0 | best_rep 4780 | S 5.5988 | rep_t 270.9s | total_t 270.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1185/2000 | beta 4.904 | gamma 0.4083 | ecut 11598.0 | hcut 11620.0 | best_rep 4780 | S 5.5671 | rep_t 271.1s | total_t 271.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1186/2000 | beta 4.91 | gamma 0.4078 | ecut 11598.0 | hcut 11620.0 | best_rep 4780 | S 5.5357 | rep_t 271.3s | total_t 271.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1187/2000 | beta 4.916 | gamma 0.4073 | ecut 11598.1 | hcut 11620.0 | best_rep 4780 | S 5.5045 | rep_t 271.5s | total_t 271.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1188/2000 | beta 4.922 | gamma 0.4068 | ecut 11598.2 | hcut 11620.0 | best_rep 4780 | S 5.4736 | rep_t 271.7s | total_t 271.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1189/2000 | beta 4.929 | gamma 0.4063 | ecut 11598.2 | hcut 11620.0 | best_rep 4780 | S 5.4429 | rep_t 271.9s | total_t 271.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1190/2000 | beta 4.935 | gamma 0.4058 | ecut 11598.3 | hcut 11620.0 | best_rep 4780 | S 5.4125 | rep_t 272.1s | total_t 272.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1191/2000 | beta 4.941 | gamma 0.4053 | ecut 11598.4 | hcut 11620.0 | best_rep 4780 | S 5.3823 | rep_t 272.3s | total_t 272.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1192/2000 | beta 4.947 | gamma 0.4048 | ecut 11598.5 | hcut 11620.0 | best_rep 4780 | S 5.3524 | rep_t 272.5s | total_t 272.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1193/2000 | beta 4.953 | gamma 0.4043 | ecut 11598.5 | hcut 11620.0 | best_rep 4780 | S 5.3228 | rep_t 272.7s | total_t 272.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1194/2000 | beta 4.959 | gamma 0.4038 | ecut 11598.6 | hcut 11620.0 | best_rep 4780 | S 5.2933 | rep_t 272.9s | total_t 272.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1195/2000 | beta 4.965 | gamma 0.4033 | ecut 11598.7 | hcut 11620.0 | best_rep 4780 | S 5.2641 | rep_t 273.2s | total_t 273.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1196/2000 | beta 4.971 | gamma 0.4028 | ecut 11598.7 | hcut 11620.0 | best_rep 4780 | S 5.2352 | rep_t 273.4s | total_t 273.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1197/2000 | beta 4.978 | gamma 0.4023 | ecut 11598.8 | hcut 11620.0 | best_rep 4780 | S 5.2065 | rep_t 273.6s | total_t 273.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1198/2000 | beta 4.984 | gamma 0.4018 | ecut 11598.9 | hcut 11620.0 | best_rep 4780 | S 5.1780 | rep_t 274.0s | total_t 274.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1199/2000 | beta 4.99 | gamma 0.4013 | ecut 11598.9 | hcut 11620.0 | best_rep 4780 | S 5.1497 | rep_t 274.4s | total_t 274.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1200/2000 | beta 4.996 | gamma 0.4008 | ecut 11599.0 | hcut 11620.0 | best_rep 4780 | S 5.1217 | rep_t 274.6s | total_t 274.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1201/2000 | beta 5.003 | gamma 0.4003 | ecut 11599.1 | hcut 11620.0 | best_rep 4780 | S 5.0939 | rep_t 274.8s | total_t 274.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1202/2000 | beta 5.009 | gamma 0.3998 | ecut 11599.1 | hcut 11620.0 | best_rep 4780 | S 5.0663 | rep_t 275.0s | total_t 275.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1203/2000 | beta 5.015 | gamma 0.3993 | ecut 11599.2 | hcut 11620.0 | best_rep 4780 | S 5.0390 | rep_t 275.2s | total_t 275.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1204/2000 | beta 5.021 | gamma 0.3988 | ecut 11599.3 | hcut 11620.0 | best_rep 4780 | S 5.0118 | rep_t 275.4s | total_t 275.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1205/2000 | beta 5.028 | gamma 0.3983 | ecut 11599.4 | hcut 11620.0 | best_rep 4780 | S 4.9849 | rep_t 275.6s | total_t 275.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1206/2000 | beta 5.034 | gamma 0.3978 | ecut 11599.4 | hcut 11620.0 | best_rep 4780 | S 4.9582 | rep_t 275.9s | total_t 275.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1207/2000 | beta 5.04 | gamma 0.3973 | ecut 11599.5 | hcut 11620.0 | best_rep 4780 | S 4.9317 | rep_t 276.1s | total_t 276.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1208/2000 | beta 5.047 | gamma 0.3968 | ecut 11599.6 | hcut 11620.0 | best_rep 4780 | S 4.9054 | rep_t 276.3s | total_t 276.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1209/2000 | beta 5.053 | gamma 0.3963 | ecut 11599.6 | hcut 11620.0 | best_rep 4780 | S 4.8793 | rep_t 276.5s | total_t 276.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1210/2000 | beta 5.06 | gamma 0.3958 | ecut 11599.7 | hcut 11620.0 | best_rep 4780 | S 4.8534 | rep_t 276.7s | total_t 276.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1211/2000 | beta 5.066 | gamma 0.3953 | ecut 11599.7 | hcut 11620.0 | best_rep 4780 | S 4.8278 | rep_t 276.9s | total_t 276.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1212/2000 | beta 5.072 | gamma 0.3948 | ecut 11599.8 | hcut 11620.0 | best_rep 4780 | S 4.8023 | rep_t 277.1s | total_t 277.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1213/2000 | beta 5.079 | gamma 0.3943 | ecut 11599.9 | hcut 11620.0 | best_rep 4780 | S 4.7770 | rep_t 277.3s | total_t 277.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1214/2000 | beta 5.085 | gamma 0.3938 | ecut 11599.9 | hcut 11620.0 | best_rep 4780 | S 4.7520 | rep_t 277.5s | total_t 277.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1215/2000 | beta 5.092 | gamma 0.3933 | ecut 11600.0 | hcut 11620.0 | best_rep 4780 | S 4.7271 | rep_t 277.8s | total_t 277.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1216/2000 | beta 5.098 | gamma 0.3928 | ecut 11600.1 | hcut 11620.0 | best_rep 4780 | S 4.7024 | rep_t 278.0s | total_t 278.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1217/2000 | beta 5.105 | gamma 0.3923 | ecut 11600.1 | hcut 11620.0 | best_rep 4780 | S 4.6779 | rep_t 278.2s | total_t 278.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1218/2000 | beta 5.111 | gamma 0.3918 | ecut 11600.2 | hcut 11620.0 | best_rep 4780 | S 4.6536 | rep_t 278.4s | total_t 278.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1219/2000 | beta 5.118 | gamma 0.3913 | ecut 11600.2 | hcut 11620.0 | best_rep 4780 | S 4.6295 | rep_t 278.6s | total_t 278.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1220/2000 | beta 5.124 | gamma 0.3908 | ecut 11600.3 | hcut 11620.0 | best_rep 4780 | S 4.6056 | rep_t 278.8s | total_t 278.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1221/2000 | beta 5.131 | gamma 0.3903 | ecut 11600.4 | hcut 11620.0 | best_rep 4780 | S 4.5818 | rep_t 279.0s | total_t 279.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1222/2000 | beta 5.138 | gamma 0.3898 | ecut 11600.4 | hcut 11620.0 | best_rep 4780 | S 4.5583 | rep_t 279.2s | total_t 279.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1223/2000 | beta 5.144 | gamma 0.3893 | ecut 11600.5 | hcut 11620.0 | best_rep 4780 | S 4.5349 | rep_t 279.4s | total_t 279.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1224/2000 | beta 5.151 | gamma 0.3888 | ecut 11600.5 | hcut 11620.0 | best_rep 4780 | S 4.5117 | rep_t 279.6s | total_t 279.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1225/2000 | beta 5.157 | gamma 0.3883 | ecut 11600.6 | hcut 11620.0 | best_rep 4780 | S 4.4887 | rep_t 279.8s | total_t 279.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1226/2000 | beta 5.164 | gamma 0.3878 | ecut 11600.7 | hcut 11620.0 | best_rep 4780 | S 4.4659 | rep_t 280.0s | total_t 280.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1227/2000 | beta 5.171 | gamma 0.3873 | ecut 11600.7 | hcut 11620.0 | best_rep 4780 | S 4.4432 | rep_t 280.1s | total_t 280.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1228/2000 | beta 5.177 | gamma 0.3868 | ecut 11600.8 | hcut 11620.0 | best_rep 4780 | S 4.4208 | rep_t 280.4s | total_t 280.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1229/2000 | beta 5.184 | gamma 0.3863 | ecut 11600.9 | hcut 11620.0 | best_rep 4780 | S 4.3984 | rep_t 280.6s | total_t 280.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1230/2000 | beta 5.191 | gamma 0.3858 | ecut 11600.9 | hcut 11620.0 | best_rep 4780 | S 4.3763 | rep_t 280.9s | total_t 280.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1231/2000 | beta 5.198 | gamma 0.3853 | ecut 11601.0 | hcut 11620.0 | best_rep 4780 | S 4.3544 | rep_t 281.0s | total_t 281.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1232/2000 | beta 5.204 | gamma 0.3848 | ecut 11601.0 | hcut 11620.0 | best_rep 4780 | S 4.3326 | rep_t 281.2s | total_t 281.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1233/2000 | beta 5.211 | gamma 0.3843 | ecut 11601.1 | hcut 11620.0 | best_rep 4780 | S 4.3110 | rep_t 281.4s | total_t 281.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1234/2000 | beta 5.218 | gamma 0.3838 | ecut 11601.2 | hcut 11620.0 | best_rep 4780 | S 4.2895 | rep_t 281.6s | total_t 281.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1235/2000 | beta 5.225 | gamma 0.3833 | ecut 11601.2 | hcut 11620.0 | best_rep 4780 | S 4.2682 | rep_t 281.8s | total_t 281.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1236/2000 | beta 5.232 | gamma 0.3828 | ecut 11601.3 | hcut 11620.0 | best_rep 4780 | S 4.2471 | rep_t 282.0s | total_t 282.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1237/2000 | beta 5.238 | gamma 0.3823 | ecut 11601.3 | hcut 11620.0 | best_rep 4780 | S 4.2262 | rep_t 282.2s | total_t 282.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1238/2000 | beta 5.245 | gamma 0.3818 | ecut 11601.4 | hcut 11620.0 | best_rep 4780 | S 4.2054 | rep_t 282.4s | total_t 282.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1239/2000 | beta 5.252 | gamma 0.3813 | ecut 11601.4 | hcut 11620.0 | best_rep 4780 | S 4.1847 | rep_t 282.6s | total_t 282.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1240/2000 | beta 5.259 | gamma 0.3808 | ecut 11601.5 | hcut 11620.0 | best_rep 4780 | S 4.1642 | rep_t 282.9s | total_t 282.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1241/2000 | beta 5.266 | gamma 0.3803 | ecut 11601.6 | hcut 11620.0 | best_rep 4780 | S 4.1439 | rep_t 283.1s | total_t 283.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1242/2000 | beta 5.273 | gamma 0.3798 | ecut 11601.6 | hcut 11620.0 | best_rep 4780 | S 4.1238 | rep_t 283.3s | total_t 283.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1243/2000 | beta 5.28 | gamma 0.3793 | ecut 11601.7 | hcut 11620.0 | best_rep 4780 | S 4.1038 | rep_t 283.5s | total_t 283.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1244/2000 | beta 5.287 | gamma 0.3788 | ecut 11601.7 | hcut 11620.0 | best_rep 4780 | S 4.0839 | rep_t 283.7s | total_t 283.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1245/2000 | beta 5.294 | gamma 0.3783 | ecut 11601.8 | hcut 11620.0 | best_rep 4780 | S 4.0642 | rep_t 283.8s | total_t 283.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1246/2000 | beta 5.301 | gamma 0.3778 | ecut 11601.8 | hcut 11620.0 | best_rep 4780 | S 4.0446 | rep_t 284.0s | total_t 284.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1247/2000 | beta 5.308 | gamma 0.3773 | ecut 11601.9 | hcut 11620.0 | best_rep 4780 | S 4.0252 | rep_t 284.2s | total_t 284.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1248/2000 | beta 5.315 | gamma 0.3768 | ecut 11602.0 | hcut 11620.0 | best_rep 4780 | S 4.0059 | rep_t 284.4s | total_t 284.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1249/2000 | beta 5.322 | gamma 0.3763 | ecut 11602.0 | hcut 11620.0 | best_rep 4780 | S 3.9868 | rep_t 284.6s | total_t 284.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1250/2000 | beta 5.329 | gamma 0.3758 | ecut 11602.1 | hcut 11620.0 | best_rep 4780 | S 3.9679 | rep_t 284.9s | total_t 284.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1251/2000 | beta 5.336 | gamma 0.3753 | ecut 11602.1 | hcut 11620.0 | best_rep 4780 | S 3.9490 | rep_t 285.1s | total_t 285.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1252/2000 | beta 5.343 | gamma 0.3748 | ecut 11602.2 | hcut 11620.0 | best_rep 4780 | S 3.9303 | rep_t 285.3s | total_t 285.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1253/2000 | beta 5.351 | gamma 0.3743 | ecut 11602.2 | hcut 11620.0 | best_rep 4780 | S 3.9118 | rep_t 285.5s | total_t 285.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1254/2000 | beta 5.358 | gamma 0.3738 | ecut 11602.3 | hcut 11620.0 | best_rep 4780 | S 3.8934 | rep_t 285.7s | total_t 285.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1255/2000 | beta 5.365 | gamma 0.3733 | ecut 11602.3 | hcut 11620.0 | best_rep 4780 | S 3.8751 | rep_t 285.9s | total_t 285.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1256/2000 | beta 5.372 | gamma 0.3728 | ecut 11602.4 | hcut 11620.0 | best_rep 4780 | S 3.8569 | rep_t 286.1s | total_t 286.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1257/2000 | beta 5.379 | gamma 0.3723 | ecut 11602.5 | hcut 11620.0 | best_rep 4780 | S 3.8389 | rep_t 286.2s | total_t 286.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1258/2000 | beta 5.387 | gamma 0.3718 | ecut 11602.5 | hcut 11620.0 | best_rep 4780 | S 3.8210 | rep_t 286.4s | total_t 286.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1259/2000 | beta 5.394 | gamma 0.3713 | ecut 11602.6 | hcut 11620.0 | best_rep 4780 | S 3.8033 | rep_t 286.6s | total_t 286.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1260/2000 | beta 5.401 | gamma 0.3708 | ecut 11602.6 | hcut 11620.0 | best_rep 4780 | S 3.7857 | rep_t 286.8s | total_t 286.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1261/2000 | beta 5.409 | gamma 0.3703 | ecut 11602.7 | hcut 11620.0 | best_rep 4780 | S 3.7682 | rep_t 287.0s | total_t 287.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1262/2000 | beta 5.416 | gamma 0.3698 | ecut 11602.7 | hcut 11620.0 | best_rep 4780 | S 3.7508 | rep_t 287.2s | total_t 287.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1263/2000 | beta 5.423 | gamma 0.3693 | ecut 11602.8 | hcut 11620.0 | best_rep 4780 | S 3.7336 | rep_t 287.4s | total_t 287.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1264/2000 | beta 5.431 | gamma 0.3688 | ecut 11602.8 | hcut 11620.0 | best_rep 4780 | S 3.7165 | rep_t 287.6s | total_t 287.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1265/2000 | beta 5.438 | gamma 0.3683 | ecut 11602.9 | hcut 11620.0 | best_rep 4780 | S 3.6995 | rep_t 287.8s | total_t 287.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1266/2000 | beta 5.445 | gamma 0.3678 | ecut 11602.9 | hcut 11620.0 | best_rep 4780 | S 3.6827 | rep_t 288.0s | total_t 288.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1267/2000 | beta 5.453 | gamma 0.3673 | ecut 11603.0 | hcut 11620.0 | best_rep 4780 | S 3.6659 | rep_t 288.2s | total_t 288.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1268/2000 | beta 5.46 | gamma 0.3668 | ecut 11603.0 | hcut 11620.0 | best_rep 4780 | S 3.6493 | rep_t 288.5s | total_t 288.5s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1269/2000 | beta 5.468 | gamma 0.3663 | ecut 11603.1 | hcut 11620.0 | best_rep 4780 | S 3.6328 | rep_t 288.7s | total_t 288.7s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1270/2000 | beta 5.475 | gamma 0.3658 | ecut 11603.2 | hcut 11620.0 | best_rep 4780 | S 3.6165 | rep_t 288.9s | total_t 288.9s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1271/2000 | beta 5.483 | gamma 0.3653 | ecut 11603.2 | hcut 11620.0 | best_rep 4780 | S 3.6002 | rep_t 289.1s | total_t 289.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1272/2000 | beta 5.49 | gamma 0.3648 | ecut 11603.3 | hcut 11620.0 | best_rep 4780 | S 3.5841 | rep_t 289.4s | total_t 289.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1273/2000 | beta 5.498 | gamma 0.3643 | ecut 11603.3 | hcut 11620.0 | best_rep 4780 | S 3.5680 | rep_t 289.6s | total_t 289.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1274/2000 | beta 5.505 | gamma 0.3638 | ecut 11603.4 | hcut 11620.0 | best_rep 4780 | S 3.5521 | rep_t 289.8s | total_t 289.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1275/2000 | beta 5.513 | gamma 0.3633 | ecut 11603.4 | hcut 11620.0 | best_rep 4780 | S 3.5364 | rep_t 290.0s | total_t 290.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1276/2000 | beta 5.521 | gamma 0.3628 | ecut 11603.5 | hcut 11620.0 | best_rep 4780 | S 3.5207 | rep_t 290.2s | total_t 290.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1277/2000 | beta 5.528 | gamma 0.3623 | ecut 11603.5 | hcut 11620.0 | best_rep 4780 | S 3.5051 | rep_t 290.4s | total_t 290.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1278/2000 | beta 5.536 | gamma 0.3618 | ecut 11603.6 | hcut 11620.0 | best_rep 4780 | S 3.4897 | rep_t 290.8s | total_t 290.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1279/2000 | beta 5.544 | gamma 0.3613 | ecut 11603.6 | hcut 11620.0 | best_rep 4780 | S 3.4743 | rep_t 291.0s | total_t 291.0s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1280/2000 | beta 5.551 | gamma 0.3608 | ecut 11603.7 | hcut 11620.0 | best_rep 4780 | S 3.4591 | rep_t 291.2s | total_t 291.2s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1281/2000 | beta 5.559 | gamma 0.3603 | ecut 11603.7 | hcut 11620.0 | best_rep 4780 | S 3.4440 | rep_t 291.4s | total_t 291.4s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1282/2000 | beta 5.567 | gamma 0.3598 | ecut 11603.8 | hcut 11620.0 | best_rep 4780 | S 3.4290 | rep_t 291.6s | total_t 291.6s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1283/2000 | beta 5.574 | gamma 0.3593 | ecut 11603.8 | hcut 11620.0 | best_rep 4780 | S 3.4141 | rep_t 291.8s | total_t 291.8s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1284/2000 | beta 5.582 | gamma 0.3588 | ecut 11603.9 | hcut 11620.0 | best_rep 4780 | S 3.3993 | rep_t 292.1s | total_t 292.1s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1285/2000 | beta 5.59 | gamma 0.3583 | ecut 11603.9 | hcut 11620.0 | best_rep 4780 | S 3.3846 | rep_t 292.3s | total_t 292.3s
# G2 | rep 1/1 | gap 0.0 | acc 100.0000% | step 1286/2000 | beta 5.598 | gamma 0.3578 | ecut 11604.0 | hcut 11620.0 | best_rep 4780 | S 3.3700 | rep_t 292.5s | total_t 292.5s
# ...
# G28 | rep 1/1 | gap 11.0 | acc 99.6665% | step 950/2000 | beta 3.807 | gamma 0.5257 | ecut 3134.1 | hcut 3287.0 | best_rep 7310 | S 70.1900 | rep_t 607.6s | total_t 607.6s
# G28 | rep 1/1 | gap 11.0 | acc 99.6665% | step 1000/2000 | beta 3.997 | gamma 0.5007 | ecut 3161.5 | hcut 3287.0 | best_rep 7310 | S 48.5223 | rep_t 639.5s | total_t 639.5s
# G28 | rep 1/1 | gap 11.0 | acc 99.6665% | step 1050/2000 | beta 4.208 | gamma 0.4758 | ecut 3181.3 | hcut 3287.0 | best_rep 7310 | S 34.1505 | rep_t 671.9s | total_t 671.9s
# G28 | rep 1/1 | gap 11.0 | acc 99.6665% | step 1100/2000 | beta 4.441 | gamma 0.4508 | ecut 3196.3 | hcut 3287.0 | best_rep 7310 | S 24.7105 | rep_t 704.4s | total_t 704.4s
# G28 | rep 1/1 | gap 11.0 | acc 99.6665% | step 1150/2000 | beta 4.703 | gamma 0.4258 | ecut 3208.3 | hcut 3287.0 | best_rep 7310 | S 18.5397 | rep_t 736.3s | total_t 736.3s
# G28 | rep 1/1 | gap 11.0 | acc 99.6665% | step 1200/2000 | beta 4.996 | gamma 0.4008 | ecut 3218.3 | hcut 3287.0 | best_rep 7310 | S 14.4707 | rep_t 768.1s | total_t 768.1s
# G28 | rep 1/1 | gap 11.0 | acc 99.6665% | step 1250/2000 | beta 5.329 | gamma 0.3758 | ecut 3227.1 | hcut 3287.0 | best_rep 7310 | S 11.7149 | rep_t 800.4s | total_t 800.4s
# G28 | rep 1/1 | gap 11.0 | acc 99.6665% | step 1300/2000 | beta 5.71 | gamma 0.3508 | ecut 3235.0 | hcut 3287.0 | best_rep 7310 | S 9.7862 | rep_t 832.6s | total_t 832.6s
# G28 | rep 1/1 | gap 11.0 | acc 99.6665% | step 1350/2000 | beta 6.149 | gamma 0.3258 | ecut 3242.1 | hcut 3287.0 | best_rep 7310 | S 8.3937 | rep_t 864.4s | total_t 864.4s
# G28 | rep 1/1 | gap 11.0 | acc 99.6665% | step 1400/2000 | beta 6.661 | gamma 0.3008 | ecut 3248.6 | hcut 3287.0 | best_rep 7310 | S 7.3537 | rep_t 896.3s | total_t 896.3s
# G28 | rep 1/1 | gap 11.0 | acc 99.6665% | step 1450/2000 | beta 7.266 | gamma 0.2759 | ecut 3254.5 | hcut 3287.0 | best_rep 7310 | S 6.5563 | rep_t 928.5s | total_t 928.5s
# G28 | rep 1/1 | gap 10.0 | acc 99.6968% | step 1500/2000 | beta 7.992 | gamma 0.2509 | ecut 3260.6 | hcut 3288.0 | best_rep 7310 | S 5.9328 | rep_t 960.3s | total_t 960.3s
# G28 | rep 1/1 | gap 10.0 | acc 99.6968% | step 1550/2000 | beta 8.88 | gamma 0.2259 | ecut 3265.9 | hcut 3288.0 | best_rep 7310 | S 5.4385 | rep_t 992.1s | total_t 992.1s
# G28 | rep 1/1 | gap 10.0 | acc 99.6968% | step 1600/2000 | beta 9.989 | gamma 0.2009 | ecut 3270.3 | hcut 3288.0 | best_rep 7310 | S 5.0416 | rep_t 1025.4s | total_t 1025.4s
# G28 | rep 1/1 | gap 10.0 | acc 99.6968% | step 1650/2000 | beta 11.41 | gamma 0.1759 | ecut 3274.3 | hcut 3288.0 | best_rep 7310 | S 4.7187 | rep_t 1057.1s | total_t 1057.1s
# G28 | rep 1/1 | gap 10.0 | acc 99.6968% | step 1700/2000 | beta 13.31 | gamma 0.1509 | ecut 3277.7 | hcut 3288.0 | best_rep 7310 | S 4.4517 | rep_t 1089.0s | total_t 1089.0s
# G28 | rep 1/1 | gap 10.0 | acc 99.6968% | step 1750/2000 | beta 15.97 | gamma 0.1259 | ecut 3280.7 | hcut 3288.0 | best_rep 7310 | S 4.2271 | rep_t 1120.8s | total_t 1120.8s
# G28 | rep 1/1 | gap 10.0 | acc 99.6968% | step 1800/2000 | beta 19.96 | gamma 0.101 | ecut 3283.2 | hcut 3288.0 | best_rep 7310 | S 4.0350 | rep_t 1152.7s | total_t 1152.7s
# G28 | rep 1/1 | gap 10.0 | acc 99.6968% | step 1850/2000 | beta 26.6 | gamma 0.07596 | ecut 3285.1 | hcut 3288.0 | best_rep 7310 | S 3.8666 | rep_t 1184.5s | total_t 1184.5s
# G28 | rep 1/1 | gap 10.0 | acc 99.6968% | step 1900/2000 | beta 39.86 | gamma 0.05098 | ecut 3286.5 | hcut 3288.0 | best_rep 7310 | S 3.7111 | rep_t 1216.4s | total_t 1216.4s
# G28 | rep 1/1 | gap 10.0 | acc 99.6968% | step 1950/2000 | beta 79.46 | gamma 0.02599 | ecut 3287.3 | hcut 3288.0 | best_rep 7310 | S 3.5708 | rep_t 1248.5s | total_t 1248.5s
# G28 | rep 1/1 | gap 10.0 | acc 99.6968% | step 2000/2000 | beta 1.25e+04 | gamma 0.001 | ecut 3287.7 | hcut 3288.0 | best_rep 7310 | S 3.4260 | rep_t 1280.5s | total_t 1280.5s
# FINISHED G28
# best = 3288 | gap = 10 | gap% = 0.3032% | acc = 99.6968% | time = 1280.50s
#
# ==============================================================================================================
# STARTING G29 | historical best = 3405
# ==============================================================================================================
# Starting G29 | historical best = 3405
# G29 | rep 1/1 | gap 3179.0 | acc 6.6373% | step 1/2000 | beta 2 | gamma 1 | ecut 40.0 | hcut 226.0 | best_rep 1075 | S 1386.1924 | rep_t 0.7s | total_t 0.7s
# G29 | rep 1/1 | gap 3063.0 | acc 10.0441% | step 50/2000 | beta 2.05 | gamma 0.9755 | ecut 40.0 | hcut 236.0 | best_rep 4689 | S 1386.0259 | rep_t 31.8s | total_t 31.8s
# G29 | rep 1/1 | gap 2842.0 | acc 16.5345% | step 100/2000 | beta 2.104 | gamma 0.9505 | ecut 40.0 | hcut 56.0 | best_rep 9309 | S 1385.5801 | rep_t 64.0s | total_t 64.0s
# G29 | rep 1/1 | gap 2842.0 | acc 16.5345% | step 150/2000 | beta 2.161 | gamma 0.9255 | ecut 40.0 | hcut 369.0 | best_rep 9309 | S 1384.4182 | rep_t 96.0s | total_t 96.0s
# G29 | rep 1/1 | gap 2842.0 | acc 16.5345% | step 200/2000 | beta 2.221 | gamma 0.9005 | ecut 40.0 | hcut 411.0 | best_rep 9309 | S 1381.4673 | rep_t 127.8s | total_t 127.8s
# G29 | rep 1/1 | gap 2842.0 | acc 16.5345% | step 250/2000 | beta 2.285 | gamma 0.8756 | ecut 40.0 | hcut 68.0 | best_rep 9309 | S 1374.2664 | rep_t 159.6s | total_t 159.6s
# G29 | rep 1/1 | gap 2842.0 | acc 16.5345% | step 300/2000 | beta 2.352 | gamma 0.8506 | ecut 40.0 | hcut 2.0 | best_rep 9309 | S 1357.7158 | rep_t 191.4s | total_t 191.4s
# G29 | rep 1/1 | gap 407.0 | acc 88.0470% | step 350/2000 | beta 2.423 | gamma 0.8256 | ecut 42.5 | hcut 2998.0 | best_rep 3096 | S 1322.8052 | rep_t 223.3s | total_t 223.3s
# G29 | rep 1/1 | gap 88.0 | acc 97.4156% | step 400/2000 | beta 2.499 | gamma 0.8006 | ecut 306.6 | hcut 3316.0 | best_rep 6606 | S 1259.1910 | rep_t 255.3s | total_t 255.3s
# G29 | rep 1/1 | gap 78.0 | acc 97.7093% | step 450/2000 | beta 2.579 | gamma 0.7756 | ecut 680.4 | hcut 3327.0 | best_rep 3595 | S 1161.4521 | rep_t 287.1s | total_t 287.1s
# G29 | rep 1/1 | gap 71.0 | acc 97.9148% | step 500/2000 | beta 2.665 | gamma 0.7506 | ecut 1147.8 | hcut 3334.0 | best_rep 3595 | S 1031.5081 | rep_t 318.9s | total_t 318.9s
# G29 | rep 1/1 | gap 66.0 | acc 98.0617% | step 550/2000 | beta 2.757 | gamma 0.7256 | ecut 1631.1 | hcut 3339.0 | best_rep 3595 | S 879.4047 | rep_t 350.7s | total_t 350.7s
# G29 | rep 1/1 | gap 58.0 | acc 98.2966% | step 600/2000 | beta 2.856 | gamma 0.7006 | ecut 2068.2 | hcut 3347.0 | best_rep 8562 | S 718.9289 | rep_t 382.5s | total_t 382.5s
# G29 | rep 1/1 | gap 54.0 | acc 98.4141% | step 650/2000 | beta 2.961 | gamma 0.6757 | ecut 2427.6 | hcut 3351.0 | best_rep 5674 | S 563.6068 | rep_t 414.3s | total_t 414.3s
# G29 | rep 1/1 | gap 45.0 | acc 98.6784% | step 700/2000 | beta 3.075 | gamma 0.6507 | ecut 2699.9 | hcut 3360.0 | best_rep 7427 | S 424.2780 | rep_t 446.5s | total_t 446.5s
# G29 | rep 1/1 | gap 40.0 | acc 98.8253% | step 750/2000 | beta 3.198 | gamma 0.6257 | ecut 2894.6 | hcut 3365.0 | best_rep 462 | S 307.8914 | rep_t 478.3s | total_t 478.3s
# G29 | rep 1/1 | gap 35.0 | acc 98.9721% | step 800/2000 | beta 3.331 | gamma 0.6007 | ecut 3029.9 | hcut 3370.0 | best_rep 8174 | S 217.0479 | rep_t 510.5s | total_t 510.5s
# G29 | rep 1/1 | gap 35.0 | acc 98.9721% | step 850/2000 | beta 3.476 | gamma 0.5757 | ecut 3118.7 | hcut 3370.0 | best_rep 8174 | S 150.1759 | rep_t 542.3s | total_t 542.3s
# G29 | rep 1/1 | gap 34.0 | acc 99.0015% | step 900/2000 | beta 3.634 | gamma 0.5507 | ecut 3177.0 | hcut 3371.0 | best_rep 2124 | S 103.0167 | rep_t 574.2s | total_t 574.2s
# G29 | rep 1/1 | gap 34.0 | acc 99.0015% | step 950/2000 | beta 3.807 | gamma 0.5257 | ecut 3216.8 | hcut 3371.0 | best_rep 2124 | S 70.6772 | rep_t 606.4s | total_t 606.4s
# G29 | rep 1/1 | gap 34.0 | acc 99.0015% | step 1000/2000 | beta 3.997 | gamma 0.5007 | ecut 3244.3 | hcut 3371.0 | best_rep 2124 | S 48.9010 | rep_t 638.5s | total_t 638.5s
# G29 | rep 1/1 | gap 34.0 | acc 99.0015% | step 1050/2000 | beta 4.208 | gamma 0.4758 | ecut 3264.2 | hcut 3371.0 | best_rep 2124 | S 34.4563 | rep_t 671.6s | total_t 671.6s
# G29 | rep 1/1 | gap 34.0 | acc 99.0015% | step 1100/2000 | beta 4.441 | gamma 0.4508 | ecut 3279.4 | hcut 3371.0 | best_rep 2124 | S 24.9817 | rep_t 714.9s | total_t 714.9s
# G29 | rep 1/1 | gap 34.0 | acc 99.0015% | step 1150/2000 | beta 4.703 | gamma 0.4258 | ecut 3291.5 | hcut 3371.0 | best_rep 2124 | S 18.7736 | rep_t 762.3s | total_t 762.3s
# G29 | rep 1/1 | gap 34.0 | acc 99.0015% | step 1200/2000 | beta 4.996 | gamma 0.4008 | ecut 3301.6 | hcut 3371.0 | best_rep 2124 | S 14.6681 | rep_t 813.9s | total_t 813.9s
# G29 | rep 1/1 | gap 34.0 | acc 99.0015% | step 1250/2000 | beta 5.329 | gamma 0.3758 | ecut 3310.5 | hcut 3371.0 | best_rep 2124 | S 11.8928 | rep_t 865.0s | total_t 865.0s
# G29 | rep 1/1 | gap 34.0 | acc 99.0015% | step 1300/2000 | beta 5.71 | gamma 0.3508 | ecut 3318.5 | hcut 3371.0 | best_rep 2124 | S 9.9512 | rep_t 905.2s | total_t 905.2s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 1350/2000 | beta 6.149 | gamma 0.3258 | ecut 3326.6 | hcut 3372.0 | best_rep 2124 | S 8.5348 | rep_t 945.5s | total_t 945.5s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 1400/2000 | beta 6.661 | gamma 0.3008 | ecut 3333.2 | hcut 3372.0 | best_rep 2124 | S 7.4880 | rep_t 983.5s | total_t 983.5s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 1450/2000 | beta 7.266 | gamma 0.2759 | ecut 3339.2 | hcut 3372.0 | best_rep 2124 | S 6.6758 | rep_t 1031.4s | total_t 1031.4s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 1500/2000 | beta 7.992 | gamma 0.2509 | ecut 3344.7 | hcut 3372.0 | best_rep 2124 | S 6.0456 | rep_t 1069.0s | total_t 1069.0s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 1550/2000 | beta 8.88 | gamma 0.2259 | ecut 3349.7 | hcut 3372.0 | best_rep 2124 | S 5.5454 | rep_t 1110.0s | total_t 1110.0s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 1600/2000 | beta 9.989 | gamma 0.2009 | ecut 3354.2 | hcut 3372.0 | best_rep 2124 | S 5.1418 | rep_t 1148.7s | total_t 1148.7s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 1650/2000 | beta 11.41 | gamma 0.1759 | ecut 3358.2 | hcut 3372.0 | best_rep 2124 | S 4.8713 | rep_t 1190.3s | total_t 1190.3s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 1700/2000 | beta 13.31 | gamma 0.1509 | ecut 3361.7 | hcut 3372.0 | best_rep 2124 | S 4.5961 | rep_t 1227.2s | total_t 1227.2s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 1750/2000 | beta 15.97 | gamma 0.1259 | ecut 3364.6 | hcut 3372.0 | best_rep 2124 | S 4.4082 | rep_t 1267.1s | total_t 1267.1s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 1800/2000 | beta 19.96 | gamma 0.101 | ecut 3367.1 | hcut 3372.0 | best_rep 2124 | S 4.2026 | rep_t 1314.6s | total_t 1314.6s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 1850/2000 | beta 26.6 | gamma 0.07596 | ecut 3369.0 | hcut 3372.0 | best_rep 2124 | S 4.0420 | rep_t 1355.0s | total_t 1355.0s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 1900/2000 | beta 39.86 | gamma 0.05098 | ecut 3370.4 | hcut 3372.0 | best_rep 2124 | S 3.8806 | rep_t 1391.6s | total_t 1391.6s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 1950/2000 | beta 79.46 | gamma 0.02599 | ecut 3371.3 | hcut 3372.0 | best_rep 2124 | S 3.7253 | rep_t 1428.1s | total_t 1428.1s
# G29 | rep 1/1 | gap 33.0 | acc 99.0308% | step 2000/2000 | beta 1.25e+04 | gamma 0.001 | ecut 3371.6 | hcut 3372.0 | best_rep 2124 | S 3.5716 | rep_t 1464.3s | total_t 1464.3s
# FINISHED G29
# best = 3372 | gap = 33 | gap% = 0.9692% | acc = 99.0308% | time = 1464.33s
#
# ==============================================================================================================
# STARTING G30 | historical best = 3413
# ==============================================================================================================
# Starting G30 | historical best = 3413
# G30 | rep 1/1 | gap 3152.0 | acc 7.6472% | step 1/2000 | beta 2 | gamma 1 | ecut 50.0 | hcut 261.0 | best_rep 4783 | S 1386.1924 | rep_t 0.7s | total_t 0.7s
# G30 | rep 1/1 | gap 2981.0 | acc 12.6575% | step 50/2000 | beta 2.05 | gamma 0.9755 | ecut 50.0 | hcut 184.0 | best_rep 9374 | S 1386.0259 | rep_t 39.6s | total_t 39.6s
# G30 | rep 1/1 | gap 2828.0 | acc 17.1403% | step 100/2000 | beta 2.104 | gamma 0.9505 | ecut 50.0 | hcut 30.0 | best_rep 1365 | S 1385.5801 | rep_t 85.5s | total_t 85.5s
# G30 | rep 1/1 | gap 2828.0 | acc 17.1403% | step 150/2000 | beta 2.161 | gamma 0.9255 | ecut 50.0 | hcut 353.0 | best_rep 1365 | S 1384.4182 | rep_t 126.8s | total_t 126.8s
# G30 | rep 1/1 | gap 2828.0 | acc 17.1403% | step 200/2000 | beta 2.221 | gamma 0.9005 | ecut 50.0 | hcut 406.0 | best_rep 1365 | S 1381.4673 | rep_t 167.2s | total_t 167.2s
# G30 | rep 1/1 | gap 2828.0 | acc 17.1403% | step 250/2000 | beta 2.285 | gamma 0.8756 | ecut 50.0 | hcut 84.0 | best_rep 1365 | S 1374.2664 | rep_t 203.3s | total_t 203.3s
# G30 | rep 1/1 | gap 2828.0 | acc 17.1403% | step 300/2000 | beta 2.352 | gamma 0.8506 | ecut 50.0 | hcut 39.0 | best_rep 1365 | S 1357.7158 | rep_t 247.3s | total_t 247.3s
# G30 | rep 1/1 | gap 376.0 | acc 88.9833% | step 350/2000 | beta 2.423 | gamma 0.8256 | ecut 53.1 | hcut 3037.0 | best_rep 8682 | S 1322.8052 | rep_t 282.8s | total_t 282.8s
# G30 | rep 1/1 | gap 116.0 | acc 96.6012% | step 400/2000 | beta 2.499 | gamma 0.8006 | ecut 317.0 | hcut 3297.0 | best_rep 9776 | S 1259.2413 | rep_t 319.7s | total_t 319.7s
# G30 | rep 1/1 | gap 98.0 | acc 97.1286% | step 450/2000 | beta 2.579 | gamma 0.7756 | ecut 688.3 | hcut 3315.0 | best_rep 2444 | S 1161.6672 | rep_t 361.3s | total_t 361.3s
# G30 | rep 1/1 | gap 82.0 | acc 97.5974% | step 500/2000 | beta 2.665 | gamma 0.7506 | ecut 1149.9 | hcut 3331.0 | best_rep 2444 | S 1032.0579 | rep_t 407.2s | total_t 407.2s
# G30 | rep 1/1 | gap 66.0 | acc 98.0662% | step 550/2000 | beta 2.757 | gamma 0.7256 | ecut 1630.2 | hcut 3347.0 | best_rep 2444 | S 880.4030 | rep_t 458.6s | total_t 458.6s
# G30 | rep 1/1 | gap 57.0 | acc 98.3299% | step 600/2000 | beta 2.856 | gamma 0.7006 | ecut 2072.5 | hcut 3356.0 | best_rep 2444 | S 720.2874 | rep_t 500.2s | total_t 500.2s
# G30 | rep 1/1 | gap 45.0 | acc 98.6815% | step 650/2000 | beta 2.961 | gamma 0.6757 | ecut 2434.9 | hcut 3368.0 | best_rep 2444 | S 565.0312 | rep_t 534.9s | total_t 534.9s
# G30 | rep 1/1 | gap 41.0 | acc 98.7987% | step 700/2000 | beta 3.075 | gamma 0.6507 | ecut 2708.9 | hcut 3372.0 | best_rep 2444 | S 425.4579 | rep_t 571.2s | total_t 571.2s
# G30 | rep 1/1 | gap 37.0 | acc 98.9159% | step 750/2000 | beta 3.198 | gamma 0.6257 | ecut 2903.7 | hcut 3376.0 | best_rep 9301 | S 308.6894 | rep_t 644.9s | total_t 644.9s
# G30 | rep 1/1 | gap 33.0 | acc 99.0331% | step 800/2000 | beta 3.331 | gamma 0.6007 | ecut 3037.9 | hcut 3380.0 | best_rep 9301 | S 217.5025 | rep_t 718.2s | total_t 718.2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 58
#      54         g_idx=g_idx,
#      55         n_batch=10000,
#      56     )
#      57
# ---> 58     row = run_and_save_one_v2(
#      59         graph_name=graph_name,
#      60         W=W,
#      61         best_known_cut=best_known_cut,
#
# Cell In[17], line 263, in run_and_save_one_v2(graph_name, W, best_known_cut, local_hparams, print_every)
#     259     print("=" * 110)
#     260     print(f"STARTING {graph_name} | historical best = {best_known_cut:.0f}")
#     261     print("=" * 110)
#     262
# --> 263     result = run_qefem_single_instance(
#     264         W=W,
#     265         best_known_cut=float(best_known_cut),
#     266         local_hparams=local_hparams,
#
# Cell In[18], line 353, in run_qefem_single_instance(W, best_known_cut, local_hparams, seed, print_every, device, dtype, eps)
#     349                 hcut = discrete_cut(W, spins)
#     350                 entropy = quantum_entropy(R, eps=eps)
#     351
#     352                 hard_max = hcut.max()
# --> 353                 hard_argmax = int(torch.argmax(hcut).item())
#     354
#     355                 if hard_max.item() > best_cut_so_far:
#     356                     best_cut_so_far = float(hard_max.item())
#
# KeyboardInterrupt:
