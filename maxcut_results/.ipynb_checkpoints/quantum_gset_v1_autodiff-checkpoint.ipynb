# %% [markdown]
# ## Quantum Run - Maxcut GSet
#
# We use polar coordinates for opt, mf density = Tensor_prod($\rho_i$), each density = 1/2 (I + $x_i \sigma_x + z_i \sigma_z$)
#
# $x_i = R_i \sin{\theta_i} \ $
# $z_i = R_i \cos{\theta_i}$

# %% [markdown]
# Try with both Adam, SGD and RMSprop, right now test with same params as vanilla run for direct performance benchmarking, hyperparams are already defined in the very beginning.

# %%
from pathlib import Path
import time
import math

import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

try:
    from tqdm.auto import tqdm
except ImportError:
    tqdm = None

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: mps

# %%
DATA_GSET_DIR = Path("../data-gset")

VANILLA_RESULTS_PATH = Path("naive_vanilla_fem_G1-G54_full_results.csv")
VALIDATION_PATH = Path("gset_validation.txt")

OUTPUT_DIR = Path("qefem_v1_outputs")
OUTPUT_DIR.mkdir(exist_ok=True)

# %% [markdown]
# ### Use same settings as naive vanilla for gset maxcut

# %%
N_STEPS = 1000
REPLICAS = 128
SEED = 0
PRINT_EVERY = 100

DTYPE = torch.float32

BETA_MIN = 2.0
BETA_MAX = 12500.0
BETA_SCHEDULE_KIND = "linear"

LR = 0.01
OPTIMIZER_NAME = "Adam"

# %% [markdown]
# For now just do linear gamma, later try with poly/ exponent

# %%
# R is Bloch length. It must start small.
R_INIT = 1e-2

# theta starts near pi/2 so rx is initially active and rz is initially small.
THETA_CENTER = math.pi / 2
THETA_NOISE = 1e-3

# Gamma sanity test and real QEFEM schedule.
GAMMA_ZERO = 0.0

GAMMA_MAX = 1.0
GAMMA_MIN = 0.0
GAMMA_SCHEDULE_KIND = "linear"


print("\nGlobal settings:")
print("N_STEPS:", N_STEPS)
print("REPLICAS:", REPLICAS)
print("SEED:", SEED)
print("BETA:", BETA_MIN, "->", BETA_MAX)
print("LR:", LR)
print("R_INIT:", R_INIT)
print("THETA_CENTER:", THETA_CENTER)
print("THETA_NOISE:", THETA_NOISE)
print("GAMMA full schedule:", GAMMA_MAX, "->", GAMMA_MIN)
# Out:
# Global settings:
# N_STEPS: 1000
# REPLICAS: 128
# SEED: 0
# BETA: 2.0 -> 12500.0
# LR: 0.01
# R_INIT: 0.01
# THETA_CENTER: 1.5707963267948966
# THETA_NOISE: 0.001
# GAMMA full schedule: 1.0 -> 0.0

# %% [markdown]
# #### Load Vanilla FEM baseline for comparison!

# %%
if not VANILLA_RESULTS_PATH.exists():
    raise FileNotFoundError(
        f"Could not find vanilla baseline CSV:\n{VANILLA_RESULTS_PATH.resolve()}\n\n"
        "Place naive_vanilla_fem_G1-G54_full_results.csv in the same directory as this notebook."
    )

vanilla_results_df = pd.read_csv(VANILLA_RESULTS_PATH)

print("Loaded vanilla baseline:")
print("Rows:", len(vanilla_results_df))
print("Columns:")
print(list(vanilla_results_df.columns))
# Out:
# Loaded vanilla baseline:
# Rows: 54
# Columns:
# ['batch', 'g_index', 'instance', 'N', 'edges', 'best_known_cut', 'vanilla_fem_best_cut', 'gap', 'accuracy', 'percent_accuracy', 'runtime_sec', 'best_replica', 'R', 'N_steps', 'beta_min', 'beta_max', 'schedule_kind', 'lr', 'seed']

# %%
display(vanilla_results_df.head())
# Out:
#    batch  g_index instance    N  edges  best_known_cut  vanilla_fem_best_cut  \
# 0      1        1       G1  800  19176           11624               11446.0
# 1      1        2       G2  800  19176           11620               11435.0
# 2      1        3       G3  800  19176           11622               11443.0
# 3      1        4       G4  800  19176           11646               11503.0
# 4      1        5       G5  800  19176           11631               11450.0
#
#      gap  accuracy  percent_accuracy  runtime_sec  best_replica    R  N_steps  \
# 0  178.0  0.984687         98.468685     4.368305            10  128     1000
# 1  185.0  0.984079         98.407917     4.299664            55  128     1000
# 2  179.0  0.984598         98.459818     4.356321            14  128     1000
# 3  143.0  0.987721         98.772111     4.275009            75  128     1000
# 4  181.0  0.984438         98.443814     4.161925           106  128     1000
#
#    beta_min  beta_max schedule_kind    lr  seed
# 0       2.0   12500.0        linear  0.01     0
# 1       2.0   12500.0        linear  0.01     0
# 2       2.0   12500.0        linear  0.01     0
# 3       2.0   12500.0        linear  0.01     0
# 4       2.0   12500.0        linear  0.01     0

# %%
vanilla_compare_df = vanilla_results_df.copy()

# Keep only the comparison columns we actually need.
vanilla_compare_df = vanilla_compare_df[
    [
        "instance",
        "N",
        "edges",
        "best_known_cut",
        "vanilla_fem_best_cut",
        "gap",
        "accuracy",
        "percent_accuracy",
        "runtime_sec",
    ]
].rename(
    columns={
        "N": "nodes",
        "best_known_cut": "best_value",
        "vanilla_fem_best_cut": "vanilla_cut",
        "gap": "vanilla_gap",
        "accuracy": "vanilla_accuracy",
        "percent_accuracy": "vanilla_percent_accuracy",
        "runtime_sec": "vanilla_tts_seconds",
    }
)

vanilla_compare_df["instance"] = vanilla_compare_df["instance"].astype(str)

print("\nStandardized vanilla comparison dataframe:")
# Out:
# Standardized vanilla comparison dataframe:

# %%
display(vanilla_compare_df.head())
# Out:
#   instance  nodes  edges  best_value  vanilla_cut  vanilla_gap  \
# 0       G1    800  19176       11624      11446.0        178.0
# 1       G2    800  19176       11620      11435.0        185.0
# 2       G3    800  19176       11622      11443.0        179.0
# 3       G4    800  19176       11646      11503.0        143.0
# 4       G5    800  19176       11631      11450.0        181.0
#
#    vanilla_accuracy  vanilla_percent_accuracy  vanilla_tts_seconds
# 0          0.984687                 98.468685             4.368305
# 1          0.984079                 98.407917             4.299664
# 2          0.984598                 98.459818             4.356321
# 3          0.987721                 98.772111             4.275009
# 4          0.984438                 98.443814             4.161925

# %% [markdown]
# ### GSet historical validation table

# %%
if not VALIDATION_PATH.exists():
    raise FileNotFoundError(
        f"Could not find validation file:\n{VALIDATION_PATH.resolve()}\n\n"
        "Place gset_validation.txt in the same directory as this notebook."
    )

records = []

with VALIDATION_PATH.open("r") as f:
    for line_no, line in enumerate(f, start=1):
        line = line.strip()

        if not line or line.startswith("#"):
            continue

        parts = line.split()

        if len(parts) != 2:
            raise ValueError(
                f"Bad line {line_no}: {line!r}. "
                "Expected format: <gset_index> <best_known_cut>"
            )

        g_index = int(parts[0])
        best_known_cut = int(parts[1])

        records.append(
            {
                "g_index": g_index,
                "instance": f"G{g_index}",
                "best_known_cut": best_known_cut,
            }
        )

gset_all_best_df = (
    pd.DataFrame(records)
    .sort_values("g_index")
    .reset_index(drop=True)
)

GSET_BEST_KNOWN_ALL = dict(
    zip(gset_all_best_df["instance"], gset_all_best_df["best_known_cut"])
)

print("\nLoaded Gset validation:")
print("Rows:", len(gset_all_best_df))
display(gset_all_best_df.head(10))
# Out:
# Loaded Gset validation:
# Rows: 71
#    g_index instance  best_known_cut
# 0        1       G1           11624
# 1        2       G2           11620
# 2        3       G3           11622
# 3        4       G4           11646
# 4        5       G5           11631
# 5        6       G6            2178
# 6        7       G7            2006
# 7        8       G8            2005
# 8        9       G9            2054
# 9       10      G10            2000

# %%
merged_vanilla_validation_check = vanilla_compare_df.merge(
    gset_all_best_df[["instance", "best_known_cut"]],
    on="instance",
    how="left",
)

bad_rows = merged_vanilla_validation_check[
    merged_vanilla_validation_check["best_value"]
    != merged_vanilla_validation_check["best_known_cut"]
]

if len(bad_rows) > 0:
    print("\nWARNING: Vanilla CSV best-known values do not match gset_validation.txt:")
    display(bad_rows)
else:
    print("\nSanity check passed:")
    print("Vanilla CSV best-known values match gset_validation.txt.")
# Out:
# Sanity check passed:
# Vanilla CSV best-known values match gset_validation.txt.

# %%
# ----------------------------
# Active benchmark scopes
# ----------------------------
GSET_G1_G10 = [f"G{i}" for i in range(1, 11)]
GSET_G1_G54 = [f"G{i}" for i in range(1, 55)]

print("\nBenchmark scopes:")
print("G1-G10:", GSET_G1_G10)
# Out:
# Benchmark scopes:
# G1-G10: ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10']

# %% [markdown]
# #### Define Gset Batch partitions

# %%
GSET_BATCHES = {
    1: [f"G{i}" for i in range(1, 11)],    # G1-G10
    2: [f"G{i}" for i in range(11, 14)],   # G11-G13
    3: [f"G{i}" for i in range(14, 22)],   # G14-G21
    4: [f"G{i}" for i in range(22, 32)],   # G22-G31
    5: [f"G{i}" for i in range(32, 35)],   # G32-G34
    6: [f"G{i}" for i in range(35, 43)],   # G35-G42
    7: [f"G{i}" for i in range(43, 48)],   # G43-G47
    8: [f"G{i}" for i in range(48, 51)],   # G48-G50
    9: [f"G{i}" for i in range(51, 55)],   # G51-G54
}

print("Gset benchmark batches:")
for batch_id, instances in GSET_BATCHES.items():
    print(
        f"Batch {batch_id}: "
        f"{instances[0]}-{instances[-1]} | "
        f"{len(instances)} instances | "
        f"{instances}"
    )
# Out:
# Gset benchmark batches:
# Batch 1: G1-G10 | 10 instances | ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10']
# Batch 2: G11-G13 | 3 instances | ['G11', 'G12', 'G13']
# Batch 3: G14-G21 | 8 instances | ['G14', 'G15', 'G16', 'G17', 'G18', 'G19', 'G20', 'G21']
# Batch 4: G22-G31 | 10 instances | ['G22', 'G23', 'G24', 'G25', 'G26', 'G27', 'G28', 'G29', 'G30', 'G31']
# Batch 5: G32-G34 | 3 instances | ['G32', 'G33', 'G34']
# Batch 6: G35-G42 | 8 instances | ['G35', 'G36', 'G37', 'G38', 'G39', 'G40', 'G41', 'G42']
# Batch 7: G43-G47 | 5 instances | ['G43', 'G44', 'G45', 'G46', 'G47']
# Batch 8: G48-G50 | 3 instances | ['G48', 'G49', 'G50']
# Batch 9: G51-G54 | 4 instances | ['G51', 'G52', 'G53', 'G54']

# %%
# ----------------------------
# Flatten full benchmark list
# ----------------------------
GSET_ALL_INSTANCES = []

for batch_id in sorted(GSET_BATCHES.keys()):
    GSET_ALL_INSTANCES.extend(GSET_BATCHES[batch_id])

print("\nTotal Gset instances in benchmark:", len(GSET_ALL_INSTANCES))
print("First instance:", GSET_ALL_INSTANCES[0])
print("Last instance:", GSET_ALL_INSTANCES[-1])
# Out:
# Total Gset instances in benchmark: 54
# First instance: G1
# Last instance: G54

# %%
# ----------------------------
# Sanity checks against validation and vanilla baseline
# ----------------------------
missing_from_validation = [
    instance for instance in GSET_ALL_INSTANCES
    if instance not in GSET_BEST_KNOWN_ALL
]

missing_from_vanilla = [
    instance for instance in GSET_ALL_INSTANCES
    if instance not in set(vanilla_compare_df["instance"])
]

if missing_from_validation:
    raise ValueError(
        "These benchmark instances are missing from gset_validation.txt:\n"
        f"{missing_from_validation}"
    )

if missing_from_vanilla:
    raise ValueError(
        "These benchmark instances are missing from vanilla baseline CSV:\n"
        f"{missing_from_vanilla}"
    )

print("\nSanity check passed:")
print("All G1-G54 instances exist in validation file and vanilla baseline CSV.")


# ----------------------------
# Useful scopes for later cells
# ----------------------------
GSET_SANITY_INSTANCE = "G1"
GSET_FIRST_SWEEP = GSET_BATCHES[1]
GSET_PROBLEM_BATCH = GSET_BATCHES[6]

print("\nUseful scopes:")
print("Single sanity instance:", GSET_SANITY_INSTANCE)
print("First sweep:", GSET_FIRST_SWEEP)
print("Problem batch:", GSET_PROBLEM_BATCH)
# Out:
# Sanity check passed:
# All G1-G54 instances exist in validation file and vanilla baseline CSV.
#
# Useful scopes:
# Single sanity instance: G1
# First sweep: ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10']
# Problem batch: ['G35', 'G36', 'G37', 'G38', 'G39', 'G40', 'G41', 'G42']

# %% [markdown]
# ### Loading the adjacency matrix :
# First test with G1

# %%
def load_gset_dense(path, device=device, dtype=DTYPE, index_start=1):

    path = Path(path)

    if not path.exists():
        raise FileNotFoundError(f"Could not find Gset file:\n{path.resolve()}")

    with path.open("r") as f:
        first = f.readline().strip().split()

        if len(first) != 2:
            raise ValueError(f"Bad first line in {path}: {first}")

        n, m = map(int, first)

        # Fill on CPU first. MPS scalar writes are slow and petty.
        W_cpu = torch.zeros((n, n), dtype=dtype, device="cpu")

        edge_count = 0
        total_weight_edges = 0.0
        positive_edges = 0
        negative_edges = 0
        zero_edges = 0
        self_edges = 0

        for line_id, line in enumerate(f, start=2):
            parts = line.strip().split()

            if not parts:
                continue

            if len(parts) != 3:
                raise ValueError(
                    f"Bad line {line_id} in {path}: {line!r}. "
                    "Expected format: i j w"
                )

            i_raw, j_raw, w_raw = parts

            i = int(i_raw) - index_start
            j = int(j_raw) - index_start
            w = float(w_raw)

            if not (0 <= i < n and 0 <= j < n):
                raise IndexError(
                    f"Node index out of range at line {line_id}: "
                    f"i={i}, j={j}, n={n}"
                )

            if i == j:
                self_edges += 1

            if w > 0:
                positive_edges += 1
            elif w < 0:
                negative_edges += 1
            else:
                zero_edges += 1

            W_cpu[i, j] = w
            W_cpu[j, i] = w

            edge_count += 1
            total_weight_edges += w

    W = W_cpu.to(device=device, dtype=dtype)

    with torch.no_grad():
        diag = torch.diag(W)
        W_sum = float(W.sum().detach().cpu())
        symmetric = bool(torch.allclose(W, W.T))
        diag_zero = bool(torch.allclose(diag, torch.zeros_like(diag)))
        nonzero_directed_entries = int(torch.count_nonzero(W).detach().cpu())

    info = {
        "path": str(path),
        "n": n,
        "m_header": m,
        "m_loaded": edge_count,
        "total_weight_edges": total_weight_edges,
        "positive_edges": positive_edges,
        "negative_edges": negative_edges,
        "zero_edges": zero_edges,
        "self_edges": self_edges,
        "W_sum": W_sum,
        "nonzero_directed_entries": nonzero_directed_entries,
        "expected_directed_entries": 2 * edge_count,
        "symmetric": symmetric,
        "diag_zero": diag_zero,
        "device": str(W.device),
        "dtype": str(W.dtype),
    }

    if edge_count != m:
        print(
            "WARNING: loaded edge count does not match header:",
            edge_count,
            "!=",
            m,
        )

    if not symmetric:
        print("WARNING: W is not symmetric. That is not cute.")

    if not diag_zero:
        print("WARNING: W diagonal is not zero.")

    return W, info

# %%
g1_path = DATA_GSET_DIR / "G1"

print("G1 path:", g1_path.resolve())
print("G1 exists?", g1_path.exists())
# Out:
# G1 path: /Users/ronit/Desktop/QeFEM/main/data-gset/G1
# G1 exists? True

# %%
instance = GSET_SANITY_INSTANCE   # "G1"
gset_path = DATA_GSET_DIR / instance

print("Loading instance:", instance)
print("Path:", gset_path.resolve())


# ----------------------------
# Load dense W
# ----------------------------
W, graph_info = load_gset_dense(
    gset_path,
    device=device,
    dtype=DTYPE,
    index_start=1,
)

N = W.shape[0]
best_known = GSET_BEST_KNOWN_ALL[instance]


# ----------------------------
# Print graph metadata
# ----------------------------
print("\nGraph info:")
for key, value in graph_info.items():
    print(f"{key}: {value}")

print("\nBenchmark info:")
print("Instance:", instance)
print("N:", N)
print("Best-known cut:", best_known)
# Out:
# Loading instance: G1
# Path: /Users/ronit/Desktop/QeFEM/main/data-gset/G1
#
# Graph info:
# path: ../data-gset/G1
# n: 800
# m_header: 19176
# m_loaded: 19176
# total_weight_edges: 19176.0
# positive_edges: 19176
# negative_edges: 0
# zero_edges: 0
# self_edges: 0
# W_sum: 38352.0
# nonzero_directed_entries: 38352
# expected_directed_entries: 38352
# symmetric: True
# diag_zero: True
# device: mps:0
# dtype: torch.float32
#
# Benchmark info:
# Instance: G1
# N: 800
# Best-known cut: 11624

# %%
print("\nGraph info:")
for key, value in graph_info.items():
    print(f"{key}: {value}")

print("\nBenchmark info:")
print("Instance:", instance)
print("N:", N)
print("Best-known cut:", best_known)


# ----------------------------
# Hard sanity assertions
# ----------------------------
assert graph_info["m_loaded"] == graph_info["m_header"], (
    "Loaded edge count does not match header. "
    "Tiny loader goblin detected."
)

assert graph_info["symmetric"] is True, "W must be symmetric."

assert graph_info["diag_zero"] is True, "W diagonal must be zero."

assert graph_info["nonzero_directed_entries"] == graph_info["expected_directed_entries"], (
    "Directed nonzero entries should be exactly 2 * edge_count "
    "for a symmetric undirected graph."
)

assert instance in vanilla_compare_df["instance"].values, (
    f"{instance} missing from vanilla baseline dataframe."
)


# ----------------------------
# Pull vanilla baseline for this instance
# ----------------------------
vanilla_row = vanilla_compare_df.query("instance == @instance").iloc[0]

print("\nVanilla baseline for this instance:")
print("Vanilla cut:", vanilla_row["vanilla_cut"])
print("Vanilla best-known:", vanilla_row["best_value"])
print("Vanilla gap:", vanilla_row["vanilla_gap"])
print("Vanilla accuracy %:", vanilla_row["vanilla_percent_accuracy"])
print("Vanilla runtime sec:", vanilla_row["vanilla_tts_seconds"])
# Out:
# Graph info:
# path: ../data-gset/G1
# n: 800
# m_header: 19176
# m_loaded: 19176
# total_weight_edges: 19176.0
# positive_edges: 19176
# negative_edges: 0
# zero_edges: 0
# self_edges: 0
# W_sum: 38352.0
# nonzero_directed_entries: 38352
# expected_directed_entries: 38352
# symmetric: True
# diag_zero: True
# device: mps:0
# dtype: torch.float32
#
# Benchmark info:
# Instance: G1
# N: 800
# Best-known cut: 11624
#
# Vanilla baseline for this instance:
# Vanilla cut: 11446.0
# Vanilla best-known: 11624
# Vanilla gap: 178.0
# Vanilla accuracy %: 98.46868547832072
# Vanilla runtime sec: 4.368304967880249

# %% [markdown]
# ### Define Cut function

# %%
def discrete_cut(W, spins):

    single_input = False

    if spins.dim() == 1:
        spins = spins.unsqueeze(0)
        single_input = True

    spins = spins.to(device=W.device, dtype=W.dtype)

    quad = torch.einsum("ri,ij,rj->r", spins, W, spins)
    cut = 0.25 * (W.sum() - quad)

    if single_input:
        return cut.squeeze(0)

    return cut

# %% [markdown]
# ### Define the Bloch parameterization

# %%
def bloch_from_raw(raw_R, theta):

    # R = sigmoid(raw_R) ---> trainable latent raw_R like fields give Bloch radius
    
    R = torch.sigmoid(raw_R)

    rx = R * torch.sin(theta)
    rz = R * torch.cos(theta)

    return R, rx, rz


def raw_R_from_init_value(R_init, device=device, dtype=DTYPE):
    """
    Convert a desired initial Bloch radius R_init into raw_R
    such that sigmoid(raw_R) = R_init.
    """
    
    # raw_R = logit(R) ---> opposite of previous function
    
    if not (0.0 < R_init < 1.0):
        raise ValueError("R_init must be strictly between 0 and 1. Humanity survives by constraints.")

    R_init_tensor = torch.tensor(R_init, device=device, dtype=dtype)
    raw_value = torch.logit(R_init_tensor)

    return raw_value

# %%
raw_R_test_value = raw_R_from_init_value(R_INIT)

raw_R_test = raw_R_test_value * torch.ones(
    REPLICAS,
    N,
    device=device,
    dtype=DTYPE,
)

theta_test = THETA_CENTER + THETA_NOISE * torch.randn(
    REPLICAS,
    N,
    device=device,
    dtype=DTYPE,
)

R_test, rx_test, rz_test = bloch_from_raw(raw_R_test, theta_test)

print("raw_R init value:", float(raw_R_test_value.detach().cpu()))
print("R_test shape:", R_test.shape)
print("rx_test shape:", rx_test.shape)
print("rz_test shape:", rz_test.shape)

print("\nInitial Bloch stats:")
print("R mean:", float(R_test.mean().detach().cpu()))
print("R min:", float(R_test.min().detach().cpu()))
print("R max:", float(R_test.max().detach().cpu()))

print("\nInitial component stats:")
print("rx mean:", float(rx_test.mean().detach().cpu()))
print("rx abs mean:", float(rx_test.abs().mean().detach().cpu()))
print("rz mean:", float(rz_test.mean().detach().cpu()))
print("rz abs mean:", float(rz_test.abs().mean().detach().cpu()))

# Since theta starts near pi/2:
# rx should be close to R_INIT, rz should be tiny.
assert torch.all(R_test > 0), "R must be positive."
assert torch.all(R_test < 1), "R must be less than 1."
# Out:
# raw_R init value: -4.595119476318359
# R_test shape: torch.Size([128, 800])
# rx_test shape: torch.Size([128, 800])
# rz_test shape: torch.Size([128, 800])
#
# Initial Bloch stats:
# R mean: 0.01000000350177288
# R min: 0.01000000350177288
# R max: 0.01000000350177288
#
# Initial component stats:
# rx mean: 0.009999998845160007
# rx abs mean: 0.009999998845160007
# rz mean: -1.7262834717257647e-08
# rz abs mean: 7.956688932608813e-06

# %% [markdown]
# ### Define Quantum entropy

# %%
def quantum_entropy_from_R(R, eps=1e-12):

    single_input = False

    if R.dim() == 1:
        R = R.unsqueeze(0)
        single_input = True

    R = R.clamp(eps, 1.0 - eps)

    lambda_plus = 0.5 * (1.0 + R)
    lambda_minus = 0.5 * (1.0 - R)

    entropy_per_spin = -(
        lambda_plus * torch.log(lambda_plus)
        + lambda_minus * torch.log(lambda_minus)
    )

    entropy = entropy_per_spin.sum(dim=1)

    if single_input:
        return entropy.squeeze(0)

    return entropy

# %%
S_test = quantum_entropy_from_R(R_test)

print("Entropy shape:", S_test.shape)
print("Entropy mean:", float(S_test.mean().detach().cpu()))
print("Entropy min:", float(S_test.min().detach().cpu()))
print("Entropy max:", float(S_test.max().detach().cpu()))

# For R near 0, each qubit has entropy close to log(2).
max_entropy_per_replica = N * math.log(2.0)

print("\nTheoretical max entropy per replica, N log 2:")
print(max_entropy_per_replica)

print("\nEntropy mean / max entropy:")
print(float(S_test.mean().detach().cpu() / max_entropy_per_replica))

# R_INIT = 1e-2 should give entropy very close to N log 2.
assert torch.all(S_test > 0), "Entropy should be positive."
assert torch.all(S_test <= max_entropy_per_replica + 1e-3), (
    "Entropy exceeded N log 2. Entropy goblin detected."
)
# Out:
# Entropy shape: torch.Size([128])
# Entropy mean: 554.4776611328125
# Entropy min: 554.4776611328125
# Entropy max: 554.4776611328125
#
# Theoretical max entropy per replica, N log 2:
# 554.5177444479563
#
# Entropy mean / max entropy:
# 0.9999276995658875

# %% [markdown]
# ### Expected Cut

# %%
def quantum_expected_cut(W, rz):
    
    single_input = False

    if rz.dim() == 1:
        rz = rz.unsqueeze(0)
        single_input = True

    rz = rz.to(device=W.device, dtype=W.dtype)

    quad = torch.einsum("ri,ij,rj->r", rz, W, rz)
    expected_cut = 0.25 * (W.sum() - quad)

    if single_input:
        return expected_cut.squeeze(0)

    return expected_cut

# %%
expected_cut_test = quantum_expected_cut(W, rz_test)

print("Expected cut shape:", expected_cut_test.shape)
print("Expected cut mean:", float(expected_cut_test.mean().detach().cpu()))
print("Expected cut min:", float(expected_cut_test.min().detach().cpu()))
print("Expected cut max:", float(expected_cut_test.max().detach().cpu()))

print("\nBest-known cut:", best_known)
print("Vanilla FEM cut:", vanilla_row["vanilla_cut"])

# Since rz starts close to 0, expected cut should be close to W.sum()/4.
soft_uniform_cut = 0.25 * float(W.sum().detach().cpu())

print("\nSoft uniform reference W.sum()/4:")
print(soft_uniform_cut)

print("\nMean expected cut - W.sum()/4:")       #should be 0 because E[C] = 1/4 (\sum W_ij - z^T W z)..... 
# z (init) -->0 thus diff => E[C] - 0.25 \sum W = 0 is expected...

print(float(expected_cut_test.mean().detach().cpu()) - soft_uniform_cut)
# Out:
# Expected cut shape: torch.Size([128])
# Expected cut mean: 9588.0
# Expected cut min: 9588.0
# Expected cut max: 9588.0
#
# Best-known cut: 11624
# Vanilla FEM cut: 11446.0
#
# Soft uniform reference W.sum()/4:
# 9588.0
#
# Mean expected cut - W.sum()/4:
# 0.0

# %% [markdown]
# ### Build the Transverse Mixer/ Driver

# %%
def transverse_driver_energy(rx, gamma):

    single_input = False

    if rx.dim() == 1:
        rx = rx.unsqueeze(0)
        single_input = True

    gamma = torch.as_tensor(
        gamma,
        device=rx.device,
        dtype=rx.dtype,
    )

    driver_energy = -gamma * rx.sum(dim=1)

    if single_input:
        return driver_energy.squeeze(0)

    return driver_energy

# %%
driver_zero_test = transverse_driver_energy(rx_test, gamma=0.0)
driver_full_test = transverse_driver_energy(rx_test, gamma=GAMMA_MAX)

print("Driver energy shape:", driver_full_test.shape)

print("\nGamma = 0 driver stats:")
print("mean:", float(driver_zero_test.mean().detach().cpu()))
print("min:", float(driver_zero_test.min().detach().cpu()))
print("max:", float(driver_zero_test.max().detach().cpu()))

print("\nGamma = 1 driver stats:")
print("mean:", float(driver_full_test.mean().detach().cpu()))
print("min:", float(driver_full_test.min().detach().cpu()))
print("max:", float(driver_full_test.max().detach().cpu()))

# With theta near pi/2 and R_INIT=1e-2:
# rx.sum() should be close to N * R_INIT.
expected_initial_driver = -GAMMA_MAX * N * R_INIT

print("\nExpected rough initial driver energy for gamma=1:")
print(expected_initial_driver)

print("\nObserved mean driver energy for gamma=1:")
print(float(driver_full_test.mean().detach().cpu()))
# Out:
# Driver energy shape: torch.Size([128])
#
# Gamma = 0 driver stats:
# mean: 0.0
# min: -0.0
# max: -0.0
#
# Gamma = 1 driver stats:
# mean: -7.999999046325684
# min: -7.999999523162842
# max: -7.999998092651367
#
# Expected rough initial driver energy for gamma=1:
# -8.0
#
# Observed mean driver energy for gamma=1:
# -7.999999046325684

# %%
assert torch.allclose(
    driver_zero_test,
    torch.zeros_like(driver_zero_test),
    atol=1e-6,
    rtol=1e-6,
), "Driver energy should be exactly zero when gamma=0. The transverse goblin is lying."

assert driver_full_test.mean() < 0, (
    "Initial driver energy should be negative because rx starts positive near pi/2."
)

# %% [markdown]
# ------------------------------------------------------------------------------------------------------
# ## Building the QeFEM complete functional using :
# $F_{QMF} = - E[Q] - \Gamma \sum x_i - \frac{1}{\beta} S[Q]$

# %%
def qefem_free_energy_maxcut(W, raw_R, theta, beta, gamma):

    beta = torch.as_tensor(beta, device=W.device, dtype=W.dtype)
    gamma = torch.as_tensor(gamma, device=W.device, dtype=W.dtype)

    R, rx, rz = bloch_from_raw(raw_R, theta)

    expected_cut = quantum_expected_cut(W, rz)
    entropy = quantum_entropy_from_R(R)
    driver_energy = transverse_driver_energy(rx, gamma)

    internal_energy_cut = -expected_cut

    F = internal_energy_cut + driver_energy - entropy / beta

    aux = {
        "R": R,
        "rx": rx,
        "rz": rz,
        "expected_cut": expected_cut,
        "entropy": entropy,
        "driver_energy": driver_energy,
        "internal_energy_cut": internal_energy_cut,
        "free_energy": F,
        "beta": beta,
        "gamma": gamma,
    }

    return F, aux

# %%
beta_test = BETA_MIN
gamma_test_zero = 0.0
gamma_test_full = GAMMA_MAX

F_zero_test, aux_zero_test = qefem_free_energy_maxcut(
    W=W,
    raw_R=raw_R_test,
    theta=theta_test,
    beta=beta_test,
    gamma=gamma_test_zero,
)

F_full_test, aux_full_test = qefem_free_energy_maxcut(
    W=W,
    raw_R=raw_R_test,
    theta=theta_test,
    beta=beta_test,
    gamma=gamma_test_full,
)


print("Free energy shape:", F_zero_test.shape)

print("\nGamma = 0 initial stats:")
print("F mean:", float(F_zero_test.mean().detach().cpu()))
print("Expected cut mean:", float(aux_zero_test["expected_cut"].mean().detach().cpu()))
print("Entropy mean:", float(aux_zero_test["entropy"].mean().detach().cpu()))
print("Driver mean:", float(aux_zero_test["driver_energy"].mean().detach().cpu()))

print("\nGamma = 1 initial stats:")
print("F mean:", float(F_full_test.mean().detach().cpu()))
print("Expected cut mean:", float(aux_full_test["expected_cut"].mean().detach().cpu()))
print("Entropy mean:", float(aux_full_test["entropy"].mean().detach().cpu()))
print("Driver mean:", float(aux_full_test["driver_energy"].mean().detach().cpu()))

print("\nDifference F(gamma=1) - F(gamma=0):")
print(float((F_full_test.mean() - F_zero_test.mean()).detach().cpu()))

print("\nExpected rough driver shift:")
print(-GAMMA_MAX * N * R_INIT)
# Out:
# Free energy shape: torch.Size([128])
#
# Gamma = 0 initial stats:
# F mean: -9865.2392578125
# Expected cut mean: 9588.0
# Entropy mean: 554.4776611328125
# Driver mean: 0.0
#
# Gamma = 1 initial stats:
# F mean: -9873.2392578125
# Expected cut mean: 9588.0
# Entropy mean: 554.4776611328125
# Driver mean: -7.999999046325684
#
# Difference F(gamma=1) - F(gamma=0):
# -8.0
#
# Expected rough driver shift:
# -8.0

# %%
# ----------------------------
# Basic consistency checks
# ----------------------------
assert F_zero_test.shape == torch.Size([REPLICAS]), (
    "Free energy should return one value per replica."
)

assert torch.allclose(
    aux_zero_test["driver_energy"],
    torch.zeros_like(aux_zero_test["driver_energy"]),
    atol=1e-6,
    rtol=1e-6,
), "Driver energy should vanish when gamma=0."

assert aux_zero_test["expected_cut"].mean() > 0, (
    "Expected cut should be positive at initialization."
)

assert aux_zero_test["entropy"].mean() > 0, (
    "Entropy should be positive at initialization."
)

assert F_full_test.mean() < F_zero_test.mean(), (
    "With positive rx and gamma=1, driver should lower the free energy initially."
)

# %% [markdown]
# ## Build annealing schedules!

# %%
def make_beta_schedule(
    beta_min=BETA_MIN,
    beta_max=BETA_MAX,
    n_steps=N_STEPS,
    kind=BETA_SCHEDULE_KIND,
    device=device,
    dtype=DTYPE,
):
    # CONSISTENCY WITH VANILLA RUN USE SAME VALUES FOR BETA ANNEAL !!!
    
    if n_steps <= 0:
        raise ValueError("n_steps must be positive. Time must move, sadly.")

    if kind == "linear":
        beta_schedule = torch.linspace(
            beta_min,
            beta_max,
            n_steps,
            device=device,
            dtype=dtype,
        )

    elif kind == "exponential":
        if beta_min <= 0 or beta_max <= 0:
            raise ValueError("Exponential beta schedule needs positive beta_min and beta_max.")

        beta_schedule = torch.exp(
            torch.linspace(
                math.log(beta_min),
                math.log(beta_max),
                n_steps,
                device=device,
                dtype=dtype,
            )
        )

    else:
        raise ValueError(f"Unknown beta schedule kind: {kind}")

    return beta_schedule

# %%
def make_gamma_schedule(
    gamma_mode,
    gamma_max=GAMMA_MAX,
    gamma_min=GAMMA_MIN,
    n_steps=N_STEPS,
    kind=GAMMA_SCHEDULE_KIND,
    device=device,
    dtype=DTYPE,
):

    if n_steps <= 0:
        raise ValueError("n_steps must be positive. Even annealing needs time to suffer.")

    if gamma_mode == "zero":
        gamma_schedule = torch.zeros(
            n_steps,
            device=device,
            dtype=dtype,
        )

    elif gamma_mode == "anneal":
        if kind == "linear":
            gamma_schedule = torch.linspace(
                gamma_max,
                gamma_min,
                n_steps,
                device=device,
                dtype=dtype,
            )

        elif kind == "exponential":
            if gamma_min <= 0 or gamma_max <= 0:
                raise ValueError(
                    "Exponential gamma schedule needs positive gamma_min and gamma_max. "
                    "Use linear if gamma_min = 0."
                )

            gamma_schedule = torch.exp(
                torch.linspace(
                    math.log(gamma_max),
                    math.log(gamma_min),
                    n_steps,
                    device=device,
                    dtype=dtype,
                )
            )

        else:
            raise ValueError(f"Unknown gamma schedule kind: {kind}")

    else:
        raise ValueError(
            f"Unknown gamma_mode: {gamma_mode}. "
            "Use 'zero' or 'anneal'."
        )

    return gamma_schedule

# %%
# ----------------------------
# Build schedules
# ----------------------------
beta_schedule = make_beta_schedule()

gamma_zero_schedule = make_gamma_schedule(gamma_mode="zero")
gamma_anneal_schedule = make_gamma_schedule(gamma_mode="anneal")


# ----------------------------
# Print schedule sanity
# ----------------------------
print("Beta schedule:")
print("shape:", beta_schedule.shape)
print("first:", float(beta_schedule[0].detach().cpu()))
print("last:", float(beta_schedule[-1].detach().cpu()))

print("\nGamma zero schedule:")
print("shape:", gamma_zero_schedule.shape)
print("first:", float(gamma_zero_schedule[0].detach().cpu()))
print("last:", float(gamma_zero_schedule[-1].detach().cpu()))

print("\nGamma anneal schedule:")
print("shape:", gamma_anneal_schedule.shape)
print("first:", float(gamma_anneal_schedule[0].detach().cpu()))
print("last:", float(gamma_anneal_schedule[-1].detach().cpu()))
# Out:
# Beta schedule:
# shape: torch.Size([1000])
# first: 2.0
# last: 12500.0
#
# Gamma zero schedule:
# shape: torch.Size([1000])
# first: 0.0
# last: 0.0
#
# Gamma anneal schedule:
# shape: torch.Size([1000])
# first: 1.0
# last: 0.0

# %%
assert beta_schedule.shape[0] == N_STEPS
assert gamma_zero_schedule.shape[0] == N_STEPS
assert gamma_anneal_schedule.shape[0] == N_STEPS

assert torch.all(beta_schedule > 0), "Beta must stay positive."

assert torch.allclose(
    gamma_zero_schedule,
    torch.zeros_like(gamma_zero_schedule),
), "gamma_mode='zero' should give all zeros."

assert gamma_anneal_schedule[0] == GAMMA_MAX, (
    "Annealed gamma schedule should start at GAMMA_MAX."
)

assert gamma_anneal_schedule[-1] == GAMMA_MIN, (
    "Annealed gamma schedule should end at GAMMA_MIN."
)

# %% [markdown]
# ### Single SANITY run for G1

# %%
def initialize_qefem_variables(
    n,
    replicas=REPLICAS,
    seed=SEED,
    R_init=R_INIT,
    theta_center=THETA_CENTER,
    theta_noise=THETA_NOISE,
    device=device,
    dtype=DTYPE,
):

    torch.manual_seed(seed)

    raw_R_center = raw_R_from_init_value(
        R_init,
        device=device,
        dtype=dtype,
    )

    raw_R = raw_R_center + 1e-3 * torch.randn(
        replicas,
        n,
        device=device,
        dtype=dtype,
    )

    theta = theta_center + theta_noise * torch.randn(
        replicas,
        n,
        device=device,
        dtype=dtype,
    )

    raw_R.requires_grad_(True)
    theta.requires_grad_(True)

    return raw_R, theta

def make_qefem_optimizer(raw_R, theta, lr=LR):

    optimizer = torch.optim.Adam(
        [raw_R, theta],
        lr=lr,
    )

    return optimizer

# %%
raw_R, theta = initialize_qefem_variables(
    n=N,
    replicas=REPLICAS,
    seed=SEED,
)

optimizer = make_qefem_optimizer(
    raw_R=raw_R,
    theta=theta,
    lr=LR,
)

# %%
with torch.no_grad():
    R_init_check, rx_init_check, rz_init_check = bloch_from_raw(raw_R, theta)

print("Initialized QEFEM variables:")
print("raw_R shape:", raw_R.shape)
print("theta shape:", theta.shape)

print("\nTrainability:")
print("raw_R requires_grad:", raw_R.requires_grad)
print("theta requires_grad:", theta.requires_grad)

print("\nInitial Bloch stats:")
print("R mean:", float(R_init_check.mean().detach().cpu()))
print("R min:", float(R_init_check.min().detach().cpu()))
print("R max:", float(R_init_check.max().detach().cpu()))

print("\nInitial component stats:")
print("rx mean:", float(rx_init_check.mean().detach().cpu()))
print("rx abs mean:", float(rx_init_check.abs().mean().detach().cpu()))
print("rz mean:", float(rz_init_check.mean().detach().cpu()))
print("rz abs mean:", float(rz_init_check.abs().mean().detach().cpu()))

print("\nOptimizer:")
print(optimizer)


# ----------------------------
# Sanity assertions
# ----------------------------
assert raw_R.shape == torch.Size([REPLICAS, N])
assert theta.shape == torch.Size([REPLICAS, N])

assert raw_R.requires_grad is True
assert theta.requires_grad is True

assert torch.all(R_init_check > 0), "R must be positive."
assert torch.all(R_init_check < 1), "R must be less than 1."

assert rx_init_check.abs().mean() > rz_init_check.abs().mean(), (
    "Initial state should be mostly transverse: |rx| should exceed |rz|."
)
# Out:
# Initialized QEFEM variables:
# raw_R shape: torch.Size([128, 800])
# theta shape: torch.Size([128, 800])
#
# Trainability:
# raw_R requires_grad: True
# theta requires_grad: True
#
# Initial Bloch stats:
# R mean: 0.009999999776482582
# R min: 0.009957408532500267
# R max: 0.010043280199170113
#
# Initial component stats:
# rx mean: 0.009999995119869709
# rx abs mean: 0.009999995119869709
# rz mean: -2.542237353964083e-08
# rz abs mean: 7.966298653627746e-06
#
# Optimizer:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 0
# )

# %%
raw_R_zero, theta_zero = initialize_qefem_variables(
    n=N,
    replicas=REPLICAS,
    seed=SEED,
)

optimizer_zero = make_qefem_optimizer(
    raw_R=raw_R_zero,
    theta=theta_zero,
    lr=LR,
)

# %%
# just verifying if R = \sqrt{ rx**2 + rz**2} is properly maintained!

with torch.no_grad():
    R_check, rx_check, rz_check = bloch_from_raw(raw_R_zero, theta_zero)

    reconstructed_R = torch.sqrt(rx_check**2 + rz_check**2)

    max_error = torch.max(torch.abs(R_check - reconstructed_R))

print("|R - sqrt(rx^2 + rz^2)|:", float(max_error.detach().cpu()))
# Out:
# |R - sqrt(rx^2 + rz^2)|: 1.862645149230957e-09

# %% [markdown]
# ### We do the first run with Gamma equal zero
# to theoretically make sense of that fact that gamma = 0 training should yield equivalent result to that of VANILLA FEM!

# %%
# ----------------------------
# Schedules
# ----------------------------
beta_schedule_zero = make_beta_schedule()
gamma_schedule_zero = make_gamma_schedule(gamma_mode="zero")


# ----------------------------
# Storage
# ----------------------------
history_zero = []

best_cut_zero = -float("inf")
best_step_zero = None
best_replica_zero = None
best_spins_zero = None

start_time_zero = time.time()

print("Starting G1 QEFEM sanity run with gamma = 0")
print("Instance:", instance)
print("N:", N)
print("REPLICAS:", REPLICAS)
print("N_STEPS:", N_STEPS)
print("LR:", LR)
print("Beta:", BETA_MIN, "->", BETA_MAX)
print("Gamma mode: zero")
print("Best-known cut:", best_known)
print("Vanilla FEM cut:", vanilla_row["vanilla_cut"])
print("-" * 80)
# Out:
# Starting G1 QEFEM sanity run with gamma = 0
# Instance: G1
# N: 800
# REPLICAS: 128
# N_STEPS: 1000
# LR: 0.01
# Beta: 2.0 -> 12500.0
# Gamma mode: zero
# Best-known cut: 11624
# Vanilla FEM cut: 11446.0
# --------------------------------------------------------------------------------

# %%
# ----------------------------
# Training loop
# ----------------------------
for step in range(N_STEPS):
    beta_t = beta_schedule_zero[step]
    gamma_t = gamma_schedule_zero[step]

    optimizer_zero.zero_grad()

    F, aux = qefem_free_energy_maxcut(
        W=W,
        raw_R=raw_R_zero,
        theta=theta_zero,
        beta=beta_t,
        gamma=gamma_t,
    )

    loss = F.mean()
    loss.backward()

    grad_norm_raw_R = raw_R_zero.grad.detach().norm().item()
    grad_norm_theta = theta_zero.grad.detach().norm().item()

    optimizer_zero.step()

    # ----------------------------
    # Hard readout for tracking
    # ----------------------------
    with torch.no_grad():
        R_now, rx_now, rz_now = bloch_from_raw(raw_R_zero, theta_zero)

        spins_now = torch.where(
            rz_now >= 0,
            torch.ones_like(rz_now),
            -torch.ones_like(rz_now),
        )

        hard_cuts_now = discrete_cut(W, spins_now)

        step_best_cut = float(hard_cuts_now.max().detach().cpu())
        step_best_replica = int(torch.argmax(hard_cuts_now).detach().cpu())

        if step_best_cut > best_cut_zero:
            best_cut_zero = step_best_cut
            best_step_zero = step
            best_replica_zero = step_best_replica
            best_spins_zero = spins_now[step_best_replica].detach().cpu().clone()

        row = {
            "step": step,
            "beta": float(beta_t.detach().cpu()),
            "gamma": float(gamma_t.detach().cpu()),

            "loss_mean": float(loss.detach().cpu()),
            "free_energy_mean": float(F.mean().detach().cpu()),

            "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
            "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),

            "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
            "hard_cut_max": float(hard_cuts_now.max().detach().cpu()),
            "best_cut_so_far": best_cut_zero,

            "entropy_mean": float(aux["entropy"].mean().detach().cpu()),
            "driver_energy_mean": float(aux["driver_energy"].mean().detach().cpu()),

            "R_mean": float(R_now.mean().detach().cpu()),
            "R_min": float(R_now.min().detach().cpu()),
            "R_max": float(R_now.max().detach().cpu()),

            "rx_mean": float(rx_now.mean().detach().cpu()),
            "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),

            "rz_mean": float(rz_now.mean().detach().cpu()),
            "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),

            "grad_norm_raw_R": grad_norm_raw_R,
            "grad_norm_theta": grad_norm_theta,
        }

        history_zero.append(row)

    # ----------------------------
    # Print progress
    # ----------------------------
    if (
        step == 0
        or (step + 1) % PRINT_EVERY == 0
        or step == N_STEPS - 1
    ):
        elapsed = time.time() - start_time_zero

        print(
            f"step {step + 1:4d}/{N_STEPS} | "
            f"beta={row['beta']:.2f} | "
            f"gamma={row['gamma']:.4f} | "
            f"F={row['free_energy_mean']:.4f} | "
            f"Ecut_mean={row['expected_cut_mean']:.2f} | "
            f"hard_max={row['hard_cut_max']:.0f} | "
            f"best={row['best_cut_so_far']:.0f} | "
            f"S={row['entropy_mean']:.2f} | "
            f"R_mean={row['R_mean']:.4f} | "
            f"|rz|={row['rz_abs_mean']:.4f} | "
            f"elapsed={elapsed:.2f}s"
        )
# Out:
# step    1/1000 | beta=2.00 | gamma=0.0000 | F=-9865.2393 | Ecut_mean=9588.00 | hard_max=10367 | best=10367 | S=554.48 | R_mean=0.0099 | |rz|=0.0000 | elapsed=0.11s
# step  100/1000 | beta=1240.54 | gamma=0.0000 | F=-9590.1289 | Ecut_mean=9589.68 | hard_max=11396 | best=11396 | S=554.15 | R_mean=0.0305 | |rz|=0.0297 | elapsed=1.50s
# step  200/1000 | beta=2491.59 | gamma=0.0000 | F=-9720.6074 | Ecut_mean=9720.40 | hard_max=11401 | best=11401 | S=526.28 | R_mean=0.2654 | |rz|=0.2653 | elapsed=3.10s
# step  300/1000 | beta=3742.64 | gamma=0.0000 | F=-10726.4824 | Ecut_mean=10726.41 | hard_max=11419 | best=11419 | S=267.07 | R_mean=0.7862 | |rz|=0.7854 | elapsed=4.54s
# step  400/1000 | beta=4993.69 | gamma=0.0000 | F=-11119.0801 | Ecut_mean=11119.05 | hard_max=11428 | best=11428 | S=130.91 | R_mean=0.9205 | |rz|=0.9177 | elapsed=6.22s
# step  500/1000 | beta=6244.74 | gamma=0.0000 | F=-11240.1504 | Ecut_mean=11240.14 | hard_max=11443 | best=11443 | S=80.70 | R_mean=0.9580 | |rz|=0.9554 | elapsed=8.28s
# step  600/1000 | beta=7495.80 | gamma=0.0000 | F=-11294.6084 | Ecut_mean=11294.60 | hard_max=11462 | best=11462 | S=57.34 | R_mean=0.9726 | |rz|=0.9705 | elapsed=10.25s
# step  700/1000 | beta=8746.85 | gamma=0.0000 | F=-11325.5137 | Ecut_mean=11325.51 | hard_max=11468 | best=11468 | S=43.90 | R_mean=0.9802 | |rz|=0.9790 | elapsed=12.26s
# step  800/1000 | beta=9997.90 | gamma=0.0000 | F=-11344.2402 | Ecut_mean=11344.24 | hard_max=11473 | best=11473 | S=35.28 | R_mean=0.9847 | |rz|=0.9840 | elapsed=14.25s
# step  900/1000 | beta=11248.95 | gamma=0.0000 | F=-11356.4902 | Ecut_mean=11356.49 | hard_max=11473 | best=11473 | S=29.27 | R_mean=0.9878 | |rz|=0.9872 | elapsed=16.40s
# step 1000/1000 | beta=12500.00 | gamma=0.0000 | F=-11365.4355 | Ecut_mean=11365.43 | hard_max=11473 | best=11473 | S=24.85 | R_mean=0.9899 | |rz|=0.9894 | elapsed=18.59s

# %%
# ----------------------------
# Finalize history dataframe
# ----------------------------
runtime_zero = time.time() - start_time_zero

history_zero_df = pd.DataFrame(history_zero)

gap_zero = best_known - best_cut_zero
accuracy_zero = 100.0 * best_cut_zero / best_known

print("\n" + "=" * 80)
print("G1 QEFEM gamma=0 sanity run complete")
print("=" * 80)
print("Best cut:", best_cut_zero)
print("Best-known:", best_known)
print("Gap:", gap_zero)
print("Accuracy %:", accuracy_zero)
print("Best step:", best_step_zero)
print("Best replica:", best_replica_zero)
print("Runtime seconds:", runtime_zero)

print("\nVanilla reference:")
print("Vanilla cut:", vanilla_row["vanilla_cut"])
print("Vanilla gap:", vanilla_row["vanilla_gap"])
print("Vanilla accuracy %:", vanilla_row["vanilla_percent_accuracy"])

print("\nDelta vs vanilla:")
print("QEFEM gamma=0 cut - vanilla cut:", best_cut_zero - vanilla_row["vanilla_cut"])
print("QEFEM gamma=0 accuracy - vanilla accuracy:", accuracy_zero - vanilla_row["vanilla_percent_accuracy"])
# Out:
# ================================================================================
# G1 QEFEM gamma=0 sanity run complete
# ================================================================================
# Best cut: 11473.0
# Best-known: 11624
# Gap: 151.0
# Accuracy %: 98.70096352374398
# Best step: 763
# Best replica: 58
# Runtime seconds: 18.59985876083374
#
# Vanilla reference:
# Vanilla cut: 11446.0
# Vanilla gap: 178.0
# Vanilla accuracy %: 98.46868547832072
#
# Delta vs vanilla:
# QEFEM gamma=0 cut - vanilla cut: 27.0
# QEFEM gamma=0 accuracy - vanilla accuracy: 0.23227804542325714

# %% [markdown]
# #### QeFEM outperforms Vanilla FEM run by 0.23%

# %% [markdown]
# ### Now we inspect!

# %%
# Make sure history exists
assert "history_zero_df" in globals(), "Run Cell 14 first. The dataframe cannot be summoned from vibes."
assert len(history_zero_df) > 0, "history_zero_df is empty."

print("History shape:", history_zero_df.shape)
display(history_zero_df.head())
display(history_zero_df.tail())


# ----------------------------
# Save gamma=0 history
# ----------------------------
history_zero_path = OUTPUT_DIR / f"{instance}_qefem_gamma0_history.csv"
history_zero_df.to_csv(history_zero_path, index=False)

print("\nSaved gamma=0 history to:")
print(history_zero_path.resolve())
# Out:
# History shape: (1000, 21)
#    step       beta  gamma    loss_mean  free_energy_mean  expected_cut_mean  \
# 0     0   2.000000    0.0 -9865.239258      -9865.239258             9588.0
# 1     1  14.510510    0.0 -9626.211914      -9626.211914             9588.0
# 2     2  27.021021    0.0 -9608.520508      -9608.520508             9588.0
# 3     3  39.531532    0.0 -9602.026367      -9602.026367             9588.0
# 4     4  52.042042    0.0 -9598.654297      -9598.654297             9588.0
#
#    expected_cut_max  hard_cut_mean  hard_cut_max  best_cut_so_far  ...  \
# 0            9588.0    9888.617188       10367.0          10367.0  ...
# 1            9588.0    9582.593750       10881.0          10881.0  ...
# 2            9588.0   10725.585938       10958.0          10958.0  ...
# 3            9588.0   10717.890625       11036.0          11036.0  ...
# 4            9588.0   10909.617188       11072.0          11072.0  ...
#
#    driver_energy_mean    R_mean     R_min     R_max   rx_mean  rx_abs_mean  \
# 0                 0.0  0.009904  0.009862  0.009947  0.009904     0.009904
# 1                 0.0  0.009832  0.009790  0.009874  0.009832     0.009832
# 2                 0.0  0.009773  0.009731  0.009815  0.009773     0.009773
# 3                 0.0  0.009723  0.009682  0.009765  0.009722     0.009722
# 4                 0.0  0.009679  0.009638  0.009721  0.009678     0.009678
#
#         rz_mean  rz_abs_mean  grad_norm_raw_R  grad_norm_theta
# 0  2.929965e-07     0.000018         0.000124     8.666158e-07
# 1 -8.833248e-07     0.000036         0.000017     3.643227e-06
# 2  2.875068e-07     0.000054         0.000009     9.716818e-06
# 3  7.129265e-07     0.000085         0.000006     8.699752e-06
# 4  3.718265e-07     0.000122         0.000004     1.417477e-05
#
# [5 rows x 21 columns]
#      step          beta  gamma     loss_mean  free_energy_mean  \
# 995   995  12449.958008    0.0 -11365.125000     -11365.125000
# 996   996  12462.468750    0.0 -11365.203125     -11365.203125
# 997   997  12474.978516    0.0 -11365.281250     -11365.281250
# 998   998  12487.489258    0.0 -11365.358398     -11365.358398
# 999   999  12500.000000    0.0 -11365.435547     -11365.435547
#
#      expected_cut_mean  expected_cut_max  hard_cut_mean  hard_cut_max  \
# 995       11365.123047      11439.845703   11397.242188       11473.0
# 996       11365.201172      11439.908203   11397.257812       11473.0
# 997       11365.279297      11439.971680   11397.281250       11473.0
# 998       11365.356445      11440.034180   11397.281250       11473.0
# 999       11365.433594      11440.097656   11397.289062       11473.0
#
#      best_cut_so_far  ...  driver_energy_mean    R_mean     R_min     R_max  \
# 995          11473.0  ...                 0.0  0.989812  0.007842  0.999467
# 996          11473.0  ...                 0.0  0.989830  0.007850  0.999469
# 997          11473.0  ...                 0.0  0.989849  0.007858  0.999470
# 998          11473.0  ...                 0.0  0.989867  0.007865  0.999472
# 999          11473.0  ...                 0.0  0.989886  0.007873  0.999474
#
#       rx_mean  rx_abs_mean   rz_mean  rz_abs_mean  grad_norm_raw_R  \
# 995 -0.000055     0.000979 -0.000706     0.989362         0.113041
# 996 -0.000057     0.000975 -0.000704     0.989384         0.112834
# 997 -0.000061     0.000972 -0.000703     0.989407         0.112627
# 998 -0.000065     0.000969 -0.000702     0.989428         0.112421
# 999 -0.000068     0.000965 -0.000701     0.989448         0.112216
#
#      grad_norm_theta
# 995         0.038974
# 996         0.038854
# 997         0.038731
# 998         0.038611
# 999         0.038492
#
# [5 rows x 21 columns]
# Saved gamma=0 history to:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_v1_outputs/G1_qefem_gamma0_history.csv

# %%
qefem_gamma0_g1_summary = {
    "instance": instance,
    "nodes": N,
    "mode": "gamma_zero",
    "gamma_max": 0.0,
    "gamma_min": 0.0,
    "n_steps": N_STEPS,
    "replicas": REPLICAS,
    "seed": SEED,
    "lr": LR,
    "beta_min": BETA_MIN,
    "beta_max": BETA_MAX,
    "best_cut": best_cut_zero,
    "best_value": best_known,
    "gap": gap_zero,
    "percent_accuracy": accuracy_zero,
    "best_step": best_step_zero,
    "best_replica": best_replica_zero,
    "runtime_sec": runtime_zero,
    "vanilla_cut": float(vanilla_row["vanilla_cut"]),
    "vanilla_gap": float(vanilla_row["vanilla_gap"]),
    "vanilla_percent_accuracy": float(vanilla_row["vanilla_percent_accuracy"]),
    "delta_cut_vs_vanilla": best_cut_zero - float(vanilla_row["vanilla_cut"]),
    "delta_accuracy_vs_vanilla": accuracy_zero - float(vanilla_row["vanilla_percent_accuracy"]),
}

qefem_gamma0_g1_summary_df = pd.DataFrame([qefem_gamma0_g1_summary])

summary_zero_path = OUTPUT_DIR / f"{instance}_qefem_gamma0_summary.csv"
qefem_gamma0_g1_summary_df.to_csv(summary_zero_path, index=False)

print("\nGamma=0 G1 summary:")
display(qefem_gamma0_g1_summary_df)

print("\nSaved gamma=0 summary to:")
print(summary_zero_path.resolve())
# Out:
# Gamma=0 G1 summary:
#   instance  nodes        mode  gamma_max  gamma_min  n_steps  replicas  seed  \
# 0       G1    800  gamma_zero        0.0        0.0     1000       128     0
#
#      lr  beta_min  ...    gap  percent_accuracy  best_step  best_replica  \
# 0  0.01       2.0  ...  151.0         98.700964        763            58
#
#    runtime_sec  vanilla_cut  vanilla_gap  vanilla_percent_accuracy  \
# 0    18.599859      11446.0        178.0                 98.468685
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla
# 0                  27.0                   0.232278
#
# [1 rows x 23 columns]
# Saved gamma=0 summary to:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_v1_outputs/G1_qefem_gamma0_summary.csv

# %%
# ----------------------------
# Plot: hard cut trajectory
# ----------------------------
plt.figure(figsize=(8, 5))
plt.plot(history_zero_df["step"], history_zero_df["hard_cut_max"], label="step hard_cut_max")
plt.plot(history_zero_df["step"], history_zero_df["best_cut_so_far"], label="best_cut_so_far")
plt.axhline(best_known, linestyle="--", label="best-known")
plt.axhline(float(vanilla_row["vanilla_cut"]), linestyle="--", label="vanilla FEM")
plt.xlabel("Step")
plt.ylabel("Hard cut")
plt.title(f"{instance} QEFEM gamma=0: hard cut trajectory")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Plot: expected cut trajectory
# ----------------------------
plt.figure(figsize=(8, 5))
plt.plot(history_zero_df["step"], history_zero_df["expected_cut_mean"], label="expected_cut_mean")
plt.plot(history_zero_df["step"], history_zero_df["expected_cut_max"], label="expected_cut_max")
plt.axhline(best_known, linestyle="--", label="best-known")
plt.axhline(float(vanilla_row["vanilla_cut"]), linestyle="--", label="vanilla FEM")
plt.xlabel("Step")
plt.ylabel("Expected cut")
plt.title(f"{instance} QEFEM gamma=0: soft expected cut")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Plot: entropy and Bloch length
# ----------------------------
plt.figure(figsize=(8, 5))
plt.plot(history_zero_df["step"], history_zero_df["entropy_mean"], label="entropy_mean")
plt.xlabel("Step")
plt.ylabel("Entropy")
plt.title(f"{instance} QEFEM gamma=0: entropy")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(history_zero_df["step"], history_zero_df["R_mean"], label="R_mean")
plt.plot(history_zero_df["step"], history_zero_df["R_min"], label="R_min")
plt.plot(history_zero_df["step"], history_zero_df["R_max"], label="R_max")
plt.xlabel("Step")
plt.ylabel("Bloch length R")
plt.title(f"{instance} QEFEM gamma=0: Bloch length")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Plot: rx and rz behavior
# ----------------------------
plt.figure(figsize=(8, 5))
plt.plot(history_zero_df["step"], history_zero_df["rx_abs_mean"], label="|rx| mean")
plt.plot(history_zero_df["step"], history_zero_df["rz_abs_mean"], label="|rz| mean")
plt.xlabel("Step")
plt.ylabel("Mean absolute component")
plt.title(f"{instance} QEFEM gamma=0: component magnitudes")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Plot: gradient norms
# ----------------------------
plt.figure(figsize=(8, 5))
plt.plot(history_zero_df["step"], history_zero_df["grad_norm_raw_R"], label="grad_norm_raw_R")
plt.plot(history_zero_df["step"], history_zero_df["grad_norm_theta"], label="grad_norm_theta")
plt.xlabel("Step")
plt.ylabel("Gradient norm")
plt.title(f"{instance} QEFEM gamma=0: gradient norms")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Final interpretation printout
# ----------------------------
print("\nInterpretation:")
print(f"Best gamma=0 QEFEM cut: {best_cut_zero:.0f}")
print(f"Vanilla FEM cut: {float(vanilla_row['vanilla_cut']):.0f}")
print(f"Best-known cut: {best_known}")
print(f"Delta cut vs vanilla: {best_cut_zero - float(vanilla_row['vanilla_cut']):.0f}")
print(f"Delta accuracy vs vanilla: {accuracy_zero - float(vanilla_row['vanilla_percent_accuracy']):.4f} percentage points")

if best_cut_zero >= float(vanilla_row["vanilla_cut"]):
    print("\nVerdict: gamma=0 QEFEM is vanilla-esque and slightly better on this run.")
else:
    print("\nVerdict: gamma=0 QEFEM is below vanilla, but check closeness.")
# Out:
# Interpretation:
# Best gamma=0 QEFEM cut: 11473
# Vanilla FEM cut: 11446
# Best-known cut: 11624
# Delta cut vs vanilla: 27
# Delta accuracy vs vanilla: 0.2323 percentage points
#
# Verdict: gamma=0 QEFEM is vanilla-esque and slightly better on this run.

# %% [markdown]
# This is performing exactly as expected due to gamma reward = 0, rx (mixing) never grows!

# %% [markdown]
# #### Build single instance QeFEM runner
# for when multiple instances shall be built for different GSets in the for loop

# %%
def run_qefem_single_gset(
    instance_name,
    gamma_mode="anneal",
    replicas=REPLICAS,
    n_steps=N_STEPS,
    seed=SEED,
    lr=LR,
    beta_min=BETA_MIN,
    beta_max=BETA_MAX,
    gamma_max=GAMMA_MAX,
    gamma_min=GAMMA_MIN,
    R_init=R_INIT,
    theta_center=THETA_CENTER,
    theta_noise=THETA_NOISE,
    print_every=PRINT_EVERY,
    save_history=True,
    output_dir=OUTPUT_DIR,
    device=device,
    dtype=DTYPE,
):

    # ----------------------------
    # Load graph
    # ----------------------------
    instance_path = DATA_GSET_DIR / instance_name

    W_local, graph_info_local = load_gset_dense(
        instance_path,
        device=device,
        dtype=dtype,
        index_start=1,
    )

    n_local = W_local.shape[0]
    best_value_local = GSET_BEST_KNOWN_ALL[instance_name]

    vanilla_match = vanilla_compare_df.query("instance == @instance_name")

    if len(vanilla_match) != 1:
        raise ValueError(
            f"Expected exactly one vanilla baseline row for {instance_name}, "
            f"found {len(vanilla_match)}."
        )

    vanilla_row_local = vanilla_match.iloc[0]


    # ----------------------------
    # Initialize variables
    # ----------------------------
    raw_R_local, theta_local = initialize_qefem_variables(
        n=n_local,
        replicas=replicas,
        seed=seed,
        R_init=R_init,
        theta_center=theta_center,
        theta_noise=theta_noise,
        device=device,
        dtype=dtype,
    )

    optimizer_local = make_qefem_optimizer(
        raw_R=raw_R_local,
        theta=theta_local,
        lr=lr,
    )


    # ----------------------------
    # Build schedules
    # ----------------------------
    beta_schedule_local = make_beta_schedule(
        beta_min=beta_min,
        beta_max=beta_max,
        n_steps=n_steps,
        kind=BETA_SCHEDULE_KIND,
        device=device,
        dtype=dtype,
    )

    gamma_schedule_local = make_gamma_schedule(
        gamma_mode=gamma_mode,
        gamma_max=gamma_max,
        gamma_min=gamma_min,
        n_steps=n_steps,
        kind=GAMMA_SCHEDULE_KIND,
        device=device,
        dtype=dtype,
    )


    # ----------------------------
    # Run bookkeeping
    # ----------------------------
    history = []

    best_cut = -float("inf")
    best_step = None
    best_replica = None
    best_spins = None

    start_time = time.time()

    print("=" * 80)
    print(f"Running QEFEM single instance: {instance_name}")
    print("=" * 80)
    print("gamma_mode:", gamma_mode)
    print("N:", n_local)
    print("replicas:", replicas)
    print("n_steps:", n_steps)
    print("lr:", lr)
    print("beta:", beta_min, "->", beta_max)

    if gamma_mode == "zero":
        print("gamma: 0.0 fixed")
    elif gamma_mode == "anneal":
        print("gamma:", gamma_max, "->", gamma_min)

    print("best-known:", best_value_local)
    print("vanilla cut:", vanilla_row_local["vanilla_cut"])
    print("-" * 80)


    # ----------------------------
    # Training loop
    # ----------------------------
    for step in range(n_steps):
        beta_t = beta_schedule_local[step]
        gamma_t = gamma_schedule_local[step]

        optimizer_local.zero_grad()

        F, aux = qefem_free_energy_maxcut(
            W=W_local,
            raw_R=raw_R_local,
            theta=theta_local,
            beta=beta_t,
            gamma=gamma_t,
        )

        loss = F.mean()
        loss.backward()

        grad_norm_raw_R = raw_R_local.grad.detach().norm().item()
        grad_norm_theta = theta_local.grad.detach().norm().item()

        optimizer_local.step()

        with torch.no_grad():
            R_now, rx_now, rz_now = bloch_from_raw(raw_R_local, theta_local)

            spins_now = torch.where(
                rz_now >= 0,
                torch.ones_like(rz_now),
                -torch.ones_like(rz_now),
            )

            hard_cuts_now = discrete_cut(W_local, spins_now)

            step_best_cut = float(hard_cuts_now.max().detach().cpu())
            step_best_replica = int(torch.argmax(hard_cuts_now).detach().cpu())

            if step_best_cut > best_cut:
                best_cut = step_best_cut
                best_step = step
                best_replica = step_best_replica
                best_spins = spins_now[step_best_replica].detach().cpu().clone()

            row = {
                "instance": instance_name,
                "step": step,
                "beta": float(beta_t.detach().cpu()),
                "gamma": float(gamma_t.detach().cpu()),

                "loss_mean": float(loss.detach().cpu()),
                "free_energy_mean": float(F.mean().detach().cpu()),

                "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
                "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),

                "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
                "hard_cut_max": float(hard_cuts_now.max().detach().cpu()),
                "best_cut_so_far": best_cut,

                "entropy_mean": float(aux["entropy"].mean().detach().cpu()),
                "driver_energy_mean": float(aux["driver_energy"].mean().detach().cpu()),

                "R_mean": float(R_now.mean().detach().cpu()),
                "R_min": float(R_now.min().detach().cpu()),
                "R_max": float(R_now.max().detach().cpu()),

                "rx_mean": float(rx_now.mean().detach().cpu()),
                "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),

                "rz_mean": float(rz_now.mean().detach().cpu()),
                "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),

                "grad_norm_raw_R": grad_norm_raw_R,
                "grad_norm_theta": grad_norm_theta,
            }

            history.append(row)

        if (
            step == 0
            or (step + 1) % print_every == 0
            or step == n_steps - 1
        ):
            elapsed = time.time() - start_time

            print(
                f"{instance_name} | "
                f"step {step + 1:4d}/{n_steps} | "
                f"beta={row['beta']:.2f} | "
                f"gamma={row['gamma']:.4f} | "
                f"hard_max={row['hard_cut_max']:.0f} | "
                f"best={row['best_cut_so_far']:.0f} | "
                f"|rx|={row['rx_abs_mean']:.4f} | "
                f"|rz|={row['rz_abs_mean']:.4f} | "
                f"elapsed={elapsed:.2f}s"
            )


    # ----------------------------
    # Finalize
    # ----------------------------
    runtime = time.time() - start_time
    history_df = pd.DataFrame(history)

    gap = best_value_local - best_cut
    percent_accuracy = 100.0 * best_cut / best_value_local

    vanilla_cut = float(vanilla_row_local["vanilla_cut"])
    vanilla_gap = float(vanilla_row_local["vanilla_gap"])
    vanilla_percent_accuracy = float(vanilla_row_local["vanilla_percent_accuracy"])
    vanilla_runtime = float(vanilla_row_local["vanilla_tts_seconds"])

    summary = {
        "instance": instance_name,
        "nodes": n_local,
        "edges": graph_info_local["m_loaded"],

        "mode": f"qefem_{gamma_mode}",
        "gamma_mode": gamma_mode,
        "gamma_max": gamma_max if gamma_mode == "anneal" else 0.0,
        "gamma_min": gamma_min if gamma_mode == "anneal" else 0.0,

        "n_steps": n_steps,
        "replicas": replicas,
        "seed": seed,
        "lr": lr,
        "beta_min": beta_min,
        "beta_max": beta_max,

        "best_cut": best_cut,
        "best_value": best_value_local,
        "gap": gap,
        "percent_accuracy": percent_accuracy,
        "best_step": best_step,
        "best_replica": best_replica,
        "runtime_sec": runtime,

        "vanilla_cut": vanilla_cut,
        "vanilla_gap": vanilla_gap,
        "vanilla_percent_accuracy": vanilla_percent_accuracy,
        "vanilla_runtime_sec": vanilla_runtime,

        "delta_cut_vs_vanilla": best_cut - vanilla_cut,
        "delta_gap_vs_vanilla": vanilla_gap - gap,
        "delta_accuracy_vs_vanilla": percent_accuracy - vanilla_percent_accuracy,
        "runtime_ratio_vs_vanilla": runtime / vanilla_runtime if vanilla_runtime > 0 else np.nan,
    }


    # ----------------------------
    # Save history if requested
    # ----------------------------
    if save_history:
        output_dir = Path(output_dir)
        output_dir.mkdir(exist_ok=True)

        history_path = output_dir / f"{instance_name}_qefem_{gamma_mode}_history.csv"
        history_df.to_csv(history_path, index=False)

        summary_path = output_dir / f"{instance_name}_qefem_{gamma_mode}_summary.csv"
        pd.DataFrame([summary]).to_csv(summary_path, index=False)

        summary["history_path"] = str(history_path)
        summary["summary_path"] = str(summary_path)


    print("\nFinished:", instance_name)
    print("Best cut:", best_cut)
    print("Best-known:", best_value_local)
    print("Gap:", gap)
    print("Accuracy %:", percent_accuracy)
    print("Vanilla cut:", vanilla_cut)
    print("Delta cut vs vanilla:", best_cut - vanilla_cut)
    print("Runtime sec:", runtime)
    print("-" * 80)

    return summary, history_df

# %% [markdown]
# ### Run Batch 1 ---> {G1,..G10}

# %%
assert "run_qefem_single_gset" in globals(), "Run Cell 18 first. Wrapper function is missing."

qefem_g1_g10_summaries = []
qefem_g1_g10_histories = {}

g1_g10_output_path = OUTPUT_DIR / "qefem_anneal_G1_G10_partial_results.csv"

print("=" * 80)
print("Starting QEFEM gamma anneal sweep: G1-G10")
print("=" * 80)
print("Instances:", GSET_FIRST_SWEEP)
print("Partial results will be saved to:")
print(g1_g10_output_path.resolve())
print("=" * 80)
# Out:
# ================================================================================
# Starting QEFEM gamma anneal sweep: G1-G10
# ================================================================================
# Instances: ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10']
# Partial results will be saved to:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_v1_outputs/qefem_anneal_G1_G10_partial_results.csv
# ================================================================================

# %%
for run_idx, instance_name in enumerate(GSET_FIRST_SWEEP, start=1):
    print("\n\n" + "#" * 80)
    print(f"G1-G10 sweep item {run_idx}/{len(GSET_FIRST_SWEEP)}: {instance_name}")
    print("#" * 80)

    summary, history_df = run_qefem_single_gset(
        instance_name=instance_name,
        gamma_mode="anneal",
        replicas=REPLICAS,
        n_steps=N_STEPS,
        seed=SEED,
        lr=LR,
        beta_min=BETA_MIN,
        beta_max=BETA_MAX,
        gamma_max=GAMMA_MAX,
        gamma_min=GAMMA_MIN,
        R_init=R_INIT,
        theta_center=THETA_CENTER,
        theta_noise=THETA_NOISE,
        print_every=PRINT_EVERY,
        save_history=True,
        output_dir=OUTPUT_DIR,
        device=device,
        dtype=DTYPE,
    )

    qefem_g1_g10_summaries.append(summary)
    qefem_g1_g10_histories[instance_name] = history_df

    # Save partial summary after every graph because notebooks enjoy dying at bad times.
    qefem_g1_g10_results_df = pd.DataFrame(qefem_g1_g10_summaries)
    qefem_g1_g10_results_df.to_csv(g1_g10_output_path, index=False)

    print("\nCurrent partial G1-G10 results:")
    display(qefem_g1_g10_results_df[
        [
            "instance",
            "best_cut",
            "best_value",
            "gap",
            "percent_accuracy",
            "vanilla_cut",
            "delta_cut_vs_vanilla",
            "delta_accuracy_vs_vanilla",
            "runtime_sec",
        ]
    ])
# Out:
# ################################################################################
# G1-G10 sweep item 1/10: G1
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G1
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 11624
# vanilla cut: 11446.0
# --------------------------------------------------------------------------------
# G1 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=9647 | best=9647 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G1 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=9788 | best=9904 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.84s
# G1 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=7848 | best=9904 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.91s
# G1 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=11600 | best=11600 | |rx|=0.1821 | |rz|=0.6212 | elapsed=5.98s
# G1 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=11610 | best=11610 | |rx|=0.1697 | |rz|=0.8784 | elapsed=7.96s
# G1 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=11611 | best=11611 | |rx|=0.1464 | |rz|=0.9317 | elapsed=9.99s
# G1 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=11611 | best=11611 | |rx|=0.1207 | |rz|=0.9541 | elapsed=12.03s
# G1 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=11611 | best=11611 | |rx|=0.0938 | |rz|=0.9672 | elapsed=14.12s
# G1 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=11611 | best=11611 | |rx|=0.0655 | |rz|=0.9759 | elapsed=16.23s
# G1 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=11611 | best=11611 | |rx|=0.0359 | |rz|=0.9818 | elapsed=18.26s
# G1 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=11611 | best=11611 | |rx|=0.0035 | |rz|=0.9878 | elapsed=20.34s
#
# Finished: G1
# Best cut: 11611.0
# Best-known: 11624
# Gap: 13.0
# Accuracy %: 99.88816242257398
# Vanilla cut: 11446.0
# Delta cut vs vanilla: 165.0
# Runtime sec: 20.340349197387695
# --------------------------------------------------------------------------------
#
# Current partial G1-G10 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0       G1   11611.0       11624  13.0         99.888162      11446.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                 165.0                   1.419477    20.340349
# ################################################################################
# G1-G10 sweep item 2/10: G2
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G2
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 11620
# vanilla cut: 11435.0
# --------------------------------------------------------------------------------
# G2 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=9723 | best=9723 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G2 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=9803 | best=9912 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.62s
# G2 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=3731 | best=9912 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.67s
# G2 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=11594 | best=11594 | |rx|=0.1816 | |rz|=0.6219 | elapsed=5.79s
# G2 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=11610 | best=11610 | |rx|=0.1700 | |rz|=0.8781 | elapsed=7.77s
# G2 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=11610 | best=11610 | |rx|=0.1467 | |rz|=0.9313 | elapsed=9.79s
# G2 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=11610 | best=11610 | |rx|=0.1210 | |rz|=0.9538 | elapsed=11.90s
# G2 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=11610 | best=11610 | |rx|=0.0941 | |rz|=0.9669 | elapsed=13.94s
# G2 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=11610 | best=11610 | |rx|=0.0658 | |rz|=0.9755 | elapsed=16.03s
# G2 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=11610 | best=11610 | |rx|=0.0362 | |rz|=0.9814 | elapsed=18.11s
# G2 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=11610 | best=11610 | |rx|=0.0038 | |rz|=0.9877 | elapsed=20.15s
#
# Finished: G2
# Best cut: 11610.0
# Best-known: 11620
# Gap: 10.0
# Accuracy %: 99.91394148020655
# Vanilla cut: 11435.0
# Delta cut vs vanilla: 175.0
# Runtime sec: 20.147006034851074
# --------------------------------------------------------------------------------
#
# Current partial G1-G10 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0       G1   11611.0       11624  13.0         99.888162      11446.0
# 1       G2   11610.0       11620  10.0         99.913941      11435.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                 165.0                   1.419477    20.340349
# 1                 175.0                   1.506024    20.147006
# ################################################################################
# G1-G10 sweep item 3/10: G3
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G3
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 11622
# vanilla cut: 11443.0
# --------------------------------------------------------------------------------
# G3 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=9716 | best=9716 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G3 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=9784 | best=9901 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.63s
# G3 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=7408 | best=9901 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.75s
# G3 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=11601 | best=11601 | |rx|=0.1812 | |rz|=0.6223 | elapsed=5.84s
# G3 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=11608 | best=11609 | |rx|=0.1694 | |rz|=0.8783 | elapsed=7.80s
# G3 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=11610 | best=11610 | |rx|=0.1459 | |rz|=0.9316 | elapsed=9.76s
# G3 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=11610 | best=11610 | |rx|=0.1205 | |rz|=0.9538 | elapsed=11.74s
# G3 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=11610 | best=11610 | |rx|=0.0937 | |rz|=0.9669 | elapsed=13.74s
# G3 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=11610 | best=11610 | |rx|=0.0656 | |rz|=0.9755 | elapsed=15.78s
# G3 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=11610 | best=11610 | |rx|=0.0362 | |rz|=0.9814 | elapsed=17.72s
# G3 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=11610 | best=11610 | |rx|=0.0038 | |rz|=0.9878 | elapsed=19.71s
#
# Finished: G3
# Best cut: 11610.0
# Best-known: 11622
# Gap: 12.0
# Accuracy %: 99.89674754775426
# Vanilla cut: 11443.0
# Delta cut vs vanilla: 167.0
# Runtime sec: 19.713758945465088
# --------------------------------------------------------------------------------
#
# Current partial G1-G10 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0       G1   11611.0       11624  13.0         99.888162      11446.0
# 1       G2   11610.0       11620  10.0         99.913941      11435.0
# 2       G3   11610.0       11622  12.0         99.896748      11443.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                 165.0                   1.419477    20.340349
# 1                 175.0                   1.506024    20.147006
# 2                 167.0                   1.436930    19.713759
# ################################################################################
# G1-G10 sweep item 4/10: G4
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G4
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 11646
# vanilla cut: 11503.0
# --------------------------------------------------------------------------------
# G4 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=9692 | best=9692 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G4 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=9890 | best=9906 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.70s
# G4 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=2275 | best=9906 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.73s
# G4 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=11620 | best=11620 | |rx|=0.1796 | |rz|=0.6240 | elapsed=5.79s
# G4 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=11631 | best=11631 | |rx|=0.1681 | |rz|=0.8786 | elapsed=7.92s
# G4 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=11637 | best=11637 | |rx|=0.1448 | |rz|=0.9317 | elapsed=9.93s
# G4 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=11637 | best=11637 | |rx|=0.1194 | |rz|=0.9541 | elapsed=12.05s
# G4 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=11637 | best=11637 | |rx|=0.0928 | |rz|=0.9671 | elapsed=14.11s
# G4 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=11637 | best=11637 | |rx|=0.0649 | |rz|=0.9757 | elapsed=16.21s
# G4 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=11637 | best=11637 | |rx|=0.0358 | |rz|=0.9815 | elapsed=18.25s
# G4 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=11637 | best=11637 | |rx|=0.0037 | |rz|=0.9877 | elapsed=20.27s
#
# Finished: G4
# Best cut: 11637.0
# Best-known: 11646
# Gap: 9.0
# Accuracy %: 99.9227202472952
# Vanilla cut: 11503.0
# Delta cut vs vanilla: 134.0
# Runtime sec: 20.27332091331482
# --------------------------------------------------------------------------------
#
# Current partial G1-G10 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0       G1   11611.0       11624  13.0         99.888162      11446.0
# 1       G2   11610.0       11620  10.0         99.913941      11435.0
# 2       G3   11610.0       11622  12.0         99.896748      11443.0
# 3       G4   11637.0       11646   9.0         99.922720      11503.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                 165.0                   1.419477    20.340349
# 1                 175.0                   1.506024    20.147006
# 2                 167.0                   1.436930    19.713759
# 3                 134.0                   1.150610    20.273321
# ################################################################################
# G1-G10 sweep item 5/10: G5
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G5
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 11631
# vanilla cut: 11450.0
# --------------------------------------------------------------------------------
# G5 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=9670 | best=9670 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G5 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=9785 | best=9916 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.42s
# G5 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=9454 | best=9916 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.47s
# G5 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=11613 | best=11613 | |rx|=0.1805 | |rz|=0.6234 | elapsed=5.63s
# G5 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=11621 | best=11621 | |rx|=0.1692 | |rz|=0.8784 | elapsed=7.66s
# G5 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=11622 | best=11622 | |rx|=0.1462 | |rz|=0.9311 | elapsed=9.70s
# G5 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=11622 | best=11622 | |rx|=0.1207 | |rz|=0.9536 | elapsed=11.72s
# G5 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=11622 | best=11622 | |rx|=0.0939 | |rz|=0.9666 | elapsed=13.71s
# G5 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=11622 | best=11622 | |rx|=0.0658 | |rz|=0.9752 | elapsed=15.75s
# G5 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=11622 | best=11622 | |rx|=0.0364 | |rz|=0.9810 | elapsed=17.83s
# G5 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=11622 | best=11622 | |rx|=0.0041 | |rz|=0.9876 | elapsed=19.92s
#
# Finished: G5
# Best cut: 11622.0
# Best-known: 11631
# Gap: 9.0
# Accuracy %: 99.92262058292494
# Vanilla cut: 11450.0
# Delta cut vs vanilla: 172.0
# Runtime sec: 19.919530868530273
# --------------------------------------------------------------------------------
#
# Current partial G1-G10 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0       G1   11611.0       11624  13.0         99.888162      11446.0
# 1       G2   11610.0       11620  10.0         99.913941      11435.0
# 2       G3   11610.0       11622  12.0         99.896748      11443.0
# 3       G4   11637.0       11646   9.0         99.922720      11503.0
# 4       G5   11622.0       11631   9.0         99.922621      11450.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                 165.0                   1.419477    20.340349
# 1                 175.0                   1.506024    20.147006
# 2                 167.0                   1.436930    19.713759
# 3                 134.0                   1.150610    20.273321
# 4                 172.0                   1.478807    19.919531
# ################################################################################
# G1-G10 sweep item 6/10: G6
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G6
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 2178
# vanilla cut: 1978.0
# --------------------------------------------------------------------------------
# G6 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=211 | best=211 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G6 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=260 | best=402 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.66s
# G6 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1861 | best=1861 | |rx|=0.1512 | |rz|=0.0003 | elapsed=3.83s
# G6 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=2165 | best=2165 | |rx|=0.1750 | |rz|=0.6363 | elapsed=6.00s
# G6 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=2171 | best=2171 | |rx|=0.1638 | |rz|=0.8799 | elapsed=8.12s
# G6 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=2173 | best=2173 | |rx|=0.1416 | |rz|=0.9321 | elapsed=10.17s
# G6 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=2173 | best=2173 | |rx|=0.1171 | |rz|=0.9542 | elapsed=12.23s
# G6 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=2173 | best=2173 | |rx|=0.0910 | |rz|=0.9672 | elapsed=14.37s
# G6 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=2173 | best=2173 | |rx|=0.0636 | |rz|=0.9758 | elapsed=16.50s
# G6 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=2173 | best=2173 | |rx|=0.0349 | |rz|=0.9815 | elapsed=18.53s
# G6 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=2173 | best=2173 | |rx|=0.0033 | |rz|=0.9880 | elapsed=20.54s
#
# Finished: G6
# Best cut: 2173.0
# Best-known: 2178
# Gap: 5.0
# Accuracy %: 99.7704315886134
# Vanilla cut: 1978.0
# Delta cut vs vanilla: 195.0
# Runtime sec: 20.54370093345642
# --------------------------------------------------------------------------------
#
# Current partial G1-G10 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0       G1   11611.0       11624  13.0         99.888162      11446.0
# 1       G2   11610.0       11620  10.0         99.913941      11435.0
# 2       G3   11610.0       11622  12.0         99.896748      11443.0
# 3       G4   11637.0       11646   9.0         99.922720      11503.0
# 4       G5   11622.0       11631   9.0         99.922621      11450.0
# 5       G6    2173.0        2178   5.0         99.770432       1978.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                 165.0                   1.419477    20.340349
# 1                 175.0                   1.506024    20.147006
# 2                 167.0                   1.436930    19.713759
# 3                 134.0                   1.150610    20.273321
# 4                 172.0                   1.478807    19.919531
# 5                 195.0                   8.953168    20.543701
# ################################################################################
# G1-G10 sweep item 7/10: G7
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G7
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 2006
# vanilla cut: 1822.0
# --------------------------------------------------------------------------------
# G7 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=24 | best=24 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G7 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=211 | best=278 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.68s
# G7 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1525 | best=1525 | |rx|=0.1512 | |rz|=0.0003 | elapsed=3.77s
# G7 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=1977 | best=1977 | |rx|=0.1768 | |rz|=0.6347 | elapsed=5.93s
# G7 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=1992 | best=1992 | |rx|=0.1655 | |rz|=0.8792 | elapsed=7.93s
# G7 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=1992 | best=1992 | |rx|=0.1430 | |rz|=0.9315 | elapsed=9.89s
# G7 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=1992 | best=1992 | |rx|=0.1182 | |rz|=0.9538 | elapsed=11.99s
# G7 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=1992 | best=1992 | |rx|=0.0920 | |rz|=0.9667 | elapsed=13.94s
# G7 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=1992 | best=1992 | |rx|=0.0644 | |rz|=0.9753 | elapsed=15.98s
# G7 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=1992 | best=1992 | |rx|=0.0356 | |rz|=0.9810 | elapsed=18.01s
# G7 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=1992 | best=1992 | |rx|=0.0037 | |rz|=0.9877 | elapsed=19.92s
#
# Finished: G7
# Best cut: 1992.0
# Best-known: 2006
# Gap: 14.0
# Accuracy %: 99.30209371884347
# Vanilla cut: 1822.0
# Delta cut vs vanilla: 170.0
# Runtime sec: 19.921515941619873
# --------------------------------------------------------------------------------
#
# Current partial G1-G10 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0       G1   11611.0       11624  13.0         99.888162      11446.0
# 1       G2   11610.0       11620  10.0         99.913941      11435.0
# 2       G3   11610.0       11622  12.0         99.896748      11443.0
# 3       G4   11637.0       11646   9.0         99.922720      11503.0
# 4       G5   11622.0       11631   9.0         99.922621      11450.0
# 5       G6    2173.0        2178   5.0         99.770432       1978.0
# 6       G7    1992.0        2006  14.0         99.302094       1822.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                 165.0                   1.419477    20.340349
# 1                 175.0                   1.506024    20.147006
# 2                 167.0                   1.436930    19.713759
# 3                 134.0                   1.150610    20.273321
# 4                 172.0                   1.478807    19.919531
# 5                 195.0                   8.953168    20.543701
# 6                 170.0                   8.474576    19.921516
# ################################################################################
# G1-G10 sweep item 8/10: G8
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G8
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 2005
# vanilla cut: 1856.0
# --------------------------------------------------------------------------------
# G8 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=5 | best=5 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G8 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=115 | best=215 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.62s
# G8 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1630 | best=1630 | |rx|=0.1512 | |rz|=0.0004 | elapsed=3.73s
# G8 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=1981 | best=1982 | |rx|=0.1762 | |rz|=0.6354 | elapsed=5.89s
# G8 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=1989 | best=1989 | |rx|=0.1651 | |rz|=0.8793 | elapsed=7.99s
# G8 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=1991 | best=1991 | |rx|=0.1428 | |rz|=0.9315 | elapsed=9.97s
# G8 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=1991 | best=1991 | |rx|=0.1180 | |rz|=0.9538 | elapsed=11.96s
# G8 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=1991 | best=1991 | |rx|=0.0918 | |rz|=0.9667 | elapsed=13.99s
# G8 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=1991 | best=1991 | |rx|=0.0643 | |rz|=0.9753 | elapsed=15.97s
# G8 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=1991 | best=1991 | |rx|=0.0355 | |rz|=0.9811 | elapsed=17.87s
# G8 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=1991 | best=1991 | |rx|=0.0036 | |rz|=0.9878 | elapsed=20.03s
#
# Finished: G8
# Best cut: 1991.0
# Best-known: 2005
# Gap: 14.0
# Accuracy %: 99.30174563591022
# Vanilla cut: 1856.0
# Delta cut vs vanilla: 135.0
# Runtime sec: 20.028872966766357
# --------------------------------------------------------------------------------
#
# Current partial G1-G10 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0       G1   11611.0       11624  13.0         99.888162      11446.0
# 1       G2   11610.0       11620  10.0         99.913941      11435.0
# 2       G3   11610.0       11622  12.0         99.896748      11443.0
# 3       G4   11637.0       11646   9.0         99.922720      11503.0
# 4       G5   11622.0       11631   9.0         99.922621      11450.0
# 5       G6    2173.0        2178   5.0         99.770432       1978.0
# 6       G7    1992.0        2006  14.0         99.302094       1822.0
# 7       G8    1991.0        2005  14.0         99.301746       1856.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                 165.0                   1.419477    20.340349
# 1                 175.0                   1.506024    20.147006
# 2                 167.0                   1.436930    19.713759
# 3                 134.0                   1.150610    20.273321
# 4                 172.0                   1.478807    19.919531
# 5                 195.0                   8.953168    20.543701
# 6                 170.0                   8.474576    19.921516
# 7                 135.0                   6.733167    20.028873
# ################################################################################
# G1-G10 sweep item 9/10: G9
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G9
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 2054
# vanilla cut: 1840.0
# --------------------------------------------------------------------------------
# G9 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=80 | best=80 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G9 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=177 | best=272 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.64s
# G9 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1655 | best=1655 | |rx|=0.1512 | |rz|=0.0003 | elapsed=3.66s
# G9 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=2040 | best=2040 | |rx|=0.1762 | |rz|=0.6353 | elapsed=5.70s
# G9 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=2041 | best=2041 | |rx|=0.1650 | |rz|=0.8795 | elapsed=7.71s
# G9 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=2041 | best=2041 | |rx|=0.1429 | |rz|=0.9315 | elapsed=9.69s
# G9 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=2041 | best=2041 | |rx|=0.1182 | |rz|=0.9537 | elapsed=11.57s
# G9 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=2041 | best=2041 | |rx|=0.0920 | |rz|=0.9666 | elapsed=13.75s
# G9 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=2041 | best=2041 | |rx|=0.0645 | |rz|=0.9752 | elapsed=15.80s
# G9 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=2041 | best=2041 | |rx|=0.0357 | |rz|=0.9809 | elapsed=17.91s
# G9 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=2041 | best=2041 | |rx|=0.0037 | |rz|=0.9877 | elapsed=19.82s
#
# Finished: G9
# Best cut: 2041.0
# Best-known: 2054
# Gap: 13.0
# Accuracy %: 99.36708860759494
# Vanilla cut: 1840.0
# Delta cut vs vanilla: 201.0
# Runtime sec: 19.82308793067932
# --------------------------------------------------------------------------------
#
# Current partial G1-G10 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0       G1   11611.0       11624  13.0         99.888162      11446.0
# 1       G2   11610.0       11620  10.0         99.913941      11435.0
# 2       G3   11610.0       11622  12.0         99.896748      11443.0
# 3       G4   11637.0       11646   9.0         99.922720      11503.0
# 4       G5   11622.0       11631   9.0         99.922621      11450.0
# 5       G6    2173.0        2178   5.0         99.770432       1978.0
# 6       G7    1992.0        2006  14.0         99.302094       1822.0
# 7       G8    1991.0        2005  14.0         99.301746       1856.0
# 8       G9    2041.0        2054  13.0         99.367089       1840.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                 165.0                   1.419477    20.340349
# 1                 175.0                   1.506024    20.147006
# 2                 167.0                   1.436930    19.713759
# 3                 134.0                   1.150610    20.273321
# 4                 172.0                   1.478807    19.919531
# 5                 195.0                   8.953168    20.543701
# 6                 170.0                   8.474576    19.921516
# 7                 135.0                   6.733167    20.028873
# 8                 201.0                   9.785784    19.823088
# ################################################################################
# G1-G10 sweep item 10/10: G10
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G10
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 2000
# vanilla cut: 1819.0
# --------------------------------------------------------------------------------
# G10 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=27 | best=27 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G10 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=111 | best=226 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.45s
# G10 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1428 | best=1428 | |rx|=0.1512 | |rz|=0.0003 | elapsed=3.49s
# G10 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=1983 | best=1983 | |rx|=0.1769 | |rz|=0.6343 | elapsed=5.61s
# G10 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=1991 | best=1991 | |rx|=0.1653 | |rz|=0.8793 | elapsed=7.37s
# G10 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=1991 | best=1991 | |rx|=0.1430 | |rz|=0.9313 | elapsed=9.32s
# G10 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=1992 | best=1992 | |rx|=0.1183 | |rz|=0.9535 | elapsed=11.31s
# G10 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=1992 | best=1992 | |rx|=0.0921 | |rz|=0.9664 | elapsed=13.31s
# G10 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=1992 | best=1992 | |rx|=0.0647 | |rz|=0.9749 | elapsed=15.18s
# G10 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=1992 | best=1992 | |rx|=0.0359 | |rz|=0.9807 | elapsed=17.14s
# G10 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=1992 | best=1992 | |rx|=0.0038 | |rz|=0.9877 | elapsed=19.07s
#
# Finished: G10
# Best cut: 1992.0
# Best-known: 2000
# Gap: 8.0
# Accuracy %: 99.6
# Vanilla cut: 1819.0
# Delta cut vs vanilla: 173.0
# Runtime sec: 19.065519094467163
# --------------------------------------------------------------------------------
#
# Current partial G1-G10 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0       G1   11611.0       11624  13.0         99.888162      11446.0
# 1       G2   11610.0       11620  10.0         99.913941      11435.0
# 2       G3   11610.0       11622  12.0         99.896748      11443.0
# 3       G4   11637.0       11646   9.0         99.922720      11503.0
# 4       G5   11622.0       11631   9.0         99.922621      11450.0
# 5       G6    2173.0        2178   5.0         99.770432       1978.0
# 6       G7    1992.0        2006  14.0         99.302094       1822.0
# 7       G8    1991.0        2005  14.0         99.301746       1856.0
# 8       G9    2041.0        2054  13.0         99.367089       1840.0
# 9      G10    1992.0        2000   8.0         99.600000       1819.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                 165.0                   1.419477    20.340349
# 1                 175.0                   1.506024    20.147006
# 2                 167.0                   1.436930    19.713759
# 3                 134.0                   1.150610    20.273321
# 4                 172.0                   1.478807    19.919531
# 5                 195.0                   8.953168    20.543701
# 6                 170.0                   8.474576    19.921516
# 7                 135.0                   6.733167    20.028873
# 8                 201.0                   9.785784    19.823088
# 9                 173.0                   8.650000    19.065519

# %%
# ----------------------------
# Finalize G1-G10 result file
# ----------------------------
qefem_g1_g10_results_df = pd.DataFrame(qefem_g1_g10_summaries)

final_g1_g10_path = OUTPUT_DIR / "qefem_anneal_G1_G10_final_results.csv"
qefem_g1_g10_results_df.to_csv(final_g1_g10_path, index=False)

print("\n" + "=" * 80)
print("G1-G10 QEFEM gamma anneal sweep complete")
print("=" * 80)

display(qefem_g1_g10_results_df[
    [
        "instance",
        "best_cut",
        "best_value",
        "gap",
        "percent_accuracy",
        "vanilla_cut",
        "delta_cut_vs_vanilla",
        "delta_accuracy_vs_vanilla",
        "runtime_sec",
    ]
])

print("\nSaved final G1-G10 results to:")
print(final_g1_g10_path.resolve())
# Out:
# ================================================================================
# G1-G10 QEFEM gamma anneal sweep complete
# ================================================================================
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0       G1   11611.0       11624  13.0         99.888162      11446.0
# 1       G2   11610.0       11620  10.0         99.913941      11435.0
# 2       G3   11610.0       11622  12.0         99.896748      11443.0
# 3       G4   11637.0       11646   9.0         99.922720      11503.0
# 4       G5   11622.0       11631   9.0         99.922621      11450.0
# 5       G6    2173.0        2178   5.0         99.770432       1978.0
# 6       G7    1992.0        2006  14.0         99.302094       1822.0
# 7       G8    1991.0        2005  14.0         99.301746       1856.0
# 8       G9    2041.0        2054  13.0         99.367089       1840.0
# 9      G10    1992.0        2000   8.0         99.600000       1819.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                 165.0                   1.419477    20.340349
# 1                 175.0                   1.506024    20.147006
# 2                 167.0                   1.436930    19.713759
# 3                 134.0                   1.150610    20.273321
# 4                 172.0                   1.478807    19.919531
# 5                 195.0                   8.953168    20.543701
# 6                 170.0                   8.474576    19.921516
# 7                 135.0                   6.733167    20.028873
# 8                 201.0                   9.785784    19.823088
# 9                 173.0                   8.650000    19.065519
# Saved final G1-G10 results to:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_v1_outputs/qefem_anneal_G1_G10_final_results.csv

# %%
# ----------------------------
# Aggregate summary
# ----------------------------
num_wins = int((qefem_g1_g10_results_df["delta_cut_vs_vanilla"] > 0).sum())
num_ties = int((qefem_g1_g10_results_df["delta_cut_vs_vanilla"] == 0).sum())
num_losses = int((qefem_g1_g10_results_df["delta_cut_vs_vanilla"] < 0).sum())

mean_delta_cut = float(qefem_g1_g10_results_df["delta_cut_vs_vanilla"].mean())
mean_delta_accuracy = float(qefem_g1_g10_results_df["delta_accuracy_vs_vanilla"].mean())
mean_accuracy = float(qefem_g1_g10_results_df["percent_accuracy"].mean())
mean_runtime = float(qefem_g1_g10_results_df["runtime_sec"].mean())

print("\nAggregate G1-G10 summary:")
print("Wins vs vanilla:", num_wins)
print("Ties vs vanilla:", num_ties)
print("Losses vs vanilla:", num_losses)
print("Mean delta cut vs vanilla:", mean_delta_cut)
print("Mean delta accuracy vs vanilla:", mean_delta_accuracy)
print("Mean QEFEM accuracy %:", mean_accuracy)
print("Mean runtime sec:", mean_runtime)
# Out:
# Aggregate G1-G10 summary:
# Wins vs vanilla: 10
# Ties vs vanilla: 0
# Losses vs vanilla: 0
# Mean delta cut vs vanilla: 168.7
# Mean delta accuracy vs vanilla: 4.958854252385012
# Mean QEFEM accuracy %: 99.6885551831717
# Mean runtime sec: 19.977666282653807

# %% [markdown]
# ### Inference & Diagnostics

# %%
# ============================================================
# Cell 20: Analyze G1-G10 QEFEM vs vanilla results
# ============================================================

# This cell does NOT rerun anything.
# It analyzes the completed G1-G10 QEFEM anneal sweep from Cell 19.

assert "qefem_g1_g10_results_df" in globals(), (
    "Run Cell 19 first. qefem_g1_g10_results_df does not exist."
)

assert len(qefem_g1_g10_results_df) > 0, (
    "qefem_g1_g10_results_df is empty. The dataframe goblin ate your sweep."
)


# ----------------------------
# Make clean comparison dataframe
# ----------------------------
g1_g10_analysis_df = qefem_g1_g10_results_df.copy()

# Helpful columns
g1_g10_analysis_df["cut_improvement_percent_vs_vanilla"] = (
    100.0
    * g1_g10_analysis_df["delta_cut_vs_vanilla"]
    / g1_g10_analysis_df["vanilla_cut"]
)

g1_g10_analysis_df["gap_reduction_percent_vs_vanilla"] = (
    100.0
    * g1_g10_analysis_df["delta_gap_vs_vanilla"]
    / g1_g10_analysis_df["vanilla_gap"]
)

g1_g10_analysis_df["qefem_minus_best_known"] = (
    g1_g10_analysis_df["best_cut"] - g1_g10_analysis_df["best_value"]
)

g1_g10_analysis_df["hit_best_known"] = (
    g1_g10_analysis_df["best_cut"] >= g1_g10_analysis_df["best_value"]
)

g1_g10_analysis_df["winner"] = np.where(
    g1_g10_analysis_df["delta_cut_vs_vanilla"] > 0,
    "QEFEM",
    np.where(
        g1_g10_analysis_df["delta_cut_vs_vanilla"] < 0,
        "Vanilla",
        "Tie",
    )
)

# %%
# ----------------------------
# Display main table
# ----------------------------
main_cols = [
    "instance",
    "best_cut",
    "vanilla_cut",
    "best_value",
    "gap",
    "vanilla_gap",
    "percent_accuracy",
    "vanilla_percent_accuracy",
    "delta_cut_vs_vanilla",
    "cut_improvement_percent_vs_vanilla",
    "delta_accuracy_vs_vanilla",
    "gap_reduction_percent_vs_vanilla",
    "runtime_sec",
    "vanilla_runtime_sec",
    "runtime_ratio_vs_vanilla",
    "winner",
]

print("G1-G10 QEFEM vs vanilla comparison:")
display(g1_g10_analysis_df[main_cols])


# ----------------------------
# Save analysis table
# ----------------------------
g1_g10_analysis_path = OUTPUT_DIR / "qefem_anneal_G1_G10_analysis_vs_vanilla.csv"
g1_g10_analysis_df.to_csv(g1_g10_analysis_path, index=False)

print("\nSaved G1-G10 analysis to:")
print(g1_g10_analysis_path.resolve())
# Out:
# G1-G10 QEFEM vs vanilla comparison:
#   instance  best_cut  vanilla_cut  best_value   gap  vanilla_gap  \
# 0       G1   11611.0      11446.0       11624  13.0        178.0
# 1       G2   11610.0      11435.0       11620  10.0        185.0
# 2       G3   11610.0      11443.0       11622  12.0        179.0
# 3       G4   11637.0      11503.0       11646   9.0        143.0
# 4       G5   11622.0      11450.0       11631   9.0        181.0
# 5       G6    2173.0       1978.0        2178   5.0        200.0
# 6       G7    1992.0       1822.0        2006  14.0        184.0
# 7       G8    1991.0       1856.0        2005  14.0        149.0
# 8       G9    2041.0       1840.0        2054  13.0        214.0
# 9      G10    1992.0       1819.0        2000   8.0        181.0
#
#    percent_accuracy  vanilla_percent_accuracy  delta_cut_vs_vanilla  \
# 0         99.888162                 98.468685                 165.0
# 1         99.913941                 98.407917                 175.0
# 2         99.896748                 98.459818                 167.0
# 3         99.922720                 98.772111                 134.0
# 4         99.922621                 98.443814                 172.0
# 5         99.770432                 90.817264                 195.0
# 6         99.302094                 90.827517                 170.0
# 7         99.301746                 92.568579                 135.0
# 8         99.367089                 89.581305                 201.0
# 9         99.600000                 90.950000                 173.0
#
#    cut_improvement_percent_vs_vanilla  delta_accuracy_vs_vanilla  \
# 0                            1.441552                   1.419477
# 1                            1.530389                   1.506024
# 2                            1.459407                   1.436930
# 3                            1.164914                   1.150610
# 4                            1.502183                   1.478807
# 5                            9.858443                   8.953168
# 6                            9.330406                   8.474576
# 7                            7.273707                   6.733167
# 8                           10.923913                   9.785784
# 9                            9.510720                   8.650000
#
#    gap_reduction_percent_vs_vanilla  runtime_sec  vanilla_runtime_sec  \
# 0                         92.696629    20.340349             4.368305
# 1                         94.594595    20.147006             4.299664
# 2                         93.296089    19.713759             4.356321
# 3                         93.706294    20.273321             4.275009
# 4                         95.027624    19.919531             4.161925
# 5                         97.500000    20.543701             4.394011
# 6                         92.391304    19.921516             4.333263
# 7                         90.604027    20.028873             4.411136
# 8                         93.925234    19.823088             4.523476
# 9                         95.580110    19.065519             4.260001
#
#    runtime_ratio_vs_vanilla winner
# 0                  4.656348  QEFEM
# 1                  4.685716  QEFEM
# 2                  4.525323  QEFEM
# 3                  4.742287  QEFEM
# 4                  4.786134  QEFEM
# 5                  4.675387  QEFEM
# 6                  4.597348  QEFEM
# 7                  4.540525  QEFEM
# 8                  4.382269  QEFEM
# 9                  4.475473  QEFEM
# Saved G1-G10 analysis to:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_v1_outputs/qefem_anneal_G1_G10_analysis_vs_vanilla.csv

# %%
# ----------------------------
# Aggregate statistics
# ----------------------------
num_instances = len(g1_g10_analysis_df)

wins = int((g1_g10_analysis_df["winner"] == "QEFEM").sum())
ties = int((g1_g10_analysis_df["winner"] == "Tie").sum())
losses = int((g1_g10_analysis_df["winner"] == "Vanilla").sum())

mean_qefem_cut = float(g1_g10_analysis_df["best_cut"].mean())
mean_vanilla_cut = float(g1_g10_analysis_df["vanilla_cut"].mean())
mean_best_value = float(g1_g10_analysis_df["best_value"].mean())

mean_delta_cut = float(g1_g10_analysis_df["delta_cut_vs_vanilla"].mean())
median_delta_cut = float(g1_g10_analysis_df["delta_cut_vs_vanilla"].median())
min_delta_cut = float(g1_g10_analysis_df["delta_cut_vs_vanilla"].min())
max_delta_cut = float(g1_g10_analysis_df["delta_cut_vs_vanilla"].max())

mean_cut_improvement_percent = float(
    g1_g10_analysis_df["cut_improvement_percent_vs_vanilla"].mean()
)

mean_qefem_accuracy = float(g1_g10_analysis_df["percent_accuracy"].mean())
mean_vanilla_accuracy = float(g1_g10_analysis_df["vanilla_percent_accuracy"].mean())
mean_delta_accuracy = float(g1_g10_analysis_df["delta_accuracy_vs_vanilla"].mean())

mean_gap = float(g1_g10_analysis_df["gap"].mean())
mean_vanilla_gap = float(g1_g10_analysis_df["vanilla_gap"].mean())
mean_gap_reduction = float(g1_g10_analysis_df["delta_gap_vs_vanilla"].mean())
mean_gap_reduction_percent = float(
    g1_g10_analysis_df["gap_reduction_percent_vs_vanilla"].mean()
)

best_known_hits = int(g1_g10_analysis_df["hit_best_known"].sum())

mean_runtime = float(g1_g10_analysis_df["runtime_sec"].mean())
mean_vanilla_runtime = float(g1_g10_analysis_df["vanilla_runtime_sec"].mean())
mean_runtime_ratio = float(g1_g10_analysis_df["runtime_ratio_vs_vanilla"].mean())


g1_g10_aggregate_summary = {
    "num_instances": num_instances,

    "wins_vs_vanilla": wins,
    "ties_vs_vanilla": ties,
    "losses_vs_vanilla": losses,

    "mean_qefem_cut": mean_qefem_cut,
    "mean_vanilla_cut": mean_vanilla_cut,
    "mean_best_value": mean_best_value,

    "mean_delta_cut_vs_vanilla": mean_delta_cut,
    "median_delta_cut_vs_vanilla": median_delta_cut,
    "min_delta_cut_vs_vanilla": min_delta_cut,
    "max_delta_cut_vs_vanilla": max_delta_cut,
    "mean_cut_improvement_percent_vs_vanilla": mean_cut_improvement_percent,

    "mean_qefem_accuracy_percent": mean_qefem_accuracy,
    "mean_vanilla_accuracy_percent": mean_vanilla_accuracy,
    "mean_delta_accuracy_percentage_points": mean_delta_accuracy,

    "mean_qefem_gap": mean_gap,
    "mean_vanilla_gap": mean_vanilla_gap,
    "mean_gap_reduction": mean_gap_reduction,
    "mean_gap_reduction_percent": mean_gap_reduction_percent,

    "best_known_hits": best_known_hits,

    "mean_qefem_runtime_sec": mean_runtime,
    "mean_vanilla_runtime_sec": mean_vanilla_runtime,
    "mean_runtime_ratio_vs_vanilla": mean_runtime_ratio,
}

g1_g10_aggregate_summary_df = pd.DataFrame([g1_g10_aggregate_summary])

aggregate_path = OUTPUT_DIR / "qefem_anneal_G1_G10_aggregate_summary.csv"
g1_g10_aggregate_summary_df.to_csv(aggregate_path, index=False)

print("\nAggregate G1-G10 summary:")
display(g1_g10_aggregate_summary_df)

print("\nSaved aggregate summary to:")
print(aggregate_path.resolve())
# Out:
# Aggregate G1-G10 summary:
#    num_instances  wins_vs_vanilla  ties_vs_vanilla  losses_vs_vanilla  \
# 0             10               10                0                  0
#
#    mean_qefem_cut  mean_vanilla_cut  mean_best_value  \
# 0          6827.9            6659.2           6838.6
#
#    mean_delta_cut_vs_vanilla  median_delta_cut_vs_vanilla  \
# 0                      168.7                        171.0
#
#    min_delta_cut_vs_vanilla  ...  mean_vanilla_accuracy_percent  \
# 0                     134.0  ...                      94.729701
#
#    mean_delta_accuracy_percentage_points  mean_qefem_gap  mean_vanilla_gap  \
# 0                               4.958854            10.7             179.4
#
#    mean_gap_reduction  mean_gap_reduction_percent  best_known_hits  \
# 0               168.7                   93.932191                0
#
#    mean_qefem_runtime_sec  mean_vanilla_runtime_sec  \
# 0               19.977666                  4.338311
#
#    mean_runtime_ratio_vs_vanilla
# 0                       4.606681
#
# [1 rows x 23 columns]
# Saved aggregate summary to:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_v1_outputs/qefem_anneal_G1_G10_aggregate_summary.csv

# %%
# ----------------------------
# Pretty print key results
# ----------------------------
print("\n" + "=" * 80)
print("G1-G10 HEAD-TO-HEAD SUMMARY")
print("=" * 80)
print(f"Wins / ties / losses vs vanilla: {wins} / {ties} / {losses}")
print(f"Mean QEFEM accuracy: {mean_qefem_accuracy:.4f}%")
print(f"Mean vanilla accuracy: {mean_vanilla_accuracy:.4f}%")
print(f"Mean accuracy gain: {mean_delta_accuracy:.4f} percentage points")
print(f"Mean cut gain: {mean_delta_cut:.2f}")
print(f"Mean cut-value improvement vs vanilla: {mean_cut_improvement_percent:.4f}%")
print(f"Mean vanilla gap: {mean_vanilla_gap:.2f}")
print(f"Mean QEFEM gap: {mean_gap:.2f}")
print(f"Mean gap reduction: {mean_gap_reduction:.2f}")
print(f"Mean gap reduction percent: {mean_gap_reduction_percent:.2f}%")
print(f"Best-known hits: {best_known_hits}/{num_instances}")
print(f"Mean QEFEM runtime: {mean_runtime:.2f}s")
print(f"Mean vanilla runtime: {mean_vanilla_runtime:.2f}s")
print(f"Runtime ratio QEFEM/vanilla: {mean_runtime_ratio:.2f}x")
print("=" * 80)
# Out:
# ================================================================================
# G1-G10 HEAD-TO-HEAD SUMMARY
# ================================================================================
# Wins / ties / losses vs vanilla: 10 / 0 / 0
# Mean QEFEM accuracy: 99.6886%
# Mean vanilla accuracy: 94.7297%
# Mean accuracy gain: 4.9589 percentage points
# Mean cut gain: 168.70
# Mean cut-value improvement vs vanilla: 5.3996%
# Mean vanilla gap: 179.40
# Mean QEFEM gap: 10.70
# Mean gap reduction: 168.70
# Mean gap reduction percent: 93.93%
# Best-known hits: 0/10
# Mean QEFEM runtime: 19.98s
# Mean vanilla runtime: 4.34s
# Runtime ratio QEFEM/vanilla: 4.61x
# ================================================================================

# %%
# ----------------------------
# Plot: cut comparison
# ----------------------------
x = np.arange(len(g1_g10_analysis_df))
labels = g1_g10_analysis_df["instance"].tolist()

plt.figure(figsize=(10, 5))
plt.plot(x, g1_g10_analysis_df["best_value"], marker="o", label="best-known")
plt.plot(x, g1_g10_analysis_df["vanilla_cut"], marker="o", label="vanilla FEM")
plt.plot(x, g1_g10_analysis_df["best_cut"], marker="o", label="QEFEM anneal")
plt.xticks(x, labels)
plt.xlabel("Instance")
plt.ylabel("Cut value")
plt.title("G1-G10: cut comparison")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Plot: delta cut vs vanilla
# ----------------------------
plt.figure(figsize=(10, 5))
plt.bar(g1_g10_analysis_df["instance"], g1_g10_analysis_df["delta_cut_vs_vanilla"])
plt.axhline(0, linestyle="--")
plt.xlabel("Instance")
plt.ylabel("QEFEM cut - vanilla cut")
plt.title("G1-G10: QEFEM improvement over vanilla")
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Plot: accuracy comparison
# ----------------------------
plt.figure(figsize=(10, 5))
plt.plot(x, g1_g10_analysis_df["vanilla_percent_accuracy"], marker="o", label="vanilla FEM")
plt.plot(x, g1_g10_analysis_df["percent_accuracy"], marker="o", label="QEFEM anneal")
plt.axhline(100.0, linestyle="--", label="best-known = 100%")
plt.xticks(x, labels)
plt.xlabel("Instance")
plt.ylabel("Accuracy % of best-known")
plt.title("G1-G10: accuracy comparison")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Plot: gap comparison
# ----------------------------
plt.figure(figsize=(10, 5))
plt.plot(x, g1_g10_analysis_df["vanilla_gap"], marker="o", label="vanilla gap")
plt.plot(x, g1_g10_analysis_df["gap"], marker="o", label="QEFEM gap")
plt.xticks(x, labels)
plt.xlabel("Instance")
plt.ylabel("Gap to best-known")
plt.title("G1-G10: gap comparison")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Plot: runtime comparison
# ----------------------------
plt.figure(figsize=(10, 5))
plt.plot(x, g1_g10_analysis_df["vanilla_runtime_sec"], marker="o", label="vanilla runtime")
plt.plot(x, g1_g10_analysis_df["runtime_sec"], marker="o", label="QEFEM runtime")
plt.xticks(x, labels)
plt.xlabel("Instance")
plt.ylabel("Runtime seconds")
plt.title("G1-G10: runtime comparison")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Final verdict
# ----------------------------
print("\nVerdict:")

if wins == num_instances:
    print(
        f"QEFEM anneal beats vanilla on all {num_instances}/{num_instances} G1-G10 instances. "
        "This is a very strong first mini-benchmark."
    )
elif wins > losses:
    print(
        "QEFEM anneal wins more often than it loses on G1-G10. Encouraging, but inspect instance-level behavior."
    )
else:
    print(
        "QEFEM anneal does not clearly beat vanilla on G1-G10. Inspect schedules, initialization, and diagnostics."
    )
# Out:
# Verdict:
# QEFEM anneal beats vanilla on all 10/10 G1-G10 instances. This is a very strong first mini-benchmark.

# %% [markdown]
# ### Run PROBLEM BATCH :
# Batch 6 - {35,...,42}

# %%
assert "run_qefem_single_gset" in globals(), "Run Cell 18 first. Wrapper function is missing."

qefem_g35_g42_summaries = []
qefem_g35_g42_histories = {}

g35_g42_output_path = OUTPUT_DIR / "qefem_anneal_G35_G42_partial_results.csv"

print("=" * 80)
print("Starting QEFEM gamma anneal sweep: G35-G42 problem batch")
print("=" * 80)
print("Instances:", GSET_PROBLEM_BATCH)
print("Partial results will be saved to:")
print(g35_g42_output_path.resolve())
print("=" * 80)
# Out:
# ================================================================================
# Starting QEFEM gamma anneal sweep: G35-G42 problem batch
# ================================================================================
# Instances: ['G35', 'G36', 'G37', 'G38', 'G39', 'G40', 'G41', 'G42']
# Partial results will be saved to:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_v1_outputs/qefem_anneal_G35_G42_partial_results.csv
# ================================================================================

# %%
for run_idx, instance_name in enumerate(GSET_PROBLEM_BATCH, start=1):
    print("\n\n" + "#" * 80)
    print(f"G35-G42 sweep item {run_idx}/{len(GSET_PROBLEM_BATCH)}: {instance_name}")
    print("#" * 80)

    summary, history_df = run_qefem_single_gset(
        instance_name=instance_name,
        gamma_mode="anneal",
        replicas=REPLICAS,
        n_steps=N_STEPS,
        seed=SEED,
        lr=LR,
        beta_min=BETA_MIN,
        beta_max=BETA_MAX,
        gamma_max=GAMMA_MAX,
        gamma_min=GAMMA_MIN,
        R_init=R_INIT,
        theta_center=THETA_CENTER,
        theta_noise=THETA_NOISE,
        print_every=PRINT_EVERY,
        save_history=True,
        output_dir=OUTPUT_DIR,
        device=device,
        dtype=DTYPE,
    )

    qefem_g35_g42_summaries.append(summary)
    qefem_g35_g42_histories[instance_name] = history_df

    # Save partial summary after every graph because notebooks die with theatrical timing.
    qefem_g35_g42_results_df = pd.DataFrame(qefem_g35_g42_summaries)
    qefem_g35_g42_results_df.to_csv(g35_g42_output_path, index=False)

    print("\nCurrent partial G35-G42 results:")
    display(qefem_g35_g42_results_df[
        [
            "instance",
            "best_cut",
            "best_value",
            "gap",
            "percent_accuracy",
            "vanilla_cut",
            "delta_cut_vs_vanilla",
            "delta_accuracy_vs_vanilla",
            "runtime_sec",
        ]
    ])
# Out:
# ################################################################################
# G35-G42 sweep item 1/8: G35
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G35
# ================================================================================
# gamma_mode: anneal
# N: 2000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 7687
# vanilla cut: 7523.0
# --------------------------------------------------------------------------------
# G35 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=6023 | best=6023 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.12s
# G35 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=5938 | best=6182 | |rx|=0.0312 | |rz|=0.0000 | elapsed=2.99s
# G35 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=4309 | best=6182 | |rx|=0.1512 | |rz|=0.0001 | elapsed=5.87s
# G35 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=7537 | best=7539 | |rx|=0.4199 | |rz|=0.3550 | elapsed=8.85s
# G35 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=7610 | best=7610 | |rx|=0.4431 | |rz|=0.6880 | elapsed=11.80s
# G35 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=7612 | best=7612 | |rx|=0.4029 | |rz|=0.7885 | elapsed=14.72s
# G35 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=7612 | best=7612 | |rx|=0.3483 | |rz|=0.8409 | elapsed=17.53s
# G35 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=7612 | best=7612 | |rx|=0.2865 | |rz|=0.8761 | elapsed=20.41s
# G35 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=7612 | best=7612 | |rx|=0.2183 | |rz|=0.9010 | elapsed=23.34s
# G35 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=7612 | best=7612 | |rx|=0.1440 | |rz|=0.9171 | elapsed=26.24s
# G35 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=7612 | best=7612 | |rx|=0.0485 | |rz|=0.9561 | elapsed=29.15s
#
# Finished: G35
# Best cut: 7612.0
# Best-known: 7687
# Gap: 75.0
# Accuracy %: 99.02432678548199
# Vanilla cut: 7523.0
# Delta cut vs vanilla: 89.0
# Runtime sec: 29.154829740524292
# --------------------------------------------------------------------------------
#
# Current partial G35-G42 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0      G35    7612.0        7687  75.0         99.024327       7523.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                  89.0                   1.157799     29.15483
# ################################################################################
# G35-G42 sweep item 2/8: G36
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G36
# ================================================================================
# gamma_mode: anneal
# N: 2000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 7680
# vanilla cut: 7515.0
# --------------------------------------------------------------------------------
# G36 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=5961 | best=5961 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G36 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=5949 | best=6184 | |rx|=0.0312 | |rz|=0.0000 | elapsed=2.32s
# G36 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=4592 | best=6184 | |rx|=0.1512 | |rz|=0.0001 | elapsed=5.29s
# G36 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=7517 | best=7517 | |rx|=0.4207 | |rz|=0.3553 | elapsed=8.29s
# G36 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=7586 | best=7586 | |rx|=0.4430 | |rz|=0.6886 | elapsed=11.26s
# G36 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=7592 | best=7592 | |rx|=0.4025 | |rz|=0.7893 | elapsed=14.19s
# G36 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=7599 | best=7599 | |rx|=0.3474 | |rz|=0.8418 | elapsed=17.12s
# G36 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=7599 | best=7599 | |rx|=0.2856 | |rz|=0.8769 | elapsed=20.04s
# G36 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=7599 | best=7599 | |rx|=0.2177 | |rz|=0.9016 | elapsed=22.99s
# G36 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=7599 | best=7599 | |rx|=0.1436 | |rz|=0.9174 | elapsed=25.93s
# G36 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=7599 | best=7599 | |rx|=0.0486 | |rz|=0.9557 | elapsed=28.86s
#
# Finished: G36
# Best cut: 7599.0
# Best-known: 7680
# Gap: 81.0
# Accuracy %: 98.9453125
# Vanilla cut: 7515.0
# Delta cut vs vanilla: 84.0
# Runtime sec: 28.860679149627686
# --------------------------------------------------------------------------------
#
# Current partial G35-G42 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0      G35    7612.0        7687  75.0         99.024327       7523.0
# 1      G36    7599.0        7680  81.0         98.945312       7515.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                  89.0                   1.157799    29.154830
# 1                  84.0                   1.093750    28.860679
# ################################################################################
# G35-G42 sweep item 3/8: G37
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G37
# ================================================================================
# gamma_mode: anneal
# N: 2000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 7691
# vanilla cut: 7520.0
# --------------------------------------------------------------------------------
# G37 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=5987 | best=5987 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G37 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=5977 | best=6202 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.39s
# G37 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=4476 | best=6202 | |rx|=0.1512 | |rz|=0.0001 | elapsed=4.33s
# G37 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=7548 | best=7548 | |rx|=0.4196 | |rz|=0.3575 | elapsed=7.30s
# G37 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=7605 | best=7605 | |rx|=0.4416 | |rz|=0.6906 | elapsed=10.24s
# G37 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=7615 | best=7615 | |rx|=0.4012 | |rz|=0.7909 | elapsed=13.13s
# G37 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=7618 | best=7618 | |rx|=0.3468 | |rz|=0.8426 | elapsed=16.07s
# G37 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=7619 | best=7619 | |rx|=0.2852 | |rz|=0.8773 | elapsed=18.88s
# G37 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=7619 | best=7619 | |rx|=0.2174 | |rz|=0.9018 | elapsed=22.01s
# G37 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=7619 | best=7619 | |rx|=0.1436 | |rz|=0.9176 | elapsed=24.93s
# G37 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=7619 | best=7619 | |rx|=0.0472 | |rz|=0.9572 | elapsed=27.97s
#
# Finished: G37
# Best cut: 7619.0
# Best-known: 7691
# Gap: 72.0
# Accuracy %: 99.063840852945
# Vanilla cut: 7520.0
# Delta cut vs vanilla: 99.0
# Runtime sec: 27.966832876205444
# --------------------------------------------------------------------------------
#
# Current partial G35-G42 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0      G35    7612.0        7687  75.0         99.024327       7523.0
# 1      G36    7599.0        7680  81.0         98.945312       7515.0
# 2      G37    7619.0        7691  72.0         99.063841       7520.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                  89.0                   1.157799    29.154830
# 1                  84.0                   1.093750    28.860679
# 2                  99.0                   1.287219    27.966833
# ################################################################################
# G35-G42 sweep item 4/8: G38
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G38
# ================================================================================
# gamma_mode: anneal
# N: 2000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 7688
# vanilla cut: 7514.0
# --------------------------------------------------------------------------------
# G38 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=6019 | best=6019 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G38 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=5967 | best=6210 | |rx|=0.0312 | |rz|=0.0000 | elapsed=2.86s
# G38 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=4046 | best=6210 | |rx|=0.1512 | |rz|=0.0001 | elapsed=5.89s
# G38 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=7541 | best=7541 | |rx|=0.4201 | |rz|=0.3554 | elapsed=8.94s
# G38 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=7615 | best=7615 | |rx|=0.4408 | |rz|=0.6910 | elapsed=11.87s
# G38 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=7616 | best=7616 | |rx|=0.3998 | |rz|=0.7920 | elapsed=14.78s
# G38 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=7616 | best=7616 | |rx|=0.3450 | |rz|=0.8441 | elapsed=17.71s
# G38 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=7616 | best=7616 | |rx|=0.2831 | |rz|=0.8790 | elapsed=20.64s
# G38 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=7616 | best=7616 | |rx|=0.2151 | |rz|=0.9037 | elapsed=23.57s
# G38 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=7616 | best=7616 | |rx|=0.1411 | |rz|=0.9196 | elapsed=26.51s
# G38 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=7616 | best=7616 | |rx|=0.0468 | |rz|=0.9573 | elapsed=29.44s
#
# Finished: G38
# Best cut: 7616.0
# Best-known: 7688
# Gap: 72.0
# Accuracy %: 99.06347554630594
# Vanilla cut: 7514.0
# Delta cut vs vanilla: 102.0
# Runtime sec: 29.44264793395996
# --------------------------------------------------------------------------------
#
# Current partial G35-G42 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0      G35    7612.0        7687  75.0         99.024327       7523.0
# 1      G36    7599.0        7680  81.0         98.945312       7515.0
# 2      G37    7619.0        7691  72.0         99.063841       7520.0
# 3      G38    7616.0        7688  72.0         99.063476       7514.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                  89.0                   1.157799    29.154830
# 1                  84.0                   1.093750    28.860679
# 2                  99.0                   1.287219    27.966833
# 3                 102.0                   1.326743    29.442648
# ################################################################################
# G35-G42 sweep item 5/8: G39
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G39
# ================================================================================
# gamma_mode: anneal
# N: 2000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 2408
# vanilla cut: 2188.0
# --------------------------------------------------------------------------------
# G39 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=86 | best=86 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G39 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=61 | best=297 | |rx|=0.0312 | |rz|=0.0000 | elapsed=2.52s
# G39 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1573 | best=1573 | |rx|=0.1512 | |rz|=0.0008 | elapsed=5.49s
# G39 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=2301 | best=2301 | |rx|=0.3532 | |rz|=0.4455 | elapsed=8.49s
# G39 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=2334 | best=2335 | |rx|=0.3697 | |rz|=0.7436 | elapsed=11.46s
# G39 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=2336 | best=2336 | |rx|=0.3359 | |rz|=0.8262 | elapsed=14.40s
# G39 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=2336 | best=2336 | |rx|=0.2902 | |rz|=0.8680 | elapsed=17.30s
# G39 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=2336 | best=2336 | |rx|=0.2383 | |rz|=0.8960 | elapsed=20.23s
# G39 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=2336 | best=2336 | |rx|=0.1813 | |rz|=0.9158 | elapsed=23.15s
# G39 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=2336 | best=2336 | |rx|=0.1194 | |rz|=0.9285 | elapsed=26.11s
# G39 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=2336 | best=2336 | |rx|=0.0426 | |rz|=0.9597 | elapsed=29.05s
#
# Finished: G39
# Best cut: 2336.0
# Best-known: 2408
# Gap: 72.0
# Accuracy %: 97.00996677740864
# Vanilla cut: 2188.0
# Delta cut vs vanilla: 148.0
# Runtime sec: 29.048542022705078
# --------------------------------------------------------------------------------
#
# Current partial G35-G42 results:
#   instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 0      G35    7612.0        7687  75.0         99.024327       7523.0
# 1      G36    7599.0        7680  81.0         98.945312       7515.0
# 2      G37    7619.0        7691  72.0         99.063841       7520.0
# 3      G38    7616.0        7688  72.0         99.063476       7514.0
# 4      G39    2336.0        2408  72.0         97.009967       2188.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                  89.0                   1.157799    29.154830
# 1                  84.0                   1.093750    28.860679
# 2                  99.0                   1.287219    27.966833
# 3                 102.0                   1.326743    29.442648
# 4                 148.0                   6.146179    29.048542
# ################################################################################
# G35-G42 sweep item 6/8: G40
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G40
# ================================================================================
# gamma_mode: anneal
# N: 2000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 2400
# vanilla cut: 2183.0
# --------------------------------------------------------------------------------
# G40 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=63 | best=63 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G40 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=-28 | best=239 | |rx|=0.0312 | |rz|=0.0000 | elapsed=2.39s
# G40 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1529 | best=1529 | |rx|=0.1512 | |rz|=0.0023 | elapsed=5.34s
# G40 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=2255 | best=2255 | |rx|=0.3498 | |rz|=0.4504 | elapsed=8.34s
# G40 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=2291 | best=2291 | |rx|=0.3654 | |rz|=0.7476 | elapsed=11.31s
# G40 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=2296 | best=2296 | |rx|=0.3315 | |rz|=0.8291 | elapsed=14.27s
# G40 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=2296 | best=2296 | |rx|=0.2864 | |rz|=0.8697 | elapsed=17.18s
# G40 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=2296 | best=2296 | |rx|=0.2352 | |rz|=0.8968 | elapsed=20.11s
# G40 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=2296 | best=2296 | |rx|=0.1790 | |rz|=0.9159 | elapsed=23.04s
# G40 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=2296 | best=2296 | |rx|=0.1182 | |rz|=0.9285 | elapsed=25.96s
# G40 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=2296 | best=2296 | |rx|=0.0436 | |rz|=0.9591 | elapsed=28.90s
#
# Finished: G40
# Best cut: 2296.0
# Best-known: 2400
# Gap: 104.0
# Accuracy %: 95.66666666666667
# Vanilla cut: 2183.0
# Delta cut vs vanilla: 113.0
# Runtime sec: 28.897351026535034
# --------------------------------------------------------------------------------
#
# Current partial G35-G42 results:
#   instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 0      G35    7612.0        7687   75.0         99.024327       7523.0
# 1      G36    7599.0        7680   81.0         98.945312       7515.0
# 2      G37    7619.0        7691   72.0         99.063841       7520.0
# 3      G38    7616.0        7688   72.0         99.063476       7514.0
# 4      G39    2336.0        2408   72.0         97.009967       2188.0
# 5      G40    2296.0        2400  104.0         95.666667       2183.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                  89.0                   1.157799    29.154830
# 1                  84.0                   1.093750    28.860679
# 2                  99.0                   1.287219    27.966833
# 3                 102.0                   1.326743    29.442648
# 4                 148.0                   6.146179    29.048542
# 5                 113.0                   4.708333    28.897351
# ################################################################################
# G35-G42 sweep item 7/8: G41
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G41
# ================================================================================
# gamma_mode: anneal
# N: 2000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 2405
# vanilla cut: 2193.0
# --------------------------------------------------------------------------------
# G41 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=116 | best=116 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G41 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=50 | best=261 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.35s
# G41 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1473 | best=1473 | |rx|=0.1512 | |rz|=0.0010 | elapsed=4.30s
# G41 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=2252 | best=2252 | |rx|=0.3566 | |rz|=0.4401 | elapsed=7.26s
# G41 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=2286 | best=2286 | |rx|=0.3729 | |rz|=0.7389 | elapsed=10.23s
# G41 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=2289 | best=2289 | |rx|=0.3389 | |rz|=0.8221 | elapsed=13.20s
# G41 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=2289 | best=2289 | |rx|=0.2933 | |rz|=0.8640 | elapsed=16.15s
# G41 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=2289 | best=2289 | |rx|=0.2416 | |rz|=0.8918 | elapsed=19.03s
# G41 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=2289 | best=2289 | |rx|=0.1848 | |rz|=0.9115 | elapsed=21.96s
# G41 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=2289 | best=2289 | |rx|=0.1233 | |rz|=0.9243 | elapsed=24.88s
# G41 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=2289 | best=2289 | |rx|=0.0467 | |rz|=0.9566 | elapsed=27.83s
#
# Finished: G41
# Best cut: 2289.0
# Best-known: 2405
# Gap: 116.0
# Accuracy %: 95.17671517671518
# Vanilla cut: 2193.0
# Delta cut vs vanilla: 96.0
# Runtime sec: 27.832200050354004
# --------------------------------------------------------------------------------
#
# Current partial G35-G42 results:
#   instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 0      G35    7612.0        7687   75.0         99.024327       7523.0
# 1      G36    7599.0        7680   81.0         98.945312       7515.0
# 2      G37    7619.0        7691   72.0         99.063841       7520.0
# 3      G38    7616.0        7688   72.0         99.063476       7514.0
# 4      G39    2336.0        2408   72.0         97.009967       2188.0
# 5      G40    2296.0        2400  104.0         95.666667       2183.0
# 6      G41    2289.0        2405  116.0         95.176715       2193.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                  89.0                   1.157799    29.154830
# 1                  84.0                   1.093750    28.860679
# 2                  99.0                   1.287219    27.966833
# 3                 102.0                   1.326743    29.442648
# 4                 148.0                   6.146179    29.048542
# 5                 113.0                   4.708333    28.897351
# 6                  96.0                   3.991684    27.832200
# ################################################################################
# G35-G42 sweep item 8/8: G42
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G42
# ================================================================================
# gamma_mode: anneal
# N: 2000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 2481
# vanilla cut: 2273.0
# --------------------------------------------------------------------------------
# G42 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=207 | best=207 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G42 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=95 | best=325 | |rx|=0.0312 | |rz|=0.0000 | elapsed=2.41s
# G42 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1636 | best=1636 | |rx|=0.1512 | |rz|=0.0013 | elapsed=5.37s
# G42 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=2333 | best=2333 | |rx|=0.3536 | |rz|=0.4458 | elapsed=8.35s
# G42 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=2380 | best=2380 | |rx|=0.3652 | |rz|=0.7490 | elapsed=11.31s
# G42 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=2381 | best=2381 | |rx|=0.3302 | |rz|=0.8325 | elapsed=14.26s
# G42 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=2381 | best=2381 | |rx|=0.2839 | |rz|=0.8741 | elapsed=17.21s
# G42 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=2381 | best=2381 | |rx|=0.2317 | |rz|=0.9018 | elapsed=20.12s
# G42 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=2381 | best=2381 | |rx|=0.1746 | |rz|=0.9213 | elapsed=23.04s
# G42 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=2381 | best=2381 | |rx|=0.1131 | |rz|=0.9339 | elapsed=25.96s
# G42 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=2381 | best=2381 | |rx|=0.0392 | |rz|=0.9621 | elapsed=28.92s
#
# Finished: G42
# Best cut: 2381.0
# Best-known: 2481
# Gap: 100.0
# Accuracy %: 95.96936719064894
# Vanilla cut: 2273.0
# Delta cut vs vanilla: 108.0
# Runtime sec: 28.917618989944458
# --------------------------------------------------------------------------------
#
# Current partial G35-G42 results:
#   instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 0      G35    7612.0        7687   75.0         99.024327       7523.0
# 1      G36    7599.0        7680   81.0         98.945312       7515.0
# 2      G37    7619.0        7691   72.0         99.063841       7520.0
# 3      G38    7616.0        7688   72.0         99.063476       7514.0
# 4      G39    2336.0        2408   72.0         97.009967       2188.0
# 5      G40    2296.0        2400  104.0         95.666667       2183.0
# 6      G41    2289.0        2405  116.0         95.176715       2193.0
# 7      G42    2381.0        2481  100.0         95.969367       2273.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                  89.0                   1.157799    29.154830
# 1                  84.0                   1.093750    28.860679
# 2                  99.0                   1.287219    27.966833
# 3                 102.0                   1.326743    29.442648
# 4                 148.0                   6.146179    29.048542
# 5                 113.0                   4.708333    28.897351
# 6                  96.0                   3.991684    27.832200
# 7                 108.0                   4.353083    28.917619

# %%
# ----------------------------
# Finalize G35-G42 result file
# ----------------------------
qefem_g35_g42_results_df = pd.DataFrame(qefem_g35_g42_summaries)

final_g35_g42_path = OUTPUT_DIR / "qefem_anneal_G35_G42_final_results.csv"
qefem_g35_g42_results_df.to_csv(final_g35_g42_path, index=False)

print("\n" + "=" * 80)
print("G35-G42 QEFEM gamma anneal sweep complete")
print("=" * 80)

display(qefem_g35_g42_results_df[
    [
        "instance",
        "best_cut",
        "best_value",
        "gap",
        "percent_accuracy",
        "vanilla_cut",
        "delta_cut_vs_vanilla",
        "delta_accuracy_vs_vanilla",
        "runtime_sec",
    ]
])

print("\nSaved final G35-G42 results to:")
print(final_g35_g42_path.resolve())
# Out:
# ================================================================================
# G35-G42 QEFEM gamma anneal sweep complete
# ================================================================================
#   instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 0      G35    7612.0        7687   75.0         99.024327       7523.0
# 1      G36    7599.0        7680   81.0         98.945312       7515.0
# 2      G37    7619.0        7691   72.0         99.063841       7520.0
# 3      G38    7616.0        7688   72.0         99.063476       7514.0
# 4      G39    2336.0        2408   72.0         97.009967       2188.0
# 5      G40    2296.0        2400  104.0         95.666667       2183.0
# 6      G41    2289.0        2405  116.0         95.176715       2193.0
# 7      G42    2381.0        2481  100.0         95.969367       2273.0
#
#    delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                  89.0                   1.157799    29.154830
# 1                  84.0                   1.093750    28.860679
# 2                  99.0                   1.287219    27.966833
# 3                 102.0                   1.326743    29.442648
# 4                 148.0                   6.146179    29.048542
# 5                 113.0                   4.708333    28.897351
# 6                  96.0                   3.991684    27.832200
# 7                 108.0                   4.353083    28.917619
# Saved final G35-G42 results to:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_v1_outputs/qefem_anneal_G35_G42_final_results.csv

# %%
# ----------------------------
# Aggregate summary
# ----------------------------
num_wins = int((qefem_g35_g42_results_df["delta_cut_vs_vanilla"] > 0).sum())
num_ties = int((qefem_g35_g42_results_df["delta_cut_vs_vanilla"] == 0).sum())
num_losses = int((qefem_g35_g42_results_df["delta_cut_vs_vanilla"] < 0).sum())

mean_delta_cut = float(qefem_g35_g42_results_df["delta_cut_vs_vanilla"].mean())
mean_delta_accuracy = float(qefem_g35_g42_results_df["delta_accuracy_vs_vanilla"].mean())
mean_accuracy = float(qefem_g35_g42_results_df["percent_accuracy"].mean())
mean_runtime = float(qefem_g35_g42_results_df["runtime_sec"].mean())

mean_gap = float(qefem_g35_g42_results_df["gap"].mean())
mean_vanilla_gap = float(qefem_g35_g42_results_df["vanilla_gap"].mean())
mean_gap_reduction = float(qefem_g35_g42_results_df["delta_gap_vs_vanilla"].mean())

print("\nAggregate G35-G42 summary:")
print("Wins vs vanilla:", num_wins)
print("Ties vs vanilla:", num_ties)
print("Losses vs vanilla:", num_losses)
print("Mean delta cut vs vanilla:", mean_delta_cut)
print("Mean delta accuracy vs vanilla:", mean_delta_accuracy)
print("Mean QEFEM accuracy %:", mean_accuracy)
print("Mean QEFEM gap:", mean_gap)
print("Mean vanilla gap:", mean_vanilla_gap)
print("Mean gap reduction:", mean_gap_reduction)
print("Mean runtime sec:", mean_runtime)
# Out:
# Aggregate G35-G42 summary:
# Wins vs vanilla: 8
# Ties vs vanilla: 0
# Losses vs vanilla: 0
# Mean delta cut vs vanilla: 104.875
# Mean delta accuracy vs vanilla: 3.0080988557006485
# Mean QEFEM accuracy %: 97.48995893702156
# Mean QEFEM gap: 86.5
# Mean vanilla gap: 191.375
# Mean gap reduction: 104.875
# Mean runtime sec: 28.765087723731995

# %% [markdown]
# #### Diagnostics & inference

# %%
assert "qefem_g35_g42_results_df" in globals(), (
    "Run Cell 21 first. qefem_g35_g42_results_df does not exist."
)

assert len(qefem_g35_g42_results_df) > 0, (
    "qefem_g35_g42_results_df is empty. The problem-batch goblin ate your results."
)


# ----------------------------
# Make clean comparison dataframe
# ----------------------------
g35_g42_analysis_df = qefem_g35_g42_results_df.copy()

g35_g42_analysis_df["cut_improvement_percent_vs_vanilla"] = (
    100.0
    * g35_g42_analysis_df["delta_cut_vs_vanilla"]
    / g35_g42_analysis_df["vanilla_cut"]
)

g35_g42_analysis_df["gap_reduction_percent_vs_vanilla"] = (
    100.0
    * g35_g42_analysis_df["delta_gap_vs_vanilla"]
    / g35_g42_analysis_df["vanilla_gap"]
)

g35_g42_analysis_df["qefem_minus_best_known"] = (
    g35_g42_analysis_df["best_cut"] - g35_g42_analysis_df["best_value"]
)

g35_g42_analysis_df["hit_best_known"] = (
    g35_g42_analysis_df["best_cut"] >= g35_g42_analysis_df["best_value"]
)

g35_g42_analysis_df["winner"] = np.where(
    g35_g42_analysis_df["delta_cut_vs_vanilla"] > 0,
    "QEFEM",
    np.where(
        g35_g42_analysis_df["delta_cut_vs_vanilla"] < 0,
        "Vanilla",
        "Tie",
    )
)

# %%
# ----------------------------
# Display main comparison table
# ----------------------------
main_cols = [
    "instance",
    "best_cut",
    "vanilla_cut",
    "best_value",
    "gap",
    "vanilla_gap",
    "percent_accuracy",
    "vanilla_percent_accuracy",
    "delta_cut_vs_vanilla",
    "cut_improvement_percent_vs_vanilla",
    "delta_accuracy_vs_vanilla",
    "gap_reduction_percent_vs_vanilla",
    "runtime_sec",
    "vanilla_runtime_sec",
    "runtime_ratio_vs_vanilla",
    "winner",
]

print("G35-G42 QEFEM vs vanilla comparison:")
display(g35_g42_analysis_df[main_cols])


# ----------------------------
# Save analysis table
# ----------------------------
g35_g42_analysis_path = OUTPUT_DIR / "qefem_anneal_G35_G42_analysis_vs_vanilla.csv"
g35_g42_analysis_df.to_csv(g35_g42_analysis_path, index=False)

print("\nSaved G35-G42 analysis to:")
print(g35_g42_analysis_path.resolve())
# Out:
# G35-G42 QEFEM vs vanilla comparison:
#   instance  best_cut  vanilla_cut  best_value    gap  vanilla_gap  \
# 0      G35    7612.0       7523.0        7687   75.0        164.0
# 1      G36    7599.0       7515.0        7680   81.0        165.0
# 2      G37    7619.0       7520.0        7691   72.0        171.0
# 3      G38    7616.0       7514.0        7688   72.0        174.0
# 4      G39    2336.0       2188.0        2408   72.0        220.0
# 5      G40    2296.0       2183.0        2400  104.0        217.0
# 6      G41    2289.0       2193.0        2405  116.0        212.0
# 7      G42    2381.0       2273.0        2481  100.0        208.0
#
#    percent_accuracy  vanilla_percent_accuracy  delta_cut_vs_vanilla  \
# 0         99.024327                 97.866528                  89.0
# 1         98.945312                 97.851562                  84.0
# 2         99.063841                 97.776622                  99.0
# 3         99.063476                 97.736733                 102.0
# 4         97.009967                 90.863787                 148.0
# 5         95.666667                 90.958333                 113.0
# 6         95.176715                 91.185031                  96.0
# 7         95.969367                 91.616284                 108.0
#
#    cut_improvement_percent_vs_vanilla  delta_accuracy_vs_vanilla  \
# 0                            1.183039                   1.157799
# 1                            1.117764                   1.093750
# 2                            1.316489                   1.287219
# 3                            1.357466                   1.326743
# 4                            6.764168                   6.146179
# 5                            5.176363                   4.708333
# 6                            4.377565                   3.991684
# 7                            4.751430                   4.353083
#
#    gap_reduction_percent_vs_vanilla  runtime_sec  vanilla_runtime_sec  \
# 0                         54.268293    29.154830             8.681002
# 1                         50.909091    28.860679             8.722572
# 2                         57.894737    27.966833             8.150533
# 3                         58.620690    29.442648             8.672927
# 4                         67.272727    29.048542             8.836483
# 5                         52.073733    28.897351             8.739482
# 6                         45.283019    27.832200             8.396403
# 7                         51.923077    28.917619             8.138303
#
#    runtime_ratio_vs_vanilla winner
# 0                  3.358464  QEFEM
# 1                  3.308735  QEFEM
# 2                  3.431289  QEFEM
# 3                  3.394776  QEFEM
# 4                  3.287342  QEFEM
# 5                  3.306529  QEFEM
# 6                  3.314777  QEFEM
# 7                  3.553274  QEFEM
# Saved G35-G42 analysis to:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_v1_outputs/qefem_anneal_G35_G42_analysis_vs_vanilla.csv

# %%
# ----------------------------
# Aggregate statistics
# ----------------------------
num_instances = len(g35_g42_analysis_df)

wins = int((g35_g42_analysis_df["winner"] == "QEFEM").sum())
ties = int((g35_g42_analysis_df["winner"] == "Tie").sum())
losses = int((g35_g42_analysis_df["winner"] == "Vanilla").sum())

mean_qefem_cut = float(g35_g42_analysis_df["best_cut"].mean())
mean_vanilla_cut = float(g35_g42_analysis_df["vanilla_cut"].mean())
mean_best_value = float(g35_g42_analysis_df["best_value"].mean())

mean_delta_cut = float(g35_g42_analysis_df["delta_cut_vs_vanilla"].mean())
median_delta_cut = float(g35_g42_analysis_df["delta_cut_vs_vanilla"].median())
min_delta_cut = float(g35_g42_analysis_df["delta_cut_vs_vanilla"].min())
max_delta_cut = float(g35_g42_analysis_df["delta_cut_vs_vanilla"].max())

mean_cut_improvement_percent = float(
    g35_g42_analysis_df["cut_improvement_percent_vs_vanilla"].mean()
)

mean_qefem_accuracy = float(g35_g42_analysis_df["percent_accuracy"].mean())
mean_vanilla_accuracy = float(g35_g42_analysis_df["vanilla_percent_accuracy"].mean())
mean_delta_accuracy = float(g35_g42_analysis_df["delta_accuracy_vs_vanilla"].mean())

mean_gap = float(g35_g42_analysis_df["gap"].mean())
mean_vanilla_gap = float(g35_g42_analysis_df["vanilla_gap"].mean())
mean_gap_reduction = float(g35_g42_analysis_df["delta_gap_vs_vanilla"].mean())
mean_gap_reduction_percent = float(
    g35_g42_analysis_df["gap_reduction_percent_vs_vanilla"].mean()
)

best_known_hits = int(g35_g42_analysis_df["hit_best_known"].sum())

mean_runtime = float(g35_g42_analysis_df["runtime_sec"].mean())
mean_vanilla_runtime = float(g35_g42_analysis_df["vanilla_runtime_sec"].mean())
mean_runtime_ratio = float(g35_g42_analysis_df["runtime_ratio_vs_vanilla"].mean())


g35_g42_aggregate_summary = {
    "num_instances": num_instances,

    "wins_vs_vanilla": wins,
    "ties_vs_vanilla": ties,
    "losses_vs_vanilla": losses,

    "mean_qefem_cut": mean_qefem_cut,
    "mean_vanilla_cut": mean_vanilla_cut,
    "mean_best_value": mean_best_value,

    "mean_delta_cut_vs_vanilla": mean_delta_cut,
    "median_delta_cut_vs_vanilla": median_delta_cut,
    "min_delta_cut_vs_vanilla": min_delta_cut,
    "max_delta_cut_vs_vanilla": max_delta_cut,
    "mean_cut_improvement_percent_vs_vanilla": mean_cut_improvement_percent,

    "mean_qefem_accuracy_percent": mean_qefem_accuracy,
    "mean_vanilla_accuracy_percent": mean_vanilla_accuracy,
    "mean_delta_accuracy_percentage_points": mean_delta_accuracy,

    "mean_qefem_gap": mean_gap,
    "mean_vanilla_gap": mean_vanilla_gap,
    "mean_gap_reduction": mean_gap_reduction,
    "mean_gap_reduction_percent": mean_gap_reduction_percent,

    "best_known_hits": best_known_hits,

    "mean_qefem_runtime_sec": mean_runtime,
    "mean_vanilla_runtime_sec": mean_vanilla_runtime,
    "mean_runtime_ratio_vs_vanilla": mean_runtime_ratio,
}

g35_g42_aggregate_summary_df = pd.DataFrame([g35_g42_aggregate_summary])

aggregate_path = OUTPUT_DIR / "qefem_anneal_G35_G42_aggregate_summary.csv"
g35_g42_aggregate_summary_df.to_csv(aggregate_path, index=False)

print("\nAggregate G35-G42 summary:")
display(g35_g42_aggregate_summary_df)

print("\nSaved aggregate summary to:")
print(aggregate_path.resolve())
# Out:
# Aggregate G35-G42 summary:
#    num_instances  wins_vs_vanilla  ties_vs_vanilla  losses_vs_vanilla  \
# 0              8                8                0                  0
#
#    mean_qefem_cut  mean_vanilla_cut  mean_best_value  \
# 0          4968.5          4863.625           5055.0
#
#    mean_delta_cut_vs_vanilla  median_delta_cut_vs_vanilla  \
# 0                    104.875                        100.5
#
#    min_delta_cut_vs_vanilla  ...  mean_vanilla_accuracy_percent  \
# 0                      84.0  ...                       94.48186
#
#    mean_delta_accuracy_percentage_points  mean_qefem_gap  mean_vanilla_gap  \
# 0                               3.008099            86.5           191.375
#
#    mean_gap_reduction  mean_gap_reduction_percent  best_known_hits  \
# 0             104.875                   54.780671                0
#
#    mean_qefem_runtime_sec  mean_vanilla_runtime_sec  \
# 0               28.765088                  8.542213
#
#    mean_runtime_ratio_vs_vanilla
# 0                       3.369398
#
# [1 rows x 23 columns]
# Saved aggregate summary to:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_v1_outputs/qefem_anneal_G35_G42_aggregate_summary.csv

# %%
# ----------------------------
# Pretty print key results
# ----------------------------
print("\n" + "=" * 80)
print("G35-G42 PROBLEM-BATCH HEAD-TO-HEAD SUMMARY")
print("=" * 80)
print(f"Wins / ties / losses vs vanilla: {wins} / {ties} / {losses}")
print(f"Mean QEFEM accuracy: {mean_qefem_accuracy:.4f}%")
print(f"Mean vanilla accuracy: {mean_vanilla_accuracy:.4f}%")
print(f"Mean accuracy gain: {mean_delta_accuracy:.4f} percentage points")
print(f"Mean cut gain: {mean_delta_cut:.2f}")
print(f"Mean cut-value improvement vs vanilla: {mean_cut_improvement_percent:.4f}%")
print(f"Mean vanilla gap: {mean_vanilla_gap:.2f}")
print(f"Mean QEFEM gap: {mean_gap:.2f}")
print(f"Mean gap reduction: {mean_gap_reduction:.2f}")
print(f"Mean gap reduction percent: {mean_gap_reduction_percent:.2f}%")
print(f"Best-known hits: {best_known_hits}/{num_instances}")
print(f"Mean QEFEM runtime: {mean_runtime:.2f}s")
print(f"Mean vanilla runtime: {mean_vanilla_runtime:.2f}s")
print(f"Runtime ratio QEFEM/vanilla: {mean_runtime_ratio:.2f}x")
print("=" * 80)
# Out:
# ================================================================================
# G35-G42 PROBLEM-BATCH HEAD-TO-HEAD SUMMARY
# ================================================================================
# Wins / ties / losses vs vanilla: 8 / 0 / 0
# Mean QEFEM accuracy: 97.4900%
# Mean vanilla accuracy: 94.4819%
# Mean accuracy gain: 3.0081 percentage points
# Mean cut gain: 104.88
# Mean cut-value improvement vs vanilla: 3.2555%
# Mean vanilla gap: 191.38
# Mean QEFEM gap: 86.50
# Mean gap reduction: 104.88
# Mean gap reduction percent: 54.78%
# Best-known hits: 0/8
# Mean QEFEM runtime: 28.77s
# Mean vanilla runtime: 8.54s
# Runtime ratio QEFEM/vanilla: 3.37x
# ================================================================================

# %%
# ----------------------------
# Plot: cut comparison
# ----------------------------
x = np.arange(len(g35_g42_analysis_df))
labels = g35_g42_analysis_df["instance"].tolist()

plt.figure(figsize=(10, 5))
plt.plot(x, g35_g42_analysis_df["best_value"], marker="o", label="best-known")
plt.plot(x, g35_g42_analysis_df["vanilla_cut"], marker="o", label="vanilla FEM")
plt.plot(x, g35_g42_analysis_df["best_cut"], marker="o", label="QEFEM anneal")
plt.xticks(x, labels)
plt.xlabel("Instance")
plt.ylabel("Cut value")
plt.title("G35-G42: cut comparison")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Plot: delta cut vs vanilla
# ----------------------------
plt.figure(figsize=(10, 5))
plt.bar(g35_g42_analysis_df["instance"], g35_g42_analysis_df["delta_cut_vs_vanilla"])
plt.axhline(0, linestyle="--")
plt.xlabel("Instance")
plt.ylabel("QEFEM cut - vanilla cut")
plt.title("G35-G42: QEFEM improvement over vanilla")
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Plot: accuracy comparison
# ----------------------------
plt.figure(figsize=(10, 5))
plt.plot(x, g35_g42_analysis_df["vanilla_percent_accuracy"], marker="o", label="vanilla FEM")
plt.plot(x, g35_g42_analysis_df["percent_accuracy"], marker="o", label="QEFEM anneal")
plt.axhline(100.0, linestyle="--", label="best-known = 100%")
plt.xticks(x, labels)
plt.xlabel("Instance")
plt.ylabel("Accuracy % of best-known")
plt.title("G35-G42: accuracy comparison")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Plot: gap comparison
# ----------------------------
plt.figure(figsize=(10, 5))
plt.plot(x, g35_g42_analysis_df["vanilla_gap"], marker="o", label="vanilla gap")
plt.plot(x, g35_g42_analysis_df["gap"], marker="o", label="QEFEM gap")
plt.xticks(x, labels)
plt.xlabel("Instance")
plt.ylabel("Gap to best-known")
plt.title("G35-G42: gap comparison")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Plot: runtime comparison
# ----------------------------
plt.figure(figsize=(10, 5))
plt.plot(x, g35_g42_analysis_df["vanilla_runtime_sec"], marker="o", label="vanilla runtime")
plt.plot(x, g35_g42_analysis_df["runtime_sec"], marker="o", label="QEFEM runtime")
plt.xticks(x, labels)
plt.xlabel("Instance")
plt.ylabel("Runtime seconds")
plt.title("G35-G42: runtime comparison")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ----------------------------
# Final verdict
# ----------------------------
print("\nVerdict:")

if wins == num_instances:
    print(
        f"QEFEM anneal beats vanilla on all {num_instances}/{num_instances} G35-G42 problem-batch instances. "
        "This would be a very strong sign that the method helps exactly where vanilla struggled." 
    )
elif wins > losses:
    print(
        "QEFEM anneal wins more often than it loses on G35-G42. Encouraging."
    )
else:
    print(
        "QEFEM anneal does not clearly beat vanilla on G35-G42. Inspect gamma schedule, rx/rz behavior, and per-instance traces."
    )
# Out:
# Verdict:
# QEFEM anneal beats vanilla on all 8/8 G35-G42 problem-batch instances. This would be a very strong sign that the method helps exactly where vanilla struggled.

# %% [markdown]
# ### Full RUN
# G1-G54 ===> all 9 batches

# %%
assert "run_qefem_single_gset" in globals(), "Run Cell 18 first. Wrapper function is missing."
# ----------------------------
# Full benchmark target
# ----------------------------
FULL_BENCHMARK_INSTANCES = GSET_ALL_INSTANCES.copy()

print("Full benchmark target:")
print(FULL_BENCHMARK_INSTANCES)
print("Total instances:", len(FULL_BENCHMARK_INSTANCES))


# ----------------------------
# Collect already-computed results
# ----------------------------
existing_result_dfs = []

if "qefem_g1_g10_results_df" in globals():
    print("\nFound existing G1-G10 QEFEM results.")
    existing_result_dfs.append(qefem_g1_g10_results_df.copy())

if "qefem_g35_g42_results_df" in globals():
    print("Found existing G35-G42 QEFEM results.")
    existing_result_dfs.append(qefem_g35_g42_results_df.copy())


if len(existing_result_dfs) > 0:
    qefem_full_results_df = pd.concat(
        existing_result_dfs,
        ignore_index=True,
    )

    # If an instance somehow appears twice, keep the first result.
    # The notebook goblin occasionally duplicates things when humans panic-run cells.
    qefem_full_results_df = (
        qefem_full_results_df
        .drop_duplicates(subset=["instance"], keep="first")
        .reset_index(drop=True)
    )

else:
    qefem_full_results_df = pd.DataFrame()


already_done_instances = set(qefem_full_results_df["instance"]) if len(qefem_full_results_df) > 0 else set()

missing_instances = [
    instance_name
    for instance_name in FULL_BENCHMARK_INSTANCES
    if instance_name not in already_done_instances
]

print("\nAlready done instances:")
print(sorted(already_done_instances, key=lambda x: int(x[1:])))

print("\nMissing instances to run:")
print(missing_instances)

print("\nNumber already done:", len(already_done_instances))
print("Number missing:", len(missing_instances))
# Out:
# Full benchmark target:
# ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'G11', 'G12', 'G13', 'G14', 'G15', 'G16', 'G17', 'G18', 'G19', 'G20', 'G21', 'G22', 'G23', 'G24', 'G25', 'G26', 'G27', 'G28', 'G29', 'G30', 'G31', 'G32', 'G33', 'G34', 'G35', 'G36', 'G37', 'G38', 'G39', 'G40', 'G41', 'G42', 'G43', 'G44', 'G45', 'G46', 'G47', 'G48', 'G49', 'G50', 'G51', 'G52', 'G53', 'G54']
# Total instances: 54
#
# Found existing G1-G10 QEFEM results.
# Found existing G35-G42 QEFEM results.
#
# Already done instances:
# ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'G35', 'G36', 'G37', 'G38', 'G39', 'G40', 'G41', 'G42']
#
# Missing instances to run:
# ['G11', 'G12', 'G13', 'G14', 'G15', 'G16', 'G17', 'G18', 'G19', 'G20', 'G21', 'G22', 'G23', 'G24', 'G25', 'G26', 'G27', 'G28', 'G29', 'G30', 'G31', 'G32', 'G33', 'G34', 'G43', 'G44', 'G45', 'G46', 'G47', 'G48', 'G49', 'G50', 'G51', 'G52', 'G53', 'G54']
#
# Number already done: 18
# Number missing: 36

# %%
# ----------------------------
# Save starting merged file
# ----------------------------
full_partial_path = OUTPUT_DIR / "qefem_anneal_G1_G54_partial_results.csv"

if len(qefem_full_results_df) > 0:
    qefem_full_results_df = (
        qefem_full_results_df
        .assign(g_index=lambda df: df["instance"].str.replace("G", "", regex=False).astype(int))
        .sort_values("g_index")
        .drop(columns=["g_index"])
        .reset_index(drop=True)
    )

    qefem_full_results_df.to_csv(full_partial_path, index=False)

    print("\nSaved starting merged partial full-results file:")
    print(full_partial_path.resolve())
# Out:
# Saved starting merged partial full-results file:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_v1_outputs/qefem_anneal_G1_G54_partial_results.csv

# %%
# ----------------------------
# Run missing instances
# ----------------------------
print("\n" + "=" * 80)
print("Starting missing-instance QEFEM full benchmark runs")
print("=" * 80)

for run_idx, instance_name in enumerate(missing_instances, start=1):
    print("\n\n" + "#" * 80)
    print(f"Full G1-G54 missing run {run_idx}/{len(missing_instances)}: {instance_name}")
    print("#" * 80)

    summary, history_df = run_qefem_single_gset(
        instance_name=instance_name,
        gamma_mode="anneal",
        replicas=REPLICAS,
        n_steps=N_STEPS,
        seed=SEED,
        lr=LR,
        beta_min=BETA_MIN,
        beta_max=BETA_MAX,
        gamma_max=GAMMA_MAX,
        gamma_min=GAMMA_MIN,
        R_init=R_INIT,
        theta_center=THETA_CENTER,
        theta_noise=THETA_NOISE,
        print_every=PRINT_EVERY,
        save_history=True,
        output_dir=OUTPUT_DIR,
        device=device,
        dtype=DTYPE,
    )

    # Append new result
    qefem_full_results_df = pd.concat(
        [
            qefem_full_results_df,
            pd.DataFrame([summary]),
        ],
        ignore_index=True,
    )

    # Sort by G index
    qefem_full_results_df = (
        qefem_full_results_df
        .drop_duplicates(subset=["instance"], keep="first")
        .assign(g_index=lambda df: df["instance"].str.replace("G", "", regex=False).astype(int))
        .sort_values("g_index")
        .drop(columns=["g_index"])
        .reset_index(drop=True)
    )

    # Save after every graph, because notebooks die like Victorian children.
    qefem_full_results_df.to_csv(full_partial_path, index=False)

    print("\nCurrent full benchmark progress:")
    print(f"Completed {len(qefem_full_results_df)}/{len(FULL_BENCHMARK_INSTANCES)} instances")

    display(qefem_full_results_df[
        [
            "instance",
            "best_cut",
            "best_value",
            "gap",
            "percent_accuracy",
            "vanilla_cut",
            "delta_cut_vs_vanilla",
            "delta_accuracy_vs_vanilla",
            "runtime_sec",
        ]
    ].tail(10))
# Out:
# ================================================================================
# Starting missing-instance QEFEM full benchmark runs
# ================================================================================
#
#
# ################################################################################
# Full G1-G54 missing run 1/36: G11
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G11
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 564
# vanilla cut: 526.0
# --------------------------------------------------------------------------------
# G11 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=64 | best=64 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G11 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=26 | best=118 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.62s
# G11 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=-88 | best=118 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.70s
# G11 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=544 | best=544 | |rx|=0.5562 | |rz|=0.0726 | elapsed=5.78s
# G11 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=556 | best=556 | |rx|=0.4615 | |rz|=0.6782 | elapsed=7.83s
# G11 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=556 | best=556 | |rx|=0.4130 | |rz|=0.7842 | elapsed=9.91s
# G11 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=556 | best=556 | |rx|=0.3556 | |rz|=0.8337 | elapsed=11.99s
# G11 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=556 | best=556 | |rx|=0.2935 | |rz|=0.8653 | elapsed=14.08s
# G11 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=556 | best=556 | |rx|=0.2274 | |rz|=0.8865 | elapsed=16.19s
# G11 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=556 | best=556 | |rx|=0.1572 | |rz|=0.8984 | elapsed=18.26s
# G11 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=556 | best=556 | |rx|=0.0714 | |rz|=0.9304 | elapsed=20.26s
#
# Finished: G11
# Best cut: 556.0
# Best-known: 564
# Gap: 8.0
# Accuracy %: 98.58156028368795
# Vanilla cut: 526.0
# Delta cut vs vanilla: 30.0
# Runtime sec: 20.26449728012085
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 19/54 instances
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 9       G10    1992.0        2000    8.0         99.600000       1819.0
# 10      G11     556.0         564    8.0         98.581560        526.0
# 11      G35    7612.0        7687   75.0         99.024327       7523.0
# 12      G36    7599.0        7680   81.0         98.945312       7515.0
# 13      G37    7619.0        7691   72.0         99.063841       7520.0
# 14      G38    7616.0        7688   72.0         99.063476       7514.0
# 15      G39    2336.0        2408   72.0         97.009967       2188.0
# 16      G40    2296.0        2400  104.0         95.666667       2183.0
# 17      G41    2289.0        2405  116.0         95.176715       2193.0
# 18      G42    2381.0        2481  100.0         95.969367       2273.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 9                  173.0                   8.650000    19.065519
# 10                  30.0                   5.319149    20.264497
# 11                  89.0                   1.157799    29.154830
# 12                  84.0                   1.093750    28.860679
# 13                  99.0                   1.287219    27.966833
# 14                 102.0                   1.326743    29.442648
# 15                 148.0                   6.146179    29.048542
# 16                 113.0                   4.708333    28.897351
# 17                  96.0                   3.991684    27.832200
# 18                 108.0                   4.353083    28.917619
# ################################################################################
# Full G1-G54 missing run 2/36: G12
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G12
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 556
# vanilla cut: 520.0
# --------------------------------------------------------------------------------
# G12 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=52 | best=52 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G12 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=24 | best=94 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.89s
# G12 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=-100 | best=116 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.98s
# G12 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=544 | best=544 | |rx|=0.5519 | |rz|=0.0948 | elapsed=6.08s
# G12 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=550 | best=550 | |rx|=0.4540 | |rz|=0.6852 | elapsed=8.12s
# G12 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=550 | best=550 | |rx|=0.4066 | |rz|=0.7892 | elapsed=10.26s
# G12 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=550 | best=550 | |rx|=0.3504 | |rz|=0.8377 | elapsed=12.40s
# G12 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=550 | best=550 | |rx|=0.2895 | |rz|=0.8688 | elapsed=14.55s
# G12 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=550 | best=550 | |rx|=0.2243 | |rz|=0.8896 | elapsed=16.66s
# G12 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=550 | best=550 | |rx|=0.1549 | |rz|=0.9012 | elapsed=18.70s
# G12 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=550 | best=550 | |rx|=0.0673 | |rz|=0.9353 | elapsed=20.75s
#
# Finished: G12
# Best cut: 550.0
# Best-known: 556
# Gap: 6.0
# Accuracy %: 98.92086330935251
# Vanilla cut: 520.0
# Delta cut vs vanilla: 30.0
# Runtime sec: 20.75463604927063
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 20/54 instances
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 10      G11     556.0         564    8.0         98.581560        526.0
# 11      G12     550.0         556    6.0         98.920863        520.0
# 12      G35    7612.0        7687   75.0         99.024327       7523.0
# 13      G36    7599.0        7680   81.0         98.945312       7515.0
# 14      G37    7619.0        7691   72.0         99.063841       7520.0
# 15      G38    7616.0        7688   72.0         99.063476       7514.0
# 16      G39    2336.0        2408   72.0         97.009967       2188.0
# 17      G40    2296.0        2400  104.0         95.666667       2183.0
# 18      G41    2289.0        2405  116.0         95.176715       2193.0
# 19      G42    2381.0        2481  100.0         95.969367       2273.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 10                  30.0                   5.319149    20.264497
# 11                  30.0                   5.395683    20.754636
# 12                  89.0                   1.157799    29.154830
# 13                  84.0                   1.093750    28.860679
# 14                  99.0                   1.287219    27.966833
# 15                 102.0                   1.326743    29.442648
# 16                 148.0                   6.146179    29.048542
# 17                 113.0                   4.708333    28.897351
# 18                  96.0                   3.991684    27.832200
# 19                 108.0                   4.353083    28.917619
# ################################################################################
# Full G1-G54 missing run 3/36: G13
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G13
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 582
# vanilla cut: 542.0
# --------------------------------------------------------------------------------
# G13 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=60 | best=60 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G13 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=28 | best=106 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.89s
# G13 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=-86 | best=106 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.96s
# G13 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=566 | best=566 | |rx|=0.5490 | |rz|=0.1078 | elapsed=5.99s
# G13 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=580 | best=580 | |rx|=0.4506 | |rz|=0.6899 | elapsed=8.03s
# G13 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=580 | best=580 | |rx|=0.4029 | |rz|=0.7940 | elapsed=10.05s
# G13 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=580 | best=580 | |rx|=0.3464 | |rz|=0.8427 | elapsed=12.14s
# G13 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=580 | best=580 | |rx|=0.2854 | |rz|=0.8739 | elapsed=14.22s
# G13 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=580 | best=580 | |rx|=0.2201 | |rz|=0.8946 | elapsed=16.25s
# G13 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=580 | best=580 | |rx|=0.1505 | |rz|=0.9062 | elapsed=18.30s
# G13 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=580 | best=580 | |rx|=0.0619 | |rz|=0.9406 | elapsed=20.26s
#
# Finished: G13
# Best cut: 580.0
# Best-known: 582
# Gap: 2.0
# Accuracy %: 99.65635738831615
# Vanilla cut: 542.0
# Delta cut vs vanilla: 38.0
# Runtime sec: 20.25663113594055
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 21/54 instances
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 11      G12     550.0         556    6.0         98.920863        520.0
# 12      G13     580.0         582    2.0         99.656357        542.0
# 13      G35    7612.0        7687   75.0         99.024327       7523.0
# 14      G36    7599.0        7680   81.0         98.945312       7515.0
# 15      G37    7619.0        7691   72.0         99.063841       7520.0
# 16      G38    7616.0        7688   72.0         99.063476       7514.0
# 17      G39    2336.0        2408   72.0         97.009967       2188.0
# 18      G40    2296.0        2400  104.0         95.666667       2183.0
# 19      G41    2289.0        2405  116.0         95.176715       2193.0
# 20      G42    2381.0        2481  100.0         95.969367       2273.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 11                  30.0                   5.395683    20.754636
# 12                  38.0                   6.529210    20.256631
# 13                  89.0                   1.157799    29.154830
# 14                  84.0                   1.093750    28.860679
# 15                  99.0                   1.287219    27.966833
# 16                 102.0                   1.326743    29.442648
# 17                 148.0                   6.146179    29.048542
# 18                 113.0                   4.708333    28.897351
# 19                  96.0                   3.991684    27.832200
# 20                 108.0                   4.353083    28.917619
# ################################################################################
# Full G1-G54 missing run 4/36: G14
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G14
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 3064
# vanilla cut: 3022.0
# --------------------------------------------------------------------------------
# G14 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=2432 | best=2432 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G14 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=2395 | best=2518 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.69s
# G14 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1703 | best=2518 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.75s
# G14 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=3011 | best=3011 | |rx|=0.4194 | |rz|=0.3538 | elapsed=5.82s
# G14 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=3036 | best=3036 | |rx|=0.4402 | |rz|=0.6925 | elapsed=7.73s
# G14 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=3040 | best=3040 | |rx|=0.3990 | |rz|=0.7943 | elapsed=9.85s
# G14 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=3040 | best=3040 | |rx|=0.3429 | |rz|=0.8481 | elapsed=11.96s
# G14 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=3040 | best=3040 | |rx|=0.2803 | |rz|=0.8837 | elapsed=14.08s
# G14 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=3040 | best=3040 | |rx|=0.2115 | |rz|=0.9088 | elapsed=16.17s
# G14 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=3040 | best=3040 | |rx|=0.1365 | |rz|=0.9252 | elapsed=18.23s
# G14 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=3040 | best=3040 | |rx|=0.0418 | |rz|=0.9604 | elapsed=20.27s
#
# Finished: G14
# Best cut: 3040.0
# Best-known: 3064
# Gap: 24.0
# Accuracy %: 99.21671018276763
# Vanilla cut: 3022.0
# Delta cut vs vanilla: 18.0
# Runtime sec: 20.271545886993408
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 22/54 instances
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 12      G13     580.0         582    2.0         99.656357        542.0
# 13      G14    3040.0        3064   24.0         99.216710       3022.0
# 14      G35    7612.0        7687   75.0         99.024327       7523.0
# 15      G36    7599.0        7680   81.0         98.945312       7515.0
# 16      G37    7619.0        7691   72.0         99.063841       7520.0
# 17      G38    7616.0        7688   72.0         99.063476       7514.0
# 18      G39    2336.0        2408   72.0         97.009967       2188.0
# 19      G40    2296.0        2400  104.0         95.666667       2183.0
# 20      G41    2289.0        2405  116.0         95.176715       2193.0
# 21      G42    2381.0        2481  100.0         95.969367       2273.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 12                  38.0                   6.529210    20.256631
# 13                  18.0                   0.587467    20.271546
# 14                  89.0                   1.157799    29.154830
# 15                  84.0                   1.093750    28.860679
# 16                  99.0                   1.287219    27.966833
# 17                 102.0                   1.326743    29.442648
# 18                 148.0                   6.146179    29.048542
# 19                 113.0                   4.708333    28.897351
# 20                  96.0                   3.991684    27.832200
# 21                 108.0                   4.353083    28.917619
# ################################################################################
# Full G1-G54 missing run 5/36: G15
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G15
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 3050
# vanilla cut: 2998.0
# --------------------------------------------------------------------------------
# G15 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=2398 | best=2398 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G15 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=2391 | best=2490 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.81s
# G15 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1625 | best=2490 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.94s
# G15 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=3003 | best=3003 | |rx|=0.4151 | |rz|=0.3603 | elapsed=6.05s
# G15 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=3025 | best=3025 | |rx|=0.4378 | |rz|=0.6949 | elapsed=8.19s
# G15 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=3025 | best=3025 | |rx|=0.3976 | |rz|=0.7950 | elapsed=10.31s
# G15 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=3025 | best=3025 | |rx|=0.3436 | |rz|=0.8466 | elapsed=12.40s
# G15 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=3025 | best=3025 | |rx|=0.2818 | |rz|=0.8818 | elapsed=14.53s
# G15 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=3025 | best=3025 | |rx|=0.2135 | |rz|=0.9069 | elapsed=16.57s
# G15 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=3025 | best=3025 | |rx|=0.1387 | |rz|=0.9233 | elapsed=18.69s
# G15 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=3025 | best=3025 | |rx|=0.0418 | |rz|=0.9611 | elapsed=20.78s
#
# Finished: G15
# Best cut: 3025.0
# Best-known: 3050
# Gap: 25.0
# Accuracy %: 99.18032786885246
# Vanilla cut: 2998.0
# Delta cut vs vanilla: 27.0
# Runtime sec: 20.780205011367798
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 23/54 instances
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 13      G14    3040.0        3064   24.0         99.216710       3022.0
# 14      G15    3025.0        3050   25.0         99.180328       2998.0
# 15      G35    7612.0        7687   75.0         99.024327       7523.0
# 16      G36    7599.0        7680   81.0         98.945312       7515.0
# 17      G37    7619.0        7691   72.0         99.063841       7520.0
# 18      G38    7616.0        7688   72.0         99.063476       7514.0
# 19      G39    2336.0        2408   72.0         97.009967       2188.0
# 20      G40    2296.0        2400  104.0         95.666667       2183.0
# 21      G41    2289.0        2405  116.0         95.176715       2193.0
# 22      G42    2381.0        2481  100.0         95.969367       2273.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 13                  18.0                   0.587467    20.271546
# 14                  27.0                   0.885246    20.780205
# 15                  89.0                   1.157799    29.154830
# 16                  84.0                   1.093750    28.860679
# 17                  99.0                   1.287219    27.966833
# 18                 102.0                   1.326743    29.442648
# 19                 148.0                   6.146179    29.048542
# 20                 113.0                   4.708333    28.897351
# 21                  96.0                   3.991684    27.832200
# 22                 108.0                   4.353083    28.917619
# ################################################################################
# Full G1-G54 missing run 6/36: G16
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G16
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 3052
# vanilla cut: 2995.0
# --------------------------------------------------------------------------------
# G16 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=2387 | best=2387 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G16 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=2395 | best=2492 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.69s
# G16 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1666 | best=2492 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.66s
# G16 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=3001 | best=3001 | |rx|=0.4188 | |rz|=0.3554 | elapsed=5.73s
# G16 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=3022 | best=3022 | |rx|=0.4385 | |rz|=0.6917 | elapsed=7.75s
# G16 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=3026 | best=3026 | |rx|=0.3988 | |rz|=0.7907 | elapsed=9.78s
# G16 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=3027 | best=3027 | |rx|=0.3447 | |rz|=0.8422 | elapsed=11.86s
# G16 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=3027 | best=3027 | |rx|=0.2838 | |rz|=0.8767 | elapsed=13.93s
# G16 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=3027 | best=3027 | |rx|=0.2169 | |rz|=0.9009 | elapsed=15.94s
# G16 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=3027 | best=3027 | |rx|=0.1440 | |rz|=0.9165 | elapsed=18.00s
# G16 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=3027 | best=3027 | |rx|=0.0491 | |rz|=0.9557 | elapsed=20.06s
#
# Finished: G16
# Best cut: 3027.0
# Best-known: 3052
# Gap: 25.0
# Accuracy %: 99.18086500655308
# Vanilla cut: 2995.0
# Delta cut vs vanilla: 32.0
# Runtime sec: 20.05973982810974
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 24/54 instances
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 14      G15    3025.0        3050   25.0         99.180328       2998.0
# 15      G16    3027.0        3052   25.0         99.180865       2995.0
# 16      G35    7612.0        7687   75.0         99.024327       7523.0
# 17      G36    7599.0        7680   81.0         98.945312       7515.0
# 18      G37    7619.0        7691   72.0         99.063841       7520.0
# 19      G38    7616.0        7688   72.0         99.063476       7514.0
# 20      G39    2336.0        2408   72.0         97.009967       2188.0
# 21      G40    2296.0        2400  104.0         95.666667       2183.0
# 22      G41    2289.0        2405  116.0         95.176715       2193.0
# 23      G42    2381.0        2481  100.0         95.969367       2273.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 14                  27.0                   0.885246    20.780205
# 15                  32.0                   1.048493    20.059740
# 16                  89.0                   1.157799    29.154830
# 17                  84.0                   1.093750    28.860679
# 18                  99.0                   1.287219    27.966833
# 19                 102.0                   1.326743    29.442648
# 20                 148.0                   6.146179    29.048542
# 21                 113.0                   4.708333    28.897351
# 22                  96.0                   3.991684    27.832200
# 23                 108.0                   4.353083    28.917619
# ################################################################################
# Full G1-G54 missing run 7/36: G17
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G17
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 3047
# vanilla cut: 2995.0
# --------------------------------------------------------------------------------
# G17 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=2380 | best=2380 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G17 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=2394 | best=2480 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.77s
# G17 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1752 | best=2488 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.84s
# G17 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=2993 | best=2994 | |rx|=0.4195 | |rz|=0.3524 | elapsed=5.84s
# G17 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=3018 | best=3018 | |rx|=0.4433 | |rz|=0.6867 | elapsed=7.89s
# G17 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=3021 | best=3021 | |rx|=0.4030 | |rz|=0.7866 | elapsed=9.90s
# G17 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=3021 | best=3021 | |rx|=0.3486 | |rz|=0.8382 | elapsed=11.97s
# G17 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=3021 | best=3021 | |rx|=0.2875 | |rz|=0.8724 | elapsed=14.06s
# G17 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=3021 | best=3021 | |rx|=0.2205 | |rz|=0.8964 | elapsed=16.11s
# G17 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=3021 | best=3021 | |rx|=0.1476 | |rz|=0.9120 | elapsed=18.13s
# G17 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=3021 | best=3021 | |rx|=0.0532 | |rz|=0.9534 | elapsed=20.20s
#
# Finished: G17
# Best cut: 3021.0
# Best-known: 3047
# Gap: 26.0
# Accuracy %: 99.14670167377749
# Vanilla cut: 2995.0
# Delta cut vs vanilla: 26.0
# Runtime sec: 20.20124101638794
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 25/54 instances
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 15      G16    3027.0        3052   25.0         99.180865       2995.0
# 16      G17    3021.0        3047   26.0         99.146702       2995.0
# 17      G35    7612.0        7687   75.0         99.024327       7523.0
# 18      G36    7599.0        7680   81.0         98.945312       7515.0
# 19      G37    7619.0        7691   72.0         99.063841       7520.0
# 20      G38    7616.0        7688   72.0         99.063476       7514.0
# 21      G39    2336.0        2408   72.0         97.009967       2188.0
# 22      G40    2296.0        2400  104.0         95.666667       2183.0
# 23      G41    2289.0        2405  116.0         95.176715       2193.0
# 24      G42    2381.0        2481  100.0         95.969367       2273.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 15                  32.0                   1.048493    20.059740
# 16                  26.0                   0.853298    20.201241
# 17                  89.0                   1.157799    29.154830
# 18                  84.0                   1.093750    28.860679
# 19                  99.0                   1.287219    27.966833
# 20                 102.0                   1.326743    29.442648
# 21                 148.0                   6.146179    29.048542
# 22                 113.0                   4.708333    28.897351
# 23                  96.0                   3.991684    27.832200
# 24                 108.0                   4.353083    28.917619
# ################################################################################
# Full G1-G54 missing run 8/36: G18
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G18
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 992
# vanilla cut: 928.0
# --------------------------------------------------------------------------------
# G18 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=125 | best=125 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G18 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=83 | best=178 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.75s
# G18 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=-247 | best=178 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.68s
# G18 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=970 | best=970 | |rx|=0.3493 | |rz|=0.4499 | elapsed=5.74s
# G18 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=978 | best=978 | |rx|=0.3647 | |rz|=0.7511 | elapsed=7.80s
# G18 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=978 | best=978 | |rx|=0.3306 | |rz|=0.8339 | elapsed=9.86s
# G18 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=978 | best=978 | |rx|=0.2850 | |rz|=0.8754 | elapsed=11.94s
# G18 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=978 | best=978 | |rx|=0.2329 | |rz|=0.9034 | elapsed=14.01s
# G18 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=978 | best=978 | |rx|=0.1753 | |rz|=0.9234 | elapsed=16.02s
# G18 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=978 | best=978 | |rx|=0.1125 | |rz|=0.9366 | elapsed=18.14s
# G18 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=978 | best=978 | |rx|=0.0348 | |rz|=0.9659 | elapsed=20.26s
#
# Finished: G18
# Best cut: 978.0
# Best-known: 992
# Gap: 14.0
# Accuracy %: 98.58870967741936
# Vanilla cut: 928.0
# Delta cut vs vanilla: 50.0
# Runtime sec: 20.259756088256836
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 26/54 instances
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 16      G17    3021.0        3047   26.0         99.146702       2995.0
# 17      G18     978.0         992   14.0         98.588710        928.0
# 18      G35    7612.0        7687   75.0         99.024327       7523.0
# 19      G36    7599.0        7680   81.0         98.945312       7515.0
# 20      G37    7619.0        7691   72.0         99.063841       7520.0
# 21      G38    7616.0        7688   72.0         99.063476       7514.0
# 22      G39    2336.0        2408   72.0         97.009967       2188.0
# 23      G40    2296.0        2400  104.0         95.666667       2183.0
# 24      G41    2289.0        2405  116.0         95.176715       2193.0
# 25      G42    2381.0        2481  100.0         95.969367       2273.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 16                  26.0                   0.853298    20.201241
# 17                  50.0                   5.040323    20.259756
# 18                  89.0                   1.157799    29.154830
# 19                  84.0                   1.093750    28.860679
# 20                  99.0                   1.287219    27.966833
# 21                 102.0                   1.326743    29.442648
# 22                 148.0                   6.146179    29.048542
# 23                 113.0                   4.708333    28.897351
# 24                  96.0                   3.991684    27.832200
# 25                 108.0                   4.353083    28.917619
# ################################################################################
# Full G1-G54 missing run 9/36: G19
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G19
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 906
# vanilla cut: 838.0
# --------------------------------------------------------------------------------
# G19 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=16 | best=16 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G19 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=-6 | best=87 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.73s
# G19 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=-239 | best=87 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.81s
# G19 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=865 | best=865 | |rx|=0.3524 | |rz|=0.4433 | elapsed=5.85s
# G19 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=876 | best=876 | |rx|=0.3704 | |rz|=0.7400 | elapsed=7.77s
# G19 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=876 | best=876 | |rx|=0.3375 | |rz|=0.8222 | elapsed=9.83s
# G19 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=876 | best=876 | |rx|=0.2922 | |rz|=0.8642 | elapsed=11.89s
# G19 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=876 | best=876 | |rx|=0.2408 | |rz|=0.8922 | elapsed=13.93s
# G19 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=876 | best=876 | |rx|=0.1842 | |rz|=0.9120 | elapsed=15.97s
# G19 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=876 | best=876 | |rx|=0.1228 | |rz|=0.9247 | elapsed=18.04s
# G19 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=876 | best=876 | |rx|=0.0457 | |rz|=0.9579 | elapsed=20.10s
#
# Finished: G19
# Best cut: 876.0
# Best-known: 906
# Gap: 30.0
# Accuracy %: 96.6887417218543
# Vanilla cut: 838.0
# Delta cut vs vanilla: 38.0
# Runtime sec: 20.099334001541138
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 27/54 instances
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 17      G18     978.0         992   14.0         98.588710        928.0
# 18      G19     876.0         906   30.0         96.688742        838.0
# 19      G35    7612.0        7687   75.0         99.024327       7523.0
# 20      G36    7599.0        7680   81.0         98.945312       7515.0
# 21      G37    7619.0        7691   72.0         99.063841       7520.0
# 22      G38    7616.0        7688   72.0         99.063476       7514.0
# 23      G39    2336.0        2408   72.0         97.009967       2188.0
# 24      G40    2296.0        2400  104.0         95.666667       2183.0
# 25      G41    2289.0        2405  116.0         95.176715       2193.0
# 26      G42    2381.0        2481  100.0         95.969367       2273.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 17                  50.0                   5.040323    20.259756
# 18                  38.0                   4.194260    20.099334
# 19                  89.0                   1.157799    29.154830
# 20                  84.0                   1.093750    28.860679
# 21                  99.0                   1.287219    27.966833
# 22                 102.0                   1.326743    29.442648
# 23                 148.0                   6.146179    29.048542
# 24                 113.0                   4.708333    28.897351
# 25                  96.0                   3.991684    27.832200
# 26                 108.0                   4.353083    28.917619
# ################################################################################
# Full G1-G54 missing run 10/36: G20
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G20
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 941
# vanilla cut: 876.0
# --------------------------------------------------------------------------------
# G20 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=51 | best=51 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G20 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=33 | best=114 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.83s
# G20 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=-332 | best=114 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.87s
# G20 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=917 | best=917 | |rx|=0.3444 | |rz|=0.4543 | elapsed=5.80s
# G20 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=928 | best=928 | |rx|=0.3607 | |rz|=0.7493 | elapsed=7.92s
# G20 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=930 | best=930 | |rx|=0.3268 | |rz|=0.8311 | elapsed=10.02s
# G20 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=930 | best=930 | |rx|=0.2814 | |rz|=0.8727 | elapsed=12.10s
# G20 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=930 | best=930 | |rx|=0.2303 | |rz|=0.9001 | elapsed=14.16s
# G20 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=930 | best=930 | |rx|=0.1743 | |rz|=0.9192 | elapsed=16.26s
# G20 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=930 | best=930 | |rx|=0.1140 | |rz|=0.9318 | elapsed=18.30s
# G20 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=930 | best=930 | |rx|=0.0407 | |rz|=0.9611 | elapsed=20.36s
#
# Finished: G20
# Best cut: 930.0
# Best-known: 941
# Gap: 11.0
# Accuracy %: 98.83103081827842
# Vanilla cut: 876.0
# Delta cut vs vanilla: 54.0
# Runtime sec: 20.358791828155518
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 28/54 instances
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 18      G19     876.0         906   30.0         96.688742        838.0
# 19      G20     930.0         941   11.0         98.831031        876.0
# 20      G35    7612.0        7687   75.0         99.024327       7523.0
# 21      G36    7599.0        7680   81.0         98.945312       7515.0
# 22      G37    7619.0        7691   72.0         99.063841       7520.0
# 23      G38    7616.0        7688   72.0         99.063476       7514.0
# 24      G39    2336.0        2408   72.0         97.009967       2188.0
# 25      G40    2296.0        2400  104.0         95.666667       2183.0
# 26      G41    2289.0        2405  116.0         95.176715       2193.0
# 27      G42    2381.0        2481  100.0         95.969367       2273.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 18                  38.0                   4.194260    20.099334
# 19                  54.0                   5.738576    20.358792
# 20                  89.0                   1.157799    29.154830
# 21                  84.0                   1.093750    28.860679
# 22                  99.0                   1.287219    27.966833
# 23                 102.0                   1.326743    29.442648
# 24                 148.0                   6.146179    29.048542
# 25                 113.0                   4.708333    28.897351
# 26                  96.0                   3.991684    27.832200
# 27                 108.0                   4.353083    28.917619
# ################################################################################
# Full G1-G54 missing run 11/36: G21
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G21
# ================================================================================
# gamma_mode: anneal
# N: 800
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 931
# vanilla cut: 863.0
# --------------------------------------------------------------------------------
# G21 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=54 | best=54 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G21 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=13 | best=120 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.85s
# G21 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=-347 | best=120 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.91s
# G21 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=901 | best=901 | |rx|=0.3525 | |rz|=0.4450 | elapsed=6.04s
# G21 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=915 | best=915 | |rx|=0.3678 | |rz|=0.7465 | elapsed=8.16s
# G21 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=915 | best=915 | |rx|=0.3333 | |rz|=0.8300 | elapsed=10.28s
# G21 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=915 | best=915 | |rx|=0.2864 | |rz|=0.8727 | elapsed=12.36s
# G21 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=915 | best=915 | |rx|=0.2335 | |rz|=0.9014 | elapsed=14.39s
# G21 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=915 | best=915 | |rx|=0.1758 | |rz|=0.9215 | elapsed=16.52s
# G21 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=915 | best=915 | |rx|=0.1134 | |rz|=0.9345 | elapsed=18.64s
# G21 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=915 | best=915 | |rx|=0.0385 | |rz|=0.9624 | elapsed=20.78s
#
# Finished: G21
# Best cut: 915.0
# Best-known: 931
# Gap: 16.0
# Accuracy %: 98.28141783029001
# Vanilla cut: 863.0
# Delta cut vs vanilla: 52.0
# Runtime sec: 20.777416944503784
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 29/54 instances
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 19      G20     930.0         941   11.0         98.831031        876.0
# 20      G21     915.0         931   16.0         98.281418        863.0
# 21      G35    7612.0        7687   75.0         99.024327       7523.0
# 22      G36    7599.0        7680   81.0         98.945312       7515.0
# 23      G37    7619.0        7691   72.0         99.063841       7520.0
# 24      G38    7616.0        7688   72.0         99.063476       7514.0
# 25      G39    2336.0        2408   72.0         97.009967       2188.0
# 26      G40    2296.0        2400  104.0         95.666667       2183.0
# 27      G41    2289.0        2405  116.0         95.176715       2193.0
# 28      G42    2381.0        2481  100.0         95.969367       2273.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 19                  54.0                   5.738576    20.358792
# 20                  52.0                   5.585392    20.777417
# 21                  89.0                   1.157799    29.154830
# 22                  84.0                   1.093750    28.860679
# 23                  99.0                   1.287219    27.966833
# 24                 102.0                   1.326743    29.442648
# 25                 148.0                   6.146179    29.048542
# 26                 113.0                   4.708333    28.897351
# 27                  96.0                   3.991684    27.832200
# 28                 108.0                   4.353083    28.917619
# ################################################################################
# Full G1-G54 missing run 12/36: G22
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G22
# ================================================================================
# gamma_mode: anneal
# N: 2000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 13359
# vanilla cut: 12995.0
# --------------------------------------------------------------------------------
# G22 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=10119 | best=10119 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G22 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=10211 | best=10353 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.23s
# G22 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=7806 | best=10353 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.82s
# G22 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=13279 | best=13279 | |rx|=0.2607 | |rz|=0.5423 | elapsed=6.73s
# G22 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=13307 | best=13307 | |rx|=0.2450 | |rz|=0.8396 | elapsed=9.65s
# G22 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=13312 | best=13312 | |rx|=0.2146 | |rz|=0.9042 | elapsed=12.56s
# G22 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=13312 | best=13312 | |rx|=0.1795 | |rz|=0.9330 | elapsed=15.46s
# G22 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=13312 | best=13312 | |rx|=0.1417 | |rz|=0.9509 | elapsed=18.37s
# G22 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=13312 | best=13312 | |rx|=0.1013 | |rz|=0.9632 | elapsed=21.28s
# G22 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=13312 | best=13312 | |rx|=0.0586 | |rz|=0.9714 | elapsed=24.19s
# G22 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=13312 | best=13312 | |rx|=0.0108 | |rz|=0.9825 | elapsed=27.09s
#
# Finished: G22
# Best cut: 13312.0
# Best-known: 13359
# Gap: 47.0
# Accuracy %: 99.64817725877685
# Vanilla cut: 12995.0
# Delta cut vs vanilla: 317.0
# Runtime sec: 27.094208002090454
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 30/54 instances
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 20      G21     915.0         931   16.0         98.281418        863.0
# 21      G22   13312.0       13359   47.0         99.648177      12995.0
# 22      G35    7612.0        7687   75.0         99.024327       7523.0
# 23      G36    7599.0        7680   81.0         98.945312       7515.0
# 24      G37    7619.0        7691   72.0         99.063841       7520.0
# 25      G38    7616.0        7688   72.0         99.063476       7514.0
# 26      G39    2336.0        2408   72.0         97.009967       2188.0
# 27      G40    2296.0        2400  104.0         95.666667       2183.0
# 28      G41    2289.0        2405  116.0         95.176715       2193.0
# 29      G42    2381.0        2481  100.0         95.969367       2273.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 20                  52.0                   5.585392    20.777417
# 21                 317.0                   2.372932    27.094208
# 22                  89.0                   1.157799    29.154830
# 23                  84.0                   1.093750    28.860679
# 24                  99.0                   1.287219    27.966833
# 25                 102.0                   1.326743    29.442648
# 26                 148.0                   6.146179    29.048542
# 27                 113.0                   4.708333    28.897351
# 28                  96.0                   3.991684    27.832200
# 29                 108.0                   4.353083    28.917619
# ################################################################################
# Full G1-G54 missing run 13/36: G23
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G23
# ================================================================================
# gamma_mode: anneal
# N: 2000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 13344
# vanilla cut: 13020.0
# --------------------------------------------------------------------------------
# G23 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=10093 | best=10093 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G23 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=10130 | best=10376 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.17s
# G23 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=8279 | best=10376 | |rx|=0.1512 | |rz|=0.0001 | elapsed=2.34s
# G23 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=13269 | best=13269 | |rx|=0.2608 | |rz|=0.5422 | elapsed=4.51s
# G23 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=13303 | best=13303 | |rx|=0.2451 | |rz|=0.8395 | elapsed=7.43s
# G23 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=13303 | best=13303 | |rx|=0.2146 | |rz|=0.9040 | elapsed=10.33s
# G23 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=13303 | best=13303 | |rx|=0.1795 | |rz|=0.9329 | elapsed=13.25s
# G23 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=13303 | best=13303 | |rx|=0.1418 | |rz|=0.9507 | elapsed=16.15s
# G23 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=13303 | best=13303 | |rx|=0.1016 | |rz|=0.9629 | elapsed=19.06s
# G23 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=13303 | best=13303 | |rx|=0.0590 | |rz|=0.9710 | elapsed=21.96s
# ...
# 41                 108.0                   4.353083    28.917619
# 42                 138.0                   2.072072    20.944125
# 43                 143.0                   2.150376    21.206207
# 44                 130.0                   1.953712    21.195994
# 45                 135.0                   2.030381    20.958253
# 46                 116.0                   1.742527    21.260555
# 47                 532.0                   8.866667    28.476684
# 48                 486.0                   8.100000    26.812453
# 49                 358.0                   6.088435    23.106228
# ################################################################################
# Full G1-G54 missing run 33/36: G51
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G51
# ================================================================================
# gamma_mode: anneal
# N: 1000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 3848
# vanilla cut: 3779.0
# --------------------------------------------------------------------------------
# G51 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=3032 | best=3032 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G51 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=3018 | best=3147 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.98s
# G51 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=1886 | best=3147 | |rx|=0.1512 | |rz|=0.0001 | elapsed=4.11s
# G51 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=3785 | best=3785 | |rx|=0.4211 | |rz|=0.3526 | elapsed=6.25s
# G51 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=3815 | best=3815 | |rx|=0.4413 | |rz|=0.6915 | elapsed=8.23s
# G51 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=3819 | best=3819 | |rx|=0.3998 | |rz|=0.7934 | elapsed=10.35s
# G51 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=3819 | best=3819 | |rx|=0.3443 | |rz|=0.8463 | elapsed=12.52s
# G51 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=3819 | best=3819 | |rx|=0.2817 | |rz|=0.8817 | elapsed=14.72s
# G51 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=3819 | best=3819 | |rx|=0.2129 | |rz|=0.9067 | elapsed=16.90s
# G51 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=3819 | best=3819 | |rx|=0.1381 | |rz|=0.9230 | elapsed=19.03s
# G51 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=3819 | best=3819 | |rx|=0.0440 | |rz|=0.9591 | elapsed=21.23s
#
# Finished: G51
# Best cut: 3819.0
# Best-known: 3848
# Gap: 29.0
# Accuracy %: 99.24636174636174
# Vanilla cut: 3779.0
# Delta cut vs vanilla: 40.0
# Runtime sec: 21.2271671295166
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 51/54 instances
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 41      G42    2381.0        2481  100.0         95.969367       2273.0
# 42      G43    6652.0        6660    8.0         99.879880       6514.0
# 43      G44    6638.0        6650   12.0         99.819549       6495.0
# 44      G45    6633.0        6654   21.0         99.684400       6503.0
# 45      G46    6627.0        6649   22.0         99.669123       6492.0
# 46      G47    6638.0        6657   19.0         99.714586       6522.0
# 47      G48    6000.0        6000    0.0        100.000000       5468.0
# 48      G49    6000.0        6000    0.0        100.000000       5514.0
# 49      G50    5852.0        5880   28.0         99.523810       5494.0
# 50      G51    3819.0        3848   29.0         99.246362       3779.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 41                 108.0                   4.353083    28.917619
# 42                 138.0                   2.072072    20.944125
# 43                 143.0                   2.150376    21.206207
# 44                 130.0                   1.953712    21.195994
# 45                 135.0                   2.030381    20.958253
# 46                 116.0                   1.742527    21.260555
# 47                 532.0                   8.866667    28.476684
# 48                 486.0                   8.100000    26.812453
# 49                 358.0                   6.088435    23.106228
# 50                  40.0                   1.039501    21.227167
# ################################################################################
# Full G1-G54 missing run 34/36: G52
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G52
# ================================================================================
# gamma_mode: anneal
# N: 1000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 3851
# vanilla cut: 3779.0
# --------------------------------------------------------------------------------
# G52 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=3056 | best=3056 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.01s
# G52 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=3026 | best=3134 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.65s
# G52 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=2064 | best=3134 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.85s
# G52 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=3787 | best=3787 | |rx|=0.4211 | |rz|=0.3516 | elapsed=6.06s
# G52 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=3821 | best=3821 | |rx|=0.4440 | |rz|=0.6879 | elapsed=8.29s
# G52 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=3823 | best=3823 | |rx|=0.4031 | |rz|=0.7899 | elapsed=10.53s
# G52 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=3825 | best=3825 | |rx|=0.3476 | |rz|=0.8429 | elapsed=12.72s
# G52 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=3825 | best=3825 | |rx|=0.2853 | |rz|=0.8784 | elapsed=14.91s
# G52 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=3825 | best=3825 | |rx|=0.2166 | |rz|=0.9037 | elapsed=16.95s
# G52 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=3825 | best=3825 | |rx|=0.1417 | |rz|=0.9197 | elapsed=19.09s
# G52 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=3825 | best=3825 | |rx|=0.0469 | |rz|=0.9563 | elapsed=21.27s
#
# Finished: G52
# Best cut: 3825.0
# Best-known: 3851
# Gap: 26.0
# Accuracy %: 99.32485068813295
# Vanilla cut: 3779.0
# Delta cut vs vanilla: 46.0
# Runtime sec: 21.26980495452881
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 52/54 instances
#    instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 42      G43    6652.0        6660   8.0         99.879880       6514.0
# 43      G44    6638.0        6650  12.0         99.819549       6495.0
# 44      G45    6633.0        6654  21.0         99.684400       6503.0
# 45      G46    6627.0        6649  22.0         99.669123       6492.0
# 46      G47    6638.0        6657  19.0         99.714586       6522.0
# 47      G48    6000.0        6000   0.0        100.000000       5468.0
# 48      G49    6000.0        6000   0.0        100.000000       5514.0
# 49      G50    5852.0        5880  28.0         99.523810       5494.0
# 50      G51    3819.0        3848  29.0         99.246362       3779.0
# 51      G52    3825.0        3851  26.0         99.324851       3779.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 42                 138.0                   2.072072    20.944125
# 43                 143.0                   2.150376    21.206207
# 44                 130.0                   1.953712    21.195994
# 45                 135.0                   2.030381    20.958253
# 46                 116.0                   1.742527    21.260555
# 47                 532.0                   8.866667    28.476684
# 48                 486.0                   8.100000    26.812453
# 49                 358.0                   6.088435    23.106228
# 50                  40.0                   1.039501    21.227167
# 51                  46.0                   1.194495    21.269805
# ################################################################################
# Full G1-G54 missing run 35/36: G53
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G53
# ================================================================================
# gamma_mode: anneal
# N: 1000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 3850
# vanilla cut: 3778.0
# --------------------------------------------------------------------------------
# G53 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=3038 | best=3038 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G53 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=3019 | best=3165 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.69s
# G53 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=2032 | best=3165 | |rx|=0.1512 | |rz|=0.0001 | elapsed=4.99s
# G53 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=3789 | best=3789 | |rx|=0.4195 | |rz|=0.3542 | elapsed=7.18s
# G53 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=3820 | best=3820 | |rx|=0.4395 | |rz|=0.6932 | elapsed=9.38s
# G53 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=3828 | best=3828 | |rx|=0.3984 | |rz|=0.7942 | elapsed=11.57s
# G53 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=3828 | best=3828 | |rx|=0.3434 | |rz|=0.8462 | elapsed=13.74s
# G53 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=3828 | best=3828 | |rx|=0.2814 | |rz|=0.8812 | elapsed=15.93s
# G53 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=3828 | best=3828 | |rx|=0.2134 | |rz|=0.9059 | elapsed=18.12s
# G53 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=3828 | best=3828 | |rx|=0.1392 | |rz|=0.9219 | elapsed=20.29s
# G53 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=3828 | best=3828 | |rx|=0.0446 | |rz|=0.9590 | elapsed=22.46s
#
# Finished: G53
# Best cut: 3828.0
# Best-known: 3850
# Gap: 22.0
# Accuracy %: 99.42857142857143
# Vanilla cut: 3778.0
# Delta cut vs vanilla: 50.0
# Runtime sec: 22.460280656814575
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 53/54 instances
#    instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 43      G44    6638.0        6650  12.0         99.819549       6495.0
# 44      G45    6633.0        6654  21.0         99.684400       6503.0
# 45      G46    6627.0        6649  22.0         99.669123       6492.0
# 46      G47    6638.0        6657  19.0         99.714586       6522.0
# 47      G48    6000.0        6000   0.0        100.000000       5468.0
# 48      G49    6000.0        6000   0.0        100.000000       5514.0
# 49      G50    5852.0        5880  28.0         99.523810       5494.0
# 50      G51    3819.0        3848  29.0         99.246362       3779.0
# 51      G52    3825.0        3851  26.0         99.324851       3779.0
# 52      G53    3828.0        3850  22.0         99.428571       3778.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 43                 143.0                   2.150376    21.206207
# 44                 130.0                   1.953712    21.195994
# 45                 135.0                   2.030381    20.958253
# 46                 116.0                   1.742527    21.260555
# 47                 532.0                   8.866667    28.476684
# 48                 486.0                   8.100000    26.812453
# 49                 358.0                   6.088435    23.106228
# 50                  40.0                   1.039501    21.227167
# 51                  46.0                   1.194495    21.269805
# 52                  50.0                   1.298701    22.460281
# ################################################################################
# Full G1-G54 missing run 36/36: G54
# ################################################################################
# ================================================================================
# Running QEFEM single instance: G54
# ================================================================================
# gamma_mode: anneal
# N: 1000
# replicas: 128
# n_steps: 1000
# lr: 0.01
# beta: 2.0 -> 12500.0
# gamma: 1.0 -> 0.0
# best-known: 3852
# vanilla cut: 3778.0
# --------------------------------------------------------------------------------
# G54 | step    1/1000 | beta=2.00 | gamma=1.0000 | hard_max=3043 | best=3043 | |rx|=0.0101 | |rz|=0.0001 | elapsed=0.02s
# G54 | step  100/1000 | beta=1240.54 | gamma=0.9009 | hard_max=3013 | best=3133 | |rx|=0.0312 | |rz|=0.0000 | elapsed=1.64s
# G54 | step  200/1000 | beta=2491.59 | gamma=0.8008 | hard_max=2082 | best=3133 | |rx|=0.1512 | |rz|=0.0001 | elapsed=3.86s
# G54 | step  300/1000 | beta=3742.64 | gamma=0.7007 | hard_max=3780 | best=3780 | |rx|=0.4216 | |rz|=0.3509 | elapsed=6.09s
# G54 | step  400/1000 | beta=4993.69 | gamma=0.6006 | hard_max=3816 | best=3816 | |rx|=0.4423 | |rz|=0.6904 | elapsed=8.29s
# G54 | step  500/1000 | beta=6244.74 | gamma=0.5005 | hard_max=3820 | best=3820 | |rx|=0.4010 | |rz|=0.7920 | elapsed=10.49s
# G54 | step  600/1000 | beta=7495.80 | gamma=0.4004 | hard_max=3820 | best=3820 | |rx|=0.3457 | |rz|=0.8448 | elapsed=12.67s
# G54 | step  700/1000 | beta=8746.85 | gamma=0.3003 | hard_max=3820 | best=3820 | |rx|=0.2835 | |rz|=0.8802 | elapsed=14.85s
# G54 | step  800/1000 | beta=9997.90 | gamma=0.2002 | hard_max=3820 | best=3820 | |rx|=0.2150 | |rz|=0.9051 | elapsed=17.05s
# G54 | step  900/1000 | beta=11248.95 | gamma=0.1001 | hard_max=3820 | best=3820 | |rx|=0.1405 | |rz|=0.9210 | elapsed=19.25s
# G54 | step 1000/1000 | beta=12500.00 | gamma=0.0000 | hard_max=3820 | best=3820 | |rx|=0.0447 | |rz|=0.9593 | elapsed=21.43s
#
# Finished: G54
# Best cut: 3820.0
# Best-known: 3852
# Gap: 32.0
# Accuracy %: 99.16926272066459
# Vanilla cut: 3778.0
# Delta cut vs vanilla: 42.0
# Runtime sec: 21.43343496322632
# --------------------------------------------------------------------------------
#
# Current full benchmark progress:
# Completed 54/54 instances
#    instance  best_cut  best_value   gap  percent_accuracy  vanilla_cut  \
# 44      G45    6633.0        6654  21.0         99.684400       6503.0
# 45      G46    6627.0        6649  22.0         99.669123       6492.0
# 46      G47    6638.0        6657  19.0         99.714586       6522.0
# 47      G48    6000.0        6000   0.0        100.000000       5468.0
# 48      G49    6000.0        6000   0.0        100.000000       5514.0
# 49      G50    5852.0        5880  28.0         99.523810       5494.0
# 50      G51    3819.0        3848  29.0         99.246362       3779.0
# 51      G52    3825.0        3851  26.0         99.324851       3779.0
# 52      G53    3828.0        3850  22.0         99.428571       3778.0
# 53      G54    3820.0        3852  32.0         99.169263       3778.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 44                 130.0                   1.953712    21.195994
# 45                 135.0                   2.030381    20.958253
# 46                 116.0                   1.742527    21.260555
# 47                 532.0                   8.866667    28.476684
# 48                 486.0                   8.100000    26.812453
# 49                 358.0                   6.088435    23.106228
# 50                  40.0                   1.039501    21.227167
# 51                  46.0                   1.194495    21.269805
# 52                  50.0                   1.298701    22.460281
# 53                  42.0                   1.090343    21.433435

# %%
# ----------------------------
# Final full result file
# ----------------------------
qefem_full_results_df = (
    qefem_full_results_df
    .drop_duplicates(subset=["instance"], keep="first")
    .assign(g_index=lambda df: df["instance"].str.replace("G", "", regex=False).astype(int))
    .sort_values("g_index")
    .drop(columns=["g_index"])
    .reset_index(drop=True)
)

final_full_path = OUTPUT_DIR / "qefem_anneal_G1_G54_final_results.csv"
qefem_full_results_df.to_csv(final_full_path, index=False)

print("\n" + "=" * 80)
print("Full G1-G54 QEFEM gamma anneal benchmark complete")
print("=" * 80)

display(qefem_full_results_df[
    [
        "instance",
        "best_cut",
        "best_value",
        "gap",
        "percent_accuracy",
        "vanilla_cut",
        "delta_cut_vs_vanilla",
        "delta_accuracy_vs_vanilla",
        "runtime_sec",
    ]
])

print("\nSaved final full G1-G54 results to:")
print(final_full_path.resolve())
# Out:
# ================================================================================
# Full G1-G54 QEFEM gamma anneal benchmark complete
# ================================================================================
#    instance  best_cut  best_value    gap  percent_accuracy  vanilla_cut  \
# 0        G1   11611.0       11624   13.0         99.888162      11446.0
# 1        G2   11610.0       11620   10.0         99.913941      11435.0
# 2        G3   11610.0       11622   12.0         99.896748      11443.0
# 3        G4   11637.0       11646    9.0         99.922720      11503.0
# 4        G5   11622.0       11631    9.0         99.922621      11450.0
# 5        G6    2173.0        2178    5.0         99.770432       1978.0
# 6        G7    1992.0        2006   14.0         99.302094       1822.0
# 7        G8    1991.0        2005   14.0         99.301746       1856.0
# 8        G9    2041.0        2054   13.0         99.367089       1840.0
# 9       G10    1992.0        2000    8.0         99.600000       1819.0
# 10      G11     556.0         564    8.0         98.581560        526.0
# 11      G12     550.0         556    6.0         98.920863        520.0
# 12      G13     580.0         582    2.0         99.656357        542.0
# 13      G14    3040.0        3064   24.0         99.216710       3022.0
# 14      G15    3025.0        3050   25.0         99.180328       2998.0
# 15      G16    3027.0        3052   25.0         99.180865       2995.0
# 16      G17    3021.0        3047   26.0         99.146702       2995.0
# 17      G18     978.0         992   14.0         98.588710        928.0
# 18      G19     876.0         906   30.0         96.688742        838.0
# 19      G20     930.0         941   11.0         98.831031        876.0
# 20      G21     915.0         931   16.0         98.281418        863.0
# 21      G22   13312.0       13359   47.0         99.648177      12995.0
# 22      G23   13303.0       13344   41.0         99.692746      13020.0
# 23      G24   13290.0       13337   47.0         99.647597      12987.0
# 24      G25   13284.0       13340   56.0         99.580210      12977.0
# 25      G26   13270.0       13328   58.0         99.564826      12987.0
# 26      G27    3310.0        3341   31.0         99.072134       2989.0
# 27      G28    3275.0        3298   23.0         99.302608       2956.0
# 28      G29    3351.0        3405   54.0         98.414097       3042.0
# 29      G30    3367.0        3413   46.0         98.652212       3045.0
# 30      G31    3282.0        3310   28.0         99.154079       2969.0
# 31      G32    1388.0        1410   22.0         98.439716       1300.0
# 32      G33    1364.0        1382   18.0         98.697540       1266.0
# 33      G34    1362.0        1384   22.0         98.410405       1272.0
# 34      G35    7612.0        7687   75.0         99.024327       7523.0
# 35      G36    7599.0        7680   81.0         98.945312       7515.0
# 36      G37    7619.0        7691   72.0         99.063841       7520.0
# 37      G38    7616.0        7688   72.0         99.063476       7514.0
# 38      G39    2336.0        2408   72.0         97.009967       2188.0
# 39      G40    2296.0        2400  104.0         95.666667       2183.0
# 40      G41    2289.0        2405  116.0         95.176715       2193.0
# 41      G42    2381.0        2481  100.0         95.969367       2273.0
# 42      G43    6652.0        6660    8.0         99.879880       6514.0
# 43      G44    6638.0        6650   12.0         99.819549       6495.0
# 44      G45    6633.0        6654   21.0         99.684400       6503.0
# 45      G46    6627.0        6649   22.0         99.669123       6492.0
# 46      G47    6638.0        6657   19.0         99.714586       6522.0
# 47      G48    6000.0        6000    0.0        100.000000       5468.0
# 48      G49    6000.0        6000    0.0        100.000000       5514.0
# 49      G50    5852.0        5880   28.0         99.523810       5494.0
# 50      G51    3819.0        3848   29.0         99.246362       3779.0
# 51      G52    3825.0        3851   26.0         99.324851       3779.0
# 52      G53    3828.0        3850   22.0         99.428571       3778.0
# 53      G54    3820.0        3852   32.0         99.169263       3778.0
#
#     delta_cut_vs_vanilla  delta_accuracy_vs_vanilla  runtime_sec
# 0                  165.0                   1.419477    20.340349
# 1                  175.0                   1.506024    20.147006
# 2                  167.0                   1.436930    19.713759
# 3                  134.0                   1.150610    20.273321
# 4                  172.0                   1.478807    19.919531
# 5                  195.0                   8.953168    20.543701
# 6                  170.0                   8.474576    19.921516
# 7                  135.0                   6.733167    20.028873
# 8                  201.0                   9.785784    19.823088
# 9                  173.0                   8.650000    19.065519
# 10                  30.0                   5.319149    20.264497
# 11                  30.0                   5.395683    20.754636
# 12                  38.0                   6.529210    20.256631
# 13                  18.0                   0.587467    20.271546
# 14                  27.0                   0.885246    20.780205
# 15                  32.0                   1.048493    20.059740
# 16                  26.0                   0.853298    20.201241
# 17                  50.0                   5.040323    20.259756
# 18                  38.0                   4.194260    20.099334
# 19                  54.0                   5.738576    20.358792
# 20                  52.0                   5.585392    20.777417
# 21                 317.0                   2.372932    27.094208
# 22                 283.0                   2.120803    24.873445
# 23                 303.0                   2.271875    14.204175
# 24                 307.0                   2.301349    27.558263
# 25                 283.0                   2.123349    27.294161
# 26                 321.0                   9.607902    28.124908
# 27                 319.0                   9.672529    25.579539
# 28                 309.0                   9.074890    23.624019
# 29                 322.0                   9.434515    24.982272
# 30                 313.0                   9.456193    29.081724
# 31                  88.0                   6.241135    28.732226
# 32                  98.0                   7.091172    29.128526
# 33                  90.0                   6.502890    28.947894
# 34                  89.0                   1.157799    29.154830
# 35                  84.0                   1.093750    28.860679
# 36                  99.0                   1.287219    27.966833
# 37                 102.0                   1.326743    29.442648
# 38                 148.0                   6.146179    29.048542
# 39                 113.0                   4.708333    28.897351
# 40                  96.0                   3.991684    27.832200
# 41                 108.0                   4.353083    28.917619
# 42                 138.0                   2.072072    20.944125
# 43                 143.0                   2.150376    21.206207
# 44                 130.0                   1.953712    21.195994
# 45                 135.0                   2.030381    20.958253
# 46                 116.0                   1.742527    21.260555
# 47                 532.0                   8.866667    28.476684
# 48                 486.0                   8.100000    26.812453
# 49                 358.0                   6.088435    23.106228
# 50                  40.0                   1.039501    21.227167
# 51                  46.0                   1.194495    21.269805
# 52                  50.0                   1.298701    22.460281
# 53                  42.0                   1.090343    21.433435
# Saved final full G1-G54 results to:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_v1_outputs/qefem_anneal_G1_G54_final_results.csv

# %%
# ----------------------------
# Basic full-run aggregate summary
# ----------------------------
num_full = len(qefem_full_results_df)

full_wins = int((qefem_full_results_df["delta_cut_vs_vanilla"] > 0).sum())
full_ties = int((qefem_full_results_df["delta_cut_vs_vanilla"] == 0).sum())
full_losses = int((qefem_full_results_df["delta_cut_vs_vanilla"] < 0).sum())

full_mean_delta_cut = float(qefem_full_results_df["delta_cut_vs_vanilla"].mean())
full_mean_delta_accuracy = float(qefem_full_results_df["delta_accuracy_vs_vanilla"].mean())
full_mean_accuracy = float(qefem_full_results_df["percent_accuracy"].mean())
full_mean_gap = float(qefem_full_results_df["gap"].mean())
full_mean_runtime = float(qefem_full_results_df["runtime_sec"].mean())

print("\nFull G1-G54 aggregate summary:")
print("Completed instances:", num_full)
print("Wins vs vanilla:", full_wins)
print("Ties vs vanilla:", full_ties)
print("Losses vs vanilla:", full_losses)
print("Mean delta cut vs vanilla:", full_mean_delta_cut)
print("Mean delta accuracy vs vanilla:", full_mean_delta_accuracy)
print("Mean QEFEM accuracy %:", full_mean_accuracy)
print("Mean QEFEM gap:", full_mean_gap)
print("Mean runtime sec:", full_mean_runtime)

assert num_full == len(FULL_BENCHMARK_INSTANCES), (
    "Full benchmark is incomplete. Some instance escaped the net."
)
# Out:
# Full G1-G54 aggregate summary:
# Completed instances: 54
# Wins vs vanilla: 54
# Ties vs vanilla: 0
# Losses vs vanilla: 0
# Mean delta cut vs vanilla: 157.22222222222223
# Mean delta accuracy vs vanilla: 4.272762509982232
# Mean QEFEM accuracy %: 99.01509721290039
# Mean QEFEM gap: 31.444444444444443
# Mean runtime sec: 23.39921678878643

# %% [markdown]
# # Exploring uncharted territory : BEYOND G54 ---> Massive graphs
#
# entering 4 digit node#

# %%
# ============================================================
# Cell 25: Define big-Gset partitions and target list
# ============================================================

from pathlib import Path
import pandas as pd

GSET_DIR = Path("../data-gset")

BIG_GSET_PARTITIONS = {
    10: ["G55", "G56"],
    11: ["G57"],
    12: ["G58", "G59"],
    13: ["G60", "G61"],
    14: ["G62"],
    15: ["G63", "G64"],
    16: ["G65"],
    17: ["G66"],
    18: ["G67", "G72"],
    19: ["G70"],
    20: ["G77"],
    21: ["G81"],
}

BIG_GSET_TARGETS = []

for partition_id, graphs in BIG_GSET_PARTITIONS.items():
    for graph in graphs:
        BIG_GSET_TARGETS.append(
            {
                "partition": partition_id,
                "graph": graph,
                "path": GSET_DIR / graph,
                "exists": (GSET_DIR / graph).exists(),
            }
        )

big_gset_targets_df = pd.DataFrame(BIG_GSET_TARGETS)

print("=" * 80)
print("BIG GSET PARTITIONS")
print("=" * 80)

for partition_id, graphs in BIG_GSET_PARTITIONS.items():
    print(
        f"Batch {partition_id}: "
        f"{graphs[0]}-{graphs[-1]} | "
        f"{len(graphs)} instances | "
        f"{graphs}"
    )

print("\nGraphs to run:")
print(big_gset_targets_df["graph"].tolist())

print("\nTarget dataframe:")
display(big_gset_targets_df)

missing_graphs = big_gset_targets_df[
    big_gset_targets_df["exists"] == False
]["graph"].tolist()

print("\nFile check:")
if len(missing_graphs) == 0:
    print("All selected graph files exist.")
else:
    print("Missing graph files:")
    print(missing_graphs)

assert len(missing_graphs) == 0, (
    f"Some graph files are missing: {missing_graphs}"
)
# Out:
# ================================================================================
# BIG GSET PARTITIONS
# ================================================================================
# Batch 10: G55-G56 | 2 instances | ['G55', 'G56']
# Batch 11: G57-G57 | 1 instances | ['G57']
# Batch 12: G58-G59 | 2 instances | ['G58', 'G59']
# Batch 13: G60-G61 | 2 instances | ['G60', 'G61']
# Batch 14: G62-G62 | 1 instances | ['G62']
# Batch 15: G63-G64 | 2 instances | ['G63', 'G64']
# Batch 16: G65-G65 | 1 instances | ['G65']
# Batch 17: G66-G66 | 1 instances | ['G66']
# Batch 18: G67-G72 | 2 instances | ['G67', 'G72']
# Batch 19: G70-G70 | 1 instances | ['G70']
# Batch 20: G77-G77 | 1 instances | ['G77']
# Batch 21: G81-G81 | 1 instances | ['G81']
#
# Graphs to run:
# ['G55', 'G56', 'G57', 'G58', 'G59', 'G60', 'G61', 'G62', 'G63', 'G64', 'G65', 'G66', 'G67', 'G72', 'G70', 'G77', 'G81']
#
# Target dataframe:
#     partition graph              path  exists
# 0          10   G55  ../data-gset/G55    True
# 1          10   G56  ../data-gset/G56    True
# 2          11   G57  ../data-gset/G57    True
# 3          12   G58  ../data-gset/G58    True
# 4          12   G59  ../data-gset/G59    True
# 5          13   G60  ../data-gset/G60    True
# 6          13   G61  ../data-gset/G61    True
# 7          14   G62  ../data-gset/G62    True
# 8          15   G63  ../data-gset/G63    True
# 9          15   G64  ../data-gset/G64    True
# 10         16   G65  ../data-gset/G65    True
# 11         17   G66  ../data-gset/G66    True
# 12         18   G67  ../data-gset/G67    True
# 13         18   G72  ../data-gset/G72    True
# 14         19   G70  ../data-gset/G70    True
# 15         20   G77  ../data-gset/G77    True
# 16         21   G81  ../data-gset/G81    True
# File check:
# All selected graph files exist.

# %%
# ============================================================
# Cell 26: Define Gset edge-list loader
# ============================================================

assert "GSET_DIR" in globals(), "Run Cell 25 first: GSET_DIR is missing."
assert "BIG_GSET_TARGETS" in globals(), "Run Cell 25 first: BIG_GSET_TARGETS is missing."
assert "device" in globals(), "device is missing."
assert "DTYPE" in globals(), "DTYPE is missing."


def load_gset_edge_list(graph, gset_dir=GSET_DIR, device=device, dtype=DTYPE):
    path = gset_dir / graph

    if not path.exists():
        raise FileNotFoundError(
            f"Could not find {graph} at:\n{path.resolve()}"
        )

    edge_i_list = []
    edge_j_list = []
    edge_w_list = []

    with path.open("r") as f:
        header = f.readline().strip().split()

        if len(header) != 2:
            raise ValueError(
                f"{graph}: bad header {header}. Expected: N M"
            )

        N_g = int(header[0])
        M_g = int(header[1])

        for line_no, line in enumerate(f, start=2):
            line = line.strip()

            if not line:
                continue

            parts = line.split()

            if len(parts) != 3:
                raise ValueError(
                    f"{graph}: bad edge line {line_no}: {line!r}"
                )

            i, j, w = map(int, parts)

            i -= 1
            j -= 1

            if not (0 <= i < N_g):
                raise IndexError(
                    f"{graph}: line {line_no}, i out of range after 0-indexing: {i}"
                )

            if not (0 <= j < N_g):
                raise IndexError(
                    f"{graph}: line {line_no}, j out of range after 0-indexing: {j}"
                )

            edge_i_list.append(i)
            edge_j_list.append(j)
            edge_w_list.append(float(w))

    if len(edge_i_list) != M_g:
        raise ValueError(
            f"{graph}: header says M={M_g}, but loaded {len(edge_i_list)} edges."
        )

    edge_i = torch.tensor(
        edge_i_list,
        device=device,
        dtype=torch.long,
    )

    edge_j = torch.tensor(
        edge_j_list,
        device=device,
        dtype=torch.long,
    )

    edge_w = torch.tensor(
        edge_w_list,
        device=device,
        dtype=dtype,
    )

    info = {
        "graph": graph,
        "N": N_g,
        "M": M_g,
        "density_upper_percent": 100.0 * M_g / (N_g * (N_g - 1) / 2.0),
        "positive_edges": int((edge_w > 0).sum().detach().cpu()),
        "negative_edges": int((edge_w < 0).sum().detach().cpu()),
        "zero_edges": int((edge_w == 0).sum().detach().cpu()),
        "weight_sum": float(edge_w.sum().detach().cpu()),
        "dense_W_float32_MB": (N_g * N_g * 4) / (1024**2),
    }

    return N_g, edge_i, edge_j, edge_w, info

# %%
assert "BIG_GSET_TARGETS" in globals(), "Run Cell 25 first: BIG_GSET_TARGETS is missing."
assert "load_gset_edge_list" in globals(), "Run Cell 26 first: load_gset_edge_list is missing."

big_gset_meta_rows = []

print("=" * 80)
print("SCANNING BIG GSET PARTITIONS AS EDGE LISTS")
print("=" * 80)

for target in BIG_GSET_TARGETS:
    partition_id = target["partition"]
    graph = target["graph"]

    N_g, edge_i, edge_j, edge_w, info = load_gset_edge_list(graph)

    row = {
        "partition": partition_id,
        "graph": graph,
        "N": info["N"],
        "M": info["M"],
        "density_upper_percent": info["density_upper_percent"],
        "positive_edges": info["positive_edges"],
        "negative_edges": info["negative_edges"],
        "zero_edges": info["zero_edges"],
        "weight_sum": info["weight_sum"],
        "dense_W_float32_MB": info["dense_W_float32_MB"],
        "edge_i_shape": tuple(edge_i.shape),
        "edge_j_shape": tuple(edge_j.shape),
        "edge_w_shape": tuple(edge_w.shape),
        "device": str(edge_w.device),
        "dtype": str(edge_w.dtype),
    }

    big_gset_meta_rows.append(row)

    print(
        f"Partition {partition_id:2d} | {graph:>3s} | "
        f"N={row['N']:6d} | "
        f"M={row['M']:7d} | "
        f"density={row['density_upper_percent']:.6f}% | "
        f"+={row['positive_edges']:7d} | "
        f"-={row['negative_edges']:7d} | "
        f"denseW={row['dense_W_float32_MB']:.2f} MB"
    )

big_gset_meta_df = pd.DataFrame(big_gset_meta_rows)

print("\nColumns:")
print(big_gset_meta_df.columns.tolist())

assert len(big_gset_meta_df) == len(BIG_GSET_TARGETS), (
    "Metadata row count does not match BIG_GSET_TARGETS."
)

assert (big_gset_meta_df["N"] > 0).all(), (
    "Some graph has non-positive N."
)

assert (big_gset_meta_df["M"] > 0).all(), (
    "Some graph has non-positive M."
)

assert (big_gset_meta_df["zero_edges"] == 0).all(), (
    "Some graph has zero-weight edges."
)
# Out:
# ================================================================================
# SCANNING BIG GSET PARTITIONS AS EDGE LISTS
# ================================================================================
# Partition 10 | G55 | N=  5000 | M=  12498 | density=0.100004% | +=  12498 | -=      0 | denseW=95.37 MB
# Partition 10 | G56 | N=  5000 | M=  12498 | density=0.100004% | +=   6222 | -=   6276 | denseW=95.37 MB
# Partition 11 | G57 | N=  5000 | M=  10000 | density=0.080016% | +=   4981 | -=   5019 | denseW=95.37 MB
# Partition 12 | G58 | N=  5000 | M=  29570 | density=0.236607% | +=  29570 | -=      0 | denseW=95.37 MB
# Partition 12 | G59 | N=  5000 | M=  29570 | density=0.236607% | +=  14833 | -=  14737 | denseW=95.37 MB
# Partition 13 | G60 | N=  7000 | M=  17148 | density=0.070002% | +=  17148 | -=      0 | denseW=186.92 MB
# Partition 13 | G61 | N=  7000 | M=  17148 | density=0.070002% | +=   8755 | -=   8393 | denseW=186.92 MB
# Partition 14 | G62 | N=  7000 | M=  14000 | density=0.057151% | +=   6960 | -=   7040 | denseW=186.92 MB
# Partition 15 | G63 | N=  7000 | M=  41459 | density=0.169245% | +=  41459 | -=      0 | denseW=186.92 MB
# Partition 15 | G64 | N=  7000 | M=  41459 | density=0.169245% | +=  20993 | -=  20466 | denseW=186.92 MB
# Partition 16 | G65 | N=  8000 | M=  16000 | density=0.050006% | +=   7959 | -=   8041 | denseW=244.14 MB
# Partition 17 | G66 | N=  9000 | M=  18000 | density=0.044449% | +=   9040 | -=   8960 | denseW=308.99 MB
# Partition 18 | G67 | N= 10000 | M=  20000 | density=0.040004% | +=   9929 | -=  10071 | denseW=381.47 MB
# Partition 18 | G72 | N= 10000 | M=  20000 | density=0.040004% | +=   9997 | -=  10003 | denseW=381.47 MB
# Partition 19 | G70 | N= 10000 | M=   9999 | density=0.020000% | +=   9999 | -=      0 | denseW=381.47 MB
# Partition 20 | G77 | N= 14000 | M=  28000 | density=0.028573% | +=  14104 | -=  13896 | denseW=747.68 MB
# Partition 21 | G81 | N= 20000 | M=  40000 | density=0.020001% | +=  20017 | -=  19983 | denseW=1525.88 MB
#
# Columns:
# ['partition', 'graph', 'N', 'M', 'density_upper_percent', 'positive_edges', 'negative_edges', 'zero_edges', 'weight_sum', 'dense_W_float32_MB', 'edge_i_shape', 'edge_j_shape', 'edge_w_shape', 'device', 'dtype']

# %% [markdown]
# ### Declaring functions

# %%
# ============================================================
# Cell 28: Load historical-best Gset validation values
# ============================================================

# This cell loads the historical-best MaxCut values from a txt file.
#
# Output dataframe:
#
#     gset_best_known_df
#
# Required columns:
#
#     graph
#     best_known_cut
#
# It does NOT run optimization.


# ------------------------------------------------------------
# Set validation file path
# ------------------------------------------------------------

GSET_BEST_KNOWN_PATH = Path("gset_validation.txt")

if not GSET_BEST_KNOWN_PATH.exists():
    GSET_BEST_KNOWN_PATH = Path("../gset_validation.txt")

if not GSET_BEST_KNOWN_PATH.exists():
    GSET_BEST_KNOWN_PATH = Path("../data-gset/gset_validation.txt")


print("=" * 80)
print("GSET HISTORICAL-BEST VALIDATION FILE")
print("=" * 80)

print("Validation path:")
print(GSET_BEST_KNOWN_PATH)

print("\nFile exists?")
print(GSET_BEST_KNOWN_PATH.exists())

assert GSET_BEST_KNOWN_PATH.exists(), (
    "Could not find gset_validation.txt. "
    "Put the file path manually in GSET_BEST_KNOWN_PATH."
)


# ------------------------------------------------------------
# Read txt file line by line
# ------------------------------------------------------------

best_known_rows = []

with GSET_BEST_KNOWN_PATH.open("r") as f:
    for line_no, line in enumerate(f, start=1):
        line = line.strip()

        if not line:
            continue

        if line.startswith("#"):
            continue

        parts = line.replace(",", " ").split()

        if len(parts) < 2:
            continue

        graph_raw = parts[0]
        cut_raw = parts[1]

        if graph_raw.lower() in ["graph", "instance", "name"]:
            continue

        if graph_raw.startswith("G"):
            graph = graph_raw
        else:
            graph = "G" + graph_raw

        best_known_cut = float(cut_raw)

        best_known_rows.append(
            {
                "graph": graph,
                "best_known_cut": best_known_cut,
            }
        )


gset_best_known_df = pd.DataFrame(best_known_rows)

print("\nLoaded validation rows:")
display(gset_best_known_df)

print("\nColumns:")
print(gset_best_known_df.columns.tolist())


# ------------------------------------------------------------
# Keep only graphs relevant to this big-Gset notebook
# ------------------------------------------------------------

assert "big_gset_targets_df" in globals(), (
    "Run Cell 25 first: big_gset_targets_df is missing."
)

big_gset_validation_df = big_gset_targets_df.merge(
    gset_best_known_df,
    on="graph",
    how="left",
)

print("\nBig-Gset validation subset:")
display(big_gset_validation_df)


# ------------------------------------------------------------
# Missing validation check
# ------------------------------------------------------------

missing_validation = big_gset_validation_df[
    big_gset_validation_df["best_known_cut"].isna()
]["graph"].tolist()

print("\nMissing validation graphs:")
print(missing_validation)

assert len(missing_validation) == 0, (
    f"Missing historical-best values for: {missing_validation}"
)
# Out:
# ================================================================================
# GSET HISTORICAL-BEST VALIDATION FILE
# ================================================================================
# Validation path:
# gset_validation.txt
#
# File exists?
# True
#
# Loaded validation rows:
#    graph  best_known_cut
# 0     G1         11624.0
# 1     G2         11620.0
# 2     G3         11622.0
# 3     G4         11646.0
# 4     G5         11631.0
# ..   ...             ...
# 66   G67          6950.0
# 67   G70          9591.0
# 68   G72          7008.0
# 69   G77          9940.0
# 70   G81         14060.0
#
# [71 rows x 2 columns]
# Columns:
# ['graph', 'best_known_cut']
#
# Big-Gset validation subset:
#     partition graph              path  exists  best_known_cut
# 0          10   G55  ../data-gset/G55    True         10299.0
# 1          10   G56  ../data-gset/G56    True          4017.0
# 2          11   G57  ../data-gset/G57    True          3494.0
# 3          12   G58  ../data-gset/G58    True         19293.0
# 4          12   G59  ../data-gset/G59    True          6086.0
# 5          13   G60  ../data-gset/G60    True         14188.0
# 6          13   G61  ../data-gset/G61    True          5796.0
# 7          14   G62  ../data-gset/G62    True          4870.0
# 8          15   G63  ../data-gset/G63    True         27047.0
# 9          15   G64  ../data-gset/G64    True          8751.0
# 10         16   G65  ../data-gset/G65    True          5562.0
# 11         17   G66  ../data-gset/G66    True          6364.0
# 12         18   G67  ../data-gset/G67    True          6950.0
# 13         18   G72  ../data-gset/G72    True          7008.0
# 14         19   G70  ../data-gset/G70    True          9591.0
# 15         20   G77  ../data-gset/G77    True          9940.0
# 16         21   G81  ../data-gset/G81    True         14060.0
# Missing validation graphs:
# []

# %%
# ============================================================
# Cell 29: Build big-Gset benchmark table with best-known cuts
# ============================================================

assert "big_gset_meta_df" in globals(), (
    "Run Cell 27 first: big_gset_meta_df is missing."
)

assert "gset_best_known_df" in globals(), (
    "Run Cell 28 first: gset_best_known_df is missing."
)


# ------------------------------------------------------------
# Merge graph metadata with historical-best MaxCut values
# ------------------------------------------------------------

big_gset_benchmark_df = big_gset_meta_df.merge(
    gset_best_known_df,
    on="graph",
    how="left",
)


# ------------------------------------------------------------
# Check missing validation values
# ------------------------------------------------------------

missing_best_known = big_gset_benchmark_df[
    big_gset_benchmark_df["best_known_cut"].isna()
]["graph"].tolist()

print("=" * 80)
print("BIG GSET BENCHMARK TABLE")
print("=" * 80)

print("Missing best-known values:")
print(missing_best_known)

assert len(missing_best_known) == 0, (
    f"Missing best-known cut values for: {missing_best_known}"
)


# ------------------------------------------------------------
# Add simple reference columns
# ------------------------------------------------------------

big_gset_benchmark_df["best_known_cut_per_edge"] = (
    big_gset_benchmark_df["best_known_cut"] / big_gset_benchmark_df["M"]
)

big_gset_benchmark_df["positive_edge_fraction"] = (
    big_gset_benchmark_df["positive_edges"] / big_gset_benchmark_df["M"]
)

big_gset_benchmark_df["negative_edge_fraction"] = (
    big_gset_benchmark_df["negative_edges"] / big_gset_benchmark_df["M"]
)


# ------------------------------------------------------------
# Reorder columns
# ------------------------------------------------------------

big_gset_benchmark_df = big_gset_benchmark_df[
    [
        "partition",
        "graph",
        "N",
        "M",
        "density_upper_percent",
        "positive_edges",
        "negative_edges",
        "positive_edge_fraction",
        "negative_edge_fraction",
        "weight_sum",
        "best_known_cut",
        "best_known_cut_per_edge",
        "dense_W_float32_MB",
        "device",
        "dtype",
    ]
]


# ------------------------------------------------------------
# Display final benchmark table
# ------------------------------------------------------------

display(big_gset_benchmark_df)

print("\nGraphs in benchmark table:")
print(big_gset_benchmark_df["graph"].tolist())

print("\nBest-known cut range:")
print("min:", float(big_gset_benchmark_df["best_known_cut"].min()))
print("max:", float(big_gset_benchmark_df["best_known_cut"].max()))
# Out:
# ================================================================================
# BIG GSET BENCHMARK TABLE
# ================================================================================
# Missing best-known values:
# []
#     partition graph      N      M  density_upper_percent  positive_edges  \
# 0          10   G55   5000  12498               0.100004           12498
# 1          10   G56   5000  12498               0.100004            6222
# 2          11   G57   5000  10000               0.080016            4981
# 3          12   G58   5000  29570               0.236607           29570
# 4          12   G59   5000  29570               0.236607           14833
# 5          13   G60   7000  17148               0.070002           17148
# 6          13   G61   7000  17148               0.070002            8755
# 7          14   G62   7000  14000               0.057151            6960
# 8          15   G63   7000  41459               0.169245           41459
# 9          15   G64   7000  41459               0.169245           20993
# 10         16   G65   8000  16000               0.050006            7959
# 11         17   G66   9000  18000               0.044449            9040
# 12         18   G67  10000  20000               0.040004            9929
# 13         18   G72  10000  20000               0.040004            9997
# 14         19   G70  10000   9999               0.020000            9999
# 15         20   G77  14000  28000               0.028573           14104
# 16         21   G81  20000  40000               0.020001           20017
#
#     negative_edges  positive_edge_fraction  negative_edge_fraction  \
# 0                0                1.000000                0.000000
# 1             6276                0.497840                0.502160
# 2             5019                0.498100                0.501900
# 3                0                1.000000                0.000000
# 4            14737                0.501623                0.498377
# 5                0                1.000000                0.000000
# 6             8393                0.510555                0.489445
# 7             7040                0.497143                0.502857
# 8                0                1.000000                0.000000
# 9            20466                0.506356                0.493644
# 10            8041                0.497437                0.502563
# 11            8960                0.502222                0.497778
# 12           10071                0.496450                0.503550
# 13           10003                0.499850                0.500150
# 14               0                1.000000                0.000000
# 15           13896                0.503714                0.496286
# 16           19983                0.500425                0.499575
#
#     weight_sum  best_known_cut  best_known_cut_per_edge  dense_W_float32_MB  \
# 0      12498.0         10299.0                 0.824052           95.367432
# 1        -54.0          4017.0                 0.321411           95.367432
# 2        -38.0          3494.0                 0.349400           95.367432
# 3      29570.0         19293.0                 0.652452           95.367432
# 4         96.0          6086.0                 0.205817           95.367432
# 5      17148.0         14188.0                 0.827385          186.920166
# 6        362.0          5796.0                 0.337999          186.920166
# 7        -80.0          4870.0                 0.347857          186.920166
# 8      41459.0         27047.0                 0.652379          186.920166
# 9        527.0          8751.0                 0.211076          186.920166
# 10       -82.0          5562.0                 0.347625          244.140625
# 11        80.0          6364.0                 0.353556          308.990479
# 12      -142.0          6950.0                 0.347500          381.469727
# 13        -6.0          7008.0                 0.350400          381.469727
# 14      9999.0          9591.0                 0.959196          381.469727
# 15       208.0          9940.0                 0.355000          747.680664
# 16        34.0         14060.0                 0.351500         1525.878906
#
#    device          dtype
# 0   mps:0  torch.float32
# 1   mps:0  torch.float32
# 2   mps:0  torch.float32
# 3   mps:0  torch.float32
# 4   mps:0  torch.float32
# 5   mps:0  torch.float32
# 6   mps:0  torch.float32
# 7   mps:0  torch.float32
# 8   mps:0  torch.float32
# 9   mps:0  torch.float32
# 10  mps:0  torch.float32
# 11  mps:0  torch.float32
# 12  mps:0  torch.float32
# 13  mps:0  torch.float32
# 14  mps:0  torch.float32
# 15  mps:0  torch.float32
# 16  mps:0  torch.float32
# Graphs in benchmark table:
# ['G55', 'G56', 'G57', 'G58', 'G59', 'G60', 'G61', 'G62', 'G63', 'G64', 'G65', 'G66', 'G67', 'G72', 'G70', 'G77', 'G81']
#
# Best-known cut range:
# min: 3494.0
# max: 27047.0

# %%
assert "bloch_from_raw" in globals(), (
    "bloch_from_raw is missing. Run the earlier QEFEM Bloch-parameter cell first."
)

assert "quantum_entropy_from_R" in globals(), (
    "quantum_entropy_from_R is missing. Run the earlier entropy cell first."
)

assert "transverse_driver_energy" in globals(), (
    "transverse_driver_energy is missing. Run the earlier driver-energy cell first."
)


def edge_discrete_cut(edge_i, edge_j, edge_w, spins):
    single_input = False

    if spins.dim() == 1:
        spins = spins.unsqueeze(0)
        single_input = True

    spins = spins.to(
        device=edge_w.device,
        dtype=edge_w.dtype,
    )

    si = spins[:, edge_i]
    sj = spins[:, edge_j]

    cut = 0.5 * (edge_w * (1.0 - si * sj)).sum(dim=1)

    if single_input:
        cut = cut.squeeze(0)

    return cut

# %%
def edge_expected_cut(edge_i, edge_j, edge_w, rz):
    rz = rz.to(
        device=edge_w.device,
        dtype=edge_w.dtype,
    )

    zi = rz[:, edge_i]
    zj = rz[:, edge_j]

    expected_cut = 0.5 * (edge_w * (1.0 - zi * zj)).sum(dim=1)

    return expected_cut

# %%
def edge_qefem_free_energy(edge_i, edge_j, edge_w, raw_R, theta, beta, gamma):
    beta = torch.as_tensor(
        beta,
        device=raw_R.device,
        dtype=raw_R.dtype,
    )

    gamma = torch.as_tensor(
        gamma,
        device=raw_R.device,
        dtype=raw_R.dtype,
    )

    R, rx, rz = bloch_from_raw(
        raw_R,
        theta,
    )

    expected_cut = edge_expected_cut(
        edge_i=edge_i,
        edge_j=edge_j,
        edge_w=edge_w,
        rz=rz,
    )

    entropy = quantum_entropy_from_R(R)

    driver_energy = transverse_driver_energy(
        rx,
        gamma,
    )

    F = -expected_cut + driver_energy - entropy / beta

    aux = {
        "R": R,
        "rx": rx,
        "rz": rz,
        "expected_cut": expected_cut,
        "entropy": entropy,
        "driver_energy": driver_energy,
        "free_energy": F,
        "beta": beta,
        "gamma": gamma,
    }

    return F, aux

# %% [markdown]
# ### Settings

# %%
import math

assert "device" in globals(), "device is missing."
assert "DTYPE" in globals(), "DTYPE is missing."


# ------------------------------------------------------------
# QEFEM run settings
# ------------------------------------------------------------

BIG_GSET_REPLICAS = 128
BIG_GSET_N_STEPS = 1000
BIG_GSET_LOG_EVERY = 50
BIG_GSET_SEED = 4
BIG_GSET_ADAM_LR = 0.01


# ------------------------------------------------------------
# Temperature / beta schedule
# ------------------------------------------------------------

BIG_GSET_TMAX = 1.16
BIG_GSET_TMIN = 6e-5

big_gset_T_schedule = torch.linspace(
    BIG_GSET_TMAX,
    BIG_GSET_TMIN,
    BIG_GSET_N_STEPS,
    device=device,
    dtype=DTYPE,
)

big_gset_beta_schedule = 1.0 / big_gset_T_schedule


# ------------------------------------------------------------
# Transverse-field gamma schedule
# ------------------------------------------------------------

BIG_GSET_GAMMA_MAX = 1.0
BIG_GSET_GAMMA_MIN = 0.0

big_gset_gamma_schedule = torch.linspace(
    BIG_GSET_GAMMA_MAX,
    BIG_GSET_GAMMA_MIN,
    BIG_GSET_N_STEPS,
    device=device,
    dtype=DTYPE,
)


# ------------------------------------------------------------
# Bloch initialization settings
# ------------------------------------------------------------

R_INIT = 1e-2
THETA_CENTER = math.pi / 2
THETA_NOISE = 1e-3


# ------------------------------------------------------------
# Print settings
# ------------------------------------------------------------

print("=" * 80)
print("BIG-GSET QEFEM SETTINGS")
print("=" * 80)

print("Replicas:", BIG_GSET_REPLICAS)
print("Steps:", BIG_GSET_N_STEPS)
print("Log every:", BIG_GSET_LOG_EVERY)
print("Seed:", BIG_GSET_SEED)
print("Optimizer: Adam")
print("Adam lr:", BIG_GSET_ADAM_LR)

print("\nTemperature schedule:")
print("T first :", float(big_gset_T_schedule[0].detach().cpu()))
print("T last  :", float(big_gset_T_schedule[-1].detach().cpu()))

print("\nBeta schedule:")
print("beta first :", float(big_gset_beta_schedule[0].detach().cpu()))
print("beta last  :", float(big_gset_beta_schedule[-1].detach().cpu()))

print("\nGamma schedule:")
print("gamma first :", float(big_gset_gamma_schedule[0].detach().cpu()))
print("gamma last  :", float(big_gset_gamma_schedule[-1].detach().cpu()))

print("\nInitialization:")
print("R_INIT:", R_INIT)
print("THETA_CENTER:", THETA_CENTER)
print("THETA_NOISE:", THETA_NOISE)


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert big_gset_T_schedule.shape == torch.Size([BIG_GSET_N_STEPS])
assert big_gset_beta_schedule.shape == torch.Size([BIG_GSET_N_STEPS])
assert big_gset_gamma_schedule.shape == torch.Size([BIG_GSET_N_STEPS])

assert torch.all(big_gset_T_schedule > 0)
assert torch.all(big_gset_beta_schedule > 0)

assert big_gset_T_schedule[0] > big_gset_T_schedule[-1], (
    "Temperature should decrease."
)

assert big_gset_beta_schedule[0] < big_gset_beta_schedule[-1], (
    "Beta should increase."
)

assert abs(float(big_gset_gamma_schedule[0].detach().cpu()) - BIG_GSET_GAMMA_MAX) < 1e-6
assert abs(float(big_gset_gamma_schedule[-1].detach().cpu()) - BIG_GSET_GAMMA_MIN) < 1e-6
# Out:
# ================================================================================
# BIG-GSET QEFEM SETTINGS
# ================================================================================
# Replicas: 128
# Steps: 1000
# Log every: 50
# Seed: 4
# Optimizer: Adam
# Adam lr: 0.01
#
# Temperature schedule:
# T first : 1.159999966621399
# T last  : 5.999999848427251e-05
#
# Beta schedule:
# beta first : 0.8620690107345581
# beta last  : 16666.66796875
#
# Gamma schedule:
# gamma first : 1.0
# gamma last  : 0.0
#
# Initialization:
# R_INIT: 0.01
# THETA_CENTER: 1.5707963267948966
# THETA_NOISE: 0.001

# %% [markdown]
# ### Select one instance and test

# %%
assert "BIG_GSET_PARTITIONS" in globals(), (
    "Run Cell 25 first: BIG_GSET_PARTITIONS is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


# ------------------------------------------------------------
# Choose one partition here
# ------------------------------------------------------------

SELECTED_BIG_GSET_PARTITION = 10


assert SELECTED_BIG_GSET_PARTITION in BIG_GSET_PARTITIONS, (
    f"Partition {SELECTED_BIG_GSET_PARTITION} is not defined."
)


selected_big_gset_graphs = BIG_GSET_PARTITIONS[SELECTED_BIG_GSET_PARTITION]


print("=" * 80)
print("SELECTED BIG-GSET PARTITION")
print("=" * 80)

print(
    f"Partition {SELECTED_BIG_GSET_PARTITION}: "
    f"{selected_big_gset_graphs[0]}-{selected_big_gset_graphs[-1]} | "
    f"{len(selected_big_gset_graphs)} graphs | "
    f"{selected_big_gset_graphs}"
)


# ------------------------------------------------------------
# Choose one test graph from this partition
# ------------------------------------------------------------

SELECTED_TEST_GRAPH = selected_big_gset_graphs[0]

print("\nSelected test graph:")
print(SELECTED_TEST_GRAPH)


# ------------------------------------------------------------
# File check
# ------------------------------------------------------------

selected_test_path = GSET_DIR / SELECTED_TEST_GRAPH

print("\nFile path:")
print(selected_test_path)

print("\nFile exists?")
print(selected_test_path.exists())

assert selected_test_path.exists(), (
    f"Could not find {SELECTED_TEST_GRAPH} at {selected_test_path}"
)


# ------------------------------------------------------------
# Benchmark metadata preview
# ------------------------------------------------------------

selected_partition_benchmark_df = big_gset_benchmark_df[
    big_gset_benchmark_df["partition"] == SELECTED_BIG_GSET_PARTITION
].copy()

selected_test_benchmark_df = big_gset_benchmark_df[
    big_gset_benchmark_df["graph"] == SELECTED_TEST_GRAPH
].copy()

print("\nSelected partition benchmark info:")
display(selected_partition_benchmark_df)

print("\nSelected test graph benchmark info:")
display(selected_test_benchmark_df)


assert len(selected_test_benchmark_df) == 1, (
    "Selected test graph should match exactly one benchmark row."
)
# Out:
# ================================================================================
# SELECTED BIG-GSET PARTITION
# ================================================================================
# Partition 10: G55-G56 | 2 graphs | ['G55', 'G56']
#
# Selected test graph:
# G55
#
# File path:
# ../data-gset/G55
#
# File exists?
# True
#
# Selected partition benchmark info:
#    partition graph     N      M  density_upper_percent  positive_edges  \
# 0         10   G55  5000  12498               0.100004           12498
# 1         10   G56  5000  12498               0.100004            6222
#
#    negative_edges  positive_edge_fraction  negative_edge_fraction  weight_sum  \
# 0               0                 1.00000                 0.00000     12498.0
# 1            6276                 0.49784                 0.50216       -54.0
#
#    best_known_cut  best_known_cut_per_edge  dense_W_float32_MB device  \
# 0         10299.0                 0.824052           95.367432  mps:0
# 1          4017.0                 0.321411           95.367432  mps:0
#
#            dtype
# 0  torch.float32
# 1  torch.float32
# Selected test graph benchmark info:
#    partition graph     N      M  density_upper_percent  positive_edges  \
# 0         10   G55  5000  12498               0.100004           12498
#
#    negative_edges  positive_edge_fraction  negative_edge_fraction  weight_sum  \
# 0               0                     1.0                     0.0     12498.0
#
#    best_known_cut  best_known_cut_per_edge  dense_W_float32_MB device  \
# 0         10299.0                 0.824052           95.367432  mps:0
#
#            dtype
# 0  torch.float32

# %%
assert "SELECTED_TEST_GRAPH" in globals(), (
    "Run Cell 32 first: SELECTED_TEST_GRAPH is missing."
)

assert "load_gset_edge_list" in globals(), (
    "Run Cell 26 first: load_gset_edge_list is missing."
)


N_test, edge_i_test, edge_j_test, edge_w_test, info_test = load_gset_edge_list(
    SELECTED_TEST_GRAPH
)


print("=" * 80)
print("LOADED TEST GRAPH")
print("=" * 80)

print("Graph:", SELECTED_TEST_GRAPH)
print("N:", N_test)
print("M:", info_test["M"])
print("density upper %:", info_test["density_upper_percent"])

print("\nWeight counts:")
print("positive edges:", info_test["positive_edges"])
print("negative edges:", info_test["negative_edges"])
print("zero edges    :", info_test["zero_edges"])
print("weight sum    :", info_test["weight_sum"])

print("\nDense W memory avoided:")
print("dense_W_float32_MB:", info_test["dense_W_float32_MB"])


print("\nEdge tensor shapes:")
print("edge_i_test:", edge_i_test.shape)
print("edge_j_test:", edge_j_test.shape)
print("edge_w_test:", edge_w_test.shape)

print("\nDevice / dtype:")
print("edge_i_test device:", edge_i_test.device)
print("edge_j_test device:", edge_j_test.device)
print("edge_w_test device:", edge_w_test.device)
print("edge_w_test dtype :", edge_w_test.dtype)


print("\nIndex ranges:")
print("edge_i min:", int(edge_i_test.min().detach().cpu()))
print("edge_i max:", int(edge_i_test.max().detach().cpu()))
print("edge_j min:", int(edge_j_test.min().detach().cpu()))
print("edge_j max:", int(edge_j_test.max().detach().cpu()))


assert edge_i_test.shape == edge_j_test.shape
assert edge_i_test.shape == edge_w_test.shape

assert edge_i_test.min() >= 0
assert edge_j_test.min() >= 0

assert edge_i_test.max() < N_test
assert edge_j_test.max() < N_test

assert torch.isfinite(edge_w_test).all(), (
    "edge_w_test contains non-finite weights."
)

assert info_test["zero_edges"] == 0, (
    "This graph has zero-weight edges."
)
# Out:
# ================================================================================
# LOADED TEST GRAPH
# ================================================================================
# Graph: G55
# N: 5000
# M: 12498
# density upper %: 0.10000400080016003
#
# Weight counts:
# positive edges: 12498
# negative edges: 0
# zero edges    : 0
# weight sum    : 12498.0
#
# Dense W memory avoided:
# dense_W_float32_MB: 95.367431640625
#
# Edge tensor shapes:
# edge_i_test: torch.Size([12498])
# edge_j_test: torch.Size([12498])
# edge_w_test: torch.Size([12498])
#
# Device / dtype:
# edge_i_test device: mps:0
# edge_j_test device: mps:0
# edge_w_test device: mps:0
# edge_w_test dtype : torch.float32
#
# Index ranges:
# edge_i min: 0
# edge_i max: 4967
# edge_j min: 16
# edge_j max: 4999

# %%
assert "N_test" in globals(), (
    "Run Cell 33 first: N_test is missing."
)

assert "edge_i_test" in globals(), (
    "Run Cell 33 first: edge_i_test is missing."
)

assert "edge_j_test" in globals(), (
    "Run Cell 33 first: edge_j_test is missing."
)

assert "edge_w_test" in globals(), (
    "Run Cell 33 first: edge_w_test is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)


# ------------------------------------------------------------
# Random spin replicas
# ------------------------------------------------------------

TEST_REPLICAS = 8
TEST_SEED = 4

torch.manual_seed(TEST_SEED)

random_spins_test = torch.where(
    torch.randn(
        TEST_REPLICAS,
        N_test,
        device=edge_w_test.device,
        dtype=edge_w_test.dtype,
    ) >= 0,
    torch.ones(
        TEST_REPLICAS,
        N_test,
        device=edge_w_test.device,
        dtype=edge_w_test.dtype,
    ),
    -torch.ones(
        TEST_REPLICAS,
        N_test,
        device=edge_w_test.device,
        dtype=edge_w_test.dtype,
    ),
)


print("=" * 80)
print("MANUAL HARD-CUT SANITY CHECK")
print("=" * 80)

print("Graph:", SELECTED_TEST_GRAPH)
print("N:", N_test)
print("M:", edge_w_test.numel())
print("random_spins_test shape:", random_spins_test.shape)
print("unique spin values:", torch.unique(random_spins_test).detach().cpu())


# ------------------------------------------------------------
# Edge-list hard cut
# ------------------------------------------------------------

random_hard_cuts_test = edge_discrete_cut(
    edge_i=edge_i_test,
    edge_j=edge_j_test,
    edge_w=edge_w_test,
    spins=random_spins_test,
)


print("\nHard-cut output:")
print("shape:", random_hard_cuts_test.shape)
print("values:", random_hard_cuts_test.detach().cpu().numpy())

print("\nHard-cut stats:")
print("mean:", float(random_hard_cuts_test.mean().detach().cpu()))
print("min :", float(random_hard_cuts_test.min().detach().cpu()))
print("max :", float(random_hard_cuts_test.max().detach().cpu()))


# ------------------------------------------------------------
# Manual replica-0 verification
# ------------------------------------------------------------

s0 = random_spins_test[0]

manual_cut_0 = 0.5 * (
    edge_w_test * (1.0 - s0[edge_i_test] * s0[edge_j_test])
).sum()

function_cut_0 = random_hard_cuts_test[0]

difference_0 = torch.abs(
    manual_cut_0 - function_cut_0
)


print("\nReplica 0 manual check:")
print("manual cut  :", float(manual_cut_0.detach().cpu()))
print("function cut:", float(function_cut_0.detach().cpu()))
print("difference  :", float(difference_0.detach().cpu()))


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert random_spins_test.shape == torch.Size([TEST_REPLICAS, N_test])

assert random_hard_cuts_test.shape == torch.Size([TEST_REPLICAS]), (
    "edge_discrete_cut should return one cut per replica."
)

assert torch.isfinite(random_hard_cuts_test).all(), (
    "Hard cut produced non-finite values."
)

assert torch.allclose(
    manual_cut_0,
    function_cut_0,
    atol=1e-5,
), (
    "Manual hard cut and edge_discrete_cut disagree."
)
# Out:
# ================================================================================
# MANUAL HARD-CUT SANITY CHECK
# ================================================================================
# Graph: G55
# N: 5000
# M: 12498
# random_spins_test shape: torch.Size([8, 5000])
# unique spin values: tensor([-1.,  1.])
#
# Hard-cut output:
# shape: torch.Size([8])
# values: [6296. 6234. 6313. 6296. 6158. 6301. 6221. 6164.]
#
# Hard-cut stats:
# mean: 6247.875
# min : 6158.0
# max : 6313.0
#
# Replica 0 manual check:
# manual cut  : 6296.0
# function cut: 6296.0
# difference  : 0.0

# %%
assert "N_test" in globals(), (
    "Run Cell 33 first: N_test is missing."
)

assert "BIG_GSET_REPLICAS" in globals(), (
    "Run Cell 31 first: BIG_GSET_REPLICAS is missing."
)

assert "BIG_GSET_SEED" in globals(), (
    "Run Cell 31 first: BIG_GSET_SEED is missing."
)

assert "R_INIT" in globals(), (
    "Run Cell 31 first: R_INIT is missing."
)

assert "THETA_CENTER" in globals(), (
    "Run Cell 31 first: THETA_CENTER is missing."
)

assert "THETA_NOISE" in globals(), (
    "Run Cell 31 first: THETA_NOISE is missing."
)

assert "bloch_from_raw" in globals(), (
    "bloch_from_raw is missing."
)


# ------------------------------------------------------------
# Convert desired initial R into raw_R space
# ------------------------------------------------------------

R_INIT_tensor = torch.tensor(
    R_INIT,
    device=device,
    dtype=DTYPE,
)

raw_R_init_value = torch.log(
    R_INIT_tensor / (1.0 - R_INIT_tensor)
)


# ------------------------------------------------------------
# Initialize trainable QEFEM variables
# ------------------------------------------------------------

torch.manual_seed(BIG_GSET_SEED)

raw_R_test = raw_R_init_value + 1e-3 * torch.randn(
    BIG_GSET_REPLICAS,
    N_test,
    device=device,
    dtype=DTYPE,
)

theta_test = THETA_CENTER + THETA_NOISE * torch.randn(
    BIG_GSET_REPLICAS,
    N_test,
    device=device,
    dtype=DTYPE,
)

raw_R_test.requires_grad_(True)
theta_test.requires_grad_(True)


# ------------------------------------------------------------
# Convert to Bloch components
# ------------------------------------------------------------

R_test, rx_test, rz_test = bloch_from_raw(
    raw_R_test,
    theta_test,
)


print("=" * 80)
print("QEFEM INITIALIZATION SANITY CHECK")
print("=" * 80)

print("Graph:", SELECTED_TEST_GRAPH)
print("N:", N_test)
print("Replicas:", BIG_GSET_REPLICAS)

print("\nTrainable tensor shapes:")
print("raw_R_test:", raw_R_test.shape)
print("theta_test:", theta_test.shape)

print("\nBloch tensor shapes:")
print("R_test :", R_test.shape)
print("rx_test:", rx_test.shape)
print("rz_test:", rz_test.shape)


print("\nR statistics:")
print("R mean:", float(R_test.mean().detach().cpu()))
print("R min :", float(R_test.min().detach().cpu()))
print("R max :", float(R_test.max().detach().cpu()))

print("\nrx statistics:")
print("rx mean     :", float(rx_test.mean().detach().cpu()))
print("abs rx mean :", float(rx_test.abs().mean().detach().cpu()))
print("rx min      :", float(rx_test.min().detach().cpu()))
print("rx max      :", float(rx_test.max().detach().cpu()))

print("\nrz statistics:")
print("rz mean     :", float(rz_test.mean().detach().cpu()))
print("abs rz mean :", float(rz_test.abs().mean().detach().cpu()))
print("rz min      :", float(rz_test.min().detach().cpu()))
print("rz max      :", float(rz_test.max().detach().cpu()))


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert raw_R_test.shape == torch.Size([BIG_GSET_REPLICAS, N_test])
assert theta_test.shape == torch.Size([BIG_GSET_REPLICAS, N_test])

assert R_test.shape == torch.Size([BIG_GSET_REPLICAS, N_test])
assert rx_test.shape == torch.Size([BIG_GSET_REPLICAS, N_test])
assert rz_test.shape == torch.Size([BIG_GSET_REPLICAS, N_test])

assert torch.isfinite(raw_R_test).all()
assert torch.isfinite(theta_test).all()

assert torch.isfinite(R_test).all()
assert torch.isfinite(rx_test).all()
assert torch.isfinite(rz_test).all()

assert R_test.min() > 0.0
assert R_test.max() < 1.0

assert raw_R_test.requires_grad
assert theta_test.requires_grad
# Out:
# ================================================================================
# QEFEM INITIALIZATION SANITY CHECK
# ================================================================================
# Graph: G55
# N: 5000
# Replicas: 128
#
# Trainable tensor shapes:
# raw_R_test: torch.Size([128, 5000])
# theta_test: torch.Size([128, 5000])
#
# Bloch tensor shapes:
# R_test : torch.Size([128, 5000])
# rx_test: torch.Size([128, 5000])
# rz_test: torch.Size([128, 5000])
#
# R statistics:
# R mean: 0.01000000350177288
# R min : 0.009952389635145664
# R max : 0.010047533549368382
#
# rx statistics:
# rx mean     : 0.009999997913837433
# abs rx mean : 0.009999997913837433
# rx min      : 0.009952375665307045
# rx max      : 0.010047524236142635
#
# rz statistics:
# rz mean     : -2.0750357876408998e-08
# abs rz mean : 7.983790055732243e-06
# rz min      : -4.742851888295263e-05
# rz max      : 4.819095556740649e-05

# %%
assert "edge_i_test" in globals(), (
    "Run Cell 33 first: edge_i_test is missing."
)

assert "edge_j_test" in globals(), (
    "Run Cell 33 first: edge_j_test is missing."
)

assert "edge_w_test" in globals(), (
    "Run Cell 33 first: edge_w_test is missing."
)

assert "raw_R_test" in globals(), (
    "Run Cell 35 first: raw_R_test is missing."
)

assert "theta_test" in globals(), (
    "Run Cell 35 first: theta_test is missing."
)

assert "big_gset_beta_schedule" in globals(), (
    "Run Cell 31 first: big_gset_beta_schedule is missing."
)

assert "big_gset_gamma_schedule" in globals(), (
    "Run Cell 31 first: big_gset_gamma_schedule is missing."
)

assert "edge_qefem_free_energy" in globals(), (
    "Run Cell 30 first: edge_qefem_free_energy is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)


# ------------------------------------------------------------
# Pick first annealing point
# ------------------------------------------------------------

test_step = 0

beta_test = big_gset_beta_schedule[test_step]
gamma_test = big_gset_gamma_schedule[test_step]


# ------------------------------------------------------------
# Forward free-energy evaluation
# ------------------------------------------------------------

F_test, aux_test = edge_qefem_free_energy(
    edge_i=edge_i_test,
    edge_j=edge_j_test,
    edge_w=edge_w_test,
    raw_R=raw_R_test,
    theta=theta_test,
    beta=beta_test,
    gamma=gamma_test,
)


# ------------------------------------------------------------
# Hard readout from current rz
# ------------------------------------------------------------

rz_forward_test = aux_test["rz"]

spins_forward_test = torch.where(
    rz_forward_test >= 0,
    torch.ones_like(rz_forward_test),
    -torch.ones_like(rz_forward_test),
)

hard_cuts_forward_test = edge_discrete_cut(
    edge_i=edge_i_test,
    edge_j=edge_j_test,
    edge_w=edge_w_test,
    spins=spins_forward_test,
)


print("=" * 80)
print("ONE-STEP FORWARD FREE-ENERGY SANITY CHECK")
print("=" * 80)

print("Graph:", SELECTED_TEST_GRAPH)
print("N:", N_test)
print("M:", edge_w_test.numel())
print("Replicas:", BIG_GSET_REPLICAS)

print("\nAnnealing point:")
print("step:", test_step)
print("beta :", float(beta_test.detach().cpu()))
print("gamma:", float(gamma_test.detach().cpu()))


print("\nFree energy:")
print("F_test shape:", F_test.shape)
print("F mean:", float(F_test.mean().detach().cpu()))
print("F min :", float(F_test.min().detach().cpu()))
print("F max :", float(F_test.max().detach().cpu()))


print("\nExpected cut:")
print("expected_cut shape:", aux_test["expected_cut"].shape)
print("mean:", float(aux_test["expected_cut"].mean().detach().cpu()))
print("min :", float(aux_test["expected_cut"].min().detach().cpu()))
print("max :", float(aux_test["expected_cut"].max().detach().cpu()))


print("\nEntropy:")
print("entropy shape:", aux_test["entropy"].shape)
print("mean:", float(aux_test["entropy"].mean().detach().cpu()))
print("min :", float(aux_test["entropy"].min().detach().cpu()))
print("max :", float(aux_test["entropy"].max().detach().cpu()))


print("\nDriver energy:")
print("driver_energy shape:", aux_test["driver_energy"].shape)
print("mean:", float(aux_test["driver_energy"].mean().detach().cpu()))
print("min :", float(aux_test["driver_energy"].min().detach().cpu()))
print("max :", float(aux_test["driver_energy"].max().detach().cpu()))


print("\nHard readout from current rz:")
print("hard_cuts shape:", hard_cuts_forward_test.shape)
print("mean:", float(hard_cuts_forward_test.mean().detach().cpu()))
print("min :", float(hard_cuts_forward_test.min().detach().cpu()))
print("max :", float(hard_cuts_forward_test.max().detach().cpu()))


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert F_test.shape == torch.Size([BIG_GSET_REPLICAS])
assert aux_test["expected_cut"].shape == torch.Size([BIG_GSET_REPLICAS])
assert aux_test["entropy"].shape == torch.Size([BIG_GSET_REPLICAS])
assert aux_test["driver_energy"].shape == torch.Size([BIG_GSET_REPLICAS])
assert hard_cuts_forward_test.shape == torch.Size([BIG_GSET_REPLICAS])

assert torch.isfinite(F_test).all(), (
    "Free energy has non-finite values."
)

assert torch.isfinite(aux_test["expected_cut"]).all(), (
    "Expected cut has non-finite values."
)

assert torch.isfinite(aux_test["entropy"]).all(), (
    "Entropy has non-finite values."
)

assert torch.isfinite(aux_test["driver_energy"]).all(), (
    "Driver energy has non-finite values."
)

assert torch.isfinite(hard_cuts_forward_test).all(), (
    "Hard cuts have non-finite values."
)
# Out:
# ================================================================================
# ONE-STEP FORWARD FREE-ENERGY SANITY CHECK
# ================================================================================
# Graph: G55
# N: 5000
# M: 12498
# Replicas: 128
#
# Annealing point:
# step: 0
# beta : 0.8620690107345581
# gamma: 1.0
#
# Free energy:
# F_test shape: torch.Size([128])
# F mean: -10318.962890625
# F min : -10318.96484375
# F max : -10318.9609375
#
# Expected cut:
# expected_cut shape: torch.Size([128])
# mean: 6249.0
# min : 6249.0
# max : 6249.0
#
# Entropy:
# entropy shape: torch.Size([128])
# mean: 3465.485595703125
# min : 3465.485595703125
# max : 3465.485595703125
#
# Driver energy:
# driver_energy shape: torch.Size([128])
# mean: -49.999996185302734
# min : -50.002044677734375
# max : -49.99811553955078
#
# Hard readout from current rz:
# hard_cuts shape: torch.Size([128])
# mean: 6249.640625
# min : 6144.0
# max : 6368.0

# %% [markdown]
# ### Run a BIG GSET instance

# %%
import time

assert "selected_big_gset_graphs" in globals(), (
    "Run Cell 32 first: selected_big_gset_graphs is missing."
)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "load_gset_edge_list" in globals(), (
    "Run Cell 26 first: load_gset_edge_list is missing."
)

assert "edge_qefem_free_energy" in globals(), (
    "Run Cell 30 first: edge_qefem_free_energy is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)

assert "big_gset_beta_schedule" in globals(), (
    "Run Cell 31 first: big_gset_beta_schedule is missing."
)

assert "big_gset_gamma_schedule" in globals(), (
    "Run Cell 31 first: big_gset_gamma_schedule is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


selected_partition_history_rows = []
selected_partition_summary_rows = []
selected_partition_best_spins = {}


print("=" * 80)
print("RUNNING SELECTED BIG-GSET PARTITION")
print("=" * 80)
print("Partition:", SELECTED_BIG_GSET_PARTITION)
print("Graphs:", selected_big_gset_graphs)
print("Replicas:", BIG_GSET_REPLICAS)
print("Steps:", BIG_GSET_N_STEPS)
print("Optimizer: Adam")
print("Adam lr:", BIG_GSET_ADAM_LR)


for graph in selected_big_gset_graphs:
    print("\n" + "=" * 80)
    print("START GRAPH:", graph)
    print("=" * 80)

    N_g, edge_i, edge_j, edge_w, info = load_gset_edge_list(graph)

    graph_benchmark_row = big_gset_benchmark_df[
        big_gset_benchmark_df["graph"] == graph
    ].iloc[0]

    best_known_cut = float(graph_benchmark_row["best_known_cut"])

    print("N:", N_g)
    print("M:", info["M"])
    print("Best-known cut:", best_known_cut)

    torch.manual_seed(BIG_GSET_SEED)

    R_INIT_tensor = torch.tensor(
        R_INIT,
        device=device,
        dtype=DTYPE,
    )

    raw_R_init_value = torch.log(
        R_INIT_tensor / (1.0 - R_INIT_tensor)
    )

    raw_R = raw_R_init_value + 1e-3 * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    theta = THETA_CENTER + THETA_NOISE * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    raw_R.requires_grad_(True)
    theta.requires_grad_(True)

    optimizer = torch.optim.Adam(
        [raw_R, theta],
        lr=BIG_GSET_ADAM_LR,
    )

    best_cut = -float("inf")
    best_step = None
    best_replica = None
    best_spins = None

    graph_start_time = time.time()

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    for step in range(BIG_GSET_N_STEPS):
        beta_t = big_gset_beta_schedule[step]
        gamma_t = big_gset_gamma_schedule[step]

        optimizer.zero_grad()

        F, aux = edge_qefem_free_energy(
            edge_i=edge_i,
            edge_j=edge_j,
            edge_w=edge_w,
            raw_R=raw_R,
            theta=theta,
            beta=beta_t,
            gamma=gamma_t,
        )

        loss = F.mean()

        loss.backward()
        optimizer.step()

        should_log = (
            step == 0
            or step == BIG_GSET_N_STEPS - 1
            or (step + 1) % BIG_GSET_LOG_EVERY == 0
        )

        if should_log:
            if edge_w.device.type == "mps":
                torch.mps.synchronize()

            elapsed = time.time() - graph_start_time

            with torch.no_grad():
                R_now, rx_now, rz_now = bloch_from_raw(
                    raw_R,
                    theta,
                )

                spins_now = torch.where(
                    rz_now >= 0,
                    torch.ones_like(rz_now),
                    -torch.ones_like(rz_now),
                )

                hard_cuts_now = edge_discrete_cut(
                    edge_i=edge_i,
                    edge_j=edge_j,
                    edge_w=edge_w,
                    spins=spins_now,
                )

                current_best_cut_tensor, current_best_replica_tensor = torch.max(
                    hard_cuts_now,
                    dim=0,
                )

                current_best_cut = float(current_best_cut_tensor.detach().cpu())
                current_best_replica = int(current_best_replica_tensor.detach().cpu())

                if current_best_cut > best_cut:
                    best_cut = current_best_cut
                    best_step = step + 1
                    best_replica = current_best_replica
                    best_spins = spins_now[current_best_replica].detach().cpu().clone()

                gap = best_known_cut - best_cut
                accuracy_percent = 100.0 * best_cut / best_known_cut

                selected_partition_history_rows.append(
                    {
                        "partition": SELECTED_BIG_GSET_PARTITION,
                        "graph": graph,
                        "step": step + 1,
                        "beta": float(beta_t.detach().cpu()),
                        "gamma": float(gamma_t.detach().cpu()),
                        "loss": float(loss.detach().cpu()),
                        "free_energy_mean": float(F.mean().detach().cpu()),
                        "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
                        "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),
                        "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
                        "hard_cut_max": current_best_cut,
                        "best_cut_so_far": best_cut,
                        "best_known_cut": best_known_cut,
                        "gap": gap,
                        "accuracy_percent": accuracy_percent,
                        "R_mean": float(R_now.mean().detach().cpu()),
                        "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),
                        "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),
                        "best_replica_so_far": best_replica,
                        "elapsed_sec": elapsed,
                    }
                )

                print(
                    f"{graph} | "
                    f"step {step + 1:5d}/{BIG_GSET_N_STEPS} | "
                    f"cut={current_best_cut:10.1f} | "
                    f"best={best_cut:10.1f} | "
                    f"gap={gap:10.1f} | "
                    f"acc={accuracy_percent:7.3f}% | "
                    f"|rz|={float(rz_now.abs().mean().detach().cpu()):.4f} | "
                    f"time={elapsed:8.2f}s"
                )

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    graph_runtime = time.time() - graph_start_time

    selected_partition_summary_rows.append(
        {
            "partition": SELECTED_BIG_GSET_PARTITION,
            "graph": graph,
            "N": N_g,
            "M": info["M"],
            "best_known_cut": best_known_cut,
            "qefem_best_cut": best_cut,
            "gap": best_known_cut - best_cut,
            "accuracy_percent": 100.0 * best_cut / best_known_cut,
            "best_step": best_step,
            "best_replica": best_replica,
            "replicas": BIG_GSET_REPLICAS,
            "steps": BIG_GSET_N_STEPS,
            "optimizer": "Adam",
            "lr": BIG_GSET_ADAM_LR,
            "runtime_sec": graph_runtime,
        }
    )

    selected_partition_best_spins[graph] = best_spins

    print("\nFINISHED GRAPH:", graph)
    print("Best cut:", best_cut)
    print("Best-known:", best_known_cut)
    print("Gap:", best_known_cut - best_cut)
    print("Accuracy %:", 100.0 * best_cut / best_known_cut)
    print("Runtime sec:", graph_runtime)


selected_partition_history_df = pd.DataFrame(selected_partition_history_rows)
selected_partition_summary_df = pd.DataFrame(selected_partition_summary_rows)

print("\n" + "=" * 80)
print("SELECTED PARTITION SUMMARY")
print("=" * 80)

display(selected_partition_summary_df)
# Out:
# ================================================================================
# RUNNING SELECTED BIG-GSET PARTITION
# ================================================================================
# Partition: 10
# Graphs: ['G55', 'G56']
# Replicas: 128
# Steps: 1000
# Optimizer: Adam
# Adam lr: 0.01
#
# ================================================================================
# START GRAPH: G55
# ================================================================================
# N: 5000
# M: 12498
# Best-known cut: 10299.0
# G55 | step     1/1000 | cut=    6326.0 | best=    6326.0 | gap=    3973.0 | acc= 61.423% | |rz|=0.0001 | time=    0.16s
# G55 | step    50/1000 | cut=    6388.0 | best=    6388.0 | gap=    3911.0 | acc= 62.025% | |rz|=0.0000 | time=    0.75s
# G55 | step   100/1000 | cut=    6139.0 | best=    6388.0 | gap=    3911.0 | acc= 62.025% | |rz|=0.0000 | time=    1.34s
# G55 | step   150/1000 | cut=    5037.0 | best=    6388.0 | gap=    3911.0 | acc= 62.025% | |rz|=0.0001 | time=    1.95s
# G55 | step   200/1000 | cut=    5672.0 | best=    6388.0 | gap=    3911.0 | acc= 62.025% | |rz|=0.0002 | time=    2.57s
# G55 | step   250/1000 | cut=    4096.0 | best=    6388.0 | gap=    3911.0 | acc= 62.025% | |rz|=0.0002 | time=    3.21s
# G55 | step   300/1000 | cut=   10030.0 | best=   10030.0 | gap=     269.0 | acc= 97.388% | |rz|=0.1903 | time=    3.78s
# G55 | step   350/1000 | cut=   10146.0 | best=   10146.0 | gap=     153.0 | acc= 98.514% | |rz|=0.4627 | time=    4.39s
# G55 | step   400/1000 | cut=   10170.0 | best=   10170.0 | gap=     129.0 | acc= 98.747% | |rz|=0.6064 | time=    4.96s
# G55 | step   450/1000 | cut=   10196.0 | best=   10196.0 | gap=     103.0 | acc= 99.000% | |rz|=0.6857 | time=    5.54s
# G55 | step   500/1000 | cut=   10197.0 | best=   10197.0 | gap=     102.0 | acc= 99.010% | |rz|=0.7368 | time=    6.14s
# G55 | step   550/1000 | cut=   10201.0 | best=   10201.0 | gap=      98.0 | acc= 99.048% | |rz|=0.7747 | time=    6.70s
# G55 | step   600/1000 | cut=   10202.0 | best=   10202.0 | gap=      97.0 | acc= 99.058% | |rz|=0.8054 | time=    7.28s
# G55 | step   650/1000 | cut=   10203.0 | best=   10203.0 | gap=      96.0 | acc= 99.068% | |rz|=0.8316 | time=    7.87s
# G55 | step   700/1000 | cut=   10203.0 | best=   10203.0 | gap=      96.0 | acc= 99.068% | |rz|=0.8544 | time=    8.45s
# G55 | step   750/1000 | cut=   10204.0 | best=   10204.0 | gap=      95.0 | acc= 99.078% | |rz|=0.8741 | time=    9.02s
# G55 | step   800/1000 | cut=   10204.0 | best=   10204.0 | gap=      95.0 | acc= 99.078% | |rz|=0.8912 | time=    9.71s
# G55 | step   850/1000 | cut=   10205.0 | best=   10205.0 | gap=      94.0 | acc= 99.087% | |rz|=0.9056 | time=   10.29s
# G55 | step   900/1000 | cut=   10205.0 | best=   10205.0 | gap=      94.0 | acc= 99.087% | |rz|=0.9174 | time=   10.90s
# G55 | step   950/1000 | cut=   10205.0 | best=   10205.0 | gap=      94.0 | acc= 99.087% | |rz|=0.9274 | time=   11.49s
# G55 | step  1000/1000 | cut=   10205.0 | best=   10205.0 | gap=      94.0 | acc= 99.087% | |rz|=0.9464 | time=   12.08s
#
# FINISHED GRAPH: G55
# Best cut: 10205.0
# Best-known: 10299.0
# Gap: 94.0
# Accuracy %: 99.08729002815808
# Runtime sec: 12.089287757873535
#
# ================================================================================
# START GRAPH: G56
# ================================================================================
# N: 5000
# M: 12498
# Best-known cut: 4017.0
# G56 | step     1/1000 | cut=      86.0 | best=      86.0 | gap=    3931.0 | acc=  2.141% | |rz|=0.0001 | time=    0.01s
# G56 | step    50/1000 | cut=     123.0 | best=     123.0 | gap=    3894.0 | acc=  3.062% | |rz|=0.0000 | time=    0.56s
# G56 | step   100/1000 | cut=    -136.0 | best=     123.0 | gap=    3894.0 | acc=  3.062% | |rz|=0.0000 | time=    1.15s
# G56 | step   150/1000 | cut=   -1154.0 | best=     123.0 | gap=    3894.0 | acc=  3.062% | |rz|=0.0000 | time=    1.73s
# G56 | step   200/1000 | cut=   -1176.0 | best=     123.0 | gap=    3894.0 | acc=  3.062% | |rz|=0.0001 | time=    2.44s
# G56 | step   250/1000 | cut=   -1984.0 | best=     123.0 | gap=    3894.0 | acc=  3.062% | |rz|=0.0002 | time=    3.04s
# G56 | step   300/1000 | cut=    3752.0 | best=    3752.0 | gap=     265.0 | acc= 93.403% | |rz|=0.2159 | time=    3.63s
# G56 | step   350/1000 | cut=    3859.0 | best=    3859.0 | gap=     158.0 | acc= 96.067% | |rz|=0.4657 | time=    4.22s
# G56 | step   400/1000 | cut=    3887.0 | best=    3887.0 | gap=     130.0 | acc= 96.764% | |rz|=0.6066 | time=    4.86s
# G56 | step   450/1000 | cut=    3898.0 | best=    3898.0 | gap=     119.0 | acc= 97.038% | |rz|=0.6848 | time=    5.51s
# G56 | step   500/1000 | cut=    3904.0 | best=    3904.0 | gap=     113.0 | acc= 97.187% | |rz|=0.7356 | time=    6.20s
# G56 | step   550/1000 | cut=    3906.0 | best=    3906.0 | gap=     111.0 | acc= 97.237% | |rz|=0.7733 | time=    6.80s
# G56 | step   600/1000 | cut=    3908.0 | best=    3908.0 | gap=     109.0 | acc= 97.287% | |rz|=0.8038 | time=    7.39s
# G56 | step   650/1000 | cut=    3908.0 | best=    3908.0 | gap=     109.0 | acc= 97.287% | |rz|=0.8299 | time=    7.99s
# G56 | step   700/1000 | cut=    3908.0 | best=    3908.0 | gap=     109.0 | acc= 97.287% | |rz|=0.8527 | time=    8.58s
# G56 | step   750/1000 | cut=    3908.0 | best=    3908.0 | gap=     109.0 | acc= 97.287% | |rz|=0.8724 | time=    9.16s
# G56 | step   800/1000 | cut=    3908.0 | best=    3908.0 | gap=     109.0 | acc= 97.287% | |rz|=0.8894 | time=    9.75s
# G56 | step   850/1000 | cut=    3908.0 | best=    3908.0 | gap=     109.0 | acc= 97.287% | |rz|=0.9037 | time=   10.33s
# G56 | step   900/1000 | cut=    3908.0 | best=    3908.0 | gap=     109.0 | acc= 97.287% | |rz|=0.9155 | time=   10.94s
# G56 | step   950/1000 | cut=    3908.0 | best=    3908.0 | gap=     109.0 | acc= 97.287% | |rz|=0.9255 | time=   11.51s
# G56 | step  1000/1000 | cut=    3908.0 | best=    3908.0 | gap=     109.0 | acc= 97.287% | |rz|=0.9448 | time=   12.10s
#
# FINISHED GRAPH: G56
# Best cut: 3908.0
# Best-known: 4017.0
# Gap: 109.0
# Accuracy %: 97.28653223798855
# Runtime sec: 12.111849069595337
#
# ================================================================================
# SELECTED PARTITION SUMMARY
# ================================================================================
#    partition graph     N      M  best_known_cut  qefem_best_cut    gap  \
# 0         10   G55  5000  12498         10299.0         10205.0   94.0
# 1         10   G56  5000  12498          4017.0          3908.0  109.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         99.087290        850            44       128   1000      Adam  0.01
# 1         97.286532        600            53       128   1000      Adam  0.01
#
#    runtime_sec
# 0    12.089288
# 1    12.111849

# %%
assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "selected_partition_history_df" in globals(), (
    "Run Cell 37 first: selected_partition_history_df is missing."
)

assert "selected_partition_summary_df" in globals(), (
    "Run Cell 37 first: selected_partition_summary_df is missing."
)

assert "selected_partition_best_spins" in globals(), (
    "Run Cell 37 first: selected_partition_best_spins is missing."
)


# ------------------------------------------------------------
# Output folder
# ------------------------------------------------------------

BIG_GSET_OUTPUT_DIR = Path("qefem_big_gset_outputs")
BIG_GSET_OUTPUT_DIR.mkdir(exist_ok=True)


# ------------------------------------------------------------
# File names
# ------------------------------------------------------------

partition_tag = f"partition_{SELECTED_BIG_GSET_PARTITION}"

history_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_history.csv"
summary_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_summary.csv"
spins_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_best_spins.pt"


# ------------------------------------------------------------
# Save CSV files
# ------------------------------------------------------------

selected_partition_history_df.to_csv(
    history_path,
    index=False,
)

selected_partition_summary_df.to_csv(
    summary_path,
    index=False,
)


# ------------------------------------------------------------
# Save best spins dictionary
# ------------------------------------------------------------

torch.save(
    selected_partition_best_spins,
    spins_path,
)


# ------------------------------------------------------------
# Print saved paths
# ------------------------------------------------------------

print("=" * 80)
print("SAVED SELECTED PARTITION RESULTS")
print("=" * 80)

print("Partition:", SELECTED_BIG_GSET_PARTITION)

print("\nSaved history CSV:")
print(history_path.resolve())

print("\nSaved summary CSV:")
print(summary_path.resolve())

print("\nSaved best spins PT:")
print(spins_path.resolve())


# ------------------------------------------------------------
# Display final summary
# ------------------------------------------------------------

print("\nFinal selected-partition summary:")
display(selected_partition_summary_df)


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert history_path.exists(), (
    f"History file was not saved: {history_path}"
)

assert summary_path.exists(), (
    f"Summary file was not saved: {summary_path}"
)

assert spins_path.exists(), (
    f"Best-spins file was not saved: {spins_path}"
)

assert len(selected_partition_summary_df) > 0, (
    "Summary dataframe is empty."
)

assert len(selected_partition_history_df) > 0, (
    "History dataframe is empty."
)
# Out:
# ================================================================================
# SAVED SELECTED PARTITION RESULTS
# ================================================================================
# Partition: 10
#
# Saved history CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_10_history.csv
#
# Saved summary CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_10_summary.csv
#
# Saved best spins PT:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_10_best_spins.pt
#
# Final selected-partition summary:
#    partition graph     N      M  best_known_cut  qefem_best_cut    gap  \
# 0         10   G55  5000  12498         10299.0         10205.0   94.0
# 1         10   G56  5000  12498          4017.0          3908.0  109.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         99.087290        850            44       128   1000      Adam  0.01
# 1         97.286532        600            53       128   1000      Adam  0.01
#
#    runtime_sec
# 0    12.089288
# 1    12.111849

# %%
assert "BIG_GSET_PARTITIONS" in globals(), (
    "Run Cell 25 first: BIG_GSET_PARTITIONS is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


# ------------------------------------------------------------
# Change this after each completed partition
# ------------------------------------------------------------

SELECTED_BIG_GSET_PARTITION = 11


# ------------------------------------------------------------
# Select graphs in this partition
# ------------------------------------------------------------

assert SELECTED_BIG_GSET_PARTITION in BIG_GSET_PARTITIONS, (
    f"Partition {SELECTED_BIG_GSET_PARTITION} is not defined."
)

selected_big_gset_graphs = BIG_GSET_PARTITIONS[SELECTED_BIG_GSET_PARTITION]


print("=" * 80)
print("NEXT BIG-GSET PARTITION SELECTED")
print("=" * 80)

print(
    f"Partition {SELECTED_BIG_GSET_PARTITION}: "
    f"{selected_big_gset_graphs[0]}-{selected_big_gset_graphs[-1]} | "
    f"{len(selected_big_gset_graphs)} graphs | "
    f"{selected_big_gset_graphs}"
)


# ------------------------------------------------------------
# Quick file check
# ------------------------------------------------------------

missing_graphs = []

for graph in selected_big_gset_graphs:
    path = GSET_DIR / graph

    print(f"{graph}: {path.exists()} | {path}")

    if not path.exists():
        missing_graphs.append(graph)

assert len(missing_graphs) == 0, (
    f"Missing graph files: {missing_graphs}"
)


# ------------------------------------------------------------
# Benchmark preview for this partition
# ------------------------------------------------------------

selected_partition_benchmark_df = big_gset_benchmark_df[
    big_gset_benchmark_df["partition"] == SELECTED_BIG_GSET_PARTITION
].copy()

display(selected_partition_benchmark_df)

assert len(selected_partition_benchmark_df) == len(selected_big_gset_graphs), (
    "Benchmark table row count does not match selected partition graph count."
)
# Out:
# ================================================================================
# NEXT BIG-GSET PARTITION SELECTED
# ================================================================================
# Partition 11: G57-G57 | 1 graphs | ['G57']
# G57: True | ../data-gset/G57
#    partition graph     N      M  density_upper_percent  positive_edges  \
# 2         11   G57  5000  10000               0.080016            4981
#
#    negative_edges  positive_edge_fraction  negative_edge_fraction  weight_sum  \
# 2            5019                  0.4981                  0.5019       -38.0
#
#    best_known_cut  best_known_cut_per_edge  dense_W_float32_MB device  \
# 2          3494.0                   0.3494           95.367432  mps:0
#
#            dtype
# 2  torch.float32

# %%
import time

assert "selected_big_gset_graphs" in globals(), (
    "Run Cell 32 first: selected_big_gset_graphs is missing."
)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "load_gset_edge_list" in globals(), (
    "Run Cell 26 first: load_gset_edge_list is missing."
)

assert "edge_qefem_free_energy" in globals(), (
    "Run Cell 30 first: edge_qefem_free_energy is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)

assert "big_gset_beta_schedule" in globals(), (
    "Run Cell 31 first: big_gset_beta_schedule is missing."
)

assert "big_gset_gamma_schedule" in globals(), (
    "Run Cell 31 first: big_gset_gamma_schedule is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


selected_partition_history_rows = []
selected_partition_summary_rows = []
selected_partition_best_spins = {}


print("=" * 80)
print("RUNNING SELECTED BIG-GSET PARTITION")
print("=" * 80)
print("Partition:", SELECTED_BIG_GSET_PARTITION)
print("Graphs:", selected_big_gset_graphs)
print("Replicas:", BIG_GSET_REPLICAS)
print("Steps:", BIG_GSET_N_STEPS)
print("Optimizer: Adam")
print("Adam lr:", BIG_GSET_ADAM_LR)


for graph in selected_big_gset_graphs:
    print("\n" + "=" * 80)
    print("START GRAPH:", graph)
    print("=" * 80)

    N_g, edge_i, edge_j, edge_w, info = load_gset_edge_list(graph)

    graph_benchmark_row = big_gset_benchmark_df[
        big_gset_benchmark_df["graph"] == graph
    ].iloc[0]

    best_known_cut = float(graph_benchmark_row["best_known_cut"])

    print("N:", N_g)
    print("M:", info["M"])
    print("Best-known cut:", best_known_cut)

    torch.manual_seed(BIG_GSET_SEED)

    R_INIT_tensor = torch.tensor(
        R_INIT,
        device=device,
        dtype=DTYPE,
    )

    raw_R_init_value = torch.log(
        R_INIT_tensor / (1.0 - R_INIT_tensor)
    )

    raw_R = raw_R_init_value + 1e-3 * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    theta = THETA_CENTER + THETA_NOISE * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    raw_R.requires_grad_(True)
    theta.requires_grad_(True)

    optimizer = torch.optim.Adam(
        [raw_R, theta],
        lr=BIG_GSET_ADAM_LR,
    )

    best_cut = -float("inf")
    best_step = None
    best_replica = None
    best_spins = None

    graph_start_time = time.time()

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    for step in range(BIG_GSET_N_STEPS):
        beta_t = big_gset_beta_schedule[step]
        gamma_t = big_gset_gamma_schedule[step]

        optimizer.zero_grad()

        F, aux = edge_qefem_free_energy(
            edge_i=edge_i,
            edge_j=edge_j,
            edge_w=edge_w,
            raw_R=raw_R,
            theta=theta,
            beta=beta_t,
            gamma=gamma_t,
        )

        loss = F.mean()

        loss.backward()
        optimizer.step()

        should_log = (
            step == 0
            or step == BIG_GSET_N_STEPS - 1
            or (step + 1) % BIG_GSET_LOG_EVERY == 0
        )

        if should_log:
            if edge_w.device.type == "mps":
                torch.mps.synchronize()

            elapsed = time.time() - graph_start_time

            with torch.no_grad():
                R_now, rx_now, rz_now = bloch_from_raw(
                    raw_R,
                    theta,
                )

                spins_now = torch.where(
                    rz_now >= 0,
                    torch.ones_like(rz_now),
                    -torch.ones_like(rz_now),
                )

                hard_cuts_now = edge_discrete_cut(
                    edge_i=edge_i,
                    edge_j=edge_j,
                    edge_w=edge_w,
                    spins=spins_now,
                )

                current_best_cut_tensor, current_best_replica_tensor = torch.max(
                    hard_cuts_now,
                    dim=0,
                )

                current_best_cut = float(current_best_cut_tensor.detach().cpu())
                current_best_replica = int(current_best_replica_tensor.detach().cpu())

                if current_best_cut > best_cut:
                    best_cut = current_best_cut
                    best_step = step + 1
                    best_replica = current_best_replica
                    best_spins = spins_now[current_best_replica].detach().cpu().clone()

                gap = best_known_cut - best_cut
                accuracy_percent = 100.0 * best_cut / best_known_cut

                selected_partition_history_rows.append(
                    {
                        "partition": SELECTED_BIG_GSET_PARTITION,
                        "graph": graph,
                        "step": step + 1,
                        "beta": float(beta_t.detach().cpu()),
                        "gamma": float(gamma_t.detach().cpu()),
                        "loss": float(loss.detach().cpu()),
                        "free_energy_mean": float(F.mean().detach().cpu()),
                        "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
                        "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),
                        "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
                        "hard_cut_max": current_best_cut,
                        "best_cut_so_far": best_cut,
                        "best_known_cut": best_known_cut,
                        "gap": gap,
                        "accuracy_percent": accuracy_percent,
                        "R_mean": float(R_now.mean().detach().cpu()),
                        "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),
                        "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),
                        "best_replica_so_far": best_replica,
                        "elapsed_sec": elapsed,
                    }
                )

                print(
                    f"{graph} | "
                    f"step {step + 1:5d}/{BIG_GSET_N_STEPS} | "
                    f"cut={current_best_cut:10.1f} | "
                    f"best={best_cut:10.1f} | "
                    f"gap={gap:10.1f} | "
                    f"acc={accuracy_percent:7.3f}% | "
                    f"|rz|={float(rz_now.abs().mean().detach().cpu()):.4f} | "
                    f"time={elapsed:8.2f}s"
                )

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    graph_runtime = time.time() - graph_start_time

    selected_partition_summary_rows.append(
        {
            "partition": SELECTED_BIG_GSET_PARTITION,
            "graph": graph,
            "N": N_g,
            "M": info["M"],
            "best_known_cut": best_known_cut,
            "qefem_best_cut": best_cut,
            "gap": best_known_cut - best_cut,
            "accuracy_percent": 100.0 * best_cut / best_known_cut,
            "best_step": best_step,
            "best_replica": best_replica,
            "replicas": BIG_GSET_REPLICAS,
            "steps": BIG_GSET_N_STEPS,
            "optimizer": "Adam",
            "lr": BIG_GSET_ADAM_LR,
            "runtime_sec": graph_runtime,
        }
    )

    selected_partition_best_spins[graph] = best_spins

    print("\nFINISHED GRAPH:", graph)
    print("Best cut:", best_cut)
    print("Best-known:", best_known_cut)
    print("Gap:", best_known_cut - best_cut)
    print("Accuracy %:", 100.0 * best_cut / best_known_cut)
    print("Runtime sec:", graph_runtime)


selected_partition_history_df = pd.DataFrame(selected_partition_history_rows)
selected_partition_summary_df = pd.DataFrame(selected_partition_summary_rows)

print("\n" + "=" * 80)
print("SELECTED PARTITION SUMMARY")
print("=" * 80)

display(selected_partition_summary_df)
# Out:
# ================================================================================
# RUNNING SELECTED BIG-GSET PARTITION
# ================================================================================
# Partition: 11
# Graphs: ['G57']
# Replicas: 128
# Steps: 1000
# Optimizer: Adam
# Adam lr: 0.01
#
# ================================================================================
# START GRAPH: G57
# ================================================================================
# N: 5000
# M: 10000
# Best-known cut: 3494.0
# G57 | step     1/1000 | cut=      74.0 | best=      74.0 | gap=    3420.0 | acc=  2.118% | |rz|=0.0001 | time=    0.07s
# G57 | step    50/1000 | cut=     132.0 | best=     132.0 | gap=    3362.0 | acc=  3.778% | |rz|=0.0000 | time=    0.60s
# G57 | step   100/1000 | cut=    -130.0 | best=     132.0 | gap=    3362.0 | acc=  3.778% | |rz|=0.0000 | time=    1.11s
# G57 | step   150/1000 | cut=    -644.0 | best=     132.0 | gap=    3362.0 | acc=  3.778% | |rz|=0.0000 | time=    1.65s
# G57 | step   200/1000 | cut=    -856.0 | best=     132.0 | gap=    3362.0 | acc=  3.778% | |rz|=0.0001 | time=    2.17s
# G57 | step   250/1000 | cut=   -1618.0 | best=     132.0 | gap=    3362.0 | acc=  3.778% | |rz|=0.0002 | time=    2.70s
# G57 | step   300/1000 | cut=     276.0 | best=     276.0 | gap=    3218.0 | acc=  7.899% | |rz|=0.0006 | time=    3.22s
# G57 | step   350/1000 | cut=    3418.0 | best=    3418.0 | gap=      76.0 | acc= 97.825% | |rz|=0.3935 | time=    3.74s
# G57 | step   400/1000 | cut=    3424.0 | best=    3424.0 | gap=      70.0 | acc= 97.997% | |rz|=0.5784 | time=    4.28s
# G57 | step   450/1000 | cut=    3424.0 | best=    3424.0 | gap=      70.0 | acc= 97.997% | |rz|=0.6804 | time=    4.82s
# G57 | step   500/1000 | cut=    3428.0 | best=    3428.0 | gap=      66.0 | acc= 98.111% | |rz|=0.7411 | time=    5.40s
# G57 | step   550/1000 | cut=    3428.0 | best=    3428.0 | gap=      66.0 | acc= 98.111% | |rz|=0.7822 | time=    5.96s
# G57 | step   600/1000 | cut=    3428.0 | best=    3428.0 | gap=      66.0 | acc= 98.111% | |rz|=0.8128 | time=    6.50s
# G57 | step   650/1000 | cut=    3428.0 | best=    3428.0 | gap=      66.0 | acc= 98.111% | |rz|=0.8370 | time=    7.05s
# G57 | step   700/1000 | cut=    3428.0 | best=    3428.0 | gap=      66.0 | acc= 98.111% | |rz|=0.8568 | time=    7.55s
# G57 | step   750/1000 | cut=    3428.0 | best=    3428.0 | gap=      66.0 | acc= 98.111% | |rz|=0.8733 | time=    8.19s
# G57 | step   800/1000 | cut=    3428.0 | best=    3428.0 | gap=      66.0 | acc= 98.111% | |rz|=0.8872 | time=    8.81s
# G57 | step   850/1000 | cut=    3428.0 | best=    3428.0 | gap=      66.0 | acc= 98.111% | |rz|=0.8989 | time=    9.42s
# G57 | step   900/1000 | cut=    3428.0 | best=    3428.0 | gap=      66.0 | acc= 98.111% | |rz|=0.9090 | time=   10.05s
# G57 | step   950/1000 | cut=    3428.0 | best=    3428.0 | gap=      66.0 | acc= 98.111% | |rz|=0.9191 | time=   10.65s
# G57 | step  1000/1000 | cut=    3428.0 | best=    3428.0 | gap=      66.0 | acc= 98.111% | |rz|=0.9396 | time=   11.20s
#
# FINISHED GRAPH: G57
# Best cut: 3428.0
# Best-known: 3494.0
# Gap: 66.0
# Accuracy %: 98.11104751001717
# Runtime sec: 11.204553127288818
#
# ================================================================================
# SELECTED PARTITION SUMMARY
# ================================================================================
#    partition graph     N      M  best_known_cut  qefem_best_cut   gap  \
# 0         11   G57  5000  10000          3494.0          3428.0  66.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         98.111048        500            10       128   1000      Adam  0.01
#
#    runtime_sec
# 0    11.204553

# %%
assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "selected_partition_history_df" in globals(), (
    "Run Cell 37 first: selected_partition_history_df is missing."
)

assert "selected_partition_summary_df" in globals(), (
    "Run Cell 37 first: selected_partition_summary_df is missing."
)

assert "selected_partition_best_spins" in globals(), (
    "Run Cell 37 first: selected_partition_best_spins is missing."
)


# ------------------------------------------------------------
# Output folder
# ------------------------------------------------------------

BIG_GSET_OUTPUT_DIR = Path("qefem_big_gset_outputs")
BIG_GSET_OUTPUT_DIR.mkdir(exist_ok=True)


# ------------------------------------------------------------
# File names
# ------------------------------------------------------------

partition_tag = f"partition_{SELECTED_BIG_GSET_PARTITION}"

history_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_history.csv"
summary_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_summary.csv"
spins_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_best_spins.pt"


# ------------------------------------------------------------
# Save CSV files
# ------------------------------------------------------------

selected_partition_history_df.to_csv(
    history_path,
    index=False,
)

selected_partition_summary_df.to_csv(
    summary_path,
    index=False,
)


# ------------------------------------------------------------
# Save best spins dictionary
# ------------------------------------------------------------

torch.save(
    selected_partition_best_spins,
    spins_path,
)


# ------------------------------------------------------------
# Print saved paths
# ------------------------------------------------------------

print("=" * 80)
print("SAVED SELECTED PARTITION RESULTS")
print("=" * 80)

print("Partition:", SELECTED_BIG_GSET_PARTITION)

print("\nSaved history CSV:")
print(history_path.resolve())

print("\nSaved summary CSV:")
print(summary_path.resolve())

print("\nSaved best spins PT:")
print(spins_path.resolve())


# ------------------------------------------------------------
# Display final summary
# ------------------------------------------------------------

print("\nFinal selected-partition summary:")
display(selected_partition_summary_df)


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert history_path.exists(), (
    f"History file was not saved: {history_path}"
)

assert summary_path.exists(), (
    f"Summary file was not saved: {summary_path}"
)

assert spins_path.exists(), (
    f"Best-spins file was not saved: {spins_path}"
)

assert len(selected_partition_summary_df) > 0, (
    "Summary dataframe is empty."
)

assert len(selected_partition_history_df) > 0, (
    "History dataframe is empty."
)
# Out:
# ================================================================================
# SAVED SELECTED PARTITION RESULTS
# ================================================================================
# Partition: 11
#
# Saved history CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_11_history.csv
#
# Saved summary CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_11_summary.csv
#
# Saved best spins PT:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_11_best_spins.pt
#
# Final selected-partition summary:
#    partition graph     N      M  best_known_cut  qefem_best_cut   gap  \
# 0         11   G57  5000  10000          3494.0          3428.0  66.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         98.111048        500            10       128   1000      Adam  0.01
#
#    runtime_sec
# 0    11.204553

# %%
assert "BIG_GSET_PARTITIONS" in globals(), (
    "Run Cell 25 first: BIG_GSET_PARTITIONS is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


# ------------------------------------------------------------
# Change this after each completed partition
# ------------------------------------------------------------

SELECTED_BIG_GSET_PARTITION = 12


# ------------------------------------------------------------
# Select graphs in this partition
# ------------------------------------------------------------

assert SELECTED_BIG_GSET_PARTITION in BIG_GSET_PARTITIONS, (
    f"Partition {SELECTED_BIG_GSET_PARTITION} is not defined."
)

selected_big_gset_graphs = BIG_GSET_PARTITIONS[SELECTED_BIG_GSET_PARTITION]


print("=" * 80)
print("NEXT BIG-GSET PARTITION SELECTED")
print("=" * 80)

print(
    f"Partition {SELECTED_BIG_GSET_PARTITION}: "
    f"{selected_big_gset_graphs[0]}-{selected_big_gset_graphs[-1]} | "
    f"{len(selected_big_gset_graphs)} graphs | "
    f"{selected_big_gset_graphs}"
)


# ------------------------------------------------------------
# Quick file check
# ------------------------------------------------------------

missing_graphs = []

for graph in selected_big_gset_graphs:
    path = GSET_DIR / graph

    print(f"{graph}: {path.exists()} | {path}")

    if not path.exists():
        missing_graphs.append(graph)

assert len(missing_graphs) == 0, (
    f"Missing graph files: {missing_graphs}"
)


# ------------------------------------------------------------
# Benchmark preview for this partition
# ------------------------------------------------------------

selected_partition_benchmark_df = big_gset_benchmark_df[
    big_gset_benchmark_df["partition"] == SELECTED_BIG_GSET_PARTITION
].copy()

display(selected_partition_benchmark_df)

assert len(selected_partition_benchmark_df) == len(selected_big_gset_graphs), (
    "Benchmark table row count does not match selected partition graph count."
)

assert "selected_big_gset_graphs" in globals(), (
    "Run Cell 32 first: selected_big_gset_graphs is missing."
)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "load_gset_edge_list" in globals(), (
    "Run Cell 26 first: load_gset_edge_list is missing."
)

assert "edge_qefem_free_energy" in globals(), (
    "Run Cell 30 first: edge_qefem_free_energy is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)

assert "big_gset_beta_schedule" in globals(), (
    "Run Cell 31 first: big_gset_beta_schedule is missing."
)

assert "big_gset_gamma_schedule" in globals(), (
    "Run Cell 31 first: big_gset_gamma_schedule is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


selected_partition_history_rows = []
selected_partition_summary_rows = []
selected_partition_best_spins = {}


print("=" * 80)
print("RUNNING SELECTED BIG-GSET PARTITION")
print("=" * 80)
print("Partition:", SELECTED_BIG_GSET_PARTITION)
print("Graphs:", selected_big_gset_graphs)
print("Replicas:", BIG_GSET_REPLICAS)
print("Steps:", BIG_GSET_N_STEPS)
print("Optimizer: Adam")
print("Adam lr:", BIG_GSET_ADAM_LR)


for graph in selected_big_gset_graphs:
    print("\n" + "=" * 80)
    print("START GRAPH:", graph)
    print("=" * 80)

    N_g, edge_i, edge_j, edge_w, info = load_gset_edge_list(graph)

    graph_benchmark_row = big_gset_benchmark_df[
        big_gset_benchmark_df["graph"] == graph
    ].iloc[0]

    best_known_cut = float(graph_benchmark_row["best_known_cut"])

    print("N:", N_g)
    print("M:", info["M"])
    print("Best-known cut:", best_known_cut)

    torch.manual_seed(BIG_GSET_SEED)

    R_INIT_tensor = torch.tensor(
        R_INIT,
        device=device,
        dtype=DTYPE,
    )

    raw_R_init_value = torch.log(
        R_INIT_tensor / (1.0 - R_INIT_tensor)
    )

    raw_R = raw_R_init_value + 1e-3 * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    theta = THETA_CENTER + THETA_NOISE * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    raw_R.requires_grad_(True)
    theta.requires_grad_(True)

    optimizer = torch.optim.Adam(
        [raw_R, theta],
        lr=BIG_GSET_ADAM_LR,
    )

    best_cut = -float("inf")
    best_step = None
    best_replica = None
    best_spins = None

    graph_start_time = time.time()

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    for step in range(BIG_GSET_N_STEPS):
        beta_t = big_gset_beta_schedule[step]
        gamma_t = big_gset_gamma_schedule[step]

        optimizer.zero_grad()

        F, aux = edge_qefem_free_energy(
            edge_i=edge_i,
            edge_j=edge_j,
            edge_w=edge_w,
            raw_R=raw_R,
            theta=theta,
            beta=beta_t,
            gamma=gamma_t,
        )

        loss = F.mean()

        loss.backward()
        optimizer.step()

        should_log = (
            step == 0
            or step == BIG_GSET_N_STEPS - 1
            or (step + 1) % BIG_GSET_LOG_EVERY == 0
        )

        if should_log:
            if edge_w.device.type == "mps":
                torch.mps.synchronize()

            elapsed = time.time() - graph_start_time

            with torch.no_grad():
                R_now, rx_now, rz_now = bloch_from_raw(
                    raw_R,
                    theta,
                )

                spins_now = torch.where(
                    rz_now >= 0,
                    torch.ones_like(rz_now),
                    -torch.ones_like(rz_now),
                )

                hard_cuts_now = edge_discrete_cut(
                    edge_i=edge_i,
                    edge_j=edge_j,
                    edge_w=edge_w,
                    spins=spins_now,
                )

                current_best_cut_tensor, current_best_replica_tensor = torch.max(
                    hard_cuts_now,
                    dim=0,
                )

                current_best_cut = float(current_best_cut_tensor.detach().cpu())
                current_best_replica = int(current_best_replica_tensor.detach().cpu())

                if current_best_cut > best_cut:
                    best_cut = current_best_cut
                    best_step = step + 1
                    best_replica = current_best_replica
                    best_spins = spins_now[current_best_replica].detach().cpu().clone()

                gap = best_known_cut - best_cut
                accuracy_percent = 100.0 * best_cut / best_known_cut

                selected_partition_history_rows.append(
                    {
                        "partition": SELECTED_BIG_GSET_PARTITION,
                        "graph": graph,
                        "step": step + 1,
                        "beta": float(beta_t.detach().cpu()),
                        "gamma": float(gamma_t.detach().cpu()),
                        "loss": float(loss.detach().cpu()),
                        "free_energy_mean": float(F.mean().detach().cpu()),
                        "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
                        "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),
                        "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
                        "hard_cut_max": current_best_cut,
                        "best_cut_so_far": best_cut,
                        "best_known_cut": best_known_cut,
                        "gap": gap,
                        "accuracy_percent": accuracy_percent,
                        "R_mean": float(R_now.mean().detach().cpu()),
                        "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),
                        "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),
                        "best_replica_so_far": best_replica,
                        "elapsed_sec": elapsed,
                    }
                )

                print(
                    f"{graph} | "
                    f"step {step + 1:5d}/{BIG_GSET_N_STEPS} | "
                    f"cut={current_best_cut:10.1f} | "
                    f"best={best_cut:10.1f} | "
                    f"gap={gap:10.1f} | "
                    f"acc={accuracy_percent:7.3f}% | "
                    f"|rz|={float(rz_now.abs().mean().detach().cpu()):.4f} | "
                    f"time={elapsed:8.2f}s"
                )

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    graph_runtime = time.time() - graph_start_time

    selected_partition_summary_rows.append(
        {
            "partition": SELECTED_BIG_GSET_PARTITION,
            "graph": graph,
            "N": N_g,
            "M": info["M"],
            "best_known_cut": best_known_cut,
            "qefem_best_cut": best_cut,
            "gap": best_known_cut - best_cut,
            "accuracy_percent": 100.0 * best_cut / best_known_cut,
            "best_step": best_step,
            "best_replica": best_replica,
            "replicas": BIG_GSET_REPLICAS,
            "steps": BIG_GSET_N_STEPS,
            "optimizer": "Adam",
            "lr": BIG_GSET_ADAM_LR,
            "runtime_sec": graph_runtime,
        }
    )

    selected_partition_best_spins[graph] = best_spins

    print("\nFINISHED GRAPH:", graph)
    print("Best cut:", best_cut)
    print("Best-known:", best_known_cut)
    print("Gap:", best_known_cut - best_cut)
    print("Accuracy %:", 100.0 * best_cut / best_known_cut)
    print("Runtime sec:", graph_runtime)


selected_partition_history_df = pd.DataFrame(selected_partition_history_rows)
selected_partition_summary_df = pd.DataFrame(selected_partition_summary_rows)

print("\n" + "=" * 80)
print("SELECTED PARTITION SUMMARY")
print("=" * 80)

display(selected_partition_summary_df)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "selected_partition_history_df" in globals(), (
    "Run Cell 37 first: selected_partition_history_df is missing."
)

assert "selected_partition_summary_df" in globals(), (
    "Run Cell 37 first: selected_partition_summary_df is missing."
)

assert "selected_partition_best_spins" in globals(), (
    "Run Cell 37 first: selected_partition_best_spins is missing."
)


# ------------------------------------------------------------
# Output folder
# ------------------------------------------------------------

BIG_GSET_OUTPUT_DIR = Path("qefem_big_gset_outputs")
BIG_GSET_OUTPUT_DIR.mkdir(exist_ok=True)


# ------------------------------------------------------------
# File names
# ------------------------------------------------------------

partition_tag = f"partition_{SELECTED_BIG_GSET_PARTITION}"

history_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_history.csv"
summary_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_summary.csv"
spins_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_best_spins.pt"


# ------------------------------------------------------------
# Save CSV files
# ------------------------------------------------------------

selected_partition_history_df.to_csv(
    history_path,
    index=False,
)

selected_partition_summary_df.to_csv(
    summary_path,
    index=False,
)


# ------------------------------------------------------------
# Save best spins dictionary
# ------------------------------------------------------------

torch.save(
    selected_partition_best_spins,
    spins_path,
)


# ------------------------------------------------------------
# Print saved paths
# ------------------------------------------------------------

print("=" * 80)
print("SAVED SELECTED PARTITION RESULTS")
print("=" * 80)

print("Partition:", SELECTED_BIG_GSET_PARTITION)

print("\nSaved history CSV:")
print(history_path.resolve())

print("\nSaved summary CSV:")
print(summary_path.resolve())

print("\nSaved best spins PT:")
print(spins_path.resolve())


# ------------------------------------------------------------
# Display final summary
# ------------------------------------------------------------

print("\nFinal selected-partition summary:")
display(selected_partition_summary_df)


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert history_path.exists(), (
    f"History file was not saved: {history_path}"
)

assert summary_path.exists(), (
    f"Summary file was not saved: {summary_path}"
)

assert spins_path.exists(), (
    f"Best-spins file was not saved: {spins_path}"
)

assert len(selected_partition_summary_df) > 0, (
    "Summary dataframe is empty."
)

assert len(selected_partition_history_df) > 0, (
    "History dataframe is empty."
)
# Out:
# ================================================================================
# NEXT BIG-GSET PARTITION SELECTED
# ================================================================================
# Partition 12: G58-G59 | 2 graphs | ['G58', 'G59']
# G58: True | ../data-gset/G58
# G59: True | ../data-gset/G59
#    partition graph     N      M  density_upper_percent  positive_edges  \
# 3         12   G58  5000  29570               0.236607           29570
# 4         12   G59  5000  29570               0.236607           14833
#
#    negative_edges  positive_edge_fraction  negative_edge_fraction  weight_sum  \
# 3               0                1.000000                0.000000     29570.0
# 4           14737                0.501623                0.498377        96.0
#
#    best_known_cut  best_known_cut_per_edge  dense_W_float32_MB device  \
# 3         19293.0                 0.652452           95.367432  mps:0
# 4          6086.0                 0.205817           95.367432  mps:0
#
#            dtype
# 3  torch.float32
# 4  torch.float32
# ================================================================================
# RUNNING SELECTED BIG-GSET PARTITION
# ================================================================================
# Partition: 12
# Graphs: ['G58', 'G59']
# Replicas: 128
# Steps: 1000
# Optimizer: Adam
# Adam lr: 0.01
#
# ================================================================================
# START GRAPH: G58
# ================================================================================
# N: 5000
# M: 29570
# Best-known cut: 19293.0
# G58 | step     1/1000 | cut=   14914.0 | best=   14914.0 | gap=    4379.0 | acc= 77.303% | |rz|=0.0001 | time=    0.10s
# G58 | step    50/1000 | cut=   15040.0 | best=   15040.0 | gap=    4253.0 | acc= 77.956% | |rz|=0.0000 | time=    1.06s
# G58 | step   100/1000 | cut=   14897.0 | best=   15040.0 | gap=    4253.0 | acc= 77.956% | |rz|=0.0000 | time=    1.97s
# G58 | step   150/1000 | cut=   13040.0 | best=   15040.0 | gap=    4253.0 | acc= 77.956% | |rz|=0.0000 | time=    2.88s
# G58 | step   200/1000 | cut=   16474.0 | best=   16474.0 | gap=    2819.0 | acc= 85.388% | |rz|=0.0002 | time=    3.79s
# G58 | step   250/1000 | cut=   17877.0 | best=   17877.0 | gap=    1416.0 | acc= 92.661% | |rz|=0.0648 | time=    4.70s
# G58 | step   300/1000 | cut=   18698.0 | best=   18698.0 | gap=     595.0 | acc= 96.916% | |rz|=0.2796 | time=    5.60s
# G58 | step   350/1000 | cut=   18922.0 | best=   18922.0 | gap=     371.0 | acc= 98.077% | |rz|=0.4846 | time=    6.51s
# G58 | step   400/1000 | cut=   19004.0 | best=   19004.0 | gap=     289.0 | acc= 98.502% | |rz|=0.6087 | time=    7.42s
# G58 | step   450/1000 | cut=   19033.0 | best=   19033.0 | gap=     260.0 | acc= 98.652% | |rz|=0.6833 | time=    8.38s
# G58 | step   500/1000 | cut=   19046.0 | best=   19046.0 | gap=     247.0 | acc= 98.720% | |rz|=0.7342 | time=    9.37s
# G58 | step   550/1000 | cut=   19052.0 | best=   19052.0 | gap=     241.0 | acc= 98.751% | |rz|=0.7730 | time=   10.31s
# G58 | step   600/1000 | cut=   19057.0 | best=   19057.0 | gap=     236.0 | acc= 98.777% | |rz|=0.8045 | time=   11.20s
# G58 | step   650/1000 | cut=   19059.0 | best=   19059.0 | gap=     234.0 | acc= 98.787% | |rz|=0.8310 | time=   12.11s
# G58 | step   700/1000 | cut=   19059.0 | best=   19059.0 | gap=     234.0 | acc= 98.787% | |rz|=0.8536 | time=   13.02s
# G58 | step   750/1000 | cut=   19059.0 | best=   19059.0 | gap=     234.0 | acc= 98.787% | |rz|=0.8729 | time=   13.93s
# G58 | step   800/1000 | cut=   19061.0 | best=   19061.0 | gap=     232.0 | acc= 98.797% | |rz|=0.8895 | time=   14.84s
# G58 | step   850/1000 | cut=   19061.0 | best=   19061.0 | gap=     232.0 | acc= 98.797% | |rz|=0.9035 | time=   15.75s
# G58 | step   900/1000 | cut=   19061.0 | best=   19061.0 | gap=     232.0 | acc= 98.797% | |rz|=0.9152 | time=   16.66s
# G58 | step   950/1000 | cut=   19061.0 | best=   19061.0 | gap=     232.0 | acc= 98.797% | |rz|=0.9262 | time=   17.64s
# G58 | step  1000/1000 | cut=   19061.0 | best=   19061.0 | gap=     232.0 | acc= 98.797% | |rz|=0.9505 | time=   18.57s
#
# FINISHED GRAPH: G58
# Best cut: 19061.0
# Best-known: 19293.0
# Gap: 232.0
# Accuracy %: 98.79749131809464
# Runtime sec: 18.577525854110718
#
# ================================================================================
# START GRAPH: G59
# ================================================================================
# N: 5000
# M: 29570
# Best-known cut: 6086.0
# G59 | step     1/1000 | cut=     141.0 | best=     141.0 | gap=    5945.0 | acc=  2.317% | |rz|=0.0001 | time=    0.02s
# G59 | step    50/1000 | cut=     287.0 | best=     287.0 | gap=    5799.0 | acc=  4.716% | |rz|=0.0000 | time=    0.87s
# G59 | step   100/1000 | cut=      77.0 | best=     287.0 | gap=    5799.0 | acc=  4.716% | |rz|=0.0000 | time=    1.82s
# G59 | step   150/1000 | cut=   -2451.0 | best=     287.0 | gap=    5799.0 | acc=  4.716% | |rz|=0.0000 | time=    2.83s
# G59 | step   200/1000 | cut=    3973.0 | best=    3973.0 | gap=    2113.0 | acc= 65.281% | |rz|=0.0048 | time=    3.78s
# G59 | step   250/1000 | cut=    5321.0 | best=    5321.0 | gap=     765.0 | acc= 87.430% | |rz|=0.1280 | time=    4.67s
# G59 | step   300/1000 | cut=    5699.0 | best=    5699.0 | gap=     387.0 | acc= 93.641% | |rz|=0.3854 | time=    5.58s
# G59 | step   350/1000 | cut=    5798.0 | best=    5798.0 | gap=     288.0 | acc= 95.268% | |rz|=0.5880 | time=    6.49s
# G59 | step   400/1000 | cut=    5830.0 | best=    5830.0 | gap=     256.0 | acc= 95.794% | |rz|=0.6943 | time=    7.45s
# G59 | step   450/1000 | cut=    5841.0 | best=    5841.0 | gap=     245.0 | acc= 95.974% | |rz|=0.7531 | time=    8.53s
# G59 | step   500/1000 | cut=    5846.0 | best=    5846.0 | gap=     240.0 | acc= 96.057% | |rz|=0.7912 | time=    9.48s
# G59 | step   550/1000 | cut=    5850.0 | best=    5850.0 | gap=     236.0 | acc= 96.122% | |rz|=0.8196 | time=   10.51s
# G59 | step   600/1000 | cut=    5853.0 | best=    5853.0 | gap=     233.0 | acc= 96.172% | |rz|=0.8425 | time=   11.53s
# G59 | step   650/1000 | cut=    5853.0 | best=    5853.0 | gap=     233.0 | acc= 96.172% | |rz|=0.8619 | time=   12.44s
# G59 | step   700/1000 | cut=    5854.0 | best=    5854.0 | gap=     232.0 | acc= 96.188% | |rz|=0.8784 | time=   13.53s
# G59 | step   750/1000 | cut=    5854.0 | best=    5854.0 | gap=     232.0 | acc= 96.188% | |rz|=0.8926 | time=   14.48s
# G59 | step   800/1000 | cut=    5854.0 | best=    5854.0 | gap=     232.0 | acc= 96.188% | |rz|=0.9048 | time=   15.52s
# G59 | step   850/1000 | cut=    5854.0 | best=    5854.0 | gap=     232.0 | acc= 96.188% | |rz|=0.9151 | time=   16.60s
# G59 | step   900/1000 | cut=    5854.0 | best=    5854.0 | gap=     232.0 | acc= 96.188% | |rz|=0.9238 | time=   17.66s
# G59 | step   950/1000 | cut=    5854.0 | best=    5854.0 | gap=     232.0 | acc= 96.188% | |rz|=0.9319 | time=   18.70s
# G59 | step  1000/1000 | cut=    5854.0 | best=    5854.0 | gap=     232.0 | acc= 96.188% | |rz|=0.9522 | time=   19.76s
#
# FINISHED GRAPH: G59
# Best cut: 5854.0
# Best-known: 6086.0
# Gap: 232.0
# Accuracy %: 96.18797239566217
# Runtime sec: 19.772762060165405
#
# ================================================================================
# SELECTED PARTITION SUMMARY
# ================================================================================
#    partition graph     N      M  best_known_cut  qefem_best_cut    gap  \
# 0         12   G58  5000  29570         19293.0         19061.0  232.0
# 1         12   G59  5000  29570          6086.0          5854.0  232.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         98.797491        800            56       128   1000      Adam  0.01
# 1         96.187972        700           122       128   1000      Adam  0.01
#
#    runtime_sec
# 0    18.577526
# 1    19.772762
# ================================================================================
# SAVED SELECTED PARTITION RESULTS
# ================================================================================
# Partition: 12
#
# Saved history CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_12_history.csv
#
# Saved summary CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_12_summary.csv
#
# Saved best spins PT:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_12_best_spins.pt
#
# Final selected-partition summary:
#    partition graph     N      M  best_known_cut  qefem_best_cut    gap  \
# 0         12   G58  5000  29570         19293.0         19061.0  232.0
# 1         12   G59  5000  29570          6086.0          5854.0  232.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         98.797491        800            56       128   1000      Adam  0.01
# 1         96.187972        700           122       128   1000      Adam  0.01
#
#    runtime_sec
# 0    18.577526
# 1    19.772762

# %%
assert "BIG_GSET_PARTITIONS" in globals(), (
    "Run Cell 25 first: BIG_GSET_PARTITIONS is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


# ------------------------------------------------------------
# Change this after each completed partition
# ------------------------------------------------------------

SELECTED_BIG_GSET_PARTITION = 13


# ------------------------------------------------------------
# Select graphs in this partition
# ------------------------------------------------------------

assert SELECTED_BIG_GSET_PARTITION in BIG_GSET_PARTITIONS, (
    f"Partition {SELECTED_BIG_GSET_PARTITION} is not defined."
)

selected_big_gset_graphs = BIG_GSET_PARTITIONS[SELECTED_BIG_GSET_PARTITION]


print("=" * 80)
print("NEXT BIG-GSET PARTITION SELECTED")
print("=" * 80)

print(
    f"Partition {SELECTED_BIG_GSET_PARTITION}: "
    f"{selected_big_gset_graphs[0]}-{selected_big_gset_graphs[-1]} | "
    f"{len(selected_big_gset_graphs)} graphs | "
    f"{selected_big_gset_graphs}"
)


# ------------------------------------------------------------
# Quick file check
# ------------------------------------------------------------

missing_graphs = []

for graph in selected_big_gset_graphs:
    path = GSET_DIR / graph

    print(f"{graph}: {path.exists()} | {path}")

    if not path.exists():
        missing_graphs.append(graph)

assert len(missing_graphs) == 0, (
    f"Missing graph files: {missing_graphs}"
)


# ------------------------------------------------------------
# Benchmark preview for this partition
# ------------------------------------------------------------

selected_partition_benchmark_df = big_gset_benchmark_df[
    big_gset_benchmark_df["partition"] == SELECTED_BIG_GSET_PARTITION
].copy()

display(selected_partition_benchmark_df)

assert len(selected_partition_benchmark_df) == len(selected_big_gset_graphs), (
    "Benchmark table row count does not match selected partition graph count."
)

assert "selected_big_gset_graphs" in globals(), (
    "Run Cell 32 first: selected_big_gset_graphs is missing."
)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "load_gset_edge_list" in globals(), (
    "Run Cell 26 first: load_gset_edge_list is missing."
)

assert "edge_qefem_free_energy" in globals(), (
    "Run Cell 30 first: edge_qefem_free_energy is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)

assert "big_gset_beta_schedule" in globals(), (
    "Run Cell 31 first: big_gset_beta_schedule is missing."
)

assert "big_gset_gamma_schedule" in globals(), (
    "Run Cell 31 first: big_gset_gamma_schedule is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


selected_partition_history_rows = []
selected_partition_summary_rows = []
selected_partition_best_spins = {}


print("=" * 80)
print("RUNNING SELECTED BIG-GSET PARTITION")
print("=" * 80)
print("Partition:", SELECTED_BIG_GSET_PARTITION)
print("Graphs:", selected_big_gset_graphs)
print("Replicas:", BIG_GSET_REPLICAS)
print("Steps:", BIG_GSET_N_STEPS)
print("Optimizer: Adam")
print("Adam lr:", BIG_GSET_ADAM_LR)


for graph in selected_big_gset_graphs:
    print("\n" + "=" * 80)
    print("START GRAPH:", graph)
    print("=" * 80)

    N_g, edge_i, edge_j, edge_w, info = load_gset_edge_list(graph)

    graph_benchmark_row = big_gset_benchmark_df[
        big_gset_benchmark_df["graph"] == graph
    ].iloc[0]

    best_known_cut = float(graph_benchmark_row["best_known_cut"])

    print("N:", N_g)
    print("M:", info["M"])
    print("Best-known cut:", best_known_cut)

    torch.manual_seed(BIG_GSET_SEED)

    R_INIT_tensor = torch.tensor(
        R_INIT,
        device=device,
        dtype=DTYPE,
    )

    raw_R_init_value = torch.log(
        R_INIT_tensor / (1.0 - R_INIT_tensor)
    )

    raw_R = raw_R_init_value + 1e-3 * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    theta = THETA_CENTER + THETA_NOISE * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    raw_R.requires_grad_(True)
    theta.requires_grad_(True)

    optimizer = torch.optim.Adam(
        [raw_R, theta],
        lr=BIG_GSET_ADAM_LR,
    )

    best_cut = -float("inf")
    best_step = None
    best_replica = None
    best_spins = None

    graph_start_time = time.time()

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    for step in range(BIG_GSET_N_STEPS):
        beta_t = big_gset_beta_schedule[step]
        gamma_t = big_gset_gamma_schedule[step]

        optimizer.zero_grad()

        F, aux = edge_qefem_free_energy(
            edge_i=edge_i,
            edge_j=edge_j,
            edge_w=edge_w,
            raw_R=raw_R,
            theta=theta,
            beta=beta_t,
            gamma=gamma_t,
        )

        loss = F.mean()

        loss.backward()
        optimizer.step()

        should_log = (
            step == 0
            or step == BIG_GSET_N_STEPS - 1
            or (step + 1) % BIG_GSET_LOG_EVERY == 0
        )

        if should_log:
            if edge_w.device.type == "mps":
                torch.mps.synchronize()

            elapsed = time.time() - graph_start_time

            with torch.no_grad():
                R_now, rx_now, rz_now = bloch_from_raw(
                    raw_R,
                    theta,
                )

                spins_now = torch.where(
                    rz_now >= 0,
                    torch.ones_like(rz_now),
                    -torch.ones_like(rz_now),
                )

                hard_cuts_now = edge_discrete_cut(
                    edge_i=edge_i,
                    edge_j=edge_j,
                    edge_w=edge_w,
                    spins=spins_now,
                )

                current_best_cut_tensor, current_best_replica_tensor = torch.max(
                    hard_cuts_now,
                    dim=0,
                )

                current_best_cut = float(current_best_cut_tensor.detach().cpu())
                current_best_replica = int(current_best_replica_tensor.detach().cpu())

                if current_best_cut > best_cut:
                    best_cut = current_best_cut
                    best_step = step + 1
                    best_replica = current_best_replica
                    best_spins = spins_now[current_best_replica].detach().cpu().clone()

                gap = best_known_cut - best_cut
                accuracy_percent = 100.0 * best_cut / best_known_cut

                selected_partition_history_rows.append(
                    {
                        "partition": SELECTED_BIG_GSET_PARTITION,
                        "graph": graph,
                        "step": step + 1,
                        "beta": float(beta_t.detach().cpu()),
                        "gamma": float(gamma_t.detach().cpu()),
                        "loss": float(loss.detach().cpu()),
                        "free_energy_mean": float(F.mean().detach().cpu()),
                        "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
                        "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),
                        "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
                        "hard_cut_max": current_best_cut,
                        "best_cut_so_far": best_cut,
                        "best_known_cut": best_known_cut,
                        "gap": gap,
                        "accuracy_percent": accuracy_percent,
                        "R_mean": float(R_now.mean().detach().cpu()),
                        "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),
                        "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),
                        "best_replica_so_far": best_replica,
                        "elapsed_sec": elapsed,
                    }
                )

                print(
                    f"{graph} | "
                    f"step {step + 1:5d}/{BIG_GSET_N_STEPS} | "
                    f"cut={current_best_cut:10.1f} | "
                    f"best={best_cut:10.1f} | "
                    f"gap={gap:10.1f} | "
                    f"acc={accuracy_percent:7.3f}% | "
                    f"|rz|={float(rz_now.abs().mean().detach().cpu()):.4f} | "
                    f"time={elapsed:8.2f}s"
                )

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    graph_runtime = time.time() - graph_start_time

    selected_partition_summary_rows.append(
        {
            "partition": SELECTED_BIG_GSET_PARTITION,
            "graph": graph,
            "N": N_g,
            "M": info["M"],
            "best_known_cut": best_known_cut,
            "qefem_best_cut": best_cut,
            "gap": best_known_cut - best_cut,
            "accuracy_percent": 100.0 * best_cut / best_known_cut,
            "best_step": best_step,
            "best_replica": best_replica,
            "replicas": BIG_GSET_REPLICAS,
            "steps": BIG_GSET_N_STEPS,
            "optimizer": "Adam",
            "lr": BIG_GSET_ADAM_LR,
            "runtime_sec": graph_runtime,
        }
    )

    selected_partition_best_spins[graph] = best_spins

    print("\nFINISHED GRAPH:", graph)
    print("Best cut:", best_cut)
    print("Best-known:", best_known_cut)
    print("Gap:", best_known_cut - best_cut)
    print("Accuracy %:", 100.0 * best_cut / best_known_cut)
    print("Runtime sec:", graph_runtime)


selected_partition_history_df = pd.DataFrame(selected_partition_history_rows)
selected_partition_summary_df = pd.DataFrame(selected_partition_summary_rows)

print("\n" + "=" * 80)
print("SELECTED PARTITION SUMMARY")
print("=" * 80)

display(selected_partition_summary_df)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "selected_partition_history_df" in globals(), (
    "Run Cell 37 first: selected_partition_history_df is missing."
)

assert "selected_partition_summary_df" in globals(), (
    "Run Cell 37 first: selected_partition_summary_df is missing."
)

assert "selected_partition_best_spins" in globals(), (
    "Run Cell 37 first: selected_partition_best_spins is missing."
)


# ------------------------------------------------------------
# Output folder
# ------------------------------------------------------------

BIG_GSET_OUTPUT_DIR = Path("qefem_big_gset_outputs")
BIG_GSET_OUTPUT_DIR.mkdir(exist_ok=True)


# ------------------------------------------------------------
# File names
# ------------------------------------------------------------

partition_tag = f"partition_{SELECTED_BIG_GSET_PARTITION}"

history_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_history.csv"
summary_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_summary.csv"
spins_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_best_spins.pt"


# ------------------------------------------------------------
# Save CSV files
# ------------------------------------------------------------

selected_partition_history_df.to_csv(
    history_path,
    index=False,
)

selected_partition_summary_df.to_csv(
    summary_path,
    index=False,
)


# ------------------------------------------------------------
# Save best spins dictionary
# ------------------------------------------------------------

torch.save(
    selected_partition_best_spins,
    spins_path,
)


# ------------------------------------------------------------
# Print saved paths
# ------------------------------------------------------------

print("=" * 80)
print("SAVED SELECTED PARTITION RESULTS")
print("=" * 80)

print("Partition:", SELECTED_BIG_GSET_PARTITION)

print("\nSaved history CSV:")
print(history_path.resolve())

print("\nSaved summary CSV:")
print(summary_path.resolve())

print("\nSaved best spins PT:")
print(spins_path.resolve())


# ------------------------------------------------------------
# Display final summary
# ------------------------------------------------------------

print("\nFinal selected-partition summary:")
display(selected_partition_summary_df)


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert history_path.exists(), (
    f"History file was not saved: {history_path}"
)

assert summary_path.exists(), (
    f"Summary file was not saved: {summary_path}"
)

assert spins_path.exists(), (
    f"Best-spins file was not saved: {spins_path}"
)

assert len(selected_partition_summary_df) > 0, (
    "Summary dataframe is empty."
)

assert len(selected_partition_history_df) > 0, (
    "History dataframe is empty."
)
# Out:
# ================================================================================
# NEXT BIG-GSET PARTITION SELECTED
# ================================================================================
# Partition 13: G60-G61 | 2 graphs | ['G60', 'G61']
# G60: True | ../data-gset/G60
# G61: True | ../data-gset/G61
#    partition graph     N      M  density_upper_percent  positive_edges  \
# 5         13   G60  7000  17148               0.070002           17148
# 6         13   G61  7000  17148               0.070002            8755
#
#    negative_edges  positive_edge_fraction  negative_edge_fraction  weight_sum  \
# 5               0                1.000000                0.000000     17148.0
# 6            8393                0.510555                0.489445       362.0
#
#    best_known_cut  best_known_cut_per_edge  dense_W_float32_MB device  \
# 5         14188.0                 0.827385          186.920166  mps:0
# 6          5796.0                 0.337999          186.920166  mps:0
#
#            dtype
# 5  torch.float32
# 6  torch.float32
# ================================================================================
# RUNNING SELECTED BIG-GSET PARTITION
# ================================================================================
# Partition: 13
# Graphs: ['G60', 'G61']
# Replicas: 128
# Steps: 1000
# Optimizer: Adam
# Adam lr: 0.01
#
# ================================================================================
# START GRAPH: G60
# ================================================================================
# N: 7000
# M: 17148
# Best-known cut: 14188.0
# G60 | step     1/1000 | cut=    8679.0 | best=    8679.0 | gap=    5509.0 | acc= 61.171% | |rz|=0.0001 | time=    0.09s
# G60 | step    50/1000 | cut=    8726.0 | best=    8726.0 | gap=    5462.0 | acc= 61.503% | |rz|=0.0000 | time=    1.02s
# G60 | step   100/1000 | cut=    8394.0 | best=    8726.0 | gap=    5462.0 | acc= 61.503% | |rz|=0.0000 | time=    1.87s
# G60 | step   150/1000 | cut=    6832.0 | best=    8726.0 | gap=    5462.0 | acc= 61.503% | |rz|=0.0000 | time=    2.70s
# G60 | step   200/1000 | cut=    8325.0 | best=    8726.0 | gap=    5462.0 | acc= 61.503% | |rz|=0.0001 | time=    3.53s
# G60 | step   250/1000 | cut=    5700.0 | best=    8726.0 | gap=    5462.0 | acc= 61.503% | |rz|=0.0002 | time=    4.36s
# G60 | step   300/1000 | cut=   13795.0 | best=   13795.0 | gap=     393.0 | acc= 97.230% | |rz|=0.1784 | time=    5.22s
# G60 | step   350/1000 | cut=   13976.0 | best=   13976.0 | gap=     212.0 | acc= 98.506% | |rz|=0.4571 | time=    6.16s
# G60 | step   400/1000 | cut=   14023.0 | best=   14023.0 | gap=     165.0 | acc= 98.837% | |rz|=0.6023 | time=    7.00s
# G60 | step   450/1000 | cut=   14031.0 | best=   14031.0 | gap=     157.0 | acc= 98.893% | |rz|=0.6826 | time=    7.82s
# G60 | step   500/1000 | cut=   14039.0 | best=   14039.0 | gap=     149.0 | acc= 98.950% | |rz|=0.7345 | time=    8.65s
# G60 | step   550/1000 | cut=   14042.0 | best=   14042.0 | gap=     146.0 | acc= 98.971% | |rz|=0.7729 | time=    9.61s
# G60 | step   600/1000 | cut=   14043.0 | best=   14043.0 | gap=     145.0 | acc= 98.978% | |rz|=0.8039 | time=   10.63s
# G60 | step   650/1000 | cut=   14043.0 | best=   14043.0 | gap=     145.0 | acc= 98.978% | |rz|=0.8304 | time=   11.74s
# G60 | step   700/1000 | cut=   14043.0 | best=   14043.0 | gap=     145.0 | acc= 98.978% | |rz|=0.8534 | time=   12.72s
# G60 | step   750/1000 | cut=   14045.0 | best=   14045.0 | gap=     143.0 | acc= 98.992% | |rz|=0.8734 | time=   13.70s
# G60 | step   800/1000 | cut=   14045.0 | best=   14045.0 | gap=     143.0 | acc= 98.992% | |rz|=0.8906 | time=   14.60s
# G60 | step   850/1000 | cut=   14045.0 | best=   14045.0 | gap=     143.0 | acc= 98.992% | |rz|=0.9051 | time=   15.48s
# G60 | step   900/1000 | cut=   14045.0 | best=   14045.0 | gap=     143.0 | acc= 98.992% | |rz|=0.9170 | time=   16.34s
# G60 | step   950/1000 | cut=   14045.0 | best=   14045.0 | gap=     143.0 | acc= 98.992% | |rz|=0.9271 | time=   17.21s
# G60 | step  1000/1000 | cut=   14045.0 | best=   14045.0 | gap=     143.0 | acc= 98.992% | |rz|=0.9460 | time=   18.04s
#
# FINISHED GRAPH: G60
# Best cut: 14045.0
# Best-known: 14188.0
# Gap: 143.0
# Accuracy %: 98.99210600507472
# Runtime sec: 18.05151081085205
#
# ================================================================================
# START GRAPH: G61
# ================================================================================
# N: 7000
# M: 17148
# Best-known cut: 5796.0
# G61 | step     1/1000 | cut=     305.0 | best=     305.0 | gap=    5491.0 | acc=  5.262% | |rz|=0.0001 | time=    0.02s
# G61 | step    50/1000 | cut=     367.0 | best=     367.0 | gap=    5429.0 | acc=  6.332% | |rz|=0.0000 | time=    0.85s
# G61 | step   100/1000 | cut=     -20.0 | best=     367.0 | gap=    5429.0 | acc=  6.332% | |rz|=0.0000 | time=    1.68s
# G61 | step   150/1000 | cut=   -1350.0 | best=     367.0 | gap=    5429.0 | acc=  6.332% | |rz|=0.0000 | time=    2.56s
# G61 | step   200/1000 | cut=   -1395.0 | best=     367.0 | gap=    5429.0 | acc=  6.332% | |rz|=0.0001 | time=    3.38s
# G61 | step   250/1000 | cut=   -2523.0 | best=     367.0 | gap=    5429.0 | acc=  6.332% | |rz|=0.0002 | time=    4.20s
# G61 | step   300/1000 | cut=    5412.0 | best=    5412.0 | gap=     384.0 | acc= 93.375% | |rz|=0.2077 | time=    5.12s
# G61 | step   350/1000 | cut=    5585.0 | best=    5585.0 | gap=     211.0 | acc= 96.360% | |rz|=0.4613 | time=    6.00s
# G61 | step   400/1000 | cut=    5622.0 | best=    5622.0 | gap=     174.0 | acc= 96.998% | |rz|=0.6035 | time=    6.87s
# G61 | step   450/1000 | cut=    5633.0 | best=    5633.0 | gap=     163.0 | acc= 97.188% | |rz|=0.6827 | time=    7.76s
# G61 | step   500/1000 | cut=    5644.0 | best=    5644.0 | gap=     152.0 | acc= 97.378% | |rz|=0.7342 | time=    8.69s
# G61 | step   550/1000 | cut=    5648.0 | best=    5648.0 | gap=     148.0 | acc= 97.447% | |rz|=0.7725 | time=    9.70s
# G61 | step   600/1000 | cut=    5650.0 | best=    5650.0 | gap=     146.0 | acc= 97.481% | |rz|=0.8034 | time=   10.72s
# G61 | step   650/1000 | cut=    5650.0 | best=    5650.0 | gap=     146.0 | acc= 97.481% | |rz|=0.8299 | time=   11.63s
# G61 | step   700/1000 | cut=    5650.0 | best=    5650.0 | gap=     146.0 | acc= 97.481% | |rz|=0.8529 | time=   12.58s
# G61 | step   750/1000 | cut=    5650.0 | best=    5650.0 | gap=     146.0 | acc= 97.481% | |rz|=0.8729 | time=   13.52s
# G61 | step   800/1000 | cut=    5650.0 | best=    5650.0 | gap=     146.0 | acc= 97.481% | |rz|=0.8901 | time=   14.49s
# G61 | step   850/1000 | cut=    5651.0 | best=    5651.0 | gap=     145.0 | acc= 97.498% | |rz|=0.9046 | time=   15.44s
# G61 | step   900/1000 | cut=    5651.0 | best=    5651.0 | gap=     145.0 | acc= 97.498% | |rz|=0.9166 | time=   16.38s
# G61 | step   950/1000 | cut=    5651.0 | best=    5651.0 | gap=     145.0 | acc= 97.498% | |rz|=0.9267 | time=   17.34s
# G61 | step  1000/1000 | cut=    5651.0 | best=    5651.0 | gap=     145.0 | acc= 97.498% | |rz|=0.9458 | time=   18.24s
#
# FINISHED GRAPH: G61
# Best cut: 5651.0
# Best-known: 5796.0
# Gap: 145.0
# Accuracy %: 97.49827467218772
# Runtime sec: 18.248646020889282
#
# ================================================================================
# SELECTED PARTITION SUMMARY
# ================================================================================
#    partition graph     N      M  best_known_cut  qefem_best_cut    gap  \
# 0         13   G60  7000  17148         14188.0         14045.0  143.0
# 1         13   G61  7000  17148          5796.0          5651.0  145.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         98.992106        750           120       128   1000      Adam  0.01
# 1         97.498275        850            51       128   1000      Adam  0.01
#
#    runtime_sec
# 0    18.051511
# 1    18.248646
# ================================================================================
# SAVED SELECTED PARTITION RESULTS
# ================================================================================
# Partition: 13
#
# Saved history CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_13_history.csv
#
# Saved summary CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_13_summary.csv
#
# Saved best spins PT:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_13_best_spins.pt
#
# Final selected-partition summary:
#    partition graph     N      M  best_known_cut  qefem_best_cut    gap  \
# 0         13   G60  7000  17148         14188.0         14045.0  143.0
# 1         13   G61  7000  17148          5796.0          5651.0  145.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         98.992106        750           120       128   1000      Adam  0.01
# 1         97.498275        850            51       128   1000      Adam  0.01
#
#    runtime_sec
# 0    18.051511
# 1    18.248646

# %%
assert "BIG_GSET_PARTITIONS" in globals(), (
    "Run Cell 25 first: BIG_GSET_PARTITIONS is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


# ------------------------------------------------------------
# Change this after each completed partition
# ------------------------------------------------------------

SELECTED_BIG_GSET_PARTITION = 14


# ------------------------------------------------------------
# Select graphs in this partition
# ------------------------------------------------------------

assert SELECTED_BIG_GSET_PARTITION in BIG_GSET_PARTITIONS, (
    f"Partition {SELECTED_BIG_GSET_PARTITION} is not defined."
)

selected_big_gset_graphs = BIG_GSET_PARTITIONS[SELECTED_BIG_GSET_PARTITION]


print("=" * 80)
print("NEXT BIG-GSET PARTITION SELECTED")
print("=" * 80)

print(
    f"Partition {SELECTED_BIG_GSET_PARTITION}: "
    f"{selected_big_gset_graphs[0]}-{selected_big_gset_graphs[-1]} | "
    f"{len(selected_big_gset_graphs)} graphs | "
    f"{selected_big_gset_graphs}"
)


# ------------------------------------------------------------
# Quick file check
# ------------------------------------------------------------

missing_graphs = []

for graph in selected_big_gset_graphs:
    path = GSET_DIR / graph

    print(f"{graph}: {path.exists()} | {path}")

    if not path.exists():
        missing_graphs.append(graph)

assert len(missing_graphs) == 0, (
    f"Missing graph files: {missing_graphs}"
)


# ------------------------------------------------------------
# Benchmark preview for this partition
# ------------------------------------------------------------

selected_partition_benchmark_df = big_gset_benchmark_df[
    big_gset_benchmark_df["partition"] == SELECTED_BIG_GSET_PARTITION
].copy()

display(selected_partition_benchmark_df)

assert len(selected_partition_benchmark_df) == len(selected_big_gset_graphs), (
    "Benchmark table row count does not match selected partition graph count."
)

assert "selected_big_gset_graphs" in globals(), (
    "Run Cell 32 first: selected_big_gset_graphs is missing."
)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "load_gset_edge_list" in globals(), (
    "Run Cell 26 first: load_gset_edge_list is missing."
)

assert "edge_qefem_free_energy" in globals(), (
    "Run Cell 30 first: edge_qefem_free_energy is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)

assert "big_gset_beta_schedule" in globals(), (
    "Run Cell 31 first: big_gset_beta_schedule is missing."
)

assert "big_gset_gamma_schedule" in globals(), (
    "Run Cell 31 first: big_gset_gamma_schedule is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


selected_partition_history_rows = []
selected_partition_summary_rows = []
selected_partition_best_spins = {}


print("=" * 80)
print("RUNNING SELECTED BIG-GSET PARTITION")
print("=" * 80)
print("Partition:", SELECTED_BIG_GSET_PARTITION)
print("Graphs:", selected_big_gset_graphs)
print("Replicas:", BIG_GSET_REPLICAS)
print("Steps:", BIG_GSET_N_STEPS)
print("Optimizer: Adam")
print("Adam lr:", BIG_GSET_ADAM_LR)


for graph in selected_big_gset_graphs:
    print("\n" + "=" * 80)
    print("START GRAPH:", graph)
    print("=" * 80)

    N_g, edge_i, edge_j, edge_w, info = load_gset_edge_list(graph)

    graph_benchmark_row = big_gset_benchmark_df[
        big_gset_benchmark_df["graph"] == graph
    ].iloc[0]

    best_known_cut = float(graph_benchmark_row["best_known_cut"])

    print("N:", N_g)
    print("M:", info["M"])
    print("Best-known cut:", best_known_cut)

    torch.manual_seed(BIG_GSET_SEED)

    R_INIT_tensor = torch.tensor(
        R_INIT,
        device=device,
        dtype=DTYPE,
    )

    raw_R_init_value = torch.log(
        R_INIT_tensor / (1.0 - R_INIT_tensor)
    )

    raw_R = raw_R_init_value + 1e-3 * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    theta = THETA_CENTER + THETA_NOISE * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    raw_R.requires_grad_(True)
    theta.requires_grad_(True)

    optimizer = torch.optim.Adam(
        [raw_R, theta],
        lr=BIG_GSET_ADAM_LR,
    )

    best_cut = -float("inf")
    best_step = None
    best_replica = None
    best_spins = None

    graph_start_time = time.time()

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    for step in range(BIG_GSET_N_STEPS):
        beta_t = big_gset_beta_schedule[step]
        gamma_t = big_gset_gamma_schedule[step]

        optimizer.zero_grad()

        F, aux = edge_qefem_free_energy(
            edge_i=edge_i,
            edge_j=edge_j,
            edge_w=edge_w,
            raw_R=raw_R,
            theta=theta,
            beta=beta_t,
            gamma=gamma_t,
        )

        loss = F.mean()

        loss.backward()
        optimizer.step()

        should_log = (
            step == 0
            or step == BIG_GSET_N_STEPS - 1
            or (step + 1) % BIG_GSET_LOG_EVERY == 0
        )

        if should_log:
            if edge_w.device.type == "mps":
                torch.mps.synchronize()

            elapsed = time.time() - graph_start_time

            with torch.no_grad():
                R_now, rx_now, rz_now = bloch_from_raw(
                    raw_R,
                    theta,
                )

                spins_now = torch.where(
                    rz_now >= 0,
                    torch.ones_like(rz_now),
                    -torch.ones_like(rz_now),
                )

                hard_cuts_now = edge_discrete_cut(
                    edge_i=edge_i,
                    edge_j=edge_j,
                    edge_w=edge_w,
                    spins=spins_now,
                )

                current_best_cut_tensor, current_best_replica_tensor = torch.max(
                    hard_cuts_now,
                    dim=0,
                )

                current_best_cut = float(current_best_cut_tensor.detach().cpu())
                current_best_replica = int(current_best_replica_tensor.detach().cpu())

                if current_best_cut > best_cut:
                    best_cut = current_best_cut
                    best_step = step + 1
                    best_replica = current_best_replica
                    best_spins = spins_now[current_best_replica].detach().cpu().clone()

                gap = best_known_cut - best_cut
                accuracy_percent = 100.0 * best_cut / best_known_cut

                selected_partition_history_rows.append(
                    {
                        "partition": SELECTED_BIG_GSET_PARTITION,
                        "graph": graph,
                        "step": step + 1,
                        "beta": float(beta_t.detach().cpu()),
                        "gamma": float(gamma_t.detach().cpu()),
                        "loss": float(loss.detach().cpu()),
                        "free_energy_mean": float(F.mean().detach().cpu()),
                        "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
                        "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),
                        "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
                        "hard_cut_max": current_best_cut,
                        "best_cut_so_far": best_cut,
                        "best_known_cut": best_known_cut,
                        "gap": gap,
                        "accuracy_percent": accuracy_percent,
                        "R_mean": float(R_now.mean().detach().cpu()),
                        "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),
                        "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),
                        "best_replica_so_far": best_replica,
                        "elapsed_sec": elapsed,
                    }
                )

                print(
                    f"{graph} | "
                    f"step {step + 1:5d}/{BIG_GSET_N_STEPS} | "
                    f"cut={current_best_cut:10.1f} | "
                    f"best={best_cut:10.1f} | "
                    f"gap={gap:10.1f} | "
                    f"acc={accuracy_percent:7.3f}% | "
                    f"|rz|={float(rz_now.abs().mean().detach().cpu()):.4f} | "
                    f"time={elapsed:8.2f}s"
                )

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    graph_runtime = time.time() - graph_start_time

    selected_partition_summary_rows.append(
        {
            "partition": SELECTED_BIG_GSET_PARTITION,
            "graph": graph,
            "N": N_g,
            "M": info["M"],
            "best_known_cut": best_known_cut,
            "qefem_best_cut": best_cut,
            "gap": best_known_cut - best_cut,
            "accuracy_percent": 100.0 * best_cut / best_known_cut,
            "best_step": best_step,
            "best_replica": best_replica,
            "replicas": BIG_GSET_REPLICAS,
            "steps": BIG_GSET_N_STEPS,
            "optimizer": "Adam",
            "lr": BIG_GSET_ADAM_LR,
            "runtime_sec": graph_runtime,
        }
    )

    selected_partition_best_spins[graph] = best_spins

    print("\nFINISHED GRAPH:", graph)
    print("Best cut:", best_cut)
    print("Best-known:", best_known_cut)
    print("Gap:", best_known_cut - best_cut)
    print("Accuracy %:", 100.0 * best_cut / best_known_cut)
    print("Runtime sec:", graph_runtime)


selected_partition_history_df = pd.DataFrame(selected_partition_history_rows)
selected_partition_summary_df = pd.DataFrame(selected_partition_summary_rows)

print("\n" + "=" * 80)
print("SELECTED PARTITION SUMMARY")
print("=" * 80)

display(selected_partition_summary_df)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "selected_partition_history_df" in globals(), (
    "Run Cell 37 first: selected_partition_history_df is missing."
)

assert "selected_partition_summary_df" in globals(), (
    "Run Cell 37 first: selected_partition_summary_df is missing."
)

assert "selected_partition_best_spins" in globals(), (
    "Run Cell 37 first: selected_partition_best_spins is missing."
)


# ------------------------------------------------------------
# Output folder
# ------------------------------------------------------------

BIG_GSET_OUTPUT_DIR = Path("qefem_big_gset_outputs")
BIG_GSET_OUTPUT_DIR.mkdir(exist_ok=True)


# ------------------------------------------------------------
# File names
# ------------------------------------------------------------

partition_tag = f"partition_{SELECTED_BIG_GSET_PARTITION}"

history_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_history.csv"
summary_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_summary.csv"
spins_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_best_spins.pt"


# ------------------------------------------------------------
# Save CSV files
# ------------------------------------------------------------

selected_partition_history_df.to_csv(
    history_path,
    index=False,
)

selected_partition_summary_df.to_csv(
    summary_path,
    index=False,
)


# ------------------------------------------------------------
# Save best spins dictionary
# ------------------------------------------------------------

torch.save(
    selected_partition_best_spins,
    spins_path,
)


# ------------------------------------------------------------
# Print saved paths
# ------------------------------------------------------------

print("=" * 80)
print("SAVED SELECTED PARTITION RESULTS")
print("=" * 80)

print("Partition:", SELECTED_BIG_GSET_PARTITION)

print("\nSaved history CSV:")
print(history_path.resolve())

print("\nSaved summary CSV:")
print(summary_path.resolve())

print("\nSaved best spins PT:")
print(spins_path.resolve())


# ------------------------------------------------------------
# Display final summary
# ------------------------------------------------------------

print("\nFinal selected-partition summary:")
display(selected_partition_summary_df)


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert history_path.exists(), (
    f"History file was not saved: {history_path}"
)

assert summary_path.exists(), (
    f"Summary file was not saved: {summary_path}"
)

assert spins_path.exists(), (
    f"Best-spins file was not saved: {spins_path}"
)

assert len(selected_partition_summary_df) > 0, (
    "Summary dataframe is empty."
)

assert len(selected_partition_history_df) > 0, (
    "History dataframe is empty."
)
# Out:
# ================================================================================
# NEXT BIG-GSET PARTITION SELECTED
# ================================================================================
# Partition 14: G62-G62 | 1 graphs | ['G62']
# G62: True | ../data-gset/G62
#    partition graph     N      M  density_upper_percent  positive_edges  \
# 7         14   G62  7000  14000               0.057151            6960
#
#    negative_edges  positive_edge_fraction  negative_edge_fraction  weight_sum  \
# 7            7040                0.497143                0.502857       -80.0
#
#    best_known_cut  best_known_cut_per_edge  dense_W_float32_MB device  \
# 7          4870.0                 0.347857          186.920166  mps:0
#
#            dtype
# 7  torch.float32
# ================================================================================
# RUNNING SELECTED BIG-GSET PARTITION
# ================================================================================
# Partition: 14
# Graphs: ['G62']
# Replicas: 128
# Steps: 1000
# Optimizer: Adam
# Adam lr: 0.01
#
# ================================================================================
# START GRAPH: G62
# ================================================================================
# N: 7000
# M: 14000
# Best-known cut: 4870.0
# G62 | step     1/1000 | cut=      66.0 | best=      66.0 | gap=    4804.0 | acc=  1.355% | |rz|=0.0001 | time=    0.02s
# G62 | step    50/1000 | cut=      96.0 | best=      96.0 | gap=    4774.0 | acc=  1.971% | |rz|=0.0000 | time=    1.04s
# G62 | step   100/1000 | cut=    -240.0 | best=      96.0 | gap=    4774.0 | acc=  1.971% | |rz|=0.0000 | time=    1.95s
# G62 | step   150/1000 | cut=    -986.0 | best=      96.0 | gap=    4774.0 | acc=  1.971% | |rz|=0.0000 | time=    2.77s
# G62 | step   200/1000 | cut=   -1214.0 | best=      96.0 | gap=    4774.0 | acc=  1.971% | |rz|=0.0001 | time=    3.57s
# G62 | step   250/1000 | cut=   -2292.0 | best=      96.0 | gap=    4774.0 | acc=  1.971% | |rz|=0.0002 | time=    4.38s
# G62 | step   300/1000 | cut=     164.0 | best=     164.0 | gap=    4706.0 | acc=  3.368% | |rz|=0.0006 | time=    5.17s
# G62 | step   350/1000 | cut=    4772.0 | best=    4772.0 | gap=      98.0 | acc= 97.988% | |rz|=0.3934 | time=    6.03s
# G62 | step   400/1000 | cut=    4790.0 | best=    4790.0 | gap=      80.0 | acc= 98.357% | |rz|=0.5783 | time=    6.83s
# G62 | step   450/1000 | cut=    4790.0 | best=    4790.0 | gap=      80.0 | acc= 98.357% | |rz|=0.6805 | time=    7.63s
# G62 | step   500/1000 | cut=    4790.0 | best=    4790.0 | gap=      80.0 | acc= 98.357% | |rz|=0.7413 | time=    8.49s
# G62 | step   550/1000 | cut=    4790.0 | best=    4790.0 | gap=      80.0 | acc= 98.357% | |rz|=0.7825 | time=    9.45s
# G62 | step   600/1000 | cut=    4790.0 | best=    4790.0 | gap=      80.0 | acc= 98.357% | |rz|=0.8132 | time=   10.39s
# G62 | step   650/1000 | cut=    4790.0 | best=    4790.0 | gap=      80.0 | acc= 98.357% | |rz|=0.8375 | time=   11.30s
# G62 | step   700/1000 | cut=    4790.0 | best=    4790.0 | gap=      80.0 | acc= 98.357% | |rz|=0.8574 | time=   12.11s
# G62 | step   750/1000 | cut=    4790.0 | best=    4790.0 | gap=      80.0 | acc= 98.357% | |rz|=0.8739 | time=   12.89s
# G62 | step   800/1000 | cut=    4790.0 | best=    4790.0 | gap=      80.0 | acc= 98.357% | |rz|=0.8879 | time=   13.69s
# G62 | step   850/1000 | cut=    4790.0 | best=    4790.0 | gap=      80.0 | acc= 98.357% | |rz|=0.8996 | time=   14.59s
# G62 | step   900/1000 | cut=    4790.0 | best=    4790.0 | gap=      80.0 | acc= 98.357% | |rz|=0.9096 | time=   15.44s
# G62 | step   950/1000 | cut=    4790.0 | best=    4790.0 | gap=      80.0 | acc= 98.357% | |rz|=0.9197 | time=   16.33s
# G62 | step  1000/1000 | cut=    4790.0 | best=    4790.0 | gap=      80.0 | acc= 98.357% | |rz|=0.9393 | time=   17.24s
#
# FINISHED GRAPH: G62
# Best cut: 4790.0
# Best-known: 4870.0
# Gap: 80.0
# Accuracy %: 98.35728952772074
# Runtime sec: 17.24835729598999
#
# ================================================================================
# SELECTED PARTITION SUMMARY
# ================================================================================
#    partition graph     N      M  best_known_cut  qefem_best_cut   gap  \
# 0         14   G62  7000  14000          4870.0          4790.0  80.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0          98.35729        400            97       128   1000      Adam  0.01
#
#    runtime_sec
# 0    17.248357
# ================================================================================
# SAVED SELECTED PARTITION RESULTS
# ================================================================================
# Partition: 14
#
# Saved history CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_14_history.csv
#
# Saved summary CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_14_summary.csv
#
# Saved best spins PT:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_14_best_spins.pt
#
# Final selected-partition summary:
#    partition graph     N      M  best_known_cut  qefem_best_cut   gap  \
# 0         14   G62  7000  14000          4870.0          4790.0  80.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0          98.35729        400            97       128   1000      Adam  0.01
#
#    runtime_sec
# 0    17.248357

# %%
assert "BIG_GSET_PARTITIONS" in globals(), (
    "Run Cell 25 first: BIG_GSET_PARTITIONS is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


# ------------------------------------------------------------
# Change this after each completed partition
# ------------------------------------------------------------

SELECTED_BIG_GSET_PARTITION = 15


# ------------------------------------------------------------
# Select graphs in this partition
# ------------------------------------------------------------

assert SELECTED_BIG_GSET_PARTITION in BIG_GSET_PARTITIONS, (
    f"Partition {SELECTED_BIG_GSET_PARTITION} is not defined."
)

selected_big_gset_graphs = BIG_GSET_PARTITIONS[SELECTED_BIG_GSET_PARTITION]


print("=" * 80)
print("NEXT BIG-GSET PARTITION SELECTED")
print("=" * 80)

print(
    f"Partition {SELECTED_BIG_GSET_PARTITION}: "
    f"{selected_big_gset_graphs[0]}-{selected_big_gset_graphs[-1]} | "
    f"{len(selected_big_gset_graphs)} graphs | "
    f"{selected_big_gset_graphs}"
)


# ------------------------------------------------------------
# Quick file check
# ------------------------------------------------------------

missing_graphs = []

for graph in selected_big_gset_graphs:
    path = GSET_DIR / graph

    print(f"{graph}: {path.exists()} | {path}")

    if not path.exists():
        missing_graphs.append(graph)

assert len(missing_graphs) == 0, (
    f"Missing graph files: {missing_graphs}"
)


# ------------------------------------------------------------
# Benchmark preview for this partition
# ------------------------------------------------------------

selected_partition_benchmark_df = big_gset_benchmark_df[
    big_gset_benchmark_df["partition"] == SELECTED_BIG_GSET_PARTITION
].copy()

display(selected_partition_benchmark_df)

assert len(selected_partition_benchmark_df) == len(selected_big_gset_graphs), (
    "Benchmark table row count does not match selected partition graph count."
)

assert "selected_big_gset_graphs" in globals(), (
    "Run Cell 32 first: selected_big_gset_graphs is missing."
)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "load_gset_edge_list" in globals(), (
    "Run Cell 26 first: load_gset_edge_list is missing."
)

assert "edge_qefem_free_energy" in globals(), (
    "Run Cell 30 first: edge_qefem_free_energy is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)

assert "big_gset_beta_schedule" in globals(), (
    "Run Cell 31 first: big_gset_beta_schedule is missing."
)

assert "big_gset_gamma_schedule" in globals(), (
    "Run Cell 31 first: big_gset_gamma_schedule is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


selected_partition_history_rows = []
selected_partition_summary_rows = []
selected_partition_best_spins = {}


print("=" * 80)
print("RUNNING SELECTED BIG-GSET PARTITION")
print("=" * 80)
print("Partition:", SELECTED_BIG_GSET_PARTITION)
print("Graphs:", selected_big_gset_graphs)
print("Replicas:", BIG_GSET_REPLICAS)
print("Steps:", BIG_GSET_N_STEPS)
print("Optimizer: Adam")
print("Adam lr:", BIG_GSET_ADAM_LR)


for graph in selected_big_gset_graphs:
    print("\n" + "=" * 80)
    print("START GRAPH:", graph)
    print("=" * 80)

    N_g, edge_i, edge_j, edge_w, info = load_gset_edge_list(graph)

    graph_benchmark_row = big_gset_benchmark_df[
        big_gset_benchmark_df["graph"] == graph
    ].iloc[0]

    best_known_cut = float(graph_benchmark_row["best_known_cut"])

    print("N:", N_g)
    print("M:", info["M"])
    print("Best-known cut:", best_known_cut)

    torch.manual_seed(BIG_GSET_SEED)

    R_INIT_tensor = torch.tensor(
        R_INIT,
        device=device,
        dtype=DTYPE,
    )

    raw_R_init_value = torch.log(
        R_INIT_tensor / (1.0 - R_INIT_tensor)
    )

    raw_R = raw_R_init_value + 1e-3 * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    theta = THETA_CENTER + THETA_NOISE * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    raw_R.requires_grad_(True)
    theta.requires_grad_(True)

    optimizer = torch.optim.Adam(
        [raw_R, theta],
        lr=BIG_GSET_ADAM_LR,
    )

    best_cut = -float("inf")
    best_step = None
    best_replica = None
    best_spins = None

    graph_start_time = time.time()

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    for step in range(BIG_GSET_N_STEPS):
        beta_t = big_gset_beta_schedule[step]
        gamma_t = big_gset_gamma_schedule[step]

        optimizer.zero_grad()

        F, aux = edge_qefem_free_energy(
            edge_i=edge_i,
            edge_j=edge_j,
            edge_w=edge_w,
            raw_R=raw_R,
            theta=theta,
            beta=beta_t,
            gamma=gamma_t,
        )

        loss = F.mean()

        loss.backward()
        optimizer.step()

        should_log = (
            step == 0
            or step == BIG_GSET_N_STEPS - 1
            or (step + 1) % BIG_GSET_LOG_EVERY == 0
        )

        if should_log:
            if edge_w.device.type == "mps":
                torch.mps.synchronize()

            elapsed = time.time() - graph_start_time

            with torch.no_grad():
                R_now, rx_now, rz_now = bloch_from_raw(
                    raw_R,
                    theta,
                )

                spins_now = torch.where(
                    rz_now >= 0,
                    torch.ones_like(rz_now),
                    -torch.ones_like(rz_now),
                )

                hard_cuts_now = edge_discrete_cut(
                    edge_i=edge_i,
                    edge_j=edge_j,
                    edge_w=edge_w,
                    spins=spins_now,
                )

                current_best_cut_tensor, current_best_replica_tensor = torch.max(
                    hard_cuts_now,
                    dim=0,
                )

                current_best_cut = float(current_best_cut_tensor.detach().cpu())
                current_best_replica = int(current_best_replica_tensor.detach().cpu())

                if current_best_cut > best_cut:
                    best_cut = current_best_cut
                    best_step = step + 1
                    best_replica = current_best_replica
                    best_spins = spins_now[current_best_replica].detach().cpu().clone()

                gap = best_known_cut - best_cut
                accuracy_percent = 100.0 * best_cut / best_known_cut

                selected_partition_history_rows.append(
                    {
                        "partition": SELECTED_BIG_GSET_PARTITION,
                        "graph": graph,
                        "step": step + 1,
                        "beta": float(beta_t.detach().cpu()),
                        "gamma": float(gamma_t.detach().cpu()),
                        "loss": float(loss.detach().cpu()),
                        "free_energy_mean": float(F.mean().detach().cpu()),
                        "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
                        "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),
                        "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
                        "hard_cut_max": current_best_cut,
                        "best_cut_so_far": best_cut,
                        "best_known_cut": best_known_cut,
                        "gap": gap,
                        "accuracy_percent": accuracy_percent,
                        "R_mean": float(R_now.mean().detach().cpu()),
                        "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),
                        "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),
                        "best_replica_so_far": best_replica,
                        "elapsed_sec": elapsed,
                    }
                )

                print(
                    f"{graph} | "
                    f"step {step + 1:5d}/{BIG_GSET_N_STEPS} | "
                    f"cut={current_best_cut:10.1f} | "
                    f"best={best_cut:10.1f} | "
                    f"gap={gap:10.1f} | "
                    f"acc={accuracy_percent:7.3f}% | "
                    f"|rz|={float(rz_now.abs().mean().detach().cpu()):.4f} | "
                    f"time={elapsed:8.2f}s"
                )

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    graph_runtime = time.time() - graph_start_time

    selected_partition_summary_rows.append(
        {
            "partition": SELECTED_BIG_GSET_PARTITION,
            "graph": graph,
            "N": N_g,
            "M": info["M"],
            "best_known_cut": best_known_cut,
            "qefem_best_cut": best_cut,
            "gap": best_known_cut - best_cut,
            "accuracy_percent": 100.0 * best_cut / best_known_cut,
            "best_step": best_step,
            "best_replica": best_replica,
            "replicas": BIG_GSET_REPLICAS,
            "steps": BIG_GSET_N_STEPS,
            "optimizer": "Adam",
            "lr": BIG_GSET_ADAM_LR,
            "runtime_sec": graph_runtime,
        }
    )

    selected_partition_best_spins[graph] = best_spins

    print("\nFINISHED GRAPH:", graph)
    print("Best cut:", best_cut)
    print("Best-known:", best_known_cut)
    print("Gap:", best_known_cut - best_cut)
    print("Accuracy %:", 100.0 * best_cut / best_known_cut)
    print("Runtime sec:", graph_runtime)


selected_partition_history_df = pd.DataFrame(selected_partition_history_rows)
selected_partition_summary_df = pd.DataFrame(selected_partition_summary_rows)

print("\n" + "=" * 80)
print("SELECTED PARTITION SUMMARY")
print("=" * 80)

display(selected_partition_summary_df)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "selected_partition_history_df" in globals(), (
    "Run Cell 37 first: selected_partition_history_df is missing."
)

assert "selected_partition_summary_df" in globals(), (
    "Run Cell 37 first: selected_partition_summary_df is missing."
)

assert "selected_partition_best_spins" in globals(), (
    "Run Cell 37 first: selected_partition_best_spins is missing."
)


# ------------------------------------------------------------
# Output folder
# ------------------------------------------------------------

BIG_GSET_OUTPUT_DIR = Path("qefem_big_gset_outputs")
BIG_GSET_OUTPUT_DIR.mkdir(exist_ok=True)


# ------------------------------------------------------------
# File names
# ------------------------------------------------------------

partition_tag = f"partition_{SELECTED_BIG_GSET_PARTITION}"

history_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_history.csv"
summary_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_summary.csv"
spins_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_best_spins.pt"


# ------------------------------------------------------------
# Save CSV files
# ------------------------------------------------------------

selected_partition_history_df.to_csv(
    history_path,
    index=False,
)

selected_partition_summary_df.to_csv(
    summary_path,
    index=False,
)


# ------------------------------------------------------------
# Save best spins dictionary
# ------------------------------------------------------------

torch.save(
    selected_partition_best_spins,
    spins_path,
)


# ------------------------------------------------------------
# Print saved paths
# ------------------------------------------------------------

print("=" * 80)
print("SAVED SELECTED PARTITION RESULTS")
print("=" * 80)

print("Partition:", SELECTED_BIG_GSET_PARTITION)

print("\nSaved history CSV:")
print(history_path.resolve())

print("\nSaved summary CSV:")
print(summary_path.resolve())

print("\nSaved best spins PT:")
print(spins_path.resolve())


# ------------------------------------------------------------
# Display final summary
# ------------------------------------------------------------

print("\nFinal selected-partition summary:")
display(selected_partition_summary_df)


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert history_path.exists(), (
    f"History file was not saved: {history_path}"
)

assert summary_path.exists(), (
    f"Summary file was not saved: {summary_path}"
)

assert spins_path.exists(), (
    f"Best-spins file was not saved: {spins_path}"
)

assert len(selected_partition_summary_df) > 0, (
    "Summary dataframe is empty."
)

assert len(selected_partition_history_df) > 0, (
    "History dataframe is empty."
)
# Out:
# ================================================================================
# NEXT BIG-GSET PARTITION SELECTED
# ================================================================================
# Partition 15: G63-G64 | 2 graphs | ['G63', 'G64']
# G63: True | ../data-gset/G63
# G64: True | ../data-gset/G64
#    partition graph     N      M  density_upper_percent  positive_edges  \
# 8         15   G63  7000  41459               0.169245           41459
# 9         15   G64  7000  41459               0.169245           20993
#
#    negative_edges  positive_edge_fraction  negative_edge_fraction  weight_sum  \
# 8               0                1.000000                0.000000     41459.0
# 9           20466                0.506356                0.493644       527.0
#
#    best_known_cut  best_known_cut_per_edge  dense_W_float32_MB device  \
# 8         27047.0                 0.652379          186.920166  mps:0
# 9          8751.0                 0.211076          186.920166  mps:0
#
#            dtype
# 8  torch.float32
# 9  torch.float32
# ================================================================================
# RUNNING SELECTED BIG-GSET PARTITION
# ================================================================================
# Partition: 15
# Graphs: ['G63', 'G64']
# Replicas: 128
# Steps: 1000
# Optimizer: Adam
# Adam lr: 0.01
#
# ================================================================================
# START GRAPH: G63
# ================================================================================
# N: 7000
# M: 41459
# Best-known cut: 27047.0
# G63 | step     1/1000 | cut=   20921.0 | best=   20921.0 | gap=    6126.0 | acc= 77.351% | |rz|=0.0001 | time=    0.03s
# G63 | step    50/1000 | cut=   21090.0 | best=   21090.0 | gap=    5957.0 | acc= 77.975% | |rz|=0.0000 | time=    1.60s
# G63 | step   100/1000 | cut=   20743.0 | best=   21090.0 | gap=    5957.0 | acc= 77.975% | |rz|=0.0000 | time=    3.09s
# G63 | step   150/1000 | cut=   18954.0 | best=   21090.0 | gap=    5957.0 | acc= 77.975% | |rz|=0.0000 | time=    4.47s
# G63 | step   200/1000 | cut=   23020.0 | best=   23020.0 | gap=    4027.0 | acc= 85.111% | |rz|=0.0002 | time=    6.04s
# G63 | step   250/1000 | cut=   25107.0 | best=   25107.0 | gap=    1940.0 | acc= 92.827% | |rz|=0.0666 | time=    7.38s
# G63 | step   300/1000 | cut=   26238.0 | best=   26238.0 | gap=     809.0 | acc= 97.009% | |rz|=0.2822 | time=    8.90s
# G63 | step   350/1000 | cut=   26583.0 | best=   26583.0 | gap=     464.0 | acc= 98.284% | |rz|=0.4863 | time=   10.42s
# G63 | step   400/1000 | cut=   26684.0 | best=   26684.0 | gap=     363.0 | acc= 98.658% | |rz|=0.6100 | time=   11.95s
# G63 | step   450/1000 | cut=   26718.0 | best=   26718.0 | gap=     329.0 | acc= 98.784% | |rz|=0.6845 | time=   13.47s
# G63 | step   500/1000 | cut=   26732.0 | best=   26732.0 | gap=     315.0 | acc= 98.835% | |rz|=0.7354 | time=   14.76s
# G63 | step   550/1000 | cut=   26743.0 | best=   26743.0 | gap=     304.0 | acc= 98.876% | |rz|=0.7742 | time=   16.09s
# G63 | step   600/1000 | cut=   26750.0 | best=   26750.0 | gap=     297.0 | acc= 98.902% | |rz|=0.8056 | time=   17.46s
# G63 | step   650/1000 | cut=   26751.0 | best=   26751.0 | gap=     296.0 | acc= 98.906% | |rz|=0.8321 | time=   18.81s
# G63 | step   700/1000 | cut=   26751.0 | best=   26751.0 | gap=     296.0 | acc= 98.906% | |rz|=0.8548 | time=   20.10s
# G63 | step   750/1000 | cut=   26752.0 | best=   26752.0 | gap=     295.0 | acc= 98.909% | |rz|=0.8742 | time=   21.58s
# G63 | step   800/1000 | cut=   26755.0 | best=   26755.0 | gap=     292.0 | acc= 98.920% | |rz|=0.8907 | time=   23.04s
# G63 | step   850/1000 | cut=   26755.0 | best=   26755.0 | gap=     292.0 | acc= 98.920% | |rz|=0.9046 | time=   24.35s
# G63 | step   900/1000 | cut=   26755.0 | best=   26755.0 | gap=     292.0 | acc= 98.920% | |rz|=0.9163 | time=   25.80s
# G63 | step   950/1000 | cut=   26755.0 | best=   26755.0 | gap=     292.0 | acc= 98.920% | |rz|=0.9273 | time=   27.30s
# G63 | step  1000/1000 | cut=   26755.0 | best=   26755.0 | gap=     292.0 | acc= 98.920% | |rz|=0.9515 | time=   28.81s
#
# FINISHED GRAPH: G63
# Best cut: 26755.0
# Best-known: 27047.0
# Gap: 292.0
# Accuracy %: 98.92039782600658
# Runtime sec: 28.825478076934814
#
# ================================================================================
# START GRAPH: G64
# ================================================================================
# N: 7000
# M: 41459
# Best-known cut: 8751.0
# G64 | step     1/1000 | cut=     417.0 | best=     417.0 | gap=    8334.0 | acc=  4.765% | |rz|=0.0001 | time=    0.02s
# G64 | step    50/1000 | cut=     549.0 | best=     549.0 | gap=    8202.0 | acc=  6.274% | |rz|=0.0000 | time=    1.36s
# G64 | step   100/1000 | cut=     226.0 | best=     549.0 | gap=    8202.0 | acc=  6.274% | |rz|=0.0000 | time=    2.71s
# G64 | step   150/1000 | cut=   -3274.0 | best=     549.0 | gap=    8202.0 | acc=  6.274% | |rz|=0.0000 | time=    4.10s
# G64 | step   200/1000 | cut=    5662.0 | best=    5662.0 | gap=    3089.0 | acc= 64.701% | |rz|=0.0054 | time=    5.40s
# G64 | step   250/1000 | cut=    7680.0 | best=    7680.0 | gap=    1071.0 | acc= 87.761% | |rz|=0.1286 | time=    6.76s
# G64 | step   300/1000 | cut=    8183.0 | best=    8183.0 | gap=     568.0 | acc= 93.509% | |rz|=0.3857 | time=    8.16s
# G64 | step   350/1000 | cut=    8322.0 | best=    8322.0 | gap=     429.0 | acc= 95.098% | |rz|=0.5881 | time=    9.78s
# G64 | step   400/1000 | cut=    8383.0 | best=    8383.0 | gap=     368.0 | acc= 95.795% | |rz|=0.6931 | time=   11.24s
# G64 | step   450/1000 | cut=    8409.0 | best=    8409.0 | gap=     342.0 | acc= 96.092% | |rz|=0.7515 | time=   12.59s
# G64 | step   500/1000 | cut=    8418.0 | best=    8418.0 | gap=     333.0 | acc= 96.195% | |rz|=0.7901 | time=   13.88s
# G64 | step   550/1000 | cut=    8425.0 | best=    8425.0 | gap=     326.0 | acc= 96.275% | |rz|=0.8191 | time=   15.22s
# G64 | step   600/1000 | cut=    8429.0 | best=    8429.0 | gap=     322.0 | acc= 96.320% | |rz|=0.8425 | time=   16.68s
# G64 | step   650/1000 | cut=    8432.0 | best=    8432.0 | gap=     319.0 | acc= 96.355% | |rz|=0.8622 | time=   18.22s
# G64 | step   700/1000 | cut=    8437.0 | best=    8437.0 | gap=     314.0 | acc= 96.412% | |rz|=0.8791 | time=   19.74s
# G64 | step   750/1000 | cut=    8437.0 | best=    8437.0 | gap=     314.0 | acc= 96.412% | |rz|=0.8939 | time=   21.20s
# G64 | step   800/1000 | cut=    8437.0 | best=    8437.0 | gap=     314.0 | acc= 96.412% | |rz|=0.9064 | time=   22.86s
# G64 | step   850/1000 | cut=    8439.0 | best=    8439.0 | gap=     312.0 | acc= 96.435% | |rz|=0.9171 | time=   24.15s
# G64 | step   900/1000 | cut=    8440.0 | best=    8440.0 | gap=     311.0 | acc= 96.446% | |rz|=0.9261 | time=   25.52s
# G64 | step   950/1000 | cut=    8440.0 | best=    8440.0 | gap=     311.0 | acc= 96.446% | |rz|=0.9343 | time=   26.88s
# G64 | step  1000/1000 | cut=    8440.0 | best=    8440.0 | gap=     311.0 | acc= 96.446% | |rz|=0.9551 | time=   28.19s
#
# FINISHED GRAPH: G64
# Best cut: 8440.0
# Best-known: 8751.0
# Gap: 311.0
# Accuracy %: 96.4461204433779
# Runtime sec: 28.19923496246338
#
# ================================================================================
# SELECTED PARTITION SUMMARY
# ================================================================================
#    partition graph     N      M  best_known_cut  qefem_best_cut    gap  \
# 0         15   G63  7000  41459         27047.0         26755.0  292.0
# 1         15   G64  7000  41459          8751.0          8440.0  311.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         98.920398        800           102       128   1000      Adam  0.01
# 1         96.446120        900           114       128   1000      Adam  0.01
#
#    runtime_sec
# 0    28.825478
# 1    28.199235
# ================================================================================
# SAVED SELECTED PARTITION RESULTS
# ================================================================================
# Partition: 15
#
# Saved history CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_15_history.csv
#
# Saved summary CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_15_summary.csv
#
# Saved best spins PT:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_15_best_spins.pt
#
# Final selected-partition summary:
#    partition graph     N      M  best_known_cut  qefem_best_cut    gap  \
# 0         15   G63  7000  41459         27047.0         26755.0  292.0
# 1         15   G64  7000  41459          8751.0          8440.0  311.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         98.920398        800           102       128   1000      Adam  0.01
# 1         96.446120        900           114       128   1000      Adam  0.01
#
#    runtime_sec
# 0    28.825478
# 1    28.199235

# %%
assert "BIG_GSET_PARTITIONS" in globals(), (
    "Run Cell 25 first: BIG_GSET_PARTITIONS is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


# ------------------------------------------------------------
# Change this after each completed partition
# ------------------------------------------------------------

SELECTED_BIG_GSET_PARTITION = 16


# ------------------------------------------------------------
# Select graphs in this partition
# ------------------------------------------------------------

assert SELECTED_BIG_GSET_PARTITION in BIG_GSET_PARTITIONS, (
    f"Partition {SELECTED_BIG_GSET_PARTITION} is not defined."
)

selected_big_gset_graphs = BIG_GSET_PARTITIONS[SELECTED_BIG_GSET_PARTITION]


print("=" * 80)
print("NEXT BIG-GSET PARTITION SELECTED")
print("=" * 80)

print(
    f"Partition {SELECTED_BIG_GSET_PARTITION}: "
    f"{selected_big_gset_graphs[0]}-{selected_big_gset_graphs[-1]} | "
    f"{len(selected_big_gset_graphs)} graphs | "
    f"{selected_big_gset_graphs}"
)


# ------------------------------------------------------------
# Quick file check
# ------------------------------------------------------------

missing_graphs = []

for graph in selected_big_gset_graphs:
    path = GSET_DIR / graph

    print(f"{graph}: {path.exists()} | {path}")

    if not path.exists():
        missing_graphs.append(graph)

assert len(missing_graphs) == 0, (
    f"Missing graph files: {missing_graphs}"
)


# ------------------------------------------------------------
# Benchmark preview for this partition
# ------------------------------------------------------------

selected_partition_benchmark_df = big_gset_benchmark_df[
    big_gset_benchmark_df["partition"] == SELECTED_BIG_GSET_PARTITION
].copy()

display(selected_partition_benchmark_df)

assert len(selected_partition_benchmark_df) == len(selected_big_gset_graphs), (
    "Benchmark table row count does not match selected partition graph count."
)

assert "selected_big_gset_graphs" in globals(), (
    "Run Cell 32 first: selected_big_gset_graphs is missing."
)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "load_gset_edge_list" in globals(), (
    "Run Cell 26 first: load_gset_edge_list is missing."
)

assert "edge_qefem_free_energy" in globals(), (
    "Run Cell 30 first: edge_qefem_free_energy is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)

assert "big_gset_beta_schedule" in globals(), (
    "Run Cell 31 first: big_gset_beta_schedule is missing."
)

assert "big_gset_gamma_schedule" in globals(), (
    "Run Cell 31 first: big_gset_gamma_schedule is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


selected_partition_history_rows = []
selected_partition_summary_rows = []
selected_partition_best_spins = {}


print("=" * 80)
print("RUNNING SELECTED BIG-GSET PARTITION")
print("=" * 80)
print("Partition:", SELECTED_BIG_GSET_PARTITION)
print("Graphs:", selected_big_gset_graphs)
print("Replicas:", BIG_GSET_REPLICAS)
print("Steps:", BIG_GSET_N_STEPS)
print("Optimizer: Adam")
print("Adam lr:", BIG_GSET_ADAM_LR)


for graph in selected_big_gset_graphs:
    print("\n" + "=" * 80)
    print("START GRAPH:", graph)
    print("=" * 80)

    N_g, edge_i, edge_j, edge_w, info = load_gset_edge_list(graph)

    graph_benchmark_row = big_gset_benchmark_df[
        big_gset_benchmark_df["graph"] == graph
    ].iloc[0]

    best_known_cut = float(graph_benchmark_row["best_known_cut"])

    print("N:", N_g)
    print("M:", info["M"])
    print("Best-known cut:", best_known_cut)

    torch.manual_seed(BIG_GSET_SEED)

    R_INIT_tensor = torch.tensor(
        R_INIT,
        device=device,
        dtype=DTYPE,
    )

    raw_R_init_value = torch.log(
        R_INIT_tensor / (1.0 - R_INIT_tensor)
    )

    raw_R = raw_R_init_value + 1e-3 * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    theta = THETA_CENTER + THETA_NOISE * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    raw_R.requires_grad_(True)
    theta.requires_grad_(True)

    optimizer = torch.optim.Adam(
        [raw_R, theta],
        lr=BIG_GSET_ADAM_LR,
    )

    best_cut = -float("inf")
    best_step = None
    best_replica = None
    best_spins = None

    graph_start_time = time.time()

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    for step in range(BIG_GSET_N_STEPS):
        beta_t = big_gset_beta_schedule[step]
        gamma_t = big_gset_gamma_schedule[step]

        optimizer.zero_grad()

        F, aux = edge_qefem_free_energy(
            edge_i=edge_i,
            edge_j=edge_j,
            edge_w=edge_w,
            raw_R=raw_R,
            theta=theta,
            beta=beta_t,
            gamma=gamma_t,
        )

        loss = F.mean()

        loss.backward()
        optimizer.step()

        should_log = (
            step == 0
            or step == BIG_GSET_N_STEPS - 1
            or (step + 1) % BIG_GSET_LOG_EVERY == 0
        )

        if should_log:
            if edge_w.device.type == "mps":
                torch.mps.synchronize()

            elapsed = time.time() - graph_start_time

            with torch.no_grad():
                R_now, rx_now, rz_now = bloch_from_raw(
                    raw_R,
                    theta,
                )

                spins_now = torch.where(
                    rz_now >= 0,
                    torch.ones_like(rz_now),
                    -torch.ones_like(rz_now),
                )

                hard_cuts_now = edge_discrete_cut(
                    edge_i=edge_i,
                    edge_j=edge_j,
                    edge_w=edge_w,
                    spins=spins_now,
                )

                current_best_cut_tensor, current_best_replica_tensor = torch.max(
                    hard_cuts_now,
                    dim=0,
                )

                current_best_cut = float(current_best_cut_tensor.detach().cpu())
                current_best_replica = int(current_best_replica_tensor.detach().cpu())

                if current_best_cut > best_cut:
                    best_cut = current_best_cut
                    best_step = step + 1
                    best_replica = current_best_replica
                    best_spins = spins_now[current_best_replica].detach().cpu().clone()

                gap = best_known_cut - best_cut
                accuracy_percent = 100.0 * best_cut / best_known_cut

                selected_partition_history_rows.append(
                    {
                        "partition": SELECTED_BIG_GSET_PARTITION,
                        "graph": graph,
                        "step": step + 1,
                        "beta": float(beta_t.detach().cpu()),
                        "gamma": float(gamma_t.detach().cpu()),
                        "loss": float(loss.detach().cpu()),
                        "free_energy_mean": float(F.mean().detach().cpu()),
                        "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
                        "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),
                        "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
                        "hard_cut_max": current_best_cut,
                        "best_cut_so_far": best_cut,
                        "best_known_cut": best_known_cut,
                        "gap": gap,
                        "accuracy_percent": accuracy_percent,
                        "R_mean": float(R_now.mean().detach().cpu()),
                        "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),
                        "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),
                        "best_replica_so_far": best_replica,
                        "elapsed_sec": elapsed,
                    }
                )

                print(
                    f"{graph} | "
                    f"step {step + 1:5d}/{BIG_GSET_N_STEPS} | "
                    f"cut={current_best_cut:10.1f} | "
                    f"best={best_cut:10.1f} | "
                    f"gap={gap:10.1f} | "
                    f"acc={accuracy_percent:7.3f}% | "
                    f"|rz|={float(rz_now.abs().mean().detach().cpu()):.4f} | "
                    f"time={elapsed:8.2f}s"
                )

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    graph_runtime = time.time() - graph_start_time

    selected_partition_summary_rows.append(
        {
            "partition": SELECTED_BIG_GSET_PARTITION,
            "graph": graph,
            "N": N_g,
            "M": info["M"],
            "best_known_cut": best_known_cut,
            "qefem_best_cut": best_cut,
            "gap": best_known_cut - best_cut,
            "accuracy_percent": 100.0 * best_cut / best_known_cut,
            "best_step": best_step,
            "best_replica": best_replica,
            "replicas": BIG_GSET_REPLICAS,
            "steps": BIG_GSET_N_STEPS,
            "optimizer": "Adam",
            "lr": BIG_GSET_ADAM_LR,
            "runtime_sec": graph_runtime,
        }
    )

    selected_partition_best_spins[graph] = best_spins

    print("\nFINISHED GRAPH:", graph)
    print("Best cut:", best_cut)
    print("Best-known:", best_known_cut)
    print("Gap:", best_known_cut - best_cut)
    print("Accuracy %:", 100.0 * best_cut / best_known_cut)
    print("Runtime sec:", graph_runtime)


selected_partition_history_df = pd.DataFrame(selected_partition_history_rows)
selected_partition_summary_df = pd.DataFrame(selected_partition_summary_rows)

print("\n" + "=" * 80)
print("SELECTED PARTITION SUMMARY")
print("=" * 80)

display(selected_partition_summary_df)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "selected_partition_history_df" in globals(), (
    "Run Cell 37 first: selected_partition_history_df is missing."
)

assert "selected_partition_summary_df" in globals(), (
    "Run Cell 37 first: selected_partition_summary_df is missing."
)

assert "selected_partition_best_spins" in globals(), (
    "Run Cell 37 first: selected_partition_best_spins is missing."
)


# ------------------------------------------------------------
# Output folder
# ------------------------------------------------------------

BIG_GSET_OUTPUT_DIR = Path("qefem_big_gset_outputs")
BIG_GSET_OUTPUT_DIR.mkdir(exist_ok=True)


# ------------------------------------------------------------
# File names
# ------------------------------------------------------------

partition_tag = f"partition_{SELECTED_BIG_GSET_PARTITION}"

history_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_history.csv"
summary_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_summary.csv"
spins_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_best_spins.pt"


# ------------------------------------------------------------
# Save CSV files
# ------------------------------------------------------------

selected_partition_history_df.to_csv(
    history_path,
    index=False,
)

selected_partition_summary_df.to_csv(
    summary_path,
    index=False,
)


# ------------------------------------------------------------
# Save best spins dictionary
# ------------------------------------------------------------

torch.save(
    selected_partition_best_spins,
    spins_path,
)


# ------------------------------------------------------------
# Print saved paths
# ------------------------------------------------------------

print("=" * 80)
print("SAVED SELECTED PARTITION RESULTS")
print("=" * 80)

print("Partition:", SELECTED_BIG_GSET_PARTITION)

print("\nSaved history CSV:")
print(history_path.resolve())

print("\nSaved summary CSV:")
print(summary_path.resolve())

print("\nSaved best spins PT:")
print(spins_path.resolve())


# ------------------------------------------------------------
# Display final summary
# ------------------------------------------------------------

print("\nFinal selected-partition summary:")
display(selected_partition_summary_df)


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert history_path.exists(), (
    f"History file was not saved: {history_path}"
)

assert summary_path.exists(), (
    f"Summary file was not saved: {summary_path}"
)

assert spins_path.exists(), (
    f"Best-spins file was not saved: {spins_path}"
)

assert len(selected_partition_summary_df) > 0, (
    "Summary dataframe is empty."
)

assert len(selected_partition_history_df) > 0, (
    "History dataframe is empty."
)
# Out:
# ================================================================================
# NEXT BIG-GSET PARTITION SELECTED
# ================================================================================
# Partition 16: G65-G65 | 1 graphs | ['G65']
# G65: True | ../data-gset/G65
#     partition graph     N      M  density_upper_percent  positive_edges  \
# 10         16   G65  8000  16000               0.050006            7959
#
#     negative_edges  positive_edge_fraction  negative_edge_fraction  \
# 10            8041                0.497437                0.502563
#
#     weight_sum  best_known_cut  best_known_cut_per_edge  dense_W_float32_MB  \
# 10       -82.0          5562.0                 0.347625          244.140625
#
#    device          dtype
# 10  mps:0  torch.float32
# ================================================================================
# RUNNING SELECTED BIG-GSET PARTITION
# ================================================================================
# Partition: 16
# Graphs: ['G65']
# Replicas: 128
# Steps: 1000
# Optimizer: Adam
# Adam lr: 0.01
#
# ================================================================================
# START GRAPH: G65
# ================================================================================
# N: 8000
# M: 16000
# Best-known cut: 5562.0
# G65 | step     1/1000 | cut=      64.0 | best=      64.0 | gap=    5498.0 | acc=  1.151% | |rz|=0.0001 | time=    0.04s
# G65 | step    50/1000 | cut=     108.0 | best=     108.0 | gap=    5454.0 | acc=  1.942% | |rz|=0.0000 | time=    1.10s
# G65 | step   100/1000 | cut=    -244.0 | best=     108.0 | gap=    5454.0 | acc=  1.942% | |rz|=0.0000 | time=    2.02s
# G65 | step   150/1000 | cut=   -1130.0 | best=     108.0 | gap=    5454.0 | acc=  1.942% | |rz|=0.0000 | time=    3.01s
# G65 | step   200/1000 | cut=   -1440.0 | best=     108.0 | gap=    5454.0 | acc=  1.942% | |rz|=0.0001 | time=    4.11s
# G65 | step   250/1000 | cut=   -2662.0 | best=     108.0 | gap=    5454.0 | acc=  1.942% | |rz|=0.0002 | time=    5.14s
# G65 | step   300/1000 | cut=      34.0 | best=     108.0 | gap=    5454.0 | acc=  1.942% | |rz|=0.0005 | time=    6.21s
# G65 | step   350/1000 | cut=    5440.0 | best=    5440.0 | gap=     122.0 | acc= 97.807% | |rz|=0.3926 | time=    7.29s
# G65 | step   400/1000 | cut=    5450.0 | best=    5450.0 | gap=     112.0 | acc= 97.986% | |rz|=0.5775 | time=    8.32s
# G65 | step   450/1000 | cut=    5450.0 | best=    5450.0 | gap=     112.0 | acc= 97.986% | |rz|=0.6797 | time=    9.20s
# G65 | step   500/1000 | cut=    5450.0 | best=    5450.0 | gap=     112.0 | acc= 97.986% | |rz|=0.7406 | time=   10.13s
# G65 | step   550/1000 | cut=    5450.0 | best=    5450.0 | gap=     112.0 | acc= 97.986% | |rz|=0.7819 | time=   11.02s
# G65 | step   600/1000 | cut=    5450.0 | best=    5450.0 | gap=     112.0 | acc= 97.986% | |rz|=0.8127 | time=   11.89s
# G65 | step   650/1000 | cut=    5450.0 | best=    5450.0 | gap=     112.0 | acc= 97.986% | |rz|=0.8371 | time=   12.77s
# G65 | step   700/1000 | cut=    5450.0 | best=    5450.0 | gap=     112.0 | acc= 97.986% | |rz|=0.8572 | time=   13.65s
# G65 | step   750/1000 | cut=    5450.0 | best=    5450.0 | gap=     112.0 | acc= 97.986% | |rz|=0.8739 | time=   14.71s
# G65 | step   800/1000 | cut=    5450.0 | best=    5450.0 | gap=     112.0 | acc= 97.986% | |rz|=0.8881 | time=   15.71s
# G65 | step   850/1000 | cut=    5450.0 | best=    5450.0 | gap=     112.0 | acc= 97.986% | |rz|=0.9000 | time=   16.77s
# G65 | step   900/1000 | cut=    5450.0 | best=    5450.0 | gap=     112.0 | acc= 97.986% | |rz|=0.9103 | time=   17.84s
# G65 | step   950/1000 | cut=    5450.0 | best=    5450.0 | gap=     112.0 | acc= 97.986% | |rz|=0.9207 | time=   18.85s
# G65 | step  1000/1000 | cut=    5450.0 | best=    5450.0 | gap=     112.0 | acc= 97.986% | |rz|=0.9413 | time=   19.73s
#
# FINISHED GRAPH: G65
# Best cut: 5450.0
# Best-known: 5562.0
# Gap: 112.0
# Accuracy %: 97.98633585041352
# Runtime sec: 19.745007753372192
#
# ================================================================================
# SELECTED PARTITION SUMMARY
# ================================================================================
#    partition graph     N      M  best_known_cut  qefem_best_cut    gap  \
# 0         16   G65  8000  16000          5562.0          5450.0  112.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         97.986336        400            89       128   1000      Adam  0.01
#
#    runtime_sec
# 0    19.745008
# ================================================================================
# SAVED SELECTED PARTITION RESULTS
# ================================================================================
# Partition: 16
#
# Saved history CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_16_history.csv
#
# Saved summary CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_16_summary.csv
#
# Saved best spins PT:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_16_best_spins.pt
#
# Final selected-partition summary:
#    partition graph     N      M  best_known_cut  qefem_best_cut    gap  \
# 0         16   G65  8000  16000          5562.0          5450.0  112.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         97.986336        400            89       128   1000      Adam  0.01
#
#    runtime_sec
# 0    19.745008

# %%
assert "BIG_GSET_PARTITIONS" in globals(), (
    "Run Cell 25 first: BIG_GSET_PARTITIONS is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


# ------------------------------------------------------------
# Change this after each completed partition
# ------------------------------------------------------------

SELECTED_BIG_GSET_PARTITION = 17


# ------------------------------------------------------------
# Select graphs in this partition
# ------------------------------------------------------------

assert SELECTED_BIG_GSET_PARTITION in BIG_GSET_PARTITIONS, (
    f"Partition {SELECTED_BIG_GSET_PARTITION} is not defined."
)

selected_big_gset_graphs = BIG_GSET_PARTITIONS[SELECTED_BIG_GSET_PARTITION]


print("=" * 80)
print("NEXT BIG-GSET PARTITION SELECTED")
print("=" * 80)

print(
    f"Partition {SELECTED_BIG_GSET_PARTITION}: "
    f"{selected_big_gset_graphs[0]}-{selected_big_gset_graphs[-1]} | "
    f"{len(selected_big_gset_graphs)} graphs | "
    f"{selected_big_gset_graphs}"
)


# ------------------------------------------------------------
# Quick file check
# ------------------------------------------------------------

missing_graphs = []

for graph in selected_big_gset_graphs:
    path = GSET_DIR / graph

    print(f"{graph}: {path.exists()} | {path}")

    if not path.exists():
        missing_graphs.append(graph)

assert len(missing_graphs) == 0, (
    f"Missing graph files: {missing_graphs}"
)


# ------------------------------------------------------------
# Benchmark preview for this partition
# ------------------------------------------------------------

selected_partition_benchmark_df = big_gset_benchmark_df[
    big_gset_benchmark_df["partition"] == SELECTED_BIG_GSET_PARTITION
].copy()

display(selected_partition_benchmark_df)

assert len(selected_partition_benchmark_df) == len(selected_big_gset_graphs), (
    "Benchmark table row count does not match selected partition graph count."
)

assert "selected_big_gset_graphs" in globals(), (
    "Run Cell 32 first: selected_big_gset_graphs is missing."
)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "load_gset_edge_list" in globals(), (
    "Run Cell 26 first: load_gset_edge_list is missing."
)

assert "edge_qefem_free_energy" in globals(), (
    "Run Cell 30 first: edge_qefem_free_energy is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)

assert "big_gset_beta_schedule" in globals(), (
    "Run Cell 31 first: big_gset_beta_schedule is missing."
)

assert "big_gset_gamma_schedule" in globals(), (
    "Run Cell 31 first: big_gset_gamma_schedule is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


selected_partition_history_rows = []
selected_partition_summary_rows = []
selected_partition_best_spins = {}


print("=" * 80)
print("RUNNING SELECTED BIG-GSET PARTITION")
print("=" * 80)
print("Partition:", SELECTED_BIG_GSET_PARTITION)
print("Graphs:", selected_big_gset_graphs)
print("Replicas:", BIG_GSET_REPLICAS)
print("Steps:", BIG_GSET_N_STEPS)
print("Optimizer: Adam")
print("Adam lr:", BIG_GSET_ADAM_LR)


for graph in selected_big_gset_graphs:
    print("\n" + "=" * 80)
    print("START GRAPH:", graph)
    print("=" * 80)

    N_g, edge_i, edge_j, edge_w, info = load_gset_edge_list(graph)

    graph_benchmark_row = big_gset_benchmark_df[
        big_gset_benchmark_df["graph"] == graph
    ].iloc[0]

    best_known_cut = float(graph_benchmark_row["best_known_cut"])

    print("N:", N_g)
    print("M:", info["M"])
    print("Best-known cut:", best_known_cut)

    torch.manual_seed(BIG_GSET_SEED)

    R_INIT_tensor = torch.tensor(
        R_INIT,
        device=device,
        dtype=DTYPE,
    )

    raw_R_init_value = torch.log(
        R_INIT_tensor / (1.0 - R_INIT_tensor)
    )

    raw_R = raw_R_init_value + 1e-3 * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    theta = THETA_CENTER + THETA_NOISE * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    raw_R.requires_grad_(True)
    theta.requires_grad_(True)

    optimizer = torch.optim.Adam(
        [raw_R, theta],
        lr=BIG_GSET_ADAM_LR,
    )

    best_cut = -float("inf")
    best_step = None
    best_replica = None
    best_spins = None

    graph_start_time = time.time()

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    for step in range(BIG_GSET_N_STEPS):
        beta_t = big_gset_beta_schedule[step]
        gamma_t = big_gset_gamma_schedule[step]

        optimizer.zero_grad()

        F, aux = edge_qefem_free_energy(
            edge_i=edge_i,
            edge_j=edge_j,
            edge_w=edge_w,
            raw_R=raw_R,
            theta=theta,
            beta=beta_t,
            gamma=gamma_t,
        )

        loss = F.mean()

        loss.backward()
        optimizer.step()

        should_log = (
            step == 0
            or step == BIG_GSET_N_STEPS - 1
            or (step + 1) % BIG_GSET_LOG_EVERY == 0
        )

        if should_log:
            if edge_w.device.type == "mps":
                torch.mps.synchronize()

            elapsed = time.time() - graph_start_time

            with torch.no_grad():
                R_now, rx_now, rz_now = bloch_from_raw(
                    raw_R,
                    theta,
                )

                spins_now = torch.where(
                    rz_now >= 0,
                    torch.ones_like(rz_now),
                    -torch.ones_like(rz_now),
                )

                hard_cuts_now = edge_discrete_cut(
                    edge_i=edge_i,
                    edge_j=edge_j,
                    edge_w=edge_w,
                    spins=spins_now,
                )

                current_best_cut_tensor, current_best_replica_tensor = torch.max(
                    hard_cuts_now,
                    dim=0,
                )

                current_best_cut = float(current_best_cut_tensor.detach().cpu())
                current_best_replica = int(current_best_replica_tensor.detach().cpu())

                if current_best_cut > best_cut:
                    best_cut = current_best_cut
                    best_step = step + 1
                    best_replica = current_best_replica
                    best_spins = spins_now[current_best_replica].detach().cpu().clone()

                gap = best_known_cut - best_cut
                accuracy_percent = 100.0 * best_cut / best_known_cut

                selected_partition_history_rows.append(
                    {
                        "partition": SELECTED_BIG_GSET_PARTITION,
                        "graph": graph,
                        "step": step + 1,
                        "beta": float(beta_t.detach().cpu()),
                        "gamma": float(gamma_t.detach().cpu()),
                        "loss": float(loss.detach().cpu()),
                        "free_energy_mean": float(F.mean().detach().cpu()),
                        "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
                        "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),
                        "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
                        "hard_cut_max": current_best_cut,
                        "best_cut_so_far": best_cut,
                        "best_known_cut": best_known_cut,
                        "gap": gap,
                        "accuracy_percent": accuracy_percent,
                        "R_mean": float(R_now.mean().detach().cpu()),
                        "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),
                        "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),
                        "best_replica_so_far": best_replica,
                        "elapsed_sec": elapsed,
                    }
                )

                print(
                    f"{graph} | "
                    f"step {step + 1:5d}/{BIG_GSET_N_STEPS} | "
                    f"cut={current_best_cut:10.1f} | "
                    f"best={best_cut:10.1f} | "
                    f"gap={gap:10.1f} | "
                    f"acc={accuracy_percent:7.3f}% | "
                    f"|rz|={float(rz_now.abs().mean().detach().cpu()):.4f} | "
                    f"time={elapsed:8.2f}s"
                )

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    graph_runtime = time.time() - graph_start_time

    selected_partition_summary_rows.append(
        {
            "partition": SELECTED_BIG_GSET_PARTITION,
            "graph": graph,
            "N": N_g,
            "M": info["M"],
            "best_known_cut": best_known_cut,
            "qefem_best_cut": best_cut,
            "gap": best_known_cut - best_cut,
            "accuracy_percent": 100.0 * best_cut / best_known_cut,
            "best_step": best_step,
            "best_replica": best_replica,
            "replicas": BIG_GSET_REPLICAS,
            "steps": BIG_GSET_N_STEPS,
            "optimizer": "Adam",
            "lr": BIG_GSET_ADAM_LR,
            "runtime_sec": graph_runtime,
        }
    )

    selected_partition_best_spins[graph] = best_spins

    print("\nFINISHED GRAPH:", graph)
    print("Best cut:", best_cut)
    print("Best-known:", best_known_cut)
    print("Gap:", best_known_cut - best_cut)
    print("Accuracy %:", 100.0 * best_cut / best_known_cut)
    print("Runtime sec:", graph_runtime)


selected_partition_history_df = pd.DataFrame(selected_partition_history_rows)
selected_partition_summary_df = pd.DataFrame(selected_partition_summary_rows)

print("\n" + "=" * 80)
print("SELECTED PARTITION SUMMARY")
print("=" * 80)

display(selected_partition_summary_df)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "selected_partition_history_df" in globals(), (
    "Run Cell 37 first: selected_partition_history_df is missing."
)

assert "selected_partition_summary_df" in globals(), (
    "Run Cell 37 first: selected_partition_summary_df is missing."
)

assert "selected_partition_best_spins" in globals(), (
    "Run Cell 37 first: selected_partition_best_spins is missing."
)


# ------------------------------------------------------------
# Output folder
# ------------------------------------------------------------

BIG_GSET_OUTPUT_DIR = Path("qefem_big_gset_outputs")
BIG_GSET_OUTPUT_DIR.mkdir(exist_ok=True)


# ------------------------------------------------------------
# File names
# ------------------------------------------------------------

partition_tag = f"partition_{SELECTED_BIG_GSET_PARTITION}"

history_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_history.csv"
summary_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_summary.csv"
spins_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_best_spins.pt"


# ------------------------------------------------------------
# Save CSV files
# ------------------------------------------------------------

selected_partition_history_df.to_csv(
    history_path,
    index=False,
)

selected_partition_summary_df.to_csv(
    summary_path,
    index=False,
)


# ------------------------------------------------------------
# Save best spins dictionary
# ------------------------------------------------------------

torch.save(
    selected_partition_best_spins,
    spins_path,
)


# ------------------------------------------------------------
# Print saved paths
# ------------------------------------------------------------

print("=" * 80)
print("SAVED SELECTED PARTITION RESULTS")
print("=" * 80)

print("Partition:", SELECTED_BIG_GSET_PARTITION)

print("\nSaved history CSV:")
print(history_path.resolve())

print("\nSaved summary CSV:")
print(summary_path.resolve())

print("\nSaved best spins PT:")
print(spins_path.resolve())


# ------------------------------------------------------------
# Display final summary
# ------------------------------------------------------------

print("\nFinal selected-partition summary:")
display(selected_partition_summary_df)


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert history_path.exists(), (
    f"History file was not saved: {history_path}"
)

assert summary_path.exists(), (
    f"Summary file was not saved: {summary_path}"
)

assert spins_path.exists(), (
    f"Best-spins file was not saved: {spins_path}"
)

assert len(selected_partition_summary_df) > 0, (
    "Summary dataframe is empty."
)

assert len(selected_partition_history_df) > 0, (
    "History dataframe is empty."
)
# Out:
# ================================================================================
# NEXT BIG-GSET PARTITION SELECTED
# ================================================================================
# Partition 17: G66-G66 | 1 graphs | ['G66']
# G66: True | ../data-gset/G66
#     partition graph     N      M  density_upper_percent  positive_edges  \
# 11         17   G66  9000  18000               0.044449            9040
#
#     negative_edges  positive_edge_fraction  negative_edge_fraction  \
# 11            8960                0.502222                0.497778
#
#     weight_sum  best_known_cut  best_known_cut_per_edge  dense_W_float32_MB  \
# 11        80.0          6364.0                 0.353556          308.990479
#
#    device          dtype
# 11  mps:0  torch.float32
# ================================================================================
# RUNNING SELECTED BIG-GSET PARTITION
# ================================================================================
# Partition: 17
# Graphs: ['G66']
# Replicas: 128
# Steps: 1000
# Optimizer: Adam
# Adam lr: 0.01
#
# ================================================================================
# START GRAPH: G66
# ================================================================================
# N: 9000
# M: 18000
# Best-known cut: 6364.0
# G66 | step     1/1000 | cut=     150.0 | best=     150.0 | gap=    6214.0 | acc=  2.357% | |rz|=0.0001 | time=    0.04s
# G66 | step    50/1000 | cut=     222.0 | best=     222.0 | gap=    6142.0 | acc=  3.488% | |rz|=0.0000 | time=    1.24s
# G66 | step   100/1000 | cut=    -214.0 | best=     222.0 | gap=    6142.0 | acc=  3.488% | |rz|=0.0000 | time=    2.31s
# G66 | step   150/1000 | cut=   -1194.0 | best=     222.0 | gap=    6142.0 | acc=  3.488% | |rz|=0.0000 | time=    3.31s
# G66 | step   200/1000 | cut=   -1500.0 | best=     222.0 | gap=    6142.0 | acc=  3.488% | |rz|=0.0001 | time=    4.31s
# G66 | step   250/1000 | cut=   -2848.0 | best=     222.0 | gap=    6142.0 | acc=  3.488% | |rz|=0.0002 | time=    5.35s
# G66 | step   300/1000 | cut=     762.0 | best=     762.0 | gap=    5602.0 | acc= 11.974% | |rz|=0.0006 | time=    6.41s
# G66 | step   350/1000 | cut=    6216.0 | best=    6216.0 | gap=     148.0 | acc= 97.674% | |rz|=0.3929 | time=    7.56s
# G66 | step   400/1000 | cut=    6228.0 | best=    6228.0 | gap=     136.0 | acc= 97.863% | |rz|=0.5774 | time=    8.87s
# G66 | step   450/1000 | cut=    6228.0 | best=    6228.0 | gap=     136.0 | acc= 97.863% | |rz|=0.6793 | time=   10.10s
# G66 | step   500/1000 | cut=    6228.0 | best=    6228.0 | gap=     136.0 | acc= 97.863% | |rz|=0.7400 | time=   11.19s
# G66 | step   550/1000 | cut=    6228.0 | best=    6228.0 | gap=     136.0 | acc= 97.863% | |rz|=0.7812 | time=   12.22s
# G66 | step   600/1000 | cut=    6228.0 | best=    6228.0 | gap=     136.0 | acc= 97.863% | |rz|=0.8120 | time=   13.30s
# G66 | step   650/1000 | cut=    6228.0 | best=    6228.0 | gap=     136.0 | acc= 97.863% | |rz|=0.8364 | time=   14.40s
# G66 | step   700/1000 | cut=    6228.0 | best=    6228.0 | gap=     136.0 | acc= 97.863% | |rz|=0.8564 | time=   15.53s
# G66 | step   750/1000 | cut=    6228.0 | best=    6228.0 | gap=     136.0 | acc= 97.863% | |rz|=0.8731 | time=   16.63s
# G66 | step   800/1000 | cut=    6228.0 | best=    6228.0 | gap=     136.0 | acc= 97.863% | |rz|=0.8873 | time=   17.72s
# G66 | step   850/1000 | cut=    6228.0 | best=    6228.0 | gap=     136.0 | acc= 97.863% | |rz|=0.8992 | time=   18.80s
# G66 | step   900/1000 | cut=    6228.0 | best=    6228.0 | gap=     136.0 | acc= 97.863% | |rz|=0.9096 | time=   20.00s
# G66 | step   950/1000 | cut=    6228.0 | best=    6228.0 | gap=     136.0 | acc= 97.863% | |rz|=0.9200 | time=   21.21s
# G66 | step  1000/1000 | cut=    6228.0 | best=    6228.0 | gap=     136.0 | acc= 97.863% | |rz|=0.9407 | time=   22.28s
#
# FINISHED GRAPH: G66
# Best cut: 6228.0
# Best-known: 6364.0
# Gap: 136.0
# Accuracy %: 97.8629792583281
# Runtime sec: 22.29799485206604
#
# ================================================================================
# SELECTED PARTITION SUMMARY
# ================================================================================
#    partition graph     N      M  best_known_cut  qefem_best_cut    gap  \
# 0         17   G66  9000  18000          6364.0          6228.0  136.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         97.862979        400            95       128   1000      Adam  0.01
#
#    runtime_sec
# 0    22.297995
# ================================================================================
# SAVED SELECTED PARTITION RESULTS
# ================================================================================
# Partition: 17
#
# Saved history CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_17_history.csv
#
# Saved summary CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_17_summary.csv
#
# Saved best spins PT:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_17_best_spins.pt
#
# Final selected-partition summary:
#    partition graph     N      M  best_known_cut  qefem_best_cut    gap  \
# 0         17   G66  9000  18000          6364.0          6228.0  136.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         97.862979        400            95       128   1000      Adam  0.01
#
#    runtime_sec
# 0    22.297995

# %%
assert "BIG_GSET_PARTITIONS" in globals(), (
    "Run Cell 25 first: BIG_GSET_PARTITIONS is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


# ------------------------------------------------------------
# Change this after each completed partition
# ------------------------------------------------------------

SELECTED_BIG_GSET_PARTITION = 18


# ------------------------------------------------------------
# Select graphs in this partition
# ------------------------------------------------------------

assert SELECTED_BIG_GSET_PARTITION in BIG_GSET_PARTITIONS, (
    f"Partition {SELECTED_BIG_GSET_PARTITION} is not defined."
)

selected_big_gset_graphs = BIG_GSET_PARTITIONS[SELECTED_BIG_GSET_PARTITION]


print("=" * 80)
print("NEXT BIG-GSET PARTITION SELECTED")
print("=" * 80)

print(
    f"Partition {SELECTED_BIG_GSET_PARTITION}: "
    f"{selected_big_gset_graphs[0]}-{selected_big_gset_graphs[-1]} | "
    f"{len(selected_big_gset_graphs)} graphs | "
    f"{selected_big_gset_graphs}"
)


# ------------------------------------------------------------
# Quick file check
# ------------------------------------------------------------

missing_graphs = []

for graph in selected_big_gset_graphs:
    path = GSET_DIR / graph

    print(f"{graph}: {path.exists()} | {path}")

    if not path.exists():
        missing_graphs.append(graph)

assert len(missing_graphs) == 0, (
    f"Missing graph files: {missing_graphs}"
)


# ------------------------------------------------------------
# Benchmark preview for this partition
# ------------------------------------------------------------

selected_partition_benchmark_df = big_gset_benchmark_df[
    big_gset_benchmark_df["partition"] == SELECTED_BIG_GSET_PARTITION
].copy()

display(selected_partition_benchmark_df)

assert len(selected_partition_benchmark_df) == len(selected_big_gset_graphs), (
    "Benchmark table row count does not match selected partition graph count."
)

assert "selected_big_gset_graphs" in globals(), (
    "Run Cell 32 first: selected_big_gset_graphs is missing."
)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "load_gset_edge_list" in globals(), (
    "Run Cell 26 first: load_gset_edge_list is missing."
)

assert "edge_qefem_free_energy" in globals(), (
    "Run Cell 30 first: edge_qefem_free_energy is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)

assert "big_gset_beta_schedule" in globals(), (
    "Run Cell 31 first: big_gset_beta_schedule is missing."
)

assert "big_gset_gamma_schedule" in globals(), (
    "Run Cell 31 first: big_gset_gamma_schedule is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


selected_partition_history_rows = []
selected_partition_summary_rows = []
selected_partition_best_spins = {}


print("=" * 80)
print("RUNNING SELECTED BIG-GSET PARTITION")
print("=" * 80)
print("Partition:", SELECTED_BIG_GSET_PARTITION)
print("Graphs:", selected_big_gset_graphs)
print("Replicas:", BIG_GSET_REPLICAS)
print("Steps:", BIG_GSET_N_STEPS)
print("Optimizer: Adam")
print("Adam lr:", BIG_GSET_ADAM_LR)


for graph in selected_big_gset_graphs:
    print("\n" + "=" * 80)
    print("START GRAPH:", graph)
    print("=" * 80)

    N_g, edge_i, edge_j, edge_w, info = load_gset_edge_list(graph)

    graph_benchmark_row = big_gset_benchmark_df[
        big_gset_benchmark_df["graph"] == graph
    ].iloc[0]

    best_known_cut = float(graph_benchmark_row["best_known_cut"])

    print("N:", N_g)
    print("M:", info["M"])
    print("Best-known cut:", best_known_cut)

    torch.manual_seed(BIG_GSET_SEED)

    R_INIT_tensor = torch.tensor(
        R_INIT,
        device=device,
        dtype=DTYPE,
    )

    raw_R_init_value = torch.log(
        R_INIT_tensor / (1.0 - R_INIT_tensor)
    )

    raw_R = raw_R_init_value + 1e-3 * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    theta = THETA_CENTER + THETA_NOISE * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    raw_R.requires_grad_(True)
    theta.requires_grad_(True)

    optimizer = torch.optim.Adam(
        [raw_R, theta],
        lr=BIG_GSET_ADAM_LR,
    )

    best_cut = -float("inf")
    best_step = None
    best_replica = None
    best_spins = None

    graph_start_time = time.time()

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    for step in range(BIG_GSET_N_STEPS):
        beta_t = big_gset_beta_schedule[step]
        gamma_t = big_gset_gamma_schedule[step]

        optimizer.zero_grad()

        F, aux = edge_qefem_free_energy(
            edge_i=edge_i,
            edge_j=edge_j,
            edge_w=edge_w,
            raw_R=raw_R,
            theta=theta,
            beta=beta_t,
            gamma=gamma_t,
        )

        loss = F.mean()

        loss.backward()
        optimizer.step()

        should_log = (
            step == 0
            or step == BIG_GSET_N_STEPS - 1
            or (step + 1) % BIG_GSET_LOG_EVERY == 0
        )

        if should_log:
            if edge_w.device.type == "mps":
                torch.mps.synchronize()

            elapsed = time.time() - graph_start_time

            with torch.no_grad():
                R_now, rx_now, rz_now = bloch_from_raw(
                    raw_R,
                    theta,
                )

                spins_now = torch.where(
                    rz_now >= 0,
                    torch.ones_like(rz_now),
                    -torch.ones_like(rz_now),
                )

                hard_cuts_now = edge_discrete_cut(
                    edge_i=edge_i,
                    edge_j=edge_j,
                    edge_w=edge_w,
                    spins=spins_now,
                )

                current_best_cut_tensor, current_best_replica_tensor = torch.max(
                    hard_cuts_now,
                    dim=0,
                )

                current_best_cut = float(current_best_cut_tensor.detach().cpu())
                current_best_replica = int(current_best_replica_tensor.detach().cpu())

                if current_best_cut > best_cut:
                    best_cut = current_best_cut
                    best_step = step + 1
                    best_replica = current_best_replica
                    best_spins = spins_now[current_best_replica].detach().cpu().clone()

                gap = best_known_cut - best_cut
                accuracy_percent = 100.0 * best_cut / best_known_cut

                selected_partition_history_rows.append(
                    {
                        "partition": SELECTED_BIG_GSET_PARTITION,
                        "graph": graph,
                        "step": step + 1,
                        "beta": float(beta_t.detach().cpu()),
                        "gamma": float(gamma_t.detach().cpu()),
                        "loss": float(loss.detach().cpu()),
                        "free_energy_mean": float(F.mean().detach().cpu()),
                        "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
                        "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),
                        "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
                        "hard_cut_max": current_best_cut,
                        "best_cut_so_far": best_cut,
                        "best_known_cut": best_known_cut,
                        "gap": gap,
                        "accuracy_percent": accuracy_percent,
                        "R_mean": float(R_now.mean().detach().cpu()),
                        "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),
                        "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),
                        "best_replica_so_far": best_replica,
                        "elapsed_sec": elapsed,
                    }
                )

                print(
                    f"{graph} | "
                    f"step {step + 1:5d}/{BIG_GSET_N_STEPS} | "
                    f"cut={current_best_cut:10.1f} | "
                    f"best={best_cut:10.1f} | "
                    f"gap={gap:10.1f} | "
                    f"acc={accuracy_percent:7.3f}% | "
                    f"|rz|={float(rz_now.abs().mean().detach().cpu()):.4f} | "
                    f"time={elapsed:8.2f}s"
                )

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    graph_runtime = time.time() - graph_start_time

    selected_partition_summary_rows.append(
        {
            "partition": SELECTED_BIG_GSET_PARTITION,
            "graph": graph,
            "N": N_g,
            "M": info["M"],
            "best_known_cut": best_known_cut,
            "qefem_best_cut": best_cut,
            "gap": best_known_cut - best_cut,
            "accuracy_percent": 100.0 * best_cut / best_known_cut,
            "best_step": best_step,
            "best_replica": best_replica,
            "replicas": BIG_GSET_REPLICAS,
            "steps": BIG_GSET_N_STEPS,
            "optimizer": "Adam",
            "lr": BIG_GSET_ADAM_LR,
            "runtime_sec": graph_runtime,
        }
    )

    selected_partition_best_spins[graph] = best_spins

    print("\nFINISHED GRAPH:", graph)
    print("Best cut:", best_cut)
    print("Best-known:", best_known_cut)
    print("Gap:", best_known_cut - best_cut)
    print("Accuracy %:", 100.0 * best_cut / best_known_cut)
    print("Runtime sec:", graph_runtime)


selected_partition_history_df = pd.DataFrame(selected_partition_history_rows)
selected_partition_summary_df = pd.DataFrame(selected_partition_summary_rows)

print("\n" + "=" * 80)
print("SELECTED PARTITION SUMMARY")
print("=" * 80)

display(selected_partition_summary_df)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "selected_partition_history_df" in globals(), (
    "Run Cell 37 first: selected_partition_history_df is missing."
)

assert "selected_partition_summary_df" in globals(), (
    "Run Cell 37 first: selected_partition_summary_df is missing."
)

assert "selected_partition_best_spins" in globals(), (
    "Run Cell 37 first: selected_partition_best_spins is missing."
)


# ------------------------------------------------------------
# Output folder
# ------------------------------------------------------------

BIG_GSET_OUTPUT_DIR = Path("qefem_big_gset_outputs")
BIG_GSET_OUTPUT_DIR.mkdir(exist_ok=True)


# ------------------------------------------------------------
# File names
# ------------------------------------------------------------

partition_tag = f"partition_{SELECTED_BIG_GSET_PARTITION}"

history_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_history.csv"
summary_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_summary.csv"
spins_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_best_spins.pt"


# ------------------------------------------------------------
# Save CSV files
# ------------------------------------------------------------

selected_partition_history_df.to_csv(
    history_path,
    index=False,
)

selected_partition_summary_df.to_csv(
    summary_path,
    index=False,
)


# ------------------------------------------------------------
# Save best spins dictionary
# ------------------------------------------------------------

torch.save(
    selected_partition_best_spins,
    spins_path,
)


# ------------------------------------------------------------
# Print saved paths
# ------------------------------------------------------------

print("=" * 80)
print("SAVED SELECTED PARTITION RESULTS")
print("=" * 80)

print("Partition:", SELECTED_BIG_GSET_PARTITION)

print("\nSaved history CSV:")
print(history_path.resolve())

print("\nSaved summary CSV:")
print(summary_path.resolve())

print("\nSaved best spins PT:")
print(spins_path.resolve())


# ------------------------------------------------------------
# Display final summary
# ------------------------------------------------------------

print("\nFinal selected-partition summary:")
display(selected_partition_summary_df)


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert history_path.exists(), (
    f"History file was not saved: {history_path}"
)

assert summary_path.exists(), (
    f"Summary file was not saved: {summary_path}"
)

assert spins_path.exists(), (
    f"Best-spins file was not saved: {spins_path}"
)

assert len(selected_partition_summary_df) > 0, (
    "Summary dataframe is empty."
)

assert len(selected_partition_history_df) > 0, (
    "History dataframe is empty."
)
# Out:
# ================================================================================
# NEXT BIG-GSET PARTITION SELECTED
# ================================================================================
# Partition 18: G67-G72 | 2 graphs | ['G67', 'G72']
# G67: True | ../data-gset/G67
# G72: True | ../data-gset/G72
#     partition graph      N      M  density_upper_percent  positive_edges  \
# 12         18   G67  10000  20000               0.040004            9929
# 13         18   G72  10000  20000               0.040004            9997
#
#     negative_edges  positive_edge_fraction  negative_edge_fraction  \
# 12           10071                 0.49645                 0.50355
# 13           10003                 0.49985                 0.50015
#
#     weight_sum  best_known_cut  best_known_cut_per_edge  dense_W_float32_MB  \
# 12      -142.0          6950.0                   0.3475          381.469727
# 13        -6.0          7008.0                   0.3504          381.469727
#
#    device          dtype
# 12  mps:0  torch.float32
# 13  mps:0  torch.float32
# ================================================================================
# RUNNING SELECTED BIG-GSET PARTITION
# ================================================================================
# Partition: 18
# Graphs: ['G67', 'G72']
# Replicas: 128
# Steps: 1000
# Optimizer: Adam
# Adam lr: 0.01
#
# ================================================================================
# START GRAPH: G67
# ================================================================================
# N: 10000
# M: 20000
# Best-known cut: 6950.0
# G67 | step     1/1000 | cut=      28.0 | best=      28.0 | gap=    6922.0 | acc=  0.403% | |rz|=0.0001 | time=    0.03s
# G67 | step    50/1000 | cut=     100.0 | best=     100.0 | gap=    6850.0 | acc=  1.439% | |rz|=0.0000 | time=    1.45s
# G67 | step   100/1000 | cut=    -360.0 | best=     100.0 | gap=    6850.0 | acc=  1.439% | |rz|=0.0000 | time=    2.77s
# G67 | step   150/1000 | cut=   -1450.0 | best=     100.0 | gap=    6850.0 | acc=  1.439% | |rz|=0.0000 | time=    4.11s
# G67 | step   200/1000 | cut=   -1816.0 | best=     100.0 | gap=    6850.0 | acc=  1.439% | |rz|=0.0001 | time=    5.37s
# G67 | step   250/1000 | cut=   -3354.0 | best=     100.0 | gap=    6850.0 | acc=  1.439% | |rz|=0.0002 | time=    6.57s
# G67 | step   300/1000 | cut=     656.0 | best=     656.0 | gap=    6294.0 | acc=  9.439% | |rz|=0.0006 | time=    7.74s
# G67 | step   350/1000 | cut=    6798.0 | best=    6798.0 | gap=     152.0 | acc= 97.813% | |rz|=0.3938 | time=    8.96s
# G67 | step   400/1000 | cut=    6804.0 | best=    6804.0 | gap=     146.0 | acc= 97.899% | |rz|=0.5787 | time=   10.21s
# G67 | step   450/1000 | cut=    6806.0 | best=    6806.0 | gap=     144.0 | acc= 97.928% | |rz|=0.6807 | time=   11.38s
# G67 | step   500/1000 | cut=    6806.0 | best=    6806.0 | gap=     144.0 | acc= 97.928% | |rz|=0.7416 | time=   12.60s
# G67 | step   550/1000 | cut=    6806.0 | best=    6806.0 | gap=     144.0 | acc= 97.928% | |rz|=0.7828 | time=   13.95s
# G67 | step   600/1000 | cut=    6806.0 | best=    6806.0 | gap=     144.0 | acc= 97.928% | |rz|=0.8136 | time=   15.28s
# G67 | step   650/1000 | cut=    6806.0 | best=    6806.0 | gap=     144.0 | acc= 97.928% | |rz|=0.8379 | time=   16.52s
# G67 | step   700/1000 | cut=    6806.0 | best=    6806.0 | gap=     144.0 | acc= 97.928% | |rz|=0.8578 | time=   17.80s
# G67 | step   750/1000 | cut=    6806.0 | best=    6806.0 | gap=     144.0 | acc= 97.928% | |rz|=0.8745 | time=   18.96s
# G67 | step   800/1000 | cut=    6806.0 | best=    6806.0 | gap=     144.0 | acc= 97.928% | |rz|=0.8885 | time=   20.12s
# G67 | step   850/1000 | cut=    6806.0 | best=    6806.0 | gap=     144.0 | acc= 97.928% | |rz|=0.9003 | time=   21.43s
# G67 | step   900/1000 | cut=    6806.0 | best=    6806.0 | gap=     144.0 | acc= 97.928% | |rz|=0.9105 | time=   22.66s
# G67 | step   950/1000 | cut=    6806.0 | best=    6806.0 | gap=     144.0 | acc= 97.928% | |rz|=0.9207 | time=   23.82s
# G67 | step  1000/1000 | cut=    6806.0 | best=    6806.0 | gap=     144.0 | acc= 97.928% | |rz|=0.9406 | time=   25.40s
#
# FINISHED GRAPH: G67
# Best cut: 6806.0
# Best-known: 6950.0
# Gap: 144.0
# Accuracy %: 97.92805755395683
# Runtime sec: 25.412379026412964
#
# ================================================================================
# START GRAPH: G72
# ================================================================================
# N: 10000
# M: 20000
# Best-known cut: 7008.0
# G72 | step     1/1000 | cut=     130.0 | best=     130.0 | gap=    6878.0 | acc=  1.855% | |rz|=0.0001 | time=    0.02s
# G72 | step    50/1000 | cut=     204.0 | best=     204.0 | gap=    6804.0 | acc=  2.911% | |rz|=0.0000 | time=    1.23s
# G72 | step   100/1000 | cut=    -278.0 | best=     204.0 | gap=    6804.0 | acc=  2.911% | |rz|=0.0000 | time=    2.39s
# G72 | step   150/1000 | cut=   -1346.0 | best=     204.0 | gap=    6804.0 | acc=  2.911% | |rz|=0.0000 | time=    3.77s
# G72 | step   200/1000 | cut=   -1802.0 | best=     204.0 | gap=    6804.0 | acc=  2.911% | |rz|=0.0001 | time=    4.96s
# G72 | step   250/1000 | cut=   -3280.0 | best=     204.0 | gap=    6804.0 | acc=  2.911% | |rz|=0.0002 | time=    6.21s
# G72 | step   300/1000 | cut=     -14.0 | best=     204.0 | gap=    6804.0 | acc=  2.911% | |rz|=0.0005 | time=    7.53s
# G72 | step   350/1000 | cut=    6848.0 | best=    6848.0 | gap=     160.0 | acc= 97.717% | |rz|=0.3921 | time=    8.80s
# G72 | step   400/1000 | cut=    6858.0 | best=    6858.0 | gap=     150.0 | acc= 97.860% | |rz|=0.5768 | time=    9.98s
# G72 | step   450/1000 | cut=    6858.0 | best=    6858.0 | gap=     150.0 | acc= 97.860% | |rz|=0.6789 | time=   11.15s
# G72 | step   500/1000 | cut=    6858.0 | best=    6858.0 | gap=     150.0 | acc= 97.860% | |rz|=0.7397 | time=   12.54s
# G72 | step   550/1000 | cut=    6858.0 | best=    6858.0 | gap=     150.0 | acc= 97.860% | |rz|=0.7808 | time=   13.97s
# G72 | step   600/1000 | cut=    6858.0 | best=    6858.0 | gap=     150.0 | acc= 97.860% | |rz|=0.8115 | time=   15.23s
# G72 | step   650/1000 | cut=    6858.0 | best=    6858.0 | gap=     150.0 | acc= 97.860% | |rz|=0.8358 | time=   16.41s
# G72 | step   700/1000 | cut=    6858.0 | best=    6858.0 | gap=     150.0 | acc= 97.860% | |rz|=0.8557 | time=   17.67s
# G72 | step   750/1000 | cut=    6858.0 | best=    6858.0 | gap=     150.0 | acc= 97.860% | |rz|=0.8724 | time=   18.86s
# G72 | step   800/1000 | cut=    6858.0 | best=    6858.0 | gap=     150.0 | acc= 97.860% | |rz|=0.8864 | time=   20.06s
# G72 | step   850/1000 | cut=    6858.0 | best=    6858.0 | gap=     150.0 | acc= 97.860% | |rz|=0.8983 | time=   21.33s
# G72 | step   900/1000 | cut=    6858.0 | best=    6858.0 | gap=     150.0 | acc= 97.860% | |rz|=0.9086 | time=   22.58s
# G72 | step   950/1000 | cut=    6858.0 | best=    6858.0 | gap=     150.0 | acc= 97.860% | |rz|=0.9191 | time=   23.83s
# G72 | step  1000/1000 | cut=    6858.0 | best=    6858.0 | gap=     150.0 | acc= 97.860% | |rz|=0.9401 | time=   25.04s
#
# FINISHED GRAPH: G72
# Best cut: 6858.0
# Best-known: 7008.0
# Gap: 150.0
# Accuracy %: 97.85958904109589
# Runtime sec: 25.05265212059021
#
# ================================================================================
# SELECTED PARTITION SUMMARY
# ================================================================================
#    partition graph      N      M  best_known_cut  qefem_best_cut    gap  \
# 0         18   G67  10000  20000          6950.0          6806.0  144.0
# 1         18   G72  10000  20000          7008.0          6858.0  150.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         97.928058        450            31       128   1000      Adam  0.01
# 1         97.859589        400            17       128   1000      Adam  0.01
#
#    runtime_sec
# 0    25.412379
# 1    25.052652
# ================================================================================
# SAVED SELECTED PARTITION RESULTS
# ================================================================================
# Partition: 18
#
# Saved history CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_18_history.csv
#
# Saved summary CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_18_summary.csv
#
# Saved best spins PT:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_18_best_spins.pt
#
# Final selected-partition summary:
#    partition graph      N      M  best_known_cut  qefem_best_cut    gap  \
# 0         18   G67  10000  20000          6950.0          6806.0  144.0
# 1         18   G72  10000  20000          7008.0          6858.0  150.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         97.928058        450            31       128   1000      Adam  0.01
# 1         97.859589        400            17       128   1000      Adam  0.01
#
#    runtime_sec
# 0    25.412379
# 1    25.052652

# %%
assert "BIG_GSET_PARTITIONS" in globals(), (
    "Run Cell 25 first: BIG_GSET_PARTITIONS is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


# ------------------------------------------------------------
# Change this after each completed partition
# ------------------------------------------------------------

SELECTED_BIG_GSET_PARTITION = 19


# ------------------------------------------------------------
# Select graphs in this partition
# ------------------------------------------------------------

assert SELECTED_BIG_GSET_PARTITION in BIG_GSET_PARTITIONS, (
    f"Partition {SELECTED_BIG_GSET_PARTITION} is not defined."
)

selected_big_gset_graphs = BIG_GSET_PARTITIONS[SELECTED_BIG_GSET_PARTITION]


print("=" * 80)
print("NEXT BIG-GSET PARTITION SELECTED")
print("=" * 80)

print(
    f"Partition {SELECTED_BIG_GSET_PARTITION}: "
    f"{selected_big_gset_graphs[0]}-{selected_big_gset_graphs[-1]} | "
    f"{len(selected_big_gset_graphs)} graphs | "
    f"{selected_big_gset_graphs}"
)


# ------------------------------------------------------------
# Quick file check
# ------------------------------------------------------------

missing_graphs = []

for graph in selected_big_gset_graphs:
    path = GSET_DIR / graph

    print(f"{graph}: {path.exists()} | {path}")

    if not path.exists():
        missing_graphs.append(graph)

assert len(missing_graphs) == 0, (
    f"Missing graph files: {missing_graphs}"
)


# ------------------------------------------------------------
# Benchmark preview for this partition
# ------------------------------------------------------------

selected_partition_benchmark_df = big_gset_benchmark_df[
    big_gset_benchmark_df["partition"] == SELECTED_BIG_GSET_PARTITION
].copy()

display(selected_partition_benchmark_df)

assert len(selected_partition_benchmark_df) == len(selected_big_gset_graphs), (
    "Benchmark table row count does not match selected partition graph count."
)

assert "selected_big_gset_graphs" in globals(), (
    "Run Cell 32 first: selected_big_gset_graphs is missing."
)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "load_gset_edge_list" in globals(), (
    "Run Cell 26 first: load_gset_edge_list is missing."
)

assert "edge_qefem_free_energy" in globals(), (
    "Run Cell 30 first: edge_qefem_free_energy is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)

assert "big_gset_beta_schedule" in globals(), (
    "Run Cell 31 first: big_gset_beta_schedule is missing."
)

assert "big_gset_gamma_schedule" in globals(), (
    "Run Cell 31 first: big_gset_gamma_schedule is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


selected_partition_history_rows = []
selected_partition_summary_rows = []
selected_partition_best_spins = {}


print("=" * 80)
print("RUNNING SELECTED BIG-GSET PARTITION")
print("=" * 80)
print("Partition:", SELECTED_BIG_GSET_PARTITION)
print("Graphs:", selected_big_gset_graphs)
print("Replicas:", BIG_GSET_REPLICAS)
print("Steps:", BIG_GSET_N_STEPS)
print("Optimizer: Adam")
print("Adam lr:", BIG_GSET_ADAM_LR)


for graph in selected_big_gset_graphs:
    print("\n" + "=" * 80)
    print("START GRAPH:", graph)
    print("=" * 80)

    N_g, edge_i, edge_j, edge_w, info = load_gset_edge_list(graph)

    graph_benchmark_row = big_gset_benchmark_df[
        big_gset_benchmark_df["graph"] == graph
    ].iloc[0]

    best_known_cut = float(graph_benchmark_row["best_known_cut"])

    print("N:", N_g)
    print("M:", info["M"])
    print("Best-known cut:", best_known_cut)

    torch.manual_seed(BIG_GSET_SEED)

    R_INIT_tensor = torch.tensor(
        R_INIT,
        device=device,
        dtype=DTYPE,
    )

    raw_R_init_value = torch.log(
        R_INIT_tensor / (1.0 - R_INIT_tensor)
    )

    raw_R = raw_R_init_value + 1e-3 * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    theta = THETA_CENTER + THETA_NOISE * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    raw_R.requires_grad_(True)
    theta.requires_grad_(True)

    optimizer = torch.optim.Adam(
        [raw_R, theta],
        lr=BIG_GSET_ADAM_LR,
    )

    best_cut = -float("inf")
    best_step = None
    best_replica = None
    best_spins = None

    graph_start_time = time.time()

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    for step in range(BIG_GSET_N_STEPS):
        beta_t = big_gset_beta_schedule[step]
        gamma_t = big_gset_gamma_schedule[step]

        optimizer.zero_grad()

        F, aux = edge_qefem_free_energy(
            edge_i=edge_i,
            edge_j=edge_j,
            edge_w=edge_w,
            raw_R=raw_R,
            theta=theta,
            beta=beta_t,
            gamma=gamma_t,
        )

        loss = F.mean()

        loss.backward()
        optimizer.step()

        should_log = (
            step == 0
            or step == BIG_GSET_N_STEPS - 1
            or (step + 1) % BIG_GSET_LOG_EVERY == 0
        )

        if should_log:
            if edge_w.device.type == "mps":
                torch.mps.synchronize()

            elapsed = time.time() - graph_start_time

            with torch.no_grad():
                R_now, rx_now, rz_now = bloch_from_raw(
                    raw_R,
                    theta,
                )

                spins_now = torch.where(
                    rz_now >= 0,
                    torch.ones_like(rz_now),
                    -torch.ones_like(rz_now),
                )

                hard_cuts_now = edge_discrete_cut(
                    edge_i=edge_i,
                    edge_j=edge_j,
                    edge_w=edge_w,
                    spins=spins_now,
                )

                current_best_cut_tensor, current_best_replica_tensor = torch.max(
                    hard_cuts_now,
                    dim=0,
                )

                current_best_cut = float(current_best_cut_tensor.detach().cpu())
                current_best_replica = int(current_best_replica_tensor.detach().cpu())

                if current_best_cut > best_cut:
                    best_cut = current_best_cut
                    best_step = step + 1
                    best_replica = current_best_replica
                    best_spins = spins_now[current_best_replica].detach().cpu().clone()

                gap = best_known_cut - best_cut
                accuracy_percent = 100.0 * best_cut / best_known_cut

                selected_partition_history_rows.append(
                    {
                        "partition": SELECTED_BIG_GSET_PARTITION,
                        "graph": graph,
                        "step": step + 1,
                        "beta": float(beta_t.detach().cpu()),
                        "gamma": float(gamma_t.detach().cpu()),
                        "loss": float(loss.detach().cpu()),
                        "free_energy_mean": float(F.mean().detach().cpu()),
                        "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
                        "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),
                        "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
                        "hard_cut_max": current_best_cut,
                        "best_cut_so_far": best_cut,
                        "best_known_cut": best_known_cut,
                        "gap": gap,
                        "accuracy_percent": accuracy_percent,
                        "R_mean": float(R_now.mean().detach().cpu()),
                        "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),
                        "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),
                        "best_replica_so_far": best_replica,
                        "elapsed_sec": elapsed,
                    }
                )

                print(
                    f"{graph} | "
                    f"step {step + 1:5d}/{BIG_GSET_N_STEPS} | "
                    f"cut={current_best_cut:10.1f} | "
                    f"best={best_cut:10.1f} | "
                    f"gap={gap:10.1f} | "
                    f"acc={accuracy_percent:7.3f}% | "
                    f"|rz|={float(rz_now.abs().mean().detach().cpu()):.4f} | "
                    f"time={elapsed:8.2f}s"
                )

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    graph_runtime = time.time() - graph_start_time

    selected_partition_summary_rows.append(
        {
            "partition": SELECTED_BIG_GSET_PARTITION,
            "graph": graph,
            "N": N_g,
            "M": info["M"],
            "best_known_cut": best_known_cut,
            "qefem_best_cut": best_cut,
            "gap": best_known_cut - best_cut,
            "accuracy_percent": 100.0 * best_cut / best_known_cut,
            "best_step": best_step,
            "best_replica": best_replica,
            "replicas": BIG_GSET_REPLICAS,
            "steps": BIG_GSET_N_STEPS,
            "optimizer": "Adam",
            "lr": BIG_GSET_ADAM_LR,
            "runtime_sec": graph_runtime,
        }
    )

    selected_partition_best_spins[graph] = best_spins

    print("\nFINISHED GRAPH:", graph)
    print("Best cut:", best_cut)
    print("Best-known:", best_known_cut)
    print("Gap:", best_known_cut - best_cut)
    print("Accuracy %:", 100.0 * best_cut / best_known_cut)
    print("Runtime sec:", graph_runtime)


selected_partition_history_df = pd.DataFrame(selected_partition_history_rows)
selected_partition_summary_df = pd.DataFrame(selected_partition_summary_rows)

print("\n" + "=" * 80)
print("SELECTED PARTITION SUMMARY")
print("=" * 80)

display(selected_partition_summary_df)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "selected_partition_history_df" in globals(), (
    "Run Cell 37 first: selected_partition_history_df is missing."
)

assert "selected_partition_summary_df" in globals(), (
    "Run Cell 37 first: selected_partition_summary_df is missing."
)

assert "selected_partition_best_spins" in globals(), (
    "Run Cell 37 first: selected_partition_best_spins is missing."
)


# ------------------------------------------------------------
# Output folder
# ------------------------------------------------------------

BIG_GSET_OUTPUT_DIR = Path("qefem_big_gset_outputs")
BIG_GSET_OUTPUT_DIR.mkdir(exist_ok=True)


# ------------------------------------------------------------
# File names
# ------------------------------------------------------------

partition_tag = f"partition_{SELECTED_BIG_GSET_PARTITION}"

history_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_history.csv"
summary_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_summary.csv"
spins_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_best_spins.pt"


# ------------------------------------------------------------
# Save CSV files
# ------------------------------------------------------------

selected_partition_history_df.to_csv(
    history_path,
    index=False,
)

selected_partition_summary_df.to_csv(
    summary_path,
    index=False,
)


# ------------------------------------------------------------
# Save best spins dictionary
# ------------------------------------------------------------

torch.save(
    selected_partition_best_spins,
    spins_path,
)


# ------------------------------------------------------------
# Print saved paths
# ------------------------------------------------------------

print("=" * 80)
print("SAVED SELECTED PARTITION RESULTS")
print("=" * 80)

print("Partition:", SELECTED_BIG_GSET_PARTITION)

print("\nSaved history CSV:")
print(history_path.resolve())

print("\nSaved summary CSV:")
print(summary_path.resolve())

print("\nSaved best spins PT:")
print(spins_path.resolve())


# ------------------------------------------------------------
# Display final summary
# ------------------------------------------------------------

print("\nFinal selected-partition summary:")
display(selected_partition_summary_df)


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert history_path.exists(), (
    f"History file was not saved: {history_path}"
)

assert summary_path.exists(), (
    f"Summary file was not saved: {summary_path}"
)

assert spins_path.exists(), (
    f"Best-spins file was not saved: {spins_path}"
)

assert len(selected_partition_summary_df) > 0, (
    "Summary dataframe is empty."
)

assert len(selected_partition_history_df) > 0, (
    "History dataframe is empty."
)
# Out:
# ================================================================================
# NEXT BIG-GSET PARTITION SELECTED
# ================================================================================
# Partition 19: G70-G70 | 1 graphs | ['G70']
# G70: True | ../data-gset/G70
#     partition graph      N     M  density_upper_percent  positive_edges  \
# 14         19   G70  10000  9999                   0.02            9999
#
#     negative_edges  positive_edge_fraction  negative_edge_fraction  \
# 14               0                     1.0                     0.0
#
#     weight_sum  best_known_cut  best_known_cut_per_edge  dense_W_float32_MB  \
# 14      9999.0          9591.0                 0.959196          381.469727
#
#    device          dtype
# 14  mps:0  torch.float32
# ================================================================================
# RUNNING SELECTED BIG-GSET PARTITION
# ================================================================================
# Partition: 19
# Graphs: ['G70']
# Replicas: 128
# Steps: 1000
# Optimizer: Adam
# Adam lr: 0.01
#
# ================================================================================
# START GRAPH: G70
# ================================================================================
# N: 10000
# M: 9999
# Best-known cut: 9591.0
# G70 | step     1/1000 | cut=    5083.0 | best=    5083.0 | gap=    4508.0 | acc= 52.998% | |rz|=0.0001 | time=    0.05s
# G70 | step    50/1000 | cut=    5166.0 | best=    5166.0 | gap=    4425.0 | acc= 53.863% | |rz|=0.0000 | time=    1.08s
# G70 | step   100/1000 | cut=    4908.0 | best=    5166.0 | gap=    4425.0 | acc= 53.863% | |rz|=0.0000 | time=    2.02s
# G70 | step   150/1000 | cut=    4023.0 | best=    5166.0 | gap=    4425.0 | acc= 53.863% | |rz|=0.0000 | time=    2.98s
# G70 | step   200/1000 | cut=    4065.0 | best=    5166.0 | gap=    4425.0 | acc= 53.863% | |rz|=0.0001 | time=    3.91s
# G70 | step   250/1000 | cut=    2991.0 | best=    5166.0 | gap=    4425.0 | acc= 53.863% | |rz|=0.0002 | time=    4.84s
# G70 | step   300/1000 | cut=    3542.0 | best=    5166.0 | gap=    4425.0 | acc= 53.863% | |rz|=0.0003 | time=    5.87s
# G70 | step   350/1000 | cut=    9089.0 | best=    9089.0 | gap=     502.0 | acc= 94.766% | |rz|=0.1953 | time=    6.83s
# G70 | step   400/1000 | cut=    9129.0 | best=    9129.0 | gap=     462.0 | acc= 95.183% | |rz|=0.3293 | time=    7.77s
# G70 | step   450/1000 | cut=    9173.0 | best=    9173.0 | gap=     418.0 | acc= 95.642% | |rz|=0.4226 | time=    8.71s
# G70 | step   500/1000 | cut=    9232.0 | best=    9232.0 | gap=     359.0 | acc= 96.257% | |rz|=0.4918 | time=    9.63s
# G70 | step   550/1000 | cut=    9294.0 | best=    9294.0 | gap=     297.0 | acc= 96.903% | |rz|=0.5464 | time=   10.56s
# G70 | step   600/1000 | cut=    9326.0 | best=    9326.0 | gap=     265.0 | acc= 97.237% | |rz|=0.5957 | time=   11.45s
# G70 | step   650/1000 | cut=    9330.0 | best=    9330.0 | gap=     261.0 | acc= 97.279% | |rz|=0.6361 | time=   12.54s
# G70 | step   700/1000 | cut=    9416.0 | best=    9416.0 | gap=     175.0 | acc= 98.175% | |rz|=0.6717 | time=   13.50s
# G70 | step   750/1000 | cut=    9417.0 | best=    9417.0 | gap=     174.0 | acc= 98.186% | |rz|=0.7104 | time=   14.53s
# G70 | step   800/1000 | cut=    9417.0 | best=    9417.0 | gap=     174.0 | acc= 98.186% | |rz|=0.7391 | time=   15.71s
# G70 | step   850/1000 | cut=    9418.0 | best=    9418.0 | gap=     173.0 | acc= 98.196% | |rz|=0.7628 | time=   16.74s
# G70 | step   900/1000 | cut=    9418.0 | best=    9418.0 | gap=     173.0 | acc= 98.196% | |rz|=0.7818 | time=   17.73s
# G70 | step   950/1000 | cut=    9419.0 | best=    9419.0 | gap=     172.0 | acc= 98.207% | |rz|=0.7963 | time=   18.78s
# G70 | step  1000/1000 | cut=    9419.0 | best=    9419.0 | gap=     172.0 | acc= 98.207% | |rz|=0.8113 | time=   19.77s
#
# FINISHED GRAPH: G70
# Best cut: 9419.0
# Best-known: 9591.0
# Gap: 172.0
# Accuracy %: 98.20665206964863
# Runtime sec: 19.783353090286255
#
# ================================================================================
# SELECTED PARTITION SUMMARY
# ================================================================================
#    partition graph      N     M  best_known_cut  qefem_best_cut    gap  \
# 0         19   G70  10000  9999          9591.0          9419.0  172.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         98.206652        950           126       128   1000      Adam  0.01
#
#    runtime_sec
# 0    19.783353
# ================================================================================
# SAVED SELECTED PARTITION RESULTS
# ================================================================================
# Partition: 19
#
# Saved history CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_19_history.csv
#
# Saved summary CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_19_summary.csv
#
# Saved best spins PT:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_19_best_spins.pt
#
# Final selected-partition summary:
#    partition graph      N     M  best_known_cut  qefem_best_cut    gap  \
# 0         19   G70  10000  9999          9591.0          9419.0  172.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         98.206652        950           126       128   1000      Adam  0.01
#
#    runtime_sec
# 0    19.783353

# %%
assert "BIG_GSET_PARTITIONS" in globals(), (
    "Run Cell 25 first: BIG_GSET_PARTITIONS is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


# ------------------------------------------------------------
# Change this after each completed partition
# ------------------------------------------------------------

SELECTED_BIG_GSET_PARTITION = 20


# ------------------------------------------------------------
# Select graphs in this partition
# ------------------------------------------------------------

assert SELECTED_BIG_GSET_PARTITION in BIG_GSET_PARTITIONS, (
    f"Partition {SELECTED_BIG_GSET_PARTITION} is not defined."
)

selected_big_gset_graphs = BIG_GSET_PARTITIONS[SELECTED_BIG_GSET_PARTITION]


print("=" * 80)
print("NEXT BIG-GSET PARTITION SELECTED")
print("=" * 80)

print(
    f"Partition {SELECTED_BIG_GSET_PARTITION}: "
    f"{selected_big_gset_graphs[0]}-{selected_big_gset_graphs[-1]} | "
    f"{len(selected_big_gset_graphs)} graphs | "
    f"{selected_big_gset_graphs}"
)


# ------------------------------------------------------------
# Quick file check
# ------------------------------------------------------------

missing_graphs = []

for graph in selected_big_gset_graphs:
    path = GSET_DIR / graph

    print(f"{graph}: {path.exists()} | {path}")

    if not path.exists():
        missing_graphs.append(graph)

assert len(missing_graphs) == 0, (
    f"Missing graph files: {missing_graphs}"
)


# ------------------------------------------------------------
# Benchmark preview for this partition
# ------------------------------------------------------------

selected_partition_benchmark_df = big_gset_benchmark_df[
    big_gset_benchmark_df["partition"] == SELECTED_BIG_GSET_PARTITION
].copy()

display(selected_partition_benchmark_df)

assert len(selected_partition_benchmark_df) == len(selected_big_gset_graphs), (
    "Benchmark table row count does not match selected partition graph count."
)

assert "selected_big_gset_graphs" in globals(), (
    "Run Cell 32 first: selected_big_gset_graphs is missing."
)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "load_gset_edge_list" in globals(), (
    "Run Cell 26 first: load_gset_edge_list is missing."
)

assert "edge_qefem_free_energy" in globals(), (
    "Run Cell 30 first: edge_qefem_free_energy is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)

assert "big_gset_beta_schedule" in globals(), (
    "Run Cell 31 first: big_gset_beta_schedule is missing."
)

assert "big_gset_gamma_schedule" in globals(), (
    "Run Cell 31 first: big_gset_gamma_schedule is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


selected_partition_history_rows = []
selected_partition_summary_rows = []
selected_partition_best_spins = {}


print("=" * 80)
print("RUNNING SELECTED BIG-GSET PARTITION")
print("=" * 80)
print("Partition:", SELECTED_BIG_GSET_PARTITION)
print("Graphs:", selected_big_gset_graphs)
print("Replicas:", BIG_GSET_REPLICAS)
print("Steps:", BIG_GSET_N_STEPS)
print("Optimizer: Adam")
print("Adam lr:", BIG_GSET_ADAM_LR)


for graph in selected_big_gset_graphs:
    print("\n" + "=" * 80)
    print("START GRAPH:", graph)
    print("=" * 80)

    N_g, edge_i, edge_j, edge_w, info = load_gset_edge_list(graph)

    graph_benchmark_row = big_gset_benchmark_df[
        big_gset_benchmark_df["graph"] == graph
    ].iloc[0]

    best_known_cut = float(graph_benchmark_row["best_known_cut"])

    print("N:", N_g)
    print("M:", info["M"])
    print("Best-known cut:", best_known_cut)

    torch.manual_seed(BIG_GSET_SEED)

    R_INIT_tensor = torch.tensor(
        R_INIT,
        device=device,
        dtype=DTYPE,
    )

    raw_R_init_value = torch.log(
        R_INIT_tensor / (1.0 - R_INIT_tensor)
    )

    raw_R = raw_R_init_value + 1e-3 * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    theta = THETA_CENTER + THETA_NOISE * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    raw_R.requires_grad_(True)
    theta.requires_grad_(True)

    optimizer = torch.optim.Adam(
        [raw_R, theta],
        lr=BIG_GSET_ADAM_LR,
    )

    best_cut = -float("inf")
    best_step = None
    best_replica = None
    best_spins = None

    graph_start_time = time.time()

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    for step in range(BIG_GSET_N_STEPS):
        beta_t = big_gset_beta_schedule[step]
        gamma_t = big_gset_gamma_schedule[step]

        optimizer.zero_grad()

        F, aux = edge_qefem_free_energy(
            edge_i=edge_i,
            edge_j=edge_j,
            edge_w=edge_w,
            raw_R=raw_R,
            theta=theta,
            beta=beta_t,
            gamma=gamma_t,
        )

        loss = F.mean()

        loss.backward()
        optimizer.step()

        should_log = (
            step == 0
            or step == BIG_GSET_N_STEPS - 1
            or (step + 1) % BIG_GSET_LOG_EVERY == 0
        )

        if should_log:
            if edge_w.device.type == "mps":
                torch.mps.synchronize()

            elapsed = time.time() - graph_start_time

            with torch.no_grad():
                R_now, rx_now, rz_now = bloch_from_raw(
                    raw_R,
                    theta,
                )

                spins_now = torch.where(
                    rz_now >= 0,
                    torch.ones_like(rz_now),
                    -torch.ones_like(rz_now),
                )

                hard_cuts_now = edge_discrete_cut(
                    edge_i=edge_i,
                    edge_j=edge_j,
                    edge_w=edge_w,
                    spins=spins_now,
                )

                current_best_cut_tensor, current_best_replica_tensor = torch.max(
                    hard_cuts_now,
                    dim=0,
                )

                current_best_cut = float(current_best_cut_tensor.detach().cpu())
                current_best_replica = int(current_best_replica_tensor.detach().cpu())

                if current_best_cut > best_cut:
                    best_cut = current_best_cut
                    best_step = step + 1
                    best_replica = current_best_replica
                    best_spins = spins_now[current_best_replica].detach().cpu().clone()

                gap = best_known_cut - best_cut
                accuracy_percent = 100.0 * best_cut / best_known_cut

                selected_partition_history_rows.append(
                    {
                        "partition": SELECTED_BIG_GSET_PARTITION,
                        "graph": graph,
                        "step": step + 1,
                        "beta": float(beta_t.detach().cpu()),
                        "gamma": float(gamma_t.detach().cpu()),
                        "loss": float(loss.detach().cpu()),
                        "free_energy_mean": float(F.mean().detach().cpu()),
                        "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
                        "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),
                        "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
                        "hard_cut_max": current_best_cut,
                        "best_cut_so_far": best_cut,
                        "best_known_cut": best_known_cut,
                        "gap": gap,
                        "accuracy_percent": accuracy_percent,
                        "R_mean": float(R_now.mean().detach().cpu()),
                        "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),
                        "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),
                        "best_replica_so_far": best_replica,
                        "elapsed_sec": elapsed,
                    }
                )

                print(
                    f"{graph} | "
                    f"step {step + 1:5d}/{BIG_GSET_N_STEPS} | "
                    f"cut={current_best_cut:10.1f} | "
                    f"best={best_cut:10.1f} | "
                    f"gap={gap:10.1f} | "
                    f"acc={accuracy_percent:7.3f}% | "
                    f"|rz|={float(rz_now.abs().mean().detach().cpu()):.4f} | "
                    f"time={elapsed:8.2f}s"
                )

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    graph_runtime = time.time() - graph_start_time

    selected_partition_summary_rows.append(
        {
            "partition": SELECTED_BIG_GSET_PARTITION,
            "graph": graph,
            "N": N_g,
            "M": info["M"],
            "best_known_cut": best_known_cut,
            "qefem_best_cut": best_cut,
            "gap": best_known_cut - best_cut,
            "accuracy_percent": 100.0 * best_cut / best_known_cut,
            "best_step": best_step,
            "best_replica": best_replica,
            "replicas": BIG_GSET_REPLICAS,
            "steps": BIG_GSET_N_STEPS,
            "optimizer": "Adam",
            "lr": BIG_GSET_ADAM_LR,
            "runtime_sec": graph_runtime,
        }
    )

    selected_partition_best_spins[graph] = best_spins

    print("\nFINISHED GRAPH:", graph)
    print("Best cut:", best_cut)
    print("Best-known:", best_known_cut)
    print("Gap:", best_known_cut - best_cut)
    print("Accuracy %:", 100.0 * best_cut / best_known_cut)
    print("Runtime sec:", graph_runtime)


selected_partition_history_df = pd.DataFrame(selected_partition_history_rows)
selected_partition_summary_df = pd.DataFrame(selected_partition_summary_rows)

print("\n" + "=" * 80)
print("SELECTED PARTITION SUMMARY")
print("=" * 80)

display(selected_partition_summary_df)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "selected_partition_history_df" in globals(), (
    "Run Cell 37 first: selected_partition_history_df is missing."
)

assert "selected_partition_summary_df" in globals(), (
    "Run Cell 37 first: selected_partition_summary_df is missing."
)

assert "selected_partition_best_spins" in globals(), (
    "Run Cell 37 first: selected_partition_best_spins is missing."
)


# ------------------------------------------------------------
# Output folder
# ------------------------------------------------------------

BIG_GSET_OUTPUT_DIR = Path("qefem_big_gset_outputs")
BIG_GSET_OUTPUT_DIR.mkdir(exist_ok=True)


# ------------------------------------------------------------
# File names
# ------------------------------------------------------------

partition_tag = f"partition_{SELECTED_BIG_GSET_PARTITION}"

history_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_history.csv"
summary_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_summary.csv"
spins_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_best_spins.pt"


# ------------------------------------------------------------
# Save CSV files
# ------------------------------------------------------------

selected_partition_history_df.to_csv(
    history_path,
    index=False,
)

selected_partition_summary_df.to_csv(
    summary_path,
    index=False,
)


# ------------------------------------------------------------
# Save best spins dictionary
# ------------------------------------------------------------

torch.save(
    selected_partition_best_spins,
    spins_path,
)


# ------------------------------------------------------------
# Print saved paths
# ------------------------------------------------------------

print("=" * 80)
print("SAVED SELECTED PARTITION RESULTS")
print("=" * 80)

print("Partition:", SELECTED_BIG_GSET_PARTITION)

print("\nSaved history CSV:")
print(history_path.resolve())

print("\nSaved summary CSV:")
print(summary_path.resolve())

print("\nSaved best spins PT:")
print(spins_path.resolve())


# ------------------------------------------------------------
# Display final summary
# ------------------------------------------------------------

print("\nFinal selected-partition summary:")
display(selected_partition_summary_df)


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert history_path.exists(), (
    f"History file was not saved: {history_path}"
)

assert summary_path.exists(), (
    f"Summary file was not saved: {summary_path}"
)

assert spins_path.exists(), (
    f"Best-spins file was not saved: {spins_path}"
)

assert len(selected_partition_summary_df) > 0, (
    "Summary dataframe is empty."
)

assert len(selected_partition_history_df) > 0, (
    "History dataframe is empty."
)
# Out:
# ================================================================================
# NEXT BIG-GSET PARTITION SELECTED
# ================================================================================
# Partition 20: G77-G77 | 1 graphs | ['G77']
# G77: True | ../data-gset/G77
#     partition graph      N      M  density_upper_percent  positive_edges  \
# 15         20   G77  14000  28000               0.028573           14104
#
#     negative_edges  positive_edge_fraction  negative_edge_fraction  \
# 15           13896                0.503714                0.496286
#
#     weight_sum  best_known_cut  best_known_cut_per_edge  dense_W_float32_MB  \
# 15       208.0          9940.0                    0.355          747.680664
#
#    device          dtype
# 15  mps:0  torch.float32
# ================================================================================
# RUNNING SELECTED BIG-GSET PARTITION
# ================================================================================
# Partition: 20
# Graphs: ['G77']
# Replicas: 128
# Steps: 1000
# Optimizer: Adam
# Adam lr: 0.01
#
# ================================================================================
# START GRAPH: G77
# ================================================================================
# N: 14000
# M: 28000
# Best-known cut: 9940.0
# G77 | step     1/1000 | cut=     198.0 | best=     198.0 | gap=    9742.0 | acc=  1.992% | |rz|=0.0001 | time=    0.04s
# G77 | step    50/1000 | cut=     300.0 | best=     300.0 | gap=    9640.0 | acc=  3.018% | |rz|=0.0000 | time=    1.88s
# G77 | step   100/1000 | cut=    -388.0 | best=     300.0 | gap=    9640.0 | acc=  3.018% | |rz|=0.0000 | time=    3.48s
# G77 | step   150/1000 | cut=   -1890.0 | best=     300.0 | gap=    9640.0 | acc=  3.018% | |rz|=0.0000 | time=    5.10s
# G77 | step   200/1000 | cut=   -2406.0 | best=     300.0 | gap=    9640.0 | acc=  3.018% | |rz|=0.0001 | time=    6.79s
# G77 | step   250/1000 | cut=   -4542.0 | best=     300.0 | gap=    9640.0 | acc=  3.018% | |rz|=0.0002 | time=    8.41s
# G77 | step   300/1000 | cut=     848.0 | best=     848.0 | gap=    9092.0 | acc=  8.531% | |rz|=0.0006 | time=    9.99s
# G77 | step   350/1000 | cut=    9712.0 | best=    9712.0 | gap=     228.0 | acc= 97.706% | |rz|=0.3934 | time=   11.69s
# G77 | step   400/1000 | cut=    9722.0 | best=    9722.0 | gap=     218.0 | acc= 97.807% | |rz|=0.5782 | time=   13.27s
# G77 | step   450/1000 | cut=    9724.0 | best=    9724.0 | gap=     216.0 | acc= 97.827% | |rz|=0.6803 | time=   14.96s
# G77 | step   500/1000 | cut=    9724.0 | best=    9724.0 | gap=     216.0 | acc= 97.827% | |rz|=0.7412 | time=   16.57s
# G77 | step   550/1000 | cut=    9724.0 | best=    9724.0 | gap=     216.0 | acc= 97.827% | |rz|=0.7826 | time=   18.14s
# G77 | step   600/1000 | cut=    9724.0 | best=    9724.0 | gap=     216.0 | acc= 97.827% | |rz|=0.8135 | time=   19.75s
# G77 | step   650/1000 | cut=    9724.0 | best=    9724.0 | gap=     216.0 | acc= 97.827% | |rz|=0.8380 | time=   21.39s
# G77 | step   700/1000 | cut=    9724.0 | best=    9724.0 | gap=     216.0 | acc= 97.827% | |rz|=0.8581 | time=   22.99s
# G77 | step   750/1000 | cut=    9724.0 | best=    9724.0 | gap=     216.0 | acc= 97.827% | |rz|=0.8749 | time=   24.60s
# G77 | step   800/1000 | cut=    9724.0 | best=    9724.0 | gap=     216.0 | acc= 97.827% | |rz|=0.8891 | time=   26.18s
# G77 | step   850/1000 | cut=    9724.0 | best=    9724.0 | gap=     216.0 | acc= 97.827% | |rz|=0.9010 | time=   27.78s
# G77 | step   900/1000 | cut=    9724.0 | best=    9724.0 | gap=     216.0 | acc= 97.827% | |rz|=0.9114 | time=   29.63s
# G77 | step   950/1000 | cut=    9724.0 | best=    9724.0 | gap=     216.0 | acc= 97.827% | |rz|=0.9218 | time=   31.23s
# G77 | step  1000/1000 | cut=    9724.0 | best=    9724.0 | gap=     216.0 | acc= 97.827% | |rz|=0.9419 | time=   32.80s
#
# FINISHED GRAPH: G77
# Best cut: 9724.0
# Best-known: 9940.0
# Gap: 216.0
# Accuracy %: 97.82696177062374
# Runtime sec: 32.81381821632385
#
# ================================================================================
# SELECTED PARTITION SUMMARY
# ================================================================================
#    partition graph      N      M  best_known_cut  qefem_best_cut    gap  \
# 0         20   G77  14000  28000          9940.0          9724.0  216.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         97.826962        450            26       128   1000      Adam  0.01
#
#    runtime_sec
# 0    32.813818
# ================================================================================
# SAVED SELECTED PARTITION RESULTS
# ================================================================================
# Partition: 20
#
# Saved history CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_20_history.csv
#
# Saved summary CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_20_summary.csv
#
# Saved best spins PT:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_20_best_spins.pt
#
# Final selected-partition summary:
#    partition graph      N      M  best_known_cut  qefem_best_cut    gap  \
# 0         20   G77  14000  28000          9940.0          9724.0  216.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         97.826962        450            26       128   1000      Adam  0.01
#
#    runtime_sec
# 0    32.813818

# %%
assert "BIG_GSET_PARTITIONS" in globals(), (
    "Run Cell 25 first: BIG_GSET_PARTITIONS is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


# ------------------------------------------------------------
# Change this after each completed partition
# ------------------------------------------------------------

SELECTED_BIG_GSET_PARTITION = 21


# ------------------------------------------------------------
# Select graphs in this partition
# ------------------------------------------------------------

assert SELECTED_BIG_GSET_PARTITION in BIG_GSET_PARTITIONS, (
    f"Partition {SELECTED_BIG_GSET_PARTITION} is not defined."
)

selected_big_gset_graphs = BIG_GSET_PARTITIONS[SELECTED_BIG_GSET_PARTITION]


print("=" * 80)
print("NEXT BIG-GSET PARTITION SELECTED")
print("=" * 80)

print(
    f"Partition {SELECTED_BIG_GSET_PARTITION}: "
    f"{selected_big_gset_graphs[0]}-{selected_big_gset_graphs[-1]} | "
    f"{len(selected_big_gset_graphs)} graphs | "
    f"{selected_big_gset_graphs}"
)


# ------------------------------------------------------------
# Quick file check
# ------------------------------------------------------------

missing_graphs = []

for graph in selected_big_gset_graphs:
    path = GSET_DIR / graph

    print(f"{graph}: {path.exists()} | {path}")

    if not path.exists():
        missing_graphs.append(graph)

assert len(missing_graphs) == 0, (
    f"Missing graph files: {missing_graphs}"
)


# ------------------------------------------------------------
# Benchmark preview for this partition
# ------------------------------------------------------------

selected_partition_benchmark_df = big_gset_benchmark_df[
    big_gset_benchmark_df["partition"] == SELECTED_BIG_GSET_PARTITION
].copy()

display(selected_partition_benchmark_df)

assert len(selected_partition_benchmark_df) == len(selected_big_gset_graphs), (
    "Benchmark table row count does not match selected partition graph count."
)

assert "selected_big_gset_graphs" in globals(), (
    "Run Cell 32 first: selected_big_gset_graphs is missing."
)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "load_gset_edge_list" in globals(), (
    "Run Cell 26 first: load_gset_edge_list is missing."
)

assert "edge_qefem_free_energy" in globals(), (
    "Run Cell 30 first: edge_qefem_free_energy is missing."
)

assert "edge_discrete_cut" in globals(), (
    "Run Cell 30 first: edge_discrete_cut is missing."
)

assert "big_gset_beta_schedule" in globals(), (
    "Run Cell 31 first: big_gset_beta_schedule is missing."
)

assert "big_gset_gamma_schedule" in globals(), (
    "Run Cell 31 first: big_gset_gamma_schedule is missing."
)

assert "big_gset_benchmark_df" in globals(), (
    "Run Cell 29 first: big_gset_benchmark_df is missing."
)


selected_partition_history_rows = []
selected_partition_summary_rows = []
selected_partition_best_spins = {}


print("=" * 80)
print("RUNNING SELECTED BIG-GSET PARTITION")
print("=" * 80)
print("Partition:", SELECTED_BIG_GSET_PARTITION)
print("Graphs:", selected_big_gset_graphs)
print("Replicas:", BIG_GSET_REPLICAS)
print("Steps:", BIG_GSET_N_STEPS)
print("Optimizer: Adam")
print("Adam lr:", BIG_GSET_ADAM_LR)


for graph in selected_big_gset_graphs:
    print("\n" + "=" * 80)
    print("START GRAPH:", graph)
    print("=" * 80)

    N_g, edge_i, edge_j, edge_w, info = load_gset_edge_list(graph)

    graph_benchmark_row = big_gset_benchmark_df[
        big_gset_benchmark_df["graph"] == graph
    ].iloc[0]

    best_known_cut = float(graph_benchmark_row["best_known_cut"])

    print("N:", N_g)
    print("M:", info["M"])
    print("Best-known cut:", best_known_cut)

    torch.manual_seed(BIG_GSET_SEED)

    R_INIT_tensor = torch.tensor(
        R_INIT,
        device=device,
        dtype=DTYPE,
    )

    raw_R_init_value = torch.log(
        R_INIT_tensor / (1.0 - R_INIT_tensor)
    )

    raw_R = raw_R_init_value + 1e-3 * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    theta = THETA_CENTER + THETA_NOISE * torch.randn(
        BIG_GSET_REPLICAS,
        N_g,
        device=device,
        dtype=DTYPE,
    )

    raw_R.requires_grad_(True)
    theta.requires_grad_(True)

    optimizer = torch.optim.Adam(
        [raw_R, theta],
        lr=BIG_GSET_ADAM_LR,
    )

    best_cut = -float("inf")
    best_step = None
    best_replica = None
    best_spins = None

    graph_start_time = time.time()

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    for step in range(BIG_GSET_N_STEPS):
        beta_t = big_gset_beta_schedule[step]
        gamma_t = big_gset_gamma_schedule[step]

        optimizer.zero_grad()

        F, aux = edge_qefem_free_energy(
            edge_i=edge_i,
            edge_j=edge_j,
            edge_w=edge_w,
            raw_R=raw_R,
            theta=theta,
            beta=beta_t,
            gamma=gamma_t,
        )

        loss = F.mean()

        loss.backward()
        optimizer.step()

        should_log = (
            step == 0
            or step == BIG_GSET_N_STEPS - 1
            or (step + 1) % BIG_GSET_LOG_EVERY == 0
        )

        if should_log:
            if edge_w.device.type == "mps":
                torch.mps.synchronize()

            elapsed = time.time() - graph_start_time

            with torch.no_grad():
                R_now, rx_now, rz_now = bloch_from_raw(
                    raw_R,
                    theta,
                )

                spins_now = torch.where(
                    rz_now >= 0,
                    torch.ones_like(rz_now),
                    -torch.ones_like(rz_now),
                )

                hard_cuts_now = edge_discrete_cut(
                    edge_i=edge_i,
                    edge_j=edge_j,
                    edge_w=edge_w,
                    spins=spins_now,
                )

                current_best_cut_tensor, current_best_replica_tensor = torch.max(
                    hard_cuts_now,
                    dim=0,
                )

                current_best_cut = float(current_best_cut_tensor.detach().cpu())
                current_best_replica = int(current_best_replica_tensor.detach().cpu())

                if current_best_cut > best_cut:
                    best_cut = current_best_cut
                    best_step = step + 1
                    best_replica = current_best_replica
                    best_spins = spins_now[current_best_replica].detach().cpu().clone()

                gap = best_known_cut - best_cut
                accuracy_percent = 100.0 * best_cut / best_known_cut

                selected_partition_history_rows.append(
                    {
                        "partition": SELECTED_BIG_GSET_PARTITION,
                        "graph": graph,
                        "step": step + 1,
                        "beta": float(beta_t.detach().cpu()),
                        "gamma": float(gamma_t.detach().cpu()),
                        "loss": float(loss.detach().cpu()),
                        "free_energy_mean": float(F.mean().detach().cpu()),
                        "expected_cut_mean": float(aux["expected_cut"].mean().detach().cpu()),
                        "expected_cut_max": float(aux["expected_cut"].max().detach().cpu()),
                        "hard_cut_mean": float(hard_cuts_now.mean().detach().cpu()),
                        "hard_cut_max": current_best_cut,
                        "best_cut_so_far": best_cut,
                        "best_known_cut": best_known_cut,
                        "gap": gap,
                        "accuracy_percent": accuracy_percent,
                        "R_mean": float(R_now.mean().detach().cpu()),
                        "rx_abs_mean": float(rx_now.abs().mean().detach().cpu()),
                        "rz_abs_mean": float(rz_now.abs().mean().detach().cpu()),
                        "best_replica_so_far": best_replica,
                        "elapsed_sec": elapsed,
                    }
                )

                print(
                    f"{graph} | "
                    f"step {step + 1:5d}/{BIG_GSET_N_STEPS} | "
                    f"cut={current_best_cut:10.1f} | "
                    f"best={best_cut:10.1f} | "
                    f"gap={gap:10.1f} | "
                    f"acc={accuracy_percent:7.3f}% | "
                    f"|rz|={float(rz_now.abs().mean().detach().cpu()):.4f} | "
                    f"time={elapsed:8.2f}s"
                )

    if edge_w.device.type == "mps":
        torch.mps.synchronize()

    graph_runtime = time.time() - graph_start_time

    selected_partition_summary_rows.append(
        {
            "partition": SELECTED_BIG_GSET_PARTITION,
            "graph": graph,
            "N": N_g,
            "M": info["M"],
            "best_known_cut": best_known_cut,
            "qefem_best_cut": best_cut,
            "gap": best_known_cut - best_cut,
            "accuracy_percent": 100.0 * best_cut / best_known_cut,
            "best_step": best_step,
            "best_replica": best_replica,
            "replicas": BIG_GSET_REPLICAS,
            "steps": BIG_GSET_N_STEPS,
            "optimizer": "Adam",
            "lr": BIG_GSET_ADAM_LR,
            "runtime_sec": graph_runtime,
        }
    )

    selected_partition_best_spins[graph] = best_spins

    print("\nFINISHED GRAPH:", graph)
    print("Best cut:", best_cut)
    print("Best-known:", best_known_cut)
    print("Gap:", best_known_cut - best_cut)
    print("Accuracy %:", 100.0 * best_cut / best_known_cut)
    print("Runtime sec:", graph_runtime)


selected_partition_history_df = pd.DataFrame(selected_partition_history_rows)
selected_partition_summary_df = pd.DataFrame(selected_partition_summary_rows)

print("\n" + "=" * 80)
print("SELECTED PARTITION SUMMARY")
print("=" * 80)

display(selected_partition_summary_df)

assert "SELECTED_BIG_GSET_PARTITION" in globals(), (
    "Run Cell 32 first: SELECTED_BIG_GSET_PARTITION is missing."
)

assert "selected_partition_history_df" in globals(), (
    "Run Cell 37 first: selected_partition_history_df is missing."
)

assert "selected_partition_summary_df" in globals(), (
    "Run Cell 37 first: selected_partition_summary_df is missing."
)

assert "selected_partition_best_spins" in globals(), (
    "Run Cell 37 first: selected_partition_best_spins is missing."
)


# ------------------------------------------------------------
# Output folder
# ------------------------------------------------------------

BIG_GSET_OUTPUT_DIR = Path("qefem_big_gset_outputs")
BIG_GSET_OUTPUT_DIR.mkdir(exist_ok=True)


# ------------------------------------------------------------
# File names
# ------------------------------------------------------------

partition_tag = f"partition_{SELECTED_BIG_GSET_PARTITION}"

history_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_history.csv"
summary_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_summary.csv"
spins_path = BIG_GSET_OUTPUT_DIR / f"{partition_tag}_best_spins.pt"


# ------------------------------------------------------------
# Save CSV files
# ------------------------------------------------------------

selected_partition_history_df.to_csv(
    history_path,
    index=False,
)

selected_partition_summary_df.to_csv(
    summary_path,
    index=False,
)


# ------------------------------------------------------------
# Save best spins dictionary
# ------------------------------------------------------------

torch.save(
    selected_partition_best_spins,
    spins_path,
)


# ------------------------------------------------------------
# Print saved paths
# ------------------------------------------------------------

print("=" * 80)
print("SAVED SELECTED PARTITION RESULTS")
print("=" * 80)

print("Partition:", SELECTED_BIG_GSET_PARTITION)

print("\nSaved history CSV:")
print(history_path.resolve())

print("\nSaved summary CSV:")
print(summary_path.resolve())

print("\nSaved best spins PT:")
print(spins_path.resolve())


# ------------------------------------------------------------
# Display final summary
# ------------------------------------------------------------

print("\nFinal selected-partition summary:")
display(selected_partition_summary_df)


# ------------------------------------------------------------
# Checks
# ------------------------------------------------------------

assert history_path.exists(), (
    f"History file was not saved: {history_path}"
)

assert summary_path.exists(), (
    f"Summary file was not saved: {summary_path}"
)

assert spins_path.exists(), (
    f"Best-spins file was not saved: {spins_path}"
)

assert len(selected_partition_summary_df) > 0, (
    "Summary dataframe is empty."
)

assert len(selected_partition_history_df) > 0, (
    "History dataframe is empty."
)
# Out:
# ================================================================================
# NEXT BIG-GSET PARTITION SELECTED
# ================================================================================
# Partition 21: G81-G81 | 1 graphs | ['G81']
# G81: True | ../data-gset/G81
#     partition graph      N      M  density_upper_percent  positive_edges  \
# 16         21   G81  20000  40000               0.020001           20017
#
#     negative_edges  positive_edge_fraction  negative_edge_fraction  \
# 16           19983                0.500425                0.499575
#
#     weight_sum  best_known_cut  best_known_cut_per_edge  dense_W_float32_MB  \
# 16        34.0         14060.0                   0.3515         1525.878906
#
#    device          dtype
# 16  mps:0  torch.float32
# ================================================================================
# RUNNING SELECTED BIG-GSET PARTITION
# ================================================================================
# Partition: 21
# Graphs: ['G81']
# Replicas: 128
# Steps: 1000
# Optimizer: Adam
# Adam lr: 0.01
#
# ================================================================================
# START GRAPH: G81
# ================================================================================
# N: 20000
# M: 40000
# Best-known cut: 14060.0
# G81 | step     1/1000 | cut=     120.0 | best=     120.0 | gap=   13940.0 | acc=  0.853% | |rz|=0.0001 | time=    0.05s
# G81 | step    50/1000 | cut=     332.0 | best=     332.0 | gap=   13728.0 | acc=  2.361% | |rz|=0.0000 | time=    2.64s
# G81 | step   100/1000 | cut=    -694.0 | best=     332.0 | gap=   13728.0 | acc=  2.361% | |rz|=0.0000 | time=    5.43s
# G81 | step   150/1000 | cut=   -2888.0 | best=     332.0 | gap=   13728.0 | acc=  2.361% | |rz|=0.0000 | time=    7.93s
# G81 | step   200/1000 | cut=   -3592.0 | best=     332.0 | gap=   13728.0 | acc=  2.361% | |rz|=0.0001 | time=   10.39s
# G81 | step   250/1000 | cut=   -6630.0 | best=     332.0 | gap=   13728.0 | acc=  2.361% | |rz|=0.0002 | time=   12.77s
# G81 | step   300/1000 | cut=    1034.0 | best=    1034.0 | gap=   13026.0 | acc=  7.354% | |rz|=0.0007 | time=   15.15s
# G81 | step   350/1000 | cut=   13700.0 | best=   13700.0 | gap=     360.0 | acc= 97.440% | |rz|=0.3931 | time=   17.49s
# G81 | step   400/1000 | cut=   13716.0 | best=   13716.0 | gap=     344.0 | acc= 97.553% | |rz|=0.5774 | time=   20.25s
# G81 | step   450/1000 | cut=   13716.0 | best=   13716.0 | gap=     344.0 | acc= 97.553% | |rz|=0.6792 | time=   22.73s
# G81 | step   500/1000 | cut=   13716.0 | best=   13716.0 | gap=     344.0 | acc= 97.553% | |rz|=0.7399 | time=   25.00s
# G81 | step   550/1000 | cut=   13716.0 | best=   13716.0 | gap=     344.0 | acc= 97.553% | |rz|=0.7810 | time=   27.22s
# G81 | step   600/1000 | cut=   13716.0 | best=   13716.0 | gap=     344.0 | acc= 97.553% | |rz|=0.8117 | time=   29.43s
# G81 | step   650/1000 | cut=   13716.0 | best=   13716.0 | gap=     344.0 | acc= 97.553% | |rz|=0.8360 | time=   31.65s
# G81 | step   700/1000 | cut=   13716.0 | best=   13716.0 | gap=     344.0 | acc= 97.553% | |rz|=0.8559 | time=   33.90s
# G81 | step   750/1000 | cut=   13716.0 | best=   13716.0 | gap=     344.0 | acc= 97.553% | |rz|=0.8726 | time=   36.14s
# G81 | step   800/1000 | cut=   13716.0 | best=   13716.0 | gap=     344.0 | acc= 97.553% | |rz|=0.8866 | time=   38.33s
# G81 | step   850/1000 | cut=   13716.0 | best=   13716.0 | gap=     344.0 | acc= 97.553% | |rz|=0.8985 | time=   40.65s
# G81 | step   900/1000 | cut=   13716.0 | best=   13716.0 | gap=     344.0 | acc= 97.553% | |rz|=0.9087 | time=   42.89s
# G81 | step   950/1000 | cut=   13716.0 | best=   13716.0 | gap=     344.0 | acc= 97.553% | |rz|=0.9192 | time=   45.11s
# G81 | step  1000/1000 | cut=   13716.0 | best=   13716.0 | gap=     344.0 | acc= 97.553% | |rz|=0.9404 | time=   47.47s
#
# FINISHED GRAPH: G81
# Best cut: 13716.0
# Best-known: 14060.0
# Gap: 344.0
# Accuracy %: 97.55334281650072
# Runtime sec: 47.49172806739807
#
# ================================================================================
# SELECTED PARTITION SUMMARY
# ================================================================================
#    partition graph      N      M  best_known_cut  qefem_best_cut    gap  \
# 0         21   G81  20000  40000         14060.0         13716.0  344.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         97.553343        400            63       128   1000      Adam  0.01
#
#    runtime_sec
# 0    47.491728
# ================================================================================
# SAVED SELECTED PARTITION RESULTS
# ================================================================================
# Partition: 21
#
# Saved history CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_21_history.csv
#
# Saved summary CSV:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_21_summary.csv
#
# Saved best spins PT:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_21_best_spins.pt
#
# Final selected-partition summary:
#    partition graph      N      M  best_known_cut  qefem_best_cut    gap  \
# 0         21   G81  20000  40000         14060.0         13716.0  344.0
#
#    accuracy_percent  best_step  best_replica  replicas  steps optimizer    lr  \
# 0         97.553343        400            63       128   1000      Adam  0.01
#
#    runtime_sec
# 0    47.491728

# %%
# ============================================================
# Cell 41: Aggregate all partitions and plot batchwise mean trends
# ============================================================

import re
import matplotlib.pyplot as plt

BIG_GSET_OUTPUT_DIR = Path("qefem_big_gset_outputs")

assert BIG_GSET_OUTPUT_DIR.exists(), (
    f"Output folder does not exist: {BIG_GSET_OUTPUT_DIR}"
)


# ------------------------------------------------------------
# Find all saved history and summary files
# ------------------------------------------------------------

history_paths = sorted(
    BIG_GSET_OUTPUT_DIR.glob("partition_*_history.csv")
)

summary_paths = sorted(
    BIG_GSET_OUTPUT_DIR.glob("partition_*_summary.csv")
)

print("=" * 80)
print("AGGREGATING SAVED BIG-GSET RESULTS")
print("=" * 80)

print("History files found:", len(history_paths))
for path in history_paths:
    print("history:", path)

print("\nSummary files found:", len(summary_paths))
for path in summary_paths:
    print("summary:", path)

assert len(history_paths) > 0, (
    "No partition history files found."
)

assert len(summary_paths) > 0, (
    "No partition summary files found."
)


# ------------------------------------------------------------
# Load all histories
# ------------------------------------------------------------

all_history_dfs = []

for path in history_paths:
    df = pd.read_csv(path)
    all_history_dfs.append(df)

all_big_gset_history_df = pd.concat(
    all_history_dfs,
    ignore_index=True,
)

all_big_gset_history_df = all_big_gset_history_df.sort_values(
    ["partition", "graph", "step"]
).reset_index(drop=True)


# ------------------------------------------------------------
# Load all summaries
# ------------------------------------------------------------

all_summary_dfs = []

for path in summary_paths:
    df = pd.read_csv(path)
    all_summary_dfs.append(df)

all_big_gset_summary_df = pd.concat(
    all_summary_dfs,
    ignore_index=True,
)

all_big_gset_summary_df = all_big_gset_summary_df.sort_values(
    ["partition", "graph"]
).reset_index(drop=True)


# ------------------------------------------------------------
# Batchwise / partitionwise mean trend over optimization steps
# ------------------------------------------------------------

partition_step_mean_df = (
    all_big_gset_history_df
    .groupby(["partition", "step"], as_index=False)
    .agg(
        mean_best_cut=("best_cut_so_far", "mean"),
        mean_hard_cut=("hard_cut_max", "mean"),
        mean_expected_cut=("expected_cut_max", "mean"),
        mean_gap=("gap", "mean"),
        mean_accuracy_percent=("accuracy_percent", "mean"),
        mean_rz_abs=("rz_abs_mean", "mean"),
        mean_rx_abs=("rx_abs_mean", "mean"),
        mean_R=("R_mean", "mean"),
        mean_elapsed_sec=("elapsed_sec", "mean"),
    )
)


# ------------------------------------------------------------
# Final partitionwise summary
# ------------------------------------------------------------

partition_final_mean_df = (
    all_big_gset_summary_df
    .groupby("partition", as_index=False)
    .agg(
        graphs=("graph", "count"),
        mean_best_known_cut=("best_known_cut", "mean"),
        mean_qefem_best_cut=("qefem_best_cut", "mean"),
        mean_gap=("gap", "mean"),
        mean_accuracy_percent=("accuracy_percent", "mean"),
        mean_runtime_sec=("runtime_sec", "mean"),
        total_runtime_sec=("runtime_sec", "sum"),
    )
)

partition_final_mean_df = partition_final_mean_df.sort_values(
    "partition"
).reset_index(drop=True)


# ------------------------------------------------------------
# Save aggregate CSVs
# ------------------------------------------------------------

all_history_path = BIG_GSET_OUTPUT_DIR / "all_big_gset_history.csv"
all_summary_path = BIG_GSET_OUTPUT_DIR / "all_big_gset_summary.csv"
partition_step_mean_path = BIG_GSET_OUTPUT_DIR / "partition_step_mean_trends.csv"
partition_final_mean_path = BIG_GSET_OUTPUT_DIR / "partition_final_mean_summary.csv"

all_big_gset_history_df.to_csv(
    all_history_path,
    index=False,
)

all_big_gset_summary_df.to_csv(
    all_summary_path,
    index=False,
)

partition_step_mean_df.to_csv(
    partition_step_mean_path,
    index=False,
)

partition_final_mean_df.to_csv(
    partition_final_mean_path,
    index=False,
)


print("\nSaved aggregate CSVs:")
print(all_history_path.resolve())
print(all_summary_path.resolve())
print(partition_step_mean_path.resolve())
print(partition_final_mean_path.resolve())


# ------------------------------------------------------------
# Display final summary tables
# ------------------------------------------------------------

print("\nAll graph-level final results:")
display(all_big_gset_summary_df)

print("\nPartition-level final mean summary:")
display(partition_final_mean_df)

print("\nPartition-step mean trends:")
display(partition_step_mean_df)


# ------------------------------------------------------------
# Plot folder
# ------------------------------------------------------------

PLOT_DIR = BIG_GSET_OUTPUT_DIR / "plots"
PLOT_DIR.mkdir(exist_ok=True)
# Out:
# ================================================================================
# AGGREGATING SAVED BIG-GSET RESULTS
# ================================================================================
# History files found: 12
# history: qefem_big_gset_outputs/partition_10_history.csv
# history: qefem_big_gset_outputs/partition_11_history.csv
# history: qefem_big_gset_outputs/partition_12_history.csv
# history: qefem_big_gset_outputs/partition_13_history.csv
# history: qefem_big_gset_outputs/partition_14_history.csv
# history: qefem_big_gset_outputs/partition_15_history.csv
# history: qefem_big_gset_outputs/partition_16_history.csv
# history: qefem_big_gset_outputs/partition_17_history.csv
# history: qefem_big_gset_outputs/partition_18_history.csv
# history: qefem_big_gset_outputs/partition_19_history.csv
# history: qefem_big_gset_outputs/partition_20_history.csv
# history: qefem_big_gset_outputs/partition_21_history.csv
#
# Summary files found: 12
# summary: qefem_big_gset_outputs/partition_10_summary.csv
# summary: qefem_big_gset_outputs/partition_11_summary.csv
# summary: qefem_big_gset_outputs/partition_12_summary.csv
# summary: qefem_big_gset_outputs/partition_13_summary.csv
# summary: qefem_big_gset_outputs/partition_14_summary.csv
# summary: qefem_big_gset_outputs/partition_15_summary.csv
# summary: qefem_big_gset_outputs/partition_16_summary.csv
# summary: qefem_big_gset_outputs/partition_17_summary.csv
# summary: qefem_big_gset_outputs/partition_18_summary.csv
# summary: qefem_big_gset_outputs/partition_19_summary.csv
# summary: qefem_big_gset_outputs/partition_20_summary.csv
# summary: qefem_big_gset_outputs/partition_21_summary.csv
#
# Saved aggregate CSVs:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/all_big_gset_history.csv
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/all_big_gset_summary.csv
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_step_mean_trends.csv
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/partition_final_mean_summary.csv
#
# All graph-level final results:
#     partition graph      N      M  best_known_cut  qefem_best_cut    gap  \
# 0          10   G55   5000  12498         10299.0         10205.0   94.0
# 1          10   G56   5000  12498          4017.0          3908.0  109.0
# 2          11   G57   5000  10000          3494.0          3428.0   66.0
# 3          12   G58   5000  29570         19293.0         19061.0  232.0
# 4          12   G59   5000  29570          6086.0          5854.0  232.0
# 5          13   G60   7000  17148         14188.0         14045.0  143.0
# 6          13   G61   7000  17148          5796.0          5651.0  145.0
# 7          14   G62   7000  14000          4870.0          4790.0   80.0
# 8          15   G63   7000  41459         27047.0         26755.0  292.0
# 9          15   G64   7000  41459          8751.0          8440.0  311.0
# 10         16   G65   8000  16000          5562.0          5450.0  112.0
# 11         17   G66   9000  18000          6364.0          6228.0  136.0
# 12         18   G67  10000  20000          6950.0          6806.0  144.0
# 13         18   G72  10000  20000          7008.0          6858.0  150.0
# 14         19   G70  10000   9999          9591.0          9419.0  172.0
# 15         20   G77  14000  28000          9940.0          9724.0  216.0
# 16         21   G81  20000  40000         14060.0         13716.0  344.0
#
#     accuracy_percent  best_step  best_replica  replicas  steps optimizer  \
# 0          99.087290        850            44       128   1000      Adam
# 1          97.286532        600            53       128   1000      Adam
# 2          98.111048        500            10       128   1000      Adam
# 3          98.797491        800            56       128   1000      Adam
# 4          96.187972        700           122       128   1000      Adam
# 5          98.992106        750           120       128   1000      Adam
# 6          97.498275        850            51       128   1000      Adam
# 7          98.357290        400            97       128   1000      Adam
# 8          98.920398        800           102       128   1000      Adam
# 9          96.446120        900           114       128   1000      Adam
# 10         97.986336        400            89       128   1000      Adam
# 11         97.862979        400            95       128   1000      Adam
# 12         97.928058        450            31       128   1000      Adam
# 13         97.859589        400            17       128   1000      Adam
# 14         98.206652        950           126       128   1000      Adam
# 15         97.826962        450            26       128   1000      Adam
# 16         97.553343        400            63       128   1000      Adam
#
#       lr  runtime_sec
# 0   0.01    12.089288
# 1   0.01    12.111849
# 2   0.01    11.204553
# 3   0.01    18.577526
# 4   0.01    19.772762
# 5   0.01    18.051511
# 6   0.01    18.248646
# 7   0.01    17.248357
# 8   0.01    28.825478
# 9   0.01    28.199235
# 10  0.01    19.745008
# 11  0.01    22.297995
# 12  0.01    25.412379
# 13  0.01    25.052652
# 14  0.01    19.783353
# 15  0.01    32.813818
# 16  0.01    47.491728
# Partition-level final mean summary:
#     partition  graphs  mean_best_known_cut  mean_qefem_best_cut  mean_gap  \
# 0          10       2               7158.0               7056.5     101.5
# 1          11       1               3494.0               3428.0      66.0
# 2          12       2              12689.5              12457.5     232.0
# 3          13       2               9992.0               9848.0     144.0
# 4          14       1               4870.0               4790.0      80.0
# 5          15       2              17899.0              17597.5     301.5
# 6          16       1               5562.0               5450.0     112.0
# 7          17       1               6364.0               6228.0     136.0
# 8          18       2               6979.0               6832.0     147.0
# 9          19       1               9591.0               9419.0     172.0
# 10         20       1               9940.0               9724.0     216.0
# 11         21       1              14060.0              13716.0     344.0
#
#     mean_accuracy_percent  mean_runtime_sec  total_runtime_sec
# 0               98.186911         12.100568          24.201137
# 1               98.111048         11.204553          11.204553
# 2               97.492732         19.175144          38.350288
# 3               98.245190         18.150078          36.300157
# 4               98.357290         17.248357          17.248357
# 5               97.683259         28.512357          57.024713
# 6               97.986336         19.745008          19.745008
# 7               97.862979         22.297995          22.297995
# 8               97.893823         25.232516          50.465031
# 9               98.206652         19.783353          19.783353
# 10              97.826962         32.813818          32.813818
# 11              97.553343         47.491728          47.491728
# Partition-step mean trends:
#      partition  step  mean_best_cut  mean_hard_cut  mean_expected_cut  \
# 0           10     1         3206.0         3206.0        3111.000000
# 1           10    50         3255.5         3255.5        3111.000000
# 2           10   100         3255.5         3001.5        3111.000000
# 3           10   150         3255.5         1941.5        3111.000000
# 4           10   200         3255.5         2248.0        3111.000000
# ..         ...   ...            ...            ...                ...
# 247         21   800        13716.0        13716.0       12733.153320
# 248         21   850        13716.0        13716.0       12977.926758
# 249         21   900        13716.0        13716.0       13167.473633
# 250         21   950        13716.0        13716.0       13305.900391
# 251         21  1000        13716.0        13716.0       13396.171875
#
#      mean_gap  mean_accuracy_percent   mean_rz_abs  mean_rx_abs    mean_R  \
# 0      3952.0              31.782170  6.973513e-05     0.010099  0.010099
# 1      3902.5              32.543713  3.714735e-06     0.016799  0.016799
# 2      3902.5              32.543713  6.111980e-07     0.031085  0.031085
# 3      3902.5              32.543713  4.432159e-05     0.064601  0.064601
# 4      3902.5              32.543713  1.252036e-04     0.144573  0.144573
# ..        ...                    ...           ...          ...       ...
# 247     344.0              97.553343  8.866126e-01     0.197037  0.946209
# 248     344.0              97.553343  8.984724e-01     0.163427  0.951663
# 249     344.0              97.553343  9.087457e-01     0.128276  0.956200
# 250     344.0              97.553343  9.191719e-01     0.090025  0.959998
# 251     344.0              97.553343  9.404089e-01     0.031177  0.963205
#
#      mean_elapsed_sec
# 0            0.083045
# 1            0.656140
# 2            1.243957
# 3            1.840147
# 4            2.507333
# ..                ...
# 247         38.333828
# 248         40.653765
# 249         42.890919
# 250         45.111010
# 251         47.469002
#
# [252 rows x 11 columns]

# %%
# ------------------------------------------------------------
# Plot 1: Mean accuracy trend by partition
# ------------------------------------------------------------

plt.figure(figsize=(10, 6))

for partition_id in sorted(partition_step_mean_df["partition"].unique()):
    dfp = partition_step_mean_df[
        partition_step_mean_df["partition"] == partition_id
    ]

    plt.plot(
        dfp["step"],
        dfp["mean_accuracy_percent"],
        label=f"Partition {partition_id}",
    )

plt.xlabel("Optimization step")
plt.ylabel("Mean accuracy (%)")
plt.title("Batchwise mean QEFEM accuracy trend")
plt.legend()
plt.grid(True)
plt.tight_layout()

accuracy_trend_path = PLOT_DIR / "batchwise_mean_accuracy_trend.png"
plt.savefig(accuracy_trend_path, dpi=200)
plt.show()

# %%
# ------------------------------------------------------------
# Plot 2: Mean gap trend by partition
# ------------------------------------------------------------

plt.figure(figsize=(10, 6))

for partition_id in sorted(partition_step_mean_df["partition"].unique()):
    dfp = partition_step_mean_df[
        partition_step_mean_df["partition"] == partition_id
    ]

    plt.plot(
        dfp["step"],
        dfp["mean_gap"],
        label=f"Partition {partition_id}",
    )

plt.xlabel("Optimization step")
plt.ylabel("Mean gap to best-known cut")
plt.title("Batchwise mean gap trend")
plt.legend()
plt.grid(True)
plt.tight_layout()

gap_trend_path = PLOT_DIR / "batchwise_mean_gap_trend.png"
plt.savefig(gap_trend_path, dpi=200)
plt.show()

# %%
# ------------------------------------------------------------
# Plot 4: Mean |rz| trend by partition
# ------------------------------------------------------------

plt.figure(figsize=(10, 6))

for partition_id in sorted(partition_step_mean_df["partition"].unique()):
    dfp = partition_step_mean_df[
        partition_step_mean_df["partition"] == partition_id
    ]

    plt.plot(
        dfp["step"],
        dfp["mean_rz_abs"],
        label=f"Partition {partition_id}",
    )

plt.xlabel("Optimization step")
plt.ylabel("Mean |rz|")
plt.title("Batchwise mean longitudinal magnetization trend")
plt.legend()
plt.grid(True)
plt.tight_layout()

rz_trend_path = PLOT_DIR / "batchwise_mean_abs_rz_trend.png"
plt.savefig(rz_trend_path, dpi=200)
plt.show()

# %%
# ------------------------------------------------------------
# Plot 5: Mean |rx| trend by partition
# ------------------------------------------------------------

plt.figure(figsize=(10, 6))

for partition_id in sorted(partition_step_mean_df["partition"].unique()):
    dfp = partition_step_mean_df[
        partition_step_mean_df["partition"] == partition_id
    ]

    plt.plot(
        dfp["step"],
        dfp["mean_rx_abs"],
        label=f"Partition {partition_id}",
    )

plt.xlabel("Optimization step")
plt.ylabel("Mean |rx|")
plt.title("Batchwise mean transverse component trend")
plt.legend()
plt.grid(True)
plt.tight_layout()

rx_trend_path = PLOT_DIR / "batchwise_mean_abs_rx_trend.png"
plt.savefig(rx_trend_path, dpi=200)
plt.show()

# %%
# ------------------------------------------------------------
# Plot 6: Final mean accuracy by partition
# ------------------------------------------------------------

plt.figure(figsize=(10, 6))

plt.bar(
    partition_final_mean_df["partition"].astype(str),
    partition_final_mean_df["mean_accuracy_percent"],
)

plt.xlabel("Partition")
plt.ylabel("Final mean accuracy (%)")
plt.title("Final mean QEFEM accuracy by partition")
plt.grid(True, axis="y")
plt.tight_layout()

final_accuracy_path = PLOT_DIR / "final_mean_accuracy_by_partition.png"
plt.savefig(final_accuracy_path, dpi=200)
plt.show()

# %%
# ------------------------------------------------------------
# Plot 7: Final mean gap by partition
# ------------------------------------------------------------

plt.figure(figsize=(10, 6))

plt.bar(
    partition_final_mean_df["partition"].astype(str),
    partition_final_mean_df["mean_gap"],
)

plt.xlabel("Partition")
plt.ylabel("Final mean gap")
plt.title("Final mean gap by partition")
plt.grid(True, axis="y")
plt.tight_layout()

final_gap_path = PLOT_DIR / "final_mean_gap_by_partition.png"
plt.savefig(final_gap_path, dpi=200)
plt.show()


# ------------------------------------------------------------
# Print saved plot paths
# ------------------------------------------------------------

print("\nSaved plots:")
print(accuracy_trend_path.resolve())
print(gap_trend_path.resolve())
print(rz_trend_path.resolve())
print(rx_trend_path.resolve())
print(final_accuracy_path.resolve())
print(final_gap_path.resolve())


# ------------------------------------------------------------
# Final checks
# ------------------------------------------------------------

assert all_history_path.exists()
assert all_summary_path.exists()
assert partition_step_mean_path.exists()
assert partition_final_mean_path.exists()

assert accuracy_trend_path.exists()
assert gap_trend_path.exists()
assert best_cut_trend_path.exists()
assert rz_trend_path.exists()
assert rx_trend_path.exists()
assert final_accuracy_path.exists()
assert final_gap_path.exists()
# Out:
# Saved plots:
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/plots/batchwise_mean_accuracy_trend.png
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/plots/batchwise_mean_gap_trend.png
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/plots/batchwise_mean_abs_rz_trend.png
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/plots/batchwise_mean_abs_rx_trend.png
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/plots/final_mean_accuracy_by_partition.png
# /Users/ronit/Desktop/QeFEM/main/maxcut_results/qefem_big_gset_outputs/plots/final_mean_gap_by_partition.png
